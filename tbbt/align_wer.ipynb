# %%
import json
import pickle as pkl
import re
from nltk.translate import bleu_score
from tqdm import tqdm
import jiwer
from matplotlib import pyplot as plt

# %% [markdown]
# #### Load Source Data of both Episode and Subtitles

# %%
# Load Open Subtitle
with open('en_subtitles.pkl', 'rb') as f:
    en_subtitle = pkl.load(f)
with open('zh_subtitles.pkl', 'rb') as f:
    zh_subtitle = pkl.load(f)

# %%
# Load Memor Dataset
with open('memor/data.json') as f:
    data = json.load(f)

# %% [markdown]
# ### Pre-Process Data for one episode

# %%
# Define sentence transformation
transformation = jiwer.Compose([
    jiwer.ToLowerCase(),
    jiwer.RemoveMultipleSpaces(),
    jiwer.ExpandCommonEnglishContractions(),
    jiwer.RemovePunctuation(),
    jiwer.Strip()
])

# %%
# Process episode
utterances = []
for item in data:
    if item.strip().split('_')[0]=='S01E01':
        utterances.extend(data[item]['sentences'])

segments = []
pattern = r'\.|\,|\?|\!|\;'
for utt in utterances:
    temp = re.split(pattern, utt.strip(' ,.-!'))
    for item in temp:
        item = transformation(item)
        if item!="":
            segments.append(item)

# %%
# Process Subtitle Subset
base = 4424331
bias = 400

subtitles = []
for item in en_subtitle[base-bias: base+bias]:
    item = transformation(item)
    if item!="":
        subtitles.append(item)

# %% [markdown]
# ### Perform Alignment with Word Error Rate (WER)

# %%
def get_optimal_wer(ground_truth, hypothesis_pool):
    scores = []
    for i, hypothesis in enumerate(hypothesis_pool):
        scores.append(jiwer.compute_measures(ground_truth, hypothesis)['wer'])
    return min(scores), hypothesis_pool[scores.index(min(scores))], utt, scores.index(min(scores))

# %%
indexs = []
count = 0
for utt in segments:
    result = get_optimal_wer(utt, subtitles)
    if 0<result[0]<1:
        indexs.append(result[-1])
        for item in result:
            count += 1
            print(item)
        print('=='*50)
print(count)
# Out:
# 0.08
# if a photon is directed through a plane with two slits in it and either is observed it will not go through both
# if a photon is directed through a plane with two slits in it and either slit is observed it will not go through both slits
# 397
# ====================================================================================================
# 0.3333333333333333
# if unobserved it will
# if it is unobserved it will
# 398
# ====================================================================================================
# 0.125
# if it is observed after it left the plane before it hits its target
# if it is observed after it is left the plane but before it hits its target
# 399
# ====================================================================================================
# 0.25
# agreed what is your point
# what is your point
# 401
# ====================================================================================================
# 0.75
# is this agreed
# there is no point
# 7
# ====================================================================================================
# 0.36363636363636365
# there is no point i just think it is a good idea for a tshirt
# i just think it is a good idea for a tshirt
# 402
# ====================================================================================================
# 0.5
# twentysix across is mcm
# one across is aegean
# 404
# ====================================================================================================
# 0.75
# eemeli what is it
# eight down is nabakov
# 47
# ====================================================================================================
# 0.6666666666666666
# nobody is
# fourteen down is
# 61
# ====================================================================================================
# 0.6666666666666666
# quit your yapping
# move your finger
# 3
# ====================================================================================================
# 0.4
# phylum which makes 14 across portauprince
# which makes fourteen across portauprince
# 406
# ====================================================================================================
# 0.8
# is this agreed
# papa doc is capital idea
# 7
# ====================================================================================================
# 0.3333333333333333
# that is nice
# that is portauprince
# 296
# ====================================================================================================
# 0.42857142857142855
# there is no guarantee our sperm is going to generate highiq offspring think about that
# there is no guarantee that our sperm is going to generate high iq offspring
# 420
# ====================================================================================================
# 0.6666666666666666
# is that
# think about that
# 212
# ====================================================================================================
# 0.25
# sheldon this was your idea
# this was your idea
# 422
# ====================================================================================================
# 0.5
# yes i know
# i know
# 521
# ====================================================================================================
# 0.2857142857142857
# i know and i do yearn for faster downloads
# and i do yearn for faster downloads
# 424
# ====================================================================================================
# 0.26666666666666666
# there is some poor woman who is gonna pin her hopes on my sperm
# but there is some poor woman is going to pin her hopes on my sperm
# 425
# ====================================================================================================
# 0.14285714285714285
# what if she winds up with a toddler who does not know if he should use a differential to solve for the area under a curve
# what if she winds up with a toddler who does not know if he should use an integral or a differential to solve the area under a curve
# 426
# ====================================================================================================
# 0.5
# well what do you wanna do
# what do you want to do
# 429
# ====================================================================================================
# 0.6666666666666666
# where is the workshop
# what is the protocol for leaving
# 110
# ====================================================================================================
# 0.25
# i do not care
# i do not know
# 440
# ====================================================================================================
# 0.4
# if the height of a step is off by as little as two millimeters  most people will trip
# if the height of a single step is off by as little as two millimetres
# 439
# ====================================================================================================
# 0.4
# two millime that does not seem right
# that does not seem right
# 441
# ====================================================================================================
# 0.1
# i did a series of experiments when i was 12
# i did a series of experiments when i was twelve
# 443
# ====================================================================================================
# 0.16666666666666666
# significant improvement over the old neighbor
# significant improvement over the old neighbour
# 449
# ====================================================================================================
# 0.625
# twohundred pound transvestite with a skin condition yes she is
# two hundred pound transvestite with a skin condition
# 450
# ====================================================================================================
# 0.6666666666666666
# yes
# yes she is
# 8
# ====================================================================================================
# 0.6666666666666666
# do not lie whippersnapper
# we do not mean to interrupt
# 59
# ====================================================================================================
# 0.8
# beginning with the hannuses
# we live across the hall
# 5
# ====================================================================================================
# 0.5
# oh thank you maybe we can have coffee sometime
# maybe we can have coffee sometime
# 460
# ====================================================================================================
# 0.7333333333333333
# i am not going to take part in that nonsense
# i am not expert here but i believe in the context of a luncheon invitation
# 1
# ====================================================================================================
# 0.7
# we want to make it up to our father
# you might want to skip the reference to bowel movements
# 223
# ====================================================================================================
# 0.14285714285714285
# oh you are inviting me over to eat
# you are inviting me over to eat
# 485
# ====================================================================================================
# 0.25
# that is nice
# that is so nice
# 296
# ====================================================================================================
# 0.5
# i would not
# i would love to
# 428
# ====================================================================================================
# 0.1111111111111111
# so what do you guys do for fun around here
# what do you guys do for fun around here
# 487
# ====================================================================================================
# 0.75
# and you sleep there
# so you are like
# 102
# ====================================================================================================
# 0.6666666666666666
# oh of course
# one of those
# 596
# ====================================================================================================
# 0.75
# i found a great stone
# i have a board
# 25
# ====================================================================================================
# 0.75
# and you sleep there
# if you like boards
# 102
# ====================================================================================================
# 0.5
# this is foolishness
# this is my board
# 172
# ====================================================================================================
# 0.058823529411764705
# at least i did not have to invent 26 dimensions just to make the math come out
# at least i did not have to invent twentysix dimensions just to make the math come out
# 501
# ====================================================================================================
# 0.6
# i can not
# i did not invent them
# 91
# ====================================================================================================
# 0.6666666666666666
# sit there
# they are there
# 282
# ====================================================================================================
# 0.75
# in what universe
# in all of them
# 503
# ====================================================================================================
# 0.5
# that is right hilla
# that is the point
# 44
# ====================================================================================================
# 0.6428571428571429
# in winter that seat is close enough to the radiator to remain warm yet not so close as to cause perspiration
# in the winter that seat is close enough to the radiator to remain warm
# 511
# ====================================================================================================
# 0.7777777777777778
# i promised not to tell
# and yet not so close as to cause perspiration
# 336
# ====================================================================================================
# 0.3888888888888889
# in the summer it is in a cross breeze created by opening windows there and there
# in the summer it is directly in the path of a cross breeze created by open windows there
# 512
# ====================================================================================================
# 0.5
# sit there
# and there
# 282
# ====================================================================================================
# 0.8181818181818182
# that is right hilla
# it faces the television at an angle that is neither direct
# 44
# ====================================================================================================
# 0.7777777777777778
# this will go to a judge
# nor so far wide to create a parallax distortion
# 117
# ====================================================================================================
# 0.75
# i made it myself
# i could go on
# 58
# ====================================================================================================
# 0.5
# i could go on but i think i have made my point
# but i think i have made my point
# 514
# ====================================================================================================
# 0.5
# yeah i remember
# i remember
# 523
# ====================================================================================================
# 0.3333333333333333
# i am sorry master
# i am sorry
# 150
# ====================================================================================================
# 0.6
# that is right hilla
# that is an antisocial implication
# 44
# ====================================================================================================
# 0.5
# so klingon boggle
# klingon boggle
# 527
# ====================================================================================================
# 0.1875
# yes it tells us that you participate in the mass cultural delusion that the sun is position relative to arbitrary constellations at the time of your birth somehow affects your personality
# it tells us that you participate in the mass cultural delusion that the sun is apparent position relative to arbitrarily defined constellations and the time of your birth somehow effects your personality
# 531
# ====================================================================================================
# 0.625
# i think this is the place
# i think what sheldon is trying to say
# 412
# ====================================================================================================
# 0.8
# you would not have made it back before sunrise
# is that sagittarius would not have been our first guess
# 169
# ====================================================================================================
# 0.2
# oh yeah a lot of people think i am a water sign
# a lot of people think i am a water sign
# 534
# ====================================================================================================
# 0.6666666666666666
# let us go home
# let us see
# 174
# ====================================================================================================
# 0.5
# what boys
# what else
# 178
# ====================================================================================================
# 0.25
# oh i am a vegetarian
# i am a vegetarian
# 536
# ====================================================================================================
# 0.6666666666666666
# for what
# except for fish
# 366
# ====================================================================================================
# 0.5
# and the winner is
# and the occasional steak
# 762
# ====================================================================================================
# 0.3333333333333333
# i love cheesecake
# i love steak
# 541
# ====================================================================================================
# 0.3333333333333333
# that is nice
# that is interesting
# 296
# ====================================================================================================
# 0.6
# mother can not do it
# leonard can not process corn
# 17
# ====================================================================================================
# 0.3333333333333333
# that is nice
# that is interesting
# 296
# ====================================================================================================
# 0.6
# mother can not do it
# leonard can not process corn
# 17
# ====================================================================================================
# 0.1111111111111111
# so do you have some sort of a job penny
# so do you have some sort of a job
# 539
# ====================================================================================================
# 0.25
# oh yeah i am a waitress at the cheesecake factory
# i am a waitress at the cheesecake factory
# 540
# ====================================================================================================
# 0.5
# yes i know
# i know
# 521
# ====================================================================================================
# 0.6666666666666666
# let us go home
# let us see
# 174
# ====================================================================================================
# 0.5
# what boys
# what else
# 178
# ====================================================================================================
# 0.5
# that is right hilla
# that is about it
# 44
# ====================================================================================================
# 0.3333333333333333
# well it sounds wonderful
# it sounds wonderful
# 553
# ====================================================================================================
# 0.3333333333333333
# what is it
# what is happening
# 248
# ====================================================================================================
# 0.25
# i do not care
# i do not know
# 440
# ====================================================================================================
# 0.5
# oh wait
# oh god
# 416
# ====================================================================================================
# 0.6666666666666666
# oh god you know four years i lived with him
# four years i lived with him
# 557
# ====================================================================================================
# 0.25
# four years that is like as long as high school
# that is like as long as high school
# 558
# ====================================================================================================
# 0.2857142857142857
# i just i can not believe i trusted him
# i can not believe i trusted him
# 560
# ====================================================================================================
# 0.2857142857142857
# i feel i should say something you
# i feel like i should say something
# 562
# ====================================================================================================
# 0.16666666666666666
# no you will only make it worse
# you will only make it worse
# 563
# ====================================================================================================
# 0.25
# you wanna know the most pathetic part
# you want to know the most pathetic part
# 564
# ====================================================================================================
# 0.8333333333333334
# i made it myself
# even though i hate his lying
# 58
# ====================================================================================================
# 0.5
# i love cheesecake
# i still love him
# 541
# ====================================================================================================
# 0.4
# okay thanks you guys are really sweet
# you guys are really sweet
# 580
# ====================================================================================================
# 0.3333333333333333
# oh good then you will not be disappointed
# then you will not be disappointed
# 590
# ====================================================================================================
# 0.16666666666666666
# yes but not of the same species
# but not of the same species
# 593
# ====================================================================================================
# 0.2222222222222222
# i am not gonna engage in hypotheticals here
# i am not going to engage in hypotheticals here
# 594
# ====================================================================================================
# 0.1111111111111111
# i am just trying to be a good neighbor
# i am just trying to be a good neighbour
# 595
# ====================================================================================================
# 0.6666666666666666
# that is a pity
# and she is not a lady
# 45
# ====================================================================================================
# 0.6666666666666666
# that is a pity
# she is just a new neighbour
# 45
# ====================================================================================================
# 0.3333333333333333
# hang on there really is a lady here
# there really is a lady here
# 614
# ====================================================================================================
# 0.07692307692307693
# hey is there a trick to getting it to switch from tub to shower
# is there a trick to getting it to switch from tub to shower
# 621
# ====================================================================================================
# 0.4
# howard wolowitz caltech department of applied physics
# caltech department of applied physics
# 624
# ====================================================================================================
# 0.4
# howard wolowitz caltech department of applied physics
# caltech department of applied physics
# 624
# ====================================================================================================
# 0.16666666666666666
# penny i work at the cheesecake factory
# i work at the cheesecake factory
# 627
# ====================================================================================================
# 0.1111111111111111
# i will show you the trick with the shower  okay
# i will show you the trick with the shower
# 628
# ====================================================================================================
# 0.2
# save it for your blog howard
# save it for your blog
# 632
# ====================================================================================================
# 0.6666666666666666
# you can try
# you are welcome
# 273
# ====================================================================================================
# 0.6666666666666666
# you are not going to cry are you
# you are going to step right
# 96
# ====================================================================================================
# 0.3333333333333333
# um can i ask you a favor
# can i ask you a favour
# 641
# ====================================================================================================
# 0.11764705882352941
# we drive halfway across town to retrieve a television set from the aforementioned woman is exboyfriend
# we drive half way across town to retrieve a television set from the aforementioned woman is exboyfriend
# 652
# ====================================================================================================
# 0.25
# she asked me to do her a favor sheldon
# she asked me to do her a favour
# 654
# ====================================================================================================
# 0.4666666666666667
# i could have stayed behind to watch wolowitz hit on penny in russian arabic and farsi
# i could have stayed behind and watched wolowitz try to hit on penny in russian
# 659
# ====================================================================================================
# 0.125
# and why can not she get her own tv
# why can not she get her own tv
# 660
# ====================================================================================================
# 0.2857142857142857
# come on you know how it is with breakups
# you know how it is with breakups
# 661
# ====================================================================================================
# 0.5
# but i i broke up with joyce kim
# you did not break up with joyce kim
# 663
# ====================================================================================================
# 0.8
# give it to me
# she defected to north korea
# 18
# ====================================================================================================
# 0.10526315789473684
# there is some dispute between penny and her exboyfriend as to who gets custody of the tv
# there is some kind of dispute between penny and her exboyfriend as to who gets custody of the tv
# 667
# ====================================================================================================
# 0.1
# she just wanted to avoid a scene with him
# she just wanted to avoid having a scene with him
# 668
# ====================================================================================================
# 0.3333333333333333
# i am sorry master
# i am sorry
# 150
# ====================================================================================================
# 0.75
# do not lie whippersnapper
# do you speak english
# 59
# ====================================================================================================
# 0.5714285714285714
# oh he speaks english he just can not speak to women
# he just can not speak to women
# 675
# ====================================================================================================
# 0.3333333333333333
# i am sorry master
# i am sorry
# 150
# ====================================================================================================
# 0.25
# you are gonna have to call her
# you are going to have to call her
# 704
# ====================================================================================================
# 0.2857142857142857
# yeah i have had him since level 10
# i have had him since level ten
# 719
# ====================================================================================================
# 0.5454545454545454
# anyway if you had your own game character we could hang out maybe go on a quest
# if you had your own game character we could hang out
# 721
# ====================================================================================================
# 0.8
# that is a pity
# maybe go on a quest
# 45
# ====================================================================================================
# 0.07692307692307693
# oh i do not think i will be able to stop thinking about it
# i do not think i will be able to stop thinking about it
# 724
# ====================================================================================================
# 0.07692307692307693
# oh i do not think i will be able to stop thinking about it
# i do not think i will be able to stop thinking about it
# 724
# ====================================================================================================
# 0.5
# my sons
# my god
# 220
# ====================================================================================================
# 0.5
# what boys
# what happened
# 178
# ====================================================================================================
# 0.07692307692307693
# well your exboyfriend sends his regards and i think the rest is fairly selfexplanatory
# your exboyfriend sends his regards and i think the rest is fairly selfexplanatory
# 728
# ====================================================================================================
# 0.5
# i am sorry master
# i am so sorry
# 150
# ====================================================================================================
# 0.2
# no it was a valid hypothesis
# it was a valid hypothesis
# 730
# ====================================================================================================
# 0.3
# really thank you so much for going and trying
# thank you so much for going and trying you are
# 733
# ====================================================================================================
# 0.5
# you are lactose intolerant
# you are so terrific
# 542
# ====================================================================================================
# 0.625
# do not you recognise timber species
# why do not you put some clothes on
# 120
# ====================================================================================================
# 0.7
# i will go inside and light the stove
# i will get my purse and dinner is on me
# 99
# ====================================================================================================
# 0.3333333333333333
# you are not done with her are you
# you are not done with her
# 738
# ====================================================================================================
# 0.5
# thank you
# are you
# 737
# ====================================================================================================
# 556
