# %%
import json
import pickle as pkl
import re
from nltk.translate import bleu_score
from tqdm import tqdm
import jiwer
from matplotlib import pyplot as plt

# %% [markdown]
# #### Load Source Data of both Episode and Subtitles

# %%
# Load Open Subtitle
with open('en_subtitles.pkl', 'rb') as f:
    en_subtitle = pkl.load(f)
with open('zh_subtitles.pkl', 'rb') as f:
    zh_subtitle = pkl.load(f)

# %%
# Load Memor Dataset
with open('memor/data.json') as f:
    data = json.load(f)

# %% [markdown]
# ### Pre-Process Data for one episode

# %%
# Define sentence transformation
transformation = jiwer.Compose([
    jiwer.ToLowerCase(),
    jiwer.RemoveMultipleSpaces(),
    jiwer.ExpandCommonEnglishContractions(),
    jiwer.RemovePunctuation(),
    jiwer.Strip()
])

# %%
for item in data:
    if item.strip().split('_')[0]=='S01E01':
        sentences = data[item]['sentences']
        speakers = data[item]['speakers']
        start_times = data[item]['seg_start']
        end_times = data[item]['seg_end']
        for sentence, speaker, start, end in zip(sentences, speakers, start_times, end_times):
            # print(sentence, speaker)
            print(start, end)
            # print()
# Out:
# 2 14.08
# 14.08 16.75
# 16.75 20
# 31 51
# 93 103.61
# 103.61 111
# 110 123.1
# 123.1 126.379999
# 126.379999 128
# 124 126.34
# 126.34 129.53
# 129.53 131.12
# 131.12 132.16
# 132.16 134.01
# 134.01 135.67
# 135.67 140
# 168 172.27
# 172.27 177.42
# 177.42 182
# 191 194.49
# 194.49 196.53
# 196.53 200.179999
# 200.179999 204
# 206 207.63
# 207.63 208.28
# 208.28 210.78
# 210.78 212.67
# 212.67 215.59
# 215.59 217
# 239 241.55
# 241.55 242.33
# 242.33 242.79
# 242.79 243.11
# 243.11 248.34
# 248.34 248.7
# 248.7 249.48
# 249.48 250
# 339 343.84
# 343.84 348.49
# 348.49 349.75
# 349.75 351.78
# 351.78 352.92
# 352.92 356
# 412 415.72
# 415.72 419.69
# 419.69 421.139999
# 421.139999 425
# 439 443.38
# 443.38 445.18
# 445.18 446.17
# 446.17 447.77
# 447.77 450.75
# 450.75 456
# 466 486.52
# 486.52 491.23
# 491.23 491.66
# 491.66 495.51
# 495.51 497
# 511 514.74
# 514.74 515.55
# 515.55 515.56
# 515.56 520
# 531 531.6
# 531.6 533.41
# 533.41 534.89
# 534.89 535.1700000000001
# 535.1700000000001 538.22
# 538.22 541
# 556 566.28
# 566.28 571.469999
# 571.469999 576
# 576 585.91
# 585.91 592
# 588 591.71
# 591.71 598.42
# 598.42 602
# 626 628.4
# 628.4 638
# 638 639.57
# 639.57 646
# 649 650.44
# 650.44 652.777
# 652.777 659
# 658 660.08
# 660.08 660.2800000000001
# 660.2800000000001 667
# 670 673.08
# 673.08 675.4
# 675.4 685
# 729 730.62
# 730.62 735
# 780 781.91
# 781.91 788.04
# 788.04 791.29
# 791.29 798
# 849 852.8
# 852.8 856.35
# 856.35 857.03
# 857.03 860
# 869 874.52
# 874.52 893
# 877 891.42
# 891.42 894.84
# 894.84 898.249999
# 898.249999 900
# 901 905.5
# 905.5 910
# 919 922.15
# 922.15 924.77
# 924.77 927.16
# 927.16 928.41
# 928.41 932
# 944 947
# 955 969.61
# 969.61 974
# 984 987.61
# 987.61 995.759999
# 995.759999 998
# 1002 1005.43
# 1005.43 1023
# 1040 1042.46
# 1042.46 1047.02
# 1047.02 1049
# 1048 1053.73
# 1053.73 1057
# 1102 1107
# 1166 1167.74
# 1167.74 1170.38
# 1170.38 1173
# 1220 1230.759999
# 1230.759999 1234.32
# 1234.32 1235.33
# 1235.33 1238
# 1231 1233.76
# 1233.76 1235.32
# 1235.32 1240.13
# 1240.13 1243.69
# 1243.69 1244.48
# 1244.48 1247
# 1246 1251.44
# 1251.44 1257.259999
# 1257.259999 1260
# 1263 1275.25
# 1275.25 1276.03
# 1276.03 1277

# %%
# Process episode
utterances = []
for item in data:
    if item.strip().split('_')[0]=='S01E01':
        sentences = data[item]['sentences']
        speakers = data[item]['speakers']
        for sentence, speaker in zip(sentences, speakers):
            utterances.append([sentence, speaker])

segments = []
pattern = r'\.|\,|\?|\!|\;'
for x in utterances:
    utt = x[0]
    temp = re.split(pattern, utt.strip(' ,.-!'))
    for item in temp:
        item = transformation(item)
        if item!="":
            segments.append([item, x[1]])

for x in segments:
    print(x[0], x[1])
# Out:
# if a photon is directed through a plane with two slits in it and either slit is observed it will not go through both slits 1
# if it is unobserved it will 1
# however 1
# if it is observed after it is left the plane but before it hits its target 1
# it will not have gone through both slits 1
# agreed 0
# what is your point 0
# there is no point 1
# i just think it is a good idea for a tshirt 1
# one across is aegean 0
# eight down is nabakov 0
# twentysix across is mcm 0
# fourteen down is 0
# move your finger 0
# phylum 0
# which makes fourteen across portauprince 0
# see 0
# papa doc is capital idea 0
# that is portauprince 0
# haiti 0
# no 1
# we are committing genetic fraud 1
# there is no guarantee that our sperm is going to generate high iq offspring 1
# think about that 1
# i have a sister with the same basic dna mix who hostesses at fuddruckers 1
# sheldon 0
# this was your idea 0
# a little extra money to get fractional t1 bandwidth in the apartment 0
# i know 1
# and i do yearn for faster downloads 1
# but there is some poor woman is going to pin her hopes on my sperm 1
# what if she winds up with a toddler who does not know if he should use an integral or a differential to solve the area under a curve 1
# i am sure she will still love him 0
# i would not 1
# i am sure she will still love him 0
# i would not 1
# well 0
# what do you want to do 0
# i want to leave 1
# okay 0
# what is the protocol for leaving 1
# i do not know 0
# i have never reneged on a proffer of sperm before 0
# if the height of a single step is off by as little as two millimetres 1
# most people will trip 1
# i do not care 0
# two millimetres 0
# that does not seem right 0
# no 1
# it is true 1
# i did a series of experiments when i was twelve 1
# my father broke his clavicle 1
# new neighbour 0
# evidently 1
# significant improvement over the old neighbour 0
# two hundred pound transvestite with a skin condition 1
# yes she is 1
# hi 1
# hi 0
# hi 1
# hi 4
# we do not mean to interrupt 0
# we live across the hall 0
# oh 4
# that is nice 4
# thank you 4
# maybe we can have coffee sometime 4
# oh 0
# great 0
# great 4
# great 1
# great 0
# well 0
# bye 0
# bye 4
# bye 1
# bye 0
# leonard 1
# i am not expert here but i believe in the context of a luncheon invitation 1
# you might want to skip the reference to bowel movements 1
# oh 4
# you are inviting me over to eat 4
# yes 0
# oh 4
# that is so nice 4
# i would love to 4
# great 0
# so 4
# what do you guys do for fun around here 4
# so you are like 4
# one of those 4
# beautiful mind genius guys 4
# yeah 1
# this is really impressive 4
# i have a board 0
# if you like boards 0
# this is my board 0
# at least i did not have to invent twentysix dimensions just to make the math come out 0
# i did not invent them 1
# they are there 1
# in what universe 0
# in all of them 1
# that is the point 1
# uh 4
# do you guys mind if i start 4
# um 1
# penny 1
# that is where i sit 1
# in the winter that seat is close enough to the radiator to remain warm 1
# and yet not so close as to cause perspiration 1
# in the summer it is directly in the path of a cross breeze created by open windows there 1
# and there 1
# it faces the television at an angle that is neither direct 1
# thus discouraging conversation 1
# nor so far wide to create a parallax distortion 1
# i could go on 1
# but i think i have made my point 1
# do you want me to move 4
# well 1
# just sit somewhere else 0
# fine 1
# sheldon 0
# sit 0
# aaah 1
# yes 0
# i remember 0
# i resent you saying we do not have company 1
# i am sorry 0
# that is an antisocial implication 1
# i said i am sorry 0
# so 4
# klingon boggle 4
# yes 1
# it tells us that you participate in the mass cultural delusion that the sun is apparent position relative to arbitrarily defined constellations and the time of your birth somehow effects your personality 1
# participate in the what 4
# i think what sheldon is trying to say 0
# is that sagittarius would not have been our first guess 0
# oh 4
# yeah 4
# a lot of people think i am a water sign 4
# okay 4
# let us see 4
# what else 4
# oh 4
# i am a vegetarian 4
# oh 4
# except for fish 4
# and the occasional steak 4
# i love steak 4
# well 1
# that is interesting 1
# leonard can not process corn 1
# well 1
# that is interesting 1
# leonard can not process corn 1
# so do you have some sort of a job 0
# oh 4
# yeah 4
# i am a waitress at the cheesecake factory 4
# well 0
# if that was a movie i would go see it 0
# i know 4
# right 4
# okay 4
# let us see 4
# what else 4
# um 4
# that is about it 4
# that is the story of penny 4
# well 0
# it sounds wonderful 0
# it was 4
# until i fell in love with a jerk 4
# what is happening 1
# i do not know 0
# oh god 4
# you know 4
# four years i lived with him 4
# four years 4
# that is like as long as high school 4
# it took you four years to get through high school 1
# do not 0
# i just 4
# i can not believe i trusted him 4
# should i say something 0
# i feel like i should say something 0
# you 1
# no 1
# you will only make it worse 1
# you want to know the most pathetic part 4
# even though i hate his lying 4
# cheating guts 4
# i still love him 4
# is that crazy 4
# it is right down the hall 0
# thanks 4
# you guys are really sweet 4
# oh 1
# good 1
# then you will not be disappointed 1
# what makes you think she would not have sex with me 0
# i am a male and she is a female 0
# yes 1
# but not of the same species 1
# i am not going to engage in hypotheticals here 0
# i am just trying to be a good neighbour 0
# no 0
# and she is not a lady 0
# she is just a new neighbour 0
# hang on 2
# there really is a lady here 2
# uhhuh 0
# and you want us out because you are anticipating coitus 2
# hey 4
# is there a trick to getting it to switch from tub to shower 4
# oh 4
# hi 4
# sorry 4
# hello 4
# enchante madamoiselle 2
# howard wolowitz 2
# caltech department of applied physics 2
# you may be familiar with some of my work 2
# it is currently orbiting jupiter is largest moon taking highresolution digital photographs 2
# enchante madamoiselle 2
# howard wolowitz 2
# caltech department of applied physics 2
# you may be familiar with some of my work 2
# it is currently orbiting jupiter is largest moon taking highresolution digital photographs 2
# penny 4
# i work at the cheesecake factory 4
# come on 0
# i will show you the trick with the shower 0
# bon douche 2
# it is french for good shower 2
# it is a sentiment i can express in six languages 2
# save it for your blog 0
# howard 0
# you are welcome 0
# oh 0
# you are going to step right 0
# okay 0
# i will 0
# hey 4
# leonard 4
# the hair products are sheldon is 0
# um 4
# okay 4
# can i ask you a favour 4
# wow 0
# event a 1
# a beautiful woman stands naked in our shower 1
# event b 1
# we drive half way across town to retrieve a television set from the aforementioned woman is exboyfriend 1
# query 1
# on what plane of existence is there even a semirational link between these events 1
# she asked me to do her a favour 0
# sheldon 0
# that is a biological impossibility and you did not have to come 0
# oh 1
# yes 1
# i could have stayed behind and watched wolowitz try to hit on penny in russian 1
# arabic and farsi 1
# why can not she get her own tv 1
# come on 0
# you know how it is with breakups 0
# you did not break up with joyce kim 1
# she defected to north korea 1
# to mend her broken heart 0
# this situation is much less complicated 0
# there is some kind of dispute between penny and her exboyfriend as to who gets custody of the tv 0
# she just wanted to avoid having a scene with him 0
# uh 4
# i am sorry 4
# do you speak english 4
# oh 2
# he speaks english 2
# he just can not speak to women 2
# really 4
# why 4
# he is kind of a nerd 2
# juice box 2
# it is just a privilege to watch your mind at work 1
# my mom bought me those pants 1
# i am sorry 0
# you are going to have to call her 1
# yeah 2
# i have had him since level ten 2
# his name is buttons 2
# anyway 2
# if you had your own game character we could hang out 2
# maybe go on a quest 2
# uh 4
# that sounds interesting 4
# so you will think about it 2
# oh 4
# i do not think i will be able to stop thinking about it 4
# uh 4
# that sounds interesting 4
# so you will think about it 2
# oh 4
# i do not think i will be able to stop thinking about it 4
# smooth 3
# we are home 0
# oh 4
# my god 4
# what happened 4
# well 0
# your exboyfriend sends his regards and i think the rest is fairly selfexplanatory 0
# i am so sorry 4
# i really thought if you guys went instead of me he would not be such an ass 4
# no 0
# it was a valid hypothesis 0
# really 4
# thank you so much for going and trying you are 4
# uh 4
# you are so terrific 4
# why do not you put some clothes on 4
# i will get my purse and dinner is on me 4
# okay 4
# really 0
# great 0
# thank you 1
# you are not done with her 1
# are you 1

# %%
# Process Subtitle Subset
base = 4424331
bias = 400

subtitles = []
for item in en_subtitle[base-bias: base+bias]:
    item = transformation(item)
    if item!="":
        subtitles.append(item)

# %%
for x in subtitles:
    print(x)
# Out:
# i think that we can manage that
# i am not going to take part in that nonsense
# you do not live here iisakki it is not of your concern
# quit your yapping
# we will all take care of nikolas
# beginning with the hannuses
# the boy will move to the next family on christmas
# is this agreed
# yes
# merry christmas sister aada
# i could not forget my mother and my father  and my sister aada
# i knew they would not be coming back  but i missed them dearly
# but time heals the wounds  and by autumn the sadness began to fade away
# my boat is broken fix it
# ask your father
# my father has gone fishing
# ask your mother then
# mother can not do it
# give it to me
# turn boat
# it will not turn
# why does not it come here turn right
# there it goes
# i did not know it back then  but eemeli would become a good friend
# good throw it bounced off the water
# i found a great stone
# stretch your arm back and throw
# you can do it one two three
# let us get another one
# then came the moment i had been dreading
# i had to move to another family for the very first time
# are you sure you will find your way to the heinos
# bye bye
# bye bye
# years families and christmases came and went
# every christmas i carved presents  for the children of my former families
# as the years passed there were so many of them  that i had to deliver the presents to their front doors at night
# it suited me fine  because i did not want to make a great fuss about it
# instead i acted ignorant  if someone came to thank me after christmas
# on my sixth year not everything went as planned
# that year was hard for the whole village
# early frost wiped out almost the entire crop
# it was like the lake was empty of fish that year
# no fish today either
# that is right hilla
# that is a pity
# if things did not turn for the better  no family would be able to house me for the winter
# eemeli what is it
# it is mad iisakki run away
# get your homes in shipshape for christmas
# scoops ladles cups
# spatulas tubs and potato mashers i have everything you need here
# and if i do not have it it can be made to order
# boy come here
# you have not bought this from me
# are you buying things from other carpenters instead of iisakki
# a bad year we have no money we can barely feed ourselves
# where did you buy this answer me
# i made it myself
# do not lie whippersnapper
# and whose boy are you
# nobody is
# oh yeah you are the poor devil who is going around from house to house
# where are the others
# at the village meeting
# what is so important that they must have a meeting
# they are deciding what to do with me they can not afford me
# no wonder you must be such a glutton  that you have ruined the village
# and now i can not sell anything
# you should have been cast into the lake get lost
# but why you do not like children
# he can help me at work
# we know you iisakki
# i was planning to shape that brat into a man within a year  but if my offer is not good enough for you there is nothing i can do
# wait iisakki
# maybe maybe we should consider it
# there is nothing to consider
# he will be better off with me  than starving to death here in this poor village right
# this might be the last time i can visit you
# iisakki lives so far away
# merry christmas little aada
# nikolas come and see
# nikolas
# it is been six years since you were orphaned and came to us
# at first i was sorry that we could not find you a family  to take you in
# you had to go around from household to household one year at a time
# but now i believe that none of us have regretted it
# we all have gotten to know you
# and so in a way you are our child
# and our brother
# on behalf of all the villagers especially the children  we want to give you a little memento
# i can not
# of course you can
# the sledge belongs to you
# are you still loafing about get in the sleigh
# or you can walk the whole way
# you are not going to cry are you
# hilma trot along home before night falls
# what are you gawking at take hilma into the stall
# i will go inside and light the stove
# and leave this sledge in the stall
# no mucking about here you came here to work get up
# and you sleep there
# no buts did you forget whose house this is
# and you will call me master
# yes master
# good your name is brat
# it suits you better than nikolas take your bags in there move it
# wake up brat get to work
# let us get to the workshop you go on ahead
# where is the workshop
# you are standing on it
# take a look at this dresser
# the secret is in the wooden inlays
# it is made of maple this is how i make money
# scoops and ladles are child is play compared to this
# these will go to parsons gentleman farmers and other wealthy people
# this will go to a judge
# is this chair going there too
# it is made of pine this is made of maple
# do not you recognise timber species
# maybe i made a mistake you are no good as a carpenter
# you have not made a mistake master i am a quick learner
# a quick learner eh let us see how quickly you learn to tidy up
# get on with it
# where are you going
# upstairs
# you do not need to go upstairs to tidy up the workshop
# there is no need to clean up here
# the workbench is covered with dust
# if it gets mixed with varnish or stain the whole work is ruined
# lesson number one
# the workshop will be kept tidy at all times no matter what
# lesson number two hand me your sheathknife
# you do not use this on my timber
# do not
# it was my father is
# take a decent sheathknife from there
# remember to snuff out the candles
# it has no branches
# how can i find my things now
# master
# a year has passed and i have to go soon  so i thought that i would thank all the villagers
# maybe i could take a day off
# when time is pressing  you do not waste time thinking you work harder
# a day off eh
# what are you doing here why are not you in bed
# have you stolen timber from me
# you threw it away master
# so this is what you do behind my back
# i am sorry master
# it is not badly broken
# bring me the wood drill and a headless nail
# why are you working in the dark it only results in duds and rejects
# now you can not tell it is broken
# you have more toys somewhere right
# you must really like those little brats
# did you plan to slip out to deliver presents  because i did not give you a day off
# that is what i thought
# go on then  but remember to return before sunrise
# we do not idle away even though it is christmas
# master
# not a word i may change my mind
# you can build your toys in the evenings
# i might even help you at least now i can get some sleep
# building toys in the middle of the night humbug
# finally you showed up i thought you had gone into hibernation
# i already put your junk in the sleigh
# what are you gawking at
# you would not have made it back before sunrise
# the last workday would have gone to waste hop in
# that was the last house
# this is foolishness
# i can understand why you do this but an old man like me
# let us go home
# there is one more place
# hold on show me that
# i made a horse like this when the boys were young
# what boys
# i had two boys hermanni and henrik
# and a wife marget she died when the boys were about your age
# then they went to sea and left me all alone  because i had become like this
# i see henrik and hermanni in all children
# that is why i am mean to children
# i still miss my boys
# what i mean to say is you could stay with me
# merry christmas nikolas
# my father is sheathknife thank you master
# from now on you can call me iisakki
# merry christmas aada
# merry christmas aada
# merry christmas iisakki
# merry christmas nikolas
# that is enough let us go
# that christmas changed everything the village overcame the bad years
# my vagabond life was over
# iisakki provided me a home that i did not have to give up
# thank you very much good day to you
# good day to you
# come and buy a dresser
# the years with iisakki passed quickly
# before i knew it i was all grown up with a beard and all
# the village had grown
# there were so many new children  that me and iisakki could not keep count
# but we had a secret helper
# nikolas
# eemeli
# long time no see you should come more often
# i have been busy iisakki is no longer young
# do you have the list
# well i will be so many new children
# as a matter of fact one name is missing from that list elsa
# is that
# a girl three months
# let us add her to the list
# what is the name of this little princess
# aada
# aada
# hello aada
# nikolas meet henrik and hermanni
# my sons
# i sought them out and asked them here
# we were wrong when we
# we want to make it up to our father
# we came to take him to live with us
# to live with you where
# away from here father is too old to be living in arctic conditions
# you will get the house and the workshop you have earned them
# wait nikolas
# nikolas
# nikolas try to understand
# even though i love you like my own son
# this key opens the chest under my bed
# i have always been skimpy maybe too much so
# i think you can do better
# try to understand
# eemeli
# nikolas
# where have you been
# here but everything is unfinished
# these should last for ten years
# this is barely enough for next christmas
# a map
# there there to this remote village to these houses
# there there there there there christmas presents
# christmas presents
# so many villages and children how do you know who will get what
# there is a simple way
# what is it
# i shall write names on the wrapping
# wrapping
# ingenious is not it
# how is all this possible
# iisakki is life savings
# now i can bring christmas cheer to the children
# nobody can live just for christmas
# i have been selfish i have only brought presents to those  who have helped me
# selfish
# from now on i am going to appear only on christmas eve
# nikolas
# i will visit your shop once a year  to replenish my supplies and to get a list of new children
# there is more to life than just christmas
# like what
# it is an impossible task
# you do not have room for all those presents
# and hilma will not be able to pull the load
# it can not be done
# yes it can
# christmas is around the corner
# animals are quick to learn
# reindeer are not horses
# hilla this is child is play
# i can handle reindeer dear reindeer dear
# you can try
# reindeer obey me better when i am wearing this colourful cap
# even the squirrels are afraid of such a garish colour
# reindeer would obey me even if i had a potholder on my head
# i do not need any red caps
# okay fall in line put your antlers down
# come to nikolas chopchop
# dasher dancer prancer and blitzen your training begins
# the first lesson lassoing dancer behave yourself
# sit there
# sit sit stay
# dasher if you do not behave nikolas will catch you prancer
# let us try again
# hold it
# dancer prancer
# a red cap a red coat and frieze trousers to boot
# what was the colour
# red
# could you repeat that
# red
# i will show you
# let us see aada what do you have there
# a spinning top
# that is nice
# in a few years the mysterious presentbearer  became the staple of children is stories
# some swore to have seen elves bringing presents at christmas
# others claimed that the presents were from a childfriendly gnome
# luckily they did not suspect me
# nikolas is coming
# run away
# good day
# where are the others
# they are afraid of you
# mikko said that it is not you who brings us presents at christmas
# that you hate children is it true
# mikko is half right
# i do not bring presents but i do not hate children either
# who brings the presents
# nikolas told me when i asked him
# aada claims that you do not bring us presents
# aada is right
# aada
# why did you say so tell her the truth
# no way children must not associate me with the presents
# it would ruin everything
# why is that
# nikolas
# eemeli
# is aada here
# aada has gone missing
# dear mother and father do not worry
# i went to find out  who brings all the presents
# we have to wake everybody up and arrange a search party
# you must lend me some clothes otherwise i will be exposed
# okay boys hurry on home
# let us form groups of two a torch and a lantern for each group
# aada could not have gone far let us hurry
# i know where she is
# what did you say mikko
# aada wants to deliver you a present
# me why
# aada does not believe that you do not bring us presents
# why did not you tell us earlier
# i promised not to tell
# will aada return
# aada does not know where you live
# and even if she knew  she will not be able to walk that far aada
# nikolas
# aada
# nobody thought that you would manage to get this far
# twelve miles in a blizzard how is it possible
# it was nothing on a reindeer sleigh
# a reindeer sleigh
# what reindeer sleigh
# suddenly a sleigh appeared
# i thought it was you but the sleigh was empty well not quite
# i was cold so i put on your clothes then the reindeer brought me here
# i told aada everything
# how i would become the way i am  and why it was so important to deliver presents at christmas
# i even revealed my dream of continuing this tradition  when i would be gone
# what kind of girl would aada be now if she had not become a water nymph
# hopefully she would be like you
# aada kept her promise
# she did not reveal my secret quite the opposite
# he did not look like nikolas
# he was a wrinkly old man  who called himself christmas codger
# the years passed and before i knew it  my friendship with aada had lasted almost twenty years
# nikolas
# well
# i am getting married
# to mikko
# nikolas will you pick me up on christmas morning
# of course i will
# for what
# for everything
# fear of losing love is part of love it is part of life
# your father eemeli taught me that
# you have taught me how wonderful it is to give
# nikolas maybe you should think of yourself for a change
# nothing lasts forever
# it was time for me to give in to my years
# next christmas would be the last my last christmas
# it is beautiful who is it for
# can i gift wrap it no
# i want to do it myself
# see you on christmas morning
# are you sure you do not want any help at christmas
# yes i want to do my rounds alone
# nikolas remember your promise this is the last christmas
# this is the last christmas
# nikolas
# merry christmas to little aada your brother nikolas
# we will not be seeing nikolas again
# i can not explain i just know it
# what are you doing there is no sense in doing that
# nikolas wanted this to continue
# a present for our nikolas will disappoint other children
# other fathers have done this too it is not the same thing
# mikko that is cheating
# mikko
# merry christmas little aada
# merry christmas nikolas
# dasher dancer prancer and blitzen ahoy
# merry christmas
# if a photon is directed through a plane with two slits in it and either is observed it will not go through both
# if unobserved it will
# if it is observed after it left the plane before it hits its target
# it will not have gone through both slits
# agreed what is your point
# there is no point i just think it is a good idea for a tshirt
# one across is aegean eight down is nabokov
# twentysix across is mcm
# fourteen down is move your finger
# phylum which makes 14 across portauprince
# see papa doc is capital idea that is portauprince
# haiti
# can i help you  yes
# um is this the highiq sperm bank
# if you have to ask maybe you should not be here
# i think this is the place
# fill these out  thank you
# we will be right back
# oh take your time i will just finish my crossword puzzle
# oh wait
# leonard i do not think i can do this
# what are you kidding
# we are committing genetic fraud
# there is no guarantee our sperm is going to generate highiq offspring think about that
# i have a sister with the same basic dna mix who hostesses at fuddruckers
# sheldon this was your idea
# a little extra money to get fractional t1 bandwidth in the apartment
# i know and i do yearn for faster downloads
# there is some poor woman who is gonna pin her hopes on my sperm
# what if she winds up with a toddler who does not know if he should use a differential to solve for the area under a curve
# i am sure she will still love him
# i would not
# well what do you wanna do
# i want to leave
# what is the protocol for leaving  i do not know
# i have never reneged on a proffer of sperm before
# let us try just walking out
# bye  byebye
# nice meeting you
# are you still mad about the sperm bank
# you wanna hear an interesting thing about stairs
# not really
# if the height of a step is off by as little as two millimeters  most people will trip
# i do not care
# two millime that does not seem right
# it is true
# i did a series of experiments when i was 12
# my father broke his clavicle
# is that why they sent you to boarding school no
# that was the result of my work with lasers
# new neighbor sheldon
# evidently
# significant improvement over the old neighbor
# twohundred pound transvestite with a skin condition yes she is
# oh hi
# hi
# we do not mean to interrupt we live across the hall
# oh that is nice
# no we do not live together
# i mean we live together but in separate heterosexual bedrooms
# okay well guess i am your new neighbor  penny
# leonard sheldon
# well oh welcome to the building
# oh thank you maybe we can have coffee sometime
# oh great
# well bye
# should we have invited her for lunch no
# we are gonna start season two of battlestar galactica
# we already watched the season two dvds
# not with commentary
# i think we should be good neighbors invite her over make her feel welcome
# we never invited louielouise over
# well and that was wrong of us
# we need to widen our circle
# i have a very wide circle
# i have 212 friends on myspace
# yes and you have never met one of them
# that is the beauty of it
# i am gonna invite her over
# we will have a nice meal and chat
# we do not chat at least not offline
# well it is not difficult
# you just listen to what she says and then you say something appropriate in response
# to what end
# hi again  hi
# anyway we brought home indian food and i know that moving can be stressful and i find that when i am undergoing stress that good food and company can have a comforting effect
# also curry is a natural laxative and i do not have to tell you that you know a clean colon is just one less thing to worry about
# i am no expert but in the context of a lunch invitation you might wanna skip the reference to bowel movements
# oh you are inviting me over to eat
# oh that is so nice i would love to
# so what do you guys do for fun around here
# well today we tried masturbating for money
# okay well make yourself at home
# this looks like some serious stuff leonard did you do this
# actually that is my work
# yeah well it is just some quantum mechanics with a little string theory doodling around the edges
# it is a spoof of the bornoppenheimer approximation
# so you are like one of those beautiful mind genius guys
# yeah
# this is really impressive
# i have a board if you like boards this is my board
# holy smokes
# if by holy smokes you mean a derivative restatement of the stuff you can find scribbled on the wall of any men is room at mit sure
# who has not seen this differential below here i sit brokenhearted
# at least i did not have to invent 26 dimensions just to make the math come out
# i did not invent them they are there
# in what universe
# in all of them that is the point
# do you guys mind if i start
# penny  yeah
# that is where i sit
# so sit next to me
# no i sit there
# here we go
# in winter that seat is close enough to the radiator to remain warm yet not so close as to cause perspiration
# in the summer it is in a cross breeze created by opening windows there and there
# it faces the television at an angle that is neither direct discouraging conversation nor so far wide as to create a parallax distortion
# i could go on but i think i have made my point
# do you want me to move
# just sit somewhere else
# sheldon sit
# well this is nice
# we do not have a lot of company over
# that is not true koothrappali and wolowitz come over
# yes i know
# tuesday night we played klingon boggle until 1 in the morning
# yeah i remember
# i resent you saying we do not have company
# that has a negative social implication
# i said i am sorry
# so klingon boggle
# yeah it is like regular boggle but in klingon
# that is probably enough about us so tell us about you
# i am a sagittarius which probably tells you way more than you need to know
# yes it tells us that you participate in the mass cultural delusion that the sun is position relative to arbitrary constellations at the time of your birth somehow affects your personality
# participate in the what
# i think what sheldon is trying to say is that sagittarius would not have been our first guess
# oh yeah a lot of people think i am a water sign
# okay let us see what else
# oh i am a vegetarian
# no except for fish and the occasional steak
# well that is interesting leonard can not process corn
# so do you have some sort of a job penny
# oh yeah i am a waitress at the cheesecake factory
# i love cheesecake
# you are lactose intolerant
# i do not eat it i think it is a good idea
# anyways i am also writing a screenplay
# it is about this sensitive girl who comes to la from lincoln nebraska to be an actress and winds up a waitress at the cheesecake factory
# so it is based on your life
# no i am from omaha
# if that was a movie i would go see it
# i know right
# okay let us see what else
# i guess that is about it
# that is the story of penny
# well it sounds wonderful
# it was
# until i fell in love with a jerk
# mouths i do not know
# oh god you know four years i lived with him
# four years that is like as long as high school
# it took you four years to get through high school
# i just i can not believe i trusted him
# should i say something
# i feel i should say something you
# no you will only make it worse
# you wanna know the most pathetic part
# even though i hate his lying cheating guts i still love him
# is that crazy
# no it is not crazy
# it is a
# it is a paradox
# paradoxes are part of nature
# i mean think about light if you look at huygens light is a wave as confirmed by the doubleslit experiments
# but then along comes albert einstein and discovers that light behaves like particles too
# well i did not make it worse
# oh i am so sorry i am such a mess
# and on top of everything else i am all gross from moving and my stupid shower does not work
# our shower works
# would it be totally weird if i used it
# no
# it is right down the hall
# okay thanks you guys are really sweet
# well this is an interesting development
# leonard how so
# sheldon it has been some time since we have had a woman take her clothes off in our apartment
# that is not true remember at thanksgiving my grandmother with alzheimer is had that episode
# it has been some time since we have had a woman take her clothes off after which we did not wanna rip our eyes out
# the worst part was watching her carve that turkey
# so what exactly are you trying to accomplish here
# that woman in there is not going to have sex with you
# well i am not trying to have sex with her
# oh good then you will not be disappointed
# what makes you think she would not have sex with me
# i am a male and she is a female
# yes but not of the same species
# i am not gonna engage in hypotheticals here
# i am just trying to be a good neighbor
# oh of course
# that is not to say that if a carnal relationship were to develop that i would not participate
# however briefly
# do you think this possibility will be hindered when she discovers your luke skywalker no more tears shampoo
# it is darth vader shampoo
# luke skywalker is the conditioner
# wait till you see this
# it is fantastic unbelievable
# see what
# it is a stephen hawking lecture from mit in 1974
# this is not a good time
# imitating computerized voice it is before he became a creepy computer voice
# that is great you guys have to go
# it is just not a good time
# leonard has a lady over
# in normal voice yeah right your grandmother back in town
# no
# and she is not a lady she is just a new neighbor
# hang on there really is a lady here
# uhhuh
# and you want us out because you are anticipating coitus
# i am not anticipating coitus
# so she is available for coitus
# can we please just stop saying coitus
# technically that would be coitus interruptus
# hey is there a trick to getting it to switch from tub to shower
# oh hi sorry hello
# enchanté mademoiselle
# howard wolowitz caltech department of applied physics
# you may be familiar with some of my work
# it is currently orbiting jupiter is largest moon taking highresolution digital photographs
# penny i work at the cheesecake factory
# i will show you the trick with the shower  okay
# speaks in french
# it is french for good shower
# it is a sentiment i can express in six languages
# save it for your blog howard
# speaks in foreign language
# leonard all right there it goes it sticks i am sorry
# okay thanks
# you are welcome oh you are just gonna step right
# okay
# penny hey leonard
# the hair products are sheldon is
# penny okay
# um can i ask you a favor
# a favor
# sure you could ask me a favor i would do you a favor for you
# it is okay if you say no
# oh i will probably say yes
# it is just not the kind of thing you ask a guy you just met
# i really think we should examine the chain of causality here
# must we
# event a
# a beautiful woman stands naked in our shower
# event b
# we drive halfway across town to retrieve a television set from the aforementioned woman is exboyfriend
# on what plane of existence is there even a semirational link between these events
# she asked me to do her a favor sheldon
# well that may be the proximal cause of our journey but we both know it exists in contradistinction to the higherlevel distal cause
# which is
# you think with your penis
# that is a biological impossibility and you did not have to come
# i could have stayed behind to watch wolowitz hit on penny in russian arabic and farsi
# and why can not she get her own tv
# come on you know how it is with breakups
# no i do not and neither do you
# but i i broke up with joyce kim
# you did not break up with joyce kim she defected to north korea
# to mend her broken heart
# this situation is much less complicated
# there is some dispute between penny and her exboyfriend as to who gets custody of the tv
# she just wanted to avoid a scene with him
# so we get to have a scene with him
# no sheldon there is not going to be a scene
# there is two of us and one of him
# leonard the two of us can not even carry a tv
# so you guys work with leonard and sheldon at the university
# i am sorry do you speak english
# oh he speaks english he just can not speak to women
# he is kind of a nerd
# juice box
# i will do the talking
# man yeah
# hi i am leonard this is sheldon
# what did i just
# we are here to pick up penny is tv
# get lost
# okay thanks for your time
# we are not gonna give up just like that
# leonard the tv is in the building
# we have been denied access to the building ergo we are done
# if i were to give up at the first hitch i never would have identified the fingerprints of string theory in the aftermath of the big bang
# my apologies what is your plan
# it is just a privilege to watch your mind at work
# come on we have a combined iq of 360
# we should be able to figure out how to get into a stupid building
# what do you think their combined iq is
# just grab the door
# leonard this is it
# i will do the talking
# good thinking i will just be the muscle
# i am leonard this is sheldon
# from the intercom
# how the hell did you get in the building
# tell him about our iq
# leonard  what
# my mom bought me those pants
# you are gonna have to call her
# sheldon i am so sorry i dragged you through this
# it is okay it was not my first pantsing and it will not be my last
# and you were right about my motives
# i was hoping to establish a relationship with penny that might have someday led to sex
# sheldon well you got me out of my pants
# anyway i have learned my lesson
# she is out of my league i am done with her
# i have got my work one day i will win the nobel prize and then i will die alone
# do not think like that you are not going to die alone
# thank you sheldon you are a good friend
# sheldon and you are certainly not gonna win a nobel prize
# this is one of my favorite places to kick back after a quest
# they have a great house ale
# penny wow cool tiger
# yeah i have had him since level 10
# his name is buttons
# anyway if you had your own game character we could hang out maybe go on a quest
# that sounds interesting
# so you will think about it
# oh i do not think i will be able to stop thinking about it
# smooth
# we are home
# oh my god what happened
# well your exboyfriend sends his regards and i think the rest is fairly selfexplanatory
# i really thought if you guys went instead of me he would not be such an ass
# no it was a valid hypothesis
# that was a valid hypo
# what is happening to you
# really thank you so much for going and trying
# you just you are so terrific
# why do not you put some clothes on i will get my purse and dinner is on me okay
# really great
# thank you
# you are not done with her are you
# our babies will be smart and beautiful
# not to mention imaginary
# is thai food okay with you penny  sure
# we can not have thai we had indian for lunch
# they are both currybased cuisines
# it would be gastronomically redundant
# i can see we are going to have to spell out everything for this girl
# any ideas raj
# turn left on lake street and head up to colorado
# i know a wonderful little sushi bar that has karaoke
# oh that sounds like fun
# singing baby baby do not get hooked on me
# oh baby baby do not get hooked on me
# i do not know your odds in the world as a whole but as far as the population of this car goes you are a veritable mac daddy
# baby do not get hooked on me
# yo we should just play this straight up
# those cats will fold under pressure
# we can take these fools with our eyes closed come on
# no doubt but i do not wanna diss them in front of their home crowd
# d i got you
# i got yall
# all right man come on let us do it
# all right all right yall that was hot
# and the winner is
# sphere and the thug unit
# who wants next
# let us get it going on in here
# yall want some of this
# we got next
# all right all right yall let us get it popping in this mall
# you have not seen him pop come on come on
# hey i got that get out of here
# get back break it up
# get back get back we good
# all right all right let us hear it for the thug unit
# give it up for the goon squad
# what is up i think the goon squad got it yall
# double or nothing says you got lucky
# it is on
# let us go let us go what the hell are you doing
# man i am out
# what the hell you walking away for
# i say we double up on these niggas
# you know this ai not our spot d
# sphere is crew do not know us
# do not know what we are bringing period
# the more paper we take home
# did you see that cat
# if he thinks he is being hustled that is paper we will not spend
# why are you acting all scared
# l am not
# l am acting smart you try it
# do not i always got your back
# do not i always have your back
# you know i got it man but i am
# lf you ai not with it just go home
# like you could do this without me
# for real dj
# we ai not shit without your brother
# you know it is gonna get nasty up in here
# do not wanna let stuff get out of hand

# %% [markdown]
# ### Perform Alignment with Word Error Rate (WER)

# %%
def get_optimal_wer_from_episode(ground_truth, hypothesis_pool):
    scores = []
    for i, hypothesis in enumerate(hypothesis_pool):
        scores.append(jiwer.compute_measures(ground_truth, hypothesis)['wer'])
    return min(scores), hypothesis_pool[scores.index(min(scores))], ground_truth, scores.index(min(scores))

# %%
# Align based on episode
valid_utterances = []

for x in tqdm(segments):
    utt = x[0]
    speaker = x[1]
    result = get_optimal_wer_from_episode(utt, subtitles)
    score = result[0]
    index = result[-1]
    subtitle = result[1]
    if 0 < score <0.2:
        if valid_utterances==[]:
            valid_utterances.append([
                utt, speaker, index
            ])
        else:
            last_index = valid_utterances[-1][-1]
            if last_index < index < last_index+40:
                valid_utterances.append([
                utt, speaker, index
            ])
# Out:
# 100%|██████████| 325/325 [00:04<00:00, 68.55it/s]

# %%
for x in valid_utterances:
    print(x)
# Out:
# ['if a photon is directed through a plane with two slits in it and either slit is observed it will not go through both slits', 1, 397]
# ['if it is observed after it is left the plane but before it hits its target', 1, 399]
# ['what if she winds up with a toddler who does not know if he should use an integral or a differential to solve the area under a curve', 1, 426]
# ['i did a series of experiments when i was twelve', 1, 443]
# ['significant improvement over the old neighbour', 0, 449]
# ['you are inviting me over to eat', 4, 485]
# ['what do you guys do for fun around here', 4, 487]
# ['at least i did not have to invent twentysix dimensions just to make the math come out', 0, 501]
# ['it tells us that you participate in the mass cultural delusion that the sun is apparent position relative to arbitrarily defined constellations and the time of your birth somehow effects your personality', 1, 531]
# ['so do you have some sort of a job', 0, 539]
# ['you will only make it worse', 1, 563]
# ['but not of the same species', 1, 593]
# ['i am just trying to be a good neighbour', 0, 595]
# ['is there a trick to getting it to switch from tub to shower', 4, 621]
# ['i work at the cheesecake factory', 4, 627]
# ['i will show you the trick with the shower', 0, 628]
# ['we drive half way across town to retrieve a television set from the aforementioned woman is exboyfriend', 1, 652]
# ['why can not she get her own tv', 1, 660]
# ['there is some kind of dispute between penny and her exboyfriend as to who gets custody of the tv', 0, 667]
# ['she just wanted to avoid having a scene with him', 0, 668]

# %%
def get_optimal_wer_from_subtitle(ground_truth, hypothesis_pool):
    scores = []
    for i, x in enumerate(hypothesis_pool):
        hypothesis = x[0]
        scores.append(jiwer.compute_measures(ground_truth, hypothesis)['wer'])
    return min(scores), hypothesis_pool[scores.index(min(scores))], ground_truth, scores.index(min(scores))

# %%
# Alignment from Open Subtitle
valid_subtitles = []

for sub in subtitles:
    results = get_optimal_wer_from_subtitle(sub, utterances)
    if results[0] < 0.4:
        print("!!!!", results)
    else:
        print(results)
# Out:
# (0.8571428571428571, ["i wouldn't.", 1], 'i think that we can manage that', 8)
# (0.8, ['i want to leave.', 1], 'i am not going to take part in that nonsense', 12)
# (0.8333333333333334, ['so do you have some sort of a job?', 0], 'you do not live here iisakki it is not of your concern', 74)
# (1.0, ["agreed, what's your point?", 0], 'quit your yapping', 1)
# (1.0, ["agreed, what's your point?", 0], 'we will all take care of nikolas', 1)
# (0.75, ['participate in the what?', 4], 'beginning with the hannuses', 69)
# (0.9, ['i want to leave.', 1], 'the boy will move to the next family on christmas', 12)
# (1.0, ["i wouldn't.", 1], 'is this agreed', 8)
# (1.0, ['okay.', 0], 'yes', 13)
# (1.0, ["agreed, what's your point?", 0], 'merry christmas sister aada', 1)
# (0.8461538461538461, ['i have a board. if you like boards, this is my board.', 0], 'i could not forget my mother and my father  and my sister aada', 46)
# (0.8461538461538461, ["i just, i can't believe i trusted him.", 4], 'i knew they would not be coming back  but i missed them dearly', 85)
# (0.8571428571428571, ["that's a biological impossibility and you didn't have to come.", 0], 'but time heals the wounds  and by autumn the sadness began to fade away', 115)
# (0.8333333333333334, ['this is really impressive.', 4], 'my boat is broken fix it', 45)
# (1.0, ["agreed, what's your point?", 0], 'ask your father', 1)
# (1.0, ["agreed, what's your point?", 0], 'my father has gone fishing', 1)
# (1.0, ["agreed, what's your point?", 0], 'ask your mother then', 1)
# (1.0, ["agreed, what's your point?", 0], 'mother can not do it', 1)
# (0.75, ['i want to leave.', 1], 'give it to me', 12)
# (1.0, ["i wouldn't.", 1], 'turn boat', 8)
# (1.0, ["agreed, what's your point?", 0], 'it will not turn', 1)
# (0.875, ['well, it sounds wonderful.', 0], 'why does not it come here turn right', 78)
# (1.0, ["i wouldn't.", 1], 'there it goes', 8)
# (0.8571428571428571, ['you did not break up with joyce kim, she defected to north korea.', 1], 'i did not know it back then  but eemeli would become a good friend', 118)
# (0.8571428571428571, ['participate in the what?', 4], 'good throw it bounced off the water', 69)
# (0.8, ["i wouldn't.", 1], 'i found a great stone', 8)
# (1.0, ["agreed, what's your point?", 0], 'stretch your arm back and throw', 1)
# (0.8571428571428571, ['well, what do you want to do?', 0], 'you can do it one two three', 11)
# (1.0, ["agreed, what's your point?", 0], 'let us get another one', 1)
# (0.875, ["i wouldn't.", 1], 'then came the moment i had been dreading', 8)
# (0.8333333333333334, ['i want to leave.', 1], 'i had to move to another family for the very first time', 12)
# (0.8181818181818182, ['well, what do you want to do?', 0], 'are you sure you will find your way to the heinos', 11)
# (1.0, ["i wouldn't.", 1], 'bye bye', 8)
# (1.0, ["i wouldn't.", 1], 'bye bye', 8)
# (1.0, ["agreed, what's your point?", 0], 'years families and christmases came and went', 1)
# (0.8333333333333334, ['penny. i work at the cheesecake factory.', 4], 'every christmas i carved presents  for the children of my former families', 102)
# (0.8695652173913043, ['in all of them, that is the point.', 1], 'as the years passed there were so many of them  that i had to deliver the presents to their front doors at night', 50)
# (0.8125, ['i want to leave.', 1], 'it suited me fine  because i did not want to make a great fuss about it', 12)
# (0.8333333333333334, ['i want to leave.', 1], 'instead i acted ignorant  if someone came to thank me after christmas', 12)
# (0.8888888888888888, ['yes, but not of the same species.', 1], 'on my sixth year not everything went as planned', 93)
# (0.875, ["what's the protocol for leaving?", 1], 'that year was hard for the whole village', 14)
# (0.875, ['significant improvement over the old neighbour.', 0], 'early frost wiped out almost the entire crop', 21)
# (0.9090909090909091, ["what's the protocol for leaving?", 1], 'it was like the lake was empty of fish that year', 14)
# (1.0, ["agreed, what's your point?", 0], 'no fish today either', 1)
# (0.75, ['this is really impressive.', 4], 'that is right hilla', 45)
# (0.75, ['this is really impressive.', 4], 'that is a pity', 45)
# (0.8421052631578947, ['you did not break up with joyce kim, she defected to north korea.', 1], 'if things did not turn for the better  no family would be able to house me for the winter', 118)
# (0.75, ['in what universe?', 0], 'eemeli what is it', 49)
# (0.8333333333333334, ['this is really impressive.', 4], 'it is mad iisakki run away', 45)
# (0.8571428571428571, ["what's the protocol for leaving?", 1], 'get your homes in shipshape for christmas', 14)
# (1.0, ["i wouldn't.", 1], 'scoops ladles cups', 8)
# (0.8181818181818182, ['um, okay. can i ask you a favour.', 4], 'spatulas tubs and potato mashers i have everything you need here', 110)
# (0.8461538461538461, ['well, what do you want to do?', 0], 'and if i do not have it it can be made to order', 11)
# (1.0, ["i wouldn't.", 1], 'boy come here', 8)
# (0.8571428571428571, ['yes, but not of the same species.', 1], 'you have not bought this from me', 93)
# (0.9, ['do you want me to move?', 4], 'are you buying things from other carpenters instead of iisakki', 54)
# (0.8333333333333334, ['thank you, maybe we can have coffee sometime.', 4], 'a bad year we have no money we can barely feed ourselves', 29)
# (0.8571428571428571, ['do you want me to move?', 4], 'where did you buy this answer me', 54)
# (0.75, ["i wouldn't.", 1], 'i made it myself', 8)
# (1.0, ["agreed, what's your point?", 0], 'do not lie whippersnapper', 1)
# (0.8, ["the hair products are sheldon's.", 0], 'and whose boy are you', 109)
# (1.0, ["i wouldn't.", 1], 'nobody is', 8)
# (0.8666666666666667, ['do you want me to move?', 4], 'oh yeah you are the poor devil who is going around from house to house', 54)
# (0.75, ['participate in the what?', 4], 'where are the others', 69)
# (1.0, ["agreed, what's your point?", 0], 'at the village meeting', 1)
# (0.9, ['thank you, maybe we can have coffee sometime.', 4], 'what is so important that they must have a meeting', 29)
# (0.8461538461538461, ['well, what do you want to do?', 0], 'they are deciding what to do with me they can not afford me', 11)
# (0.8571428571428571, ['in all of them, that is the point.', 1], 'no wonder you must be such a glutton  that you have ruined the village', 50)
# (0.8571428571428571, ["i wouldn't.", 1], 'and now i can not sell anything', 8)
# (0.9, ["what's the protocol for leaving?", 1], 'you should have been cast into the lake get lost', 14)
# (0.8571428571428571, ['do you want me to move?', 4], 'but why you do not like children', 54)
# (0.8333333333333334, ['do you want me to move?', 4], 'he can help me at work', 54)
# (1.0, ["agreed, what's your point?", 0], 'we know you iisakki', 1)
# (0.8620689655172413, ['i have a board. if you like boards, this is my board.', 0], 'i was planning to shape that brat into a man within a year  but if my offer is not good enough for you there is nothing i can do', 46)
# (1.0, ["i wouldn't.", 1], 'wait iisakki', 8)
# (1.0, ["agreed, what's your point?", 0], 'maybe maybe we should consider it', 1)
# (0.8, ['i want to leave.', 1], 'there is nothing to consider', 12)
# (0.8823529411764706, ["oh, you're inviting me over to eat?", 4], 'he will be better off with me  than starving to death here in this poor village right', 38)
# (0.9, ["i wouldn't.", 1], 'this might be the last time i can visit you', 8)
# (1.0, ["agreed, what's your point?", 0], 'iisakki lives so far away', 1)
# (1.0, ["agreed, what's your point?", 0], 'merry christmas little aada', 1)
# (1.0, ["agreed, what's your point?", 0], 'nikolas come and see', 1)
# (1.0, ['okay.', 0], 'nikolas', 13)
# (0.8461538461538461, ['well, what do you want to do?', 0], 'it is been six years since you were orphaned and came to us', 11)
# (0.8823529411764706, ['well, what do you want to do?', 0], 'at first i was sorry that we could not find you a family  to take you in', 11)
# (0.8571428571428571, ["it's just a privilege to watch your mind at work.", 1], 'you had to go around from household to household one year at a time', 125)
# (0.8181818181818182, ["i resent you saying we don't have company.", 1], 'but now i believe that none of us have regretted it', 63)
# (0.8571428571428571, ['i want to leave.', 1], 'we all have gotten to know you', 12)
# (0.8888888888888888, ['well, what do you want to do?', 0], 'and so in a way you are our child', 11)
# (1.0, ["i wouldn't.", 1], 'and our brother', 8)
# (0.8823529411764706, ['well, what do you want to do?', 0], 'on behalf of all the villagers especially the children  we want to give you a little memento', 11)
# (0.6666666666666666, ["i wouldn't.", 1], 'i can not', 8)
# (1.0, ["agreed, what's your point?", 0], 'of course you can', 1)
# (0.8, ['i want to leave.', 1], 'the sledge belongs to you', 12)
# (0.7777777777777778, ['participate in the what?', 4], 'are you still loafing about get in the sleigh', 69)
# (0.8571428571428571, ['significant improvement over the old neighbour.', 0], 'or you can walk the whole way', 21)
# (0.875, ['i want to leave.', 1], 'you are not going to cry are you', 12)
# (1.0, ["agreed, what's your point?", 0], 'hilma trot along home before night falls', 1)
# (0.9, ['well, what do you want to do?', 0], 'what are you gawking at take hilma into the stall', 11)
# (0.875, ["i wouldn't.", 1], 'i will go inside and light the stove', 8)
# (0.7142857142857143, ['participate in the what?', 4], 'and leave this sledge in the stall', 69)
# (0.8181818181818182, ['well, what do you want to do?', 0], 'no mucking about here you came here to work get up', 11)
# (1.0, ["agreed, what's your point?", 0], 'and you sleep there', 1)
# (0.8888888888888888, ['well, what do you want to do?', 0], 'no buts did you forget whose house this is', 11)
# (0.8333333333333334, ['do you want me to move?', 4], 'and you will call me master', 54)
# (1.0, ["i wouldn't.", 1], 'yes master', 8)
# (1.0, ["agreed, what's your point?", 0], 'good your name is brat', 1)
# (0.8461538461538461, ['it took you four years to get through high school?', 1], 'it suits you better than nikolas take your bags in there move it', 83)
# (0.8333333333333334, ['i want to leave.', 1], 'wake up brat get to work', 12)
# (0.9, ['well, what do you want to do?', 0], 'let us get to the workshop you go on ahead', 11)
# (0.75, ['this is really impressive.', 4], 'where is the workshop', 45)
# (1.0, ["agreed, what's your point?", 0], 'you are standing on it', 1)
# (1.0, ["agreed, what's your point?", 0], 'take a look at this dresser', 1)
# (0.7142857142857143, ['participate in the what?', 4], 'the secret is in the wooden inlays', 69)
# (0.8181818181818182, ['this is really impressive.', 4], 'it is made of maple this is how i make money', 45)
# (0.9, ['well, what do you want to do?', 0], 'scoops and ladles are child is play compared to this', 11)
# (0.9090909090909091, ['i want to leave.', 1], 'these will go to parsons gentleman farmers and other wealthy people', 12)
# (0.8333333333333334, ['i want to leave.', 1], 'this will go to a judge', 12)
# (0.8333333333333334, ['this is really impressive.', 4], 'is this chair going there too', 45)
# (0.8, ['this is really impressive.', 4], 'it is made of pine this is made of maple', 45)
# (0.8333333333333334, ['do you want me to move?', 4], 'do not you recognise timber species', 54)
# (0.8333333333333334, ['i have a board. if you like boards, this is my board.', 0], 'maybe i made a mistake you are no good as a carpenter', 46)
# (0.8333333333333334, ['well, if that was a movie i would go see it.', 0], 'you have not made a mistake master i am a quick learner', 76)
# (0.8571428571428571, ['well, what do you want to do?', 0], 'a quick learner eh let us see how quickly you learn to tidy up', 11)
# (1.0, ["agreed, what's your point?", 0], 'get on with it', 1)
# (1.0, ["agreed, what's your point?", 0], 'where are you going', 1)
# (1.0, ['okay.', 0], 'upstairs', 13)
# (0.8333333333333334, ["we don't mean to interrupt, we live across the hall.", 0], 'you do not need to go upstairs to tidy up the workshop', 27)
# (0.875, ['i want to leave.', 1], 'there is no need to clean up here', 12)
# (0.8333333333333334, ['this is really impressive.', 4], 'the workbench is covered with dust', 45)
# (0.9230769230769231, ["what's the protocol for leaving?", 1], 'if it gets mixed with varnish or stain the whole work is ruined', 14)
# (1.0, ["i wouldn't.", 1], 'lesson number one', 8)
# (0.9166666666666666, ["oh, yeah, i'm a waitress at the cheesecake factory.", 4], 'the workshop will be kept tidy at all times no matter what', 75)
# (0.8571428571428571, ["agreed, what's your point?", 0], 'lesson number two hand me your sheathknife', 1)
# (0.875, ['this is really impressive.', 4], 'you do not use this on my timber', 45)
# (1.0, ["i wouldn't.", 1], 'do not', 8)
# (0.8, ['no, it was a valid hypothesis.', 0], 'it was my father is', 141)
# (1.0, ["agreed, what's your point?", 0], 'take a decent sheathknife from there', 1)
# (0.8333333333333334, ['participate in the what?', 4], 'remember to snuff out the candles', 69)
# (1.0, ["agreed, what's your point?", 0], 'it has no branches', 1)
# (0.8571428571428571, ["i wouldn't.", 1], 'how can i find my things now', 8)
# (1.0, ['okay.', 0], 'master', 13)
# (0.85, ["i just, i can't believe i trusted him.", 4], 'a year has passed and i have to go soon  so i thought that i would thank all the villagers', 85)
# (0.8571428571428571, ["i wouldn't.", 1], 'maybe i could take a day off', 8)
# (0.8461538461538461, ["uh, i'm sorry, do you speak english?", 4], 'when time is pressing  you do not waste time thinking you work harder', 120)
# (1.0, ["agreed, what's your point?", 0], 'a day off eh', 1)
# (0.8181818181818182, ['thanks. you guys are really sweet.', 4], 'what are you doing here why are not you in bed', 90)
# (0.8333333333333334, ['do you want me to move?', 4], 'have you stolen timber from me', 54)
# (0.8, ['well, it sounds wonderful.', 0], 'you threw it away master', 78)
# (0.7777777777777778, ['this is really impressive.', 4], 'so this is what you do behind my back', 45)
# (0.75, ["i wouldn't.", 1], 'i am sorry master', 8)
# (0.8, ['this is really impressive.', 4], 'it is not badly broken', 45)
# (0.8888888888888888, ["what's the protocol for leaving?", 1], 'bring me the wood drill and a headless nail', 14)
# (0.8571428571428571, ['participate in the what?', 4], 'why are you working in the dark it only results in duds and rejects', 69)
# (0.875, ['do you want me to move?', 4], 'now you can not tell it is broken', 54)
# (0.8333333333333334, ['just sit somewhere else.', 0], 'you have more toys somewhere right', 56)
# (0.8571428571428571, ['this is really impressive.', 4], 'you must really like those little brats', 45)
# (0.8333333333333334, ["and you want us out because you're anticipating coitus?", 2], 'did you plan to slip out to deliver presents  because i did not give you a day off', 98)
# (0.6, ['that is an antisocial implication.', 1], 'that is what i thought', 65)
# (0.8888888888888888, ['well, what do you want to do?', 0], 'go on then  but remember to return before sunrise', 11)
# (0.9, ["we don't mean to interrupt, we live across the hall.", 0], 'we do not idle away even though it is christmas', 27)
# (1.0, ['okay.', 0], 'master', 13)
# (0.875, ["i wouldn't.", 1], 'not a word i may change my mind', 8)
# (0.75, ['participate in the what?', 4], 'you can build your toys in the evenings', 69)
# (0.8461538461538461, ['uh, do you guys mind if i start?', 4], 'i might even help you at least now i can get some sleep', 51)
# (0.7777777777777778, ['participate in the what?', 4], 'building toys in the middle of the night humbug', 69)
# (0.8181818181818182, ['um, okay. can i ask you a favour.', 4], 'finally you showed up i thought you had gone into hibernation', 110)
# (0.75, ['participate in the what?', 4], 'i already put your junk in the sleigh', 69)
# (1.0, ["agreed, what's your point?", 0], 'what are you gawking at', 1)
# (0.8888888888888888, ['so do you have some sort of a job?', 0], 'you would not have made it back before sunrise', 74)
# (0.8, ["you're going to have to call her.", 1], 'the last workday would have gone to waste hop in', 128)
# (0.8, ['that is an antisocial implication.', 1], 'that was the last house', 65)
# (0.6666666666666666, ['this is really impressive.', 4], 'this is foolishness', 45)
# (0.8461538461538461, ["i resent you saying we don't have company.", 1], 'i can understand why you do this but an old man like me', 63)
# (1.0, ["agreed, what's your point?", 0], 'let us go home', 1)
# (0.8, ['this is really impressive.', 4], 'there is one more place', 45)
# (1.0, ["agreed, what's your point?", 0], 'hold on show me that', 1)
# (0.9090909090909091, ["i wouldn't.", 1], 'i made a horse like this when the boys were young', 8)
# (1.0, ["i wouldn't.", 1], 'what boys', 8)
# (0.8571428571428571, ["i wouldn't.", 1], 'i had two boys hermanni and henrik', 8)
# (0.9230769230769231, ["agreed, what's your point?", 0], 'and a wife marget she died when the boys were about your age', 1)
# (0.875, ["and you want us out because you're anticipating coitus?", 2], 'then they went to sea and left me all alone  because i had become like this', 98)
# (0.875, ["i wouldn't.", 1], 'i see henrik and hermanni in all children', 8)
# (0.75, ['i want to leave.', 1], 'that is why i am mean to children', 12)
# (0.8, ["i wouldn't.", 1], 'i still miss my boys', 8)
# (0.8181818181818182, ['i want to leave.', 1], 'what i mean to say is you could stay with me', 12)
# (1.0, ["i wouldn't.", 1], 'merry christmas nikolas', 8)
# (0.8571428571428571, ['this is really impressive.', 4], 'my father is sheathknife thank you master', 45)
# (0.875, ['well, what do you want to do?', 0], 'from now on you can call me iisakki', 11)
# (1.0, ["i wouldn't.", 1], 'merry christmas aada', 8)
# (1.0, ["i wouldn't.", 1], 'merry christmas aada', 8)
# (1.0, ["i wouldn't.", 1], 'merry christmas iisakki', 8)
# (1.0, ["i wouldn't.", 1], 'merry christmas nikolas', 8)
# (0.6666666666666666, ['that is an antisocial implication.', 1], 'that is enough let us go', 65)
# (0.9, ["what's the protocol for leaving?", 1], 'that christmas changed everything the village overcame the bad years', 14)
# (1.0, ["agreed, what's your point?", 0], 'my vagabond life was over', 1)
# (0.7692307692307693, ["that's a biological impossibility and you didn't have to come.", 0], 'iisakki provided me a home that i did not have to give up', 115)
# (0.75, ['do you want me to move?', 4], 'thank you very much good day to you', 54)
# (0.75, ['i want to leave.', 1], 'good day to you', 12)
# (1.0, ["agreed, what's your point?", 0], 'come and buy a dresser', 1)
# (0.8333333333333334, ["the hair products are sheldon's.", 0], 'the years with iisakki passed quickly', 109)
# (0.7857142857142857, ['it was. until i fell in love with a jerk.', 4], 'before i knew it i was all grown up with a beard and all', 79)
# (1.0, ["agreed, what's your point?", 0], 'the village had grown', 1)
# (0.9285714285714286, ["i don't care. two millimetres? that doesn't seem right.", 0], 'there were so many new children  that me and iisakki could not keep count', 17)
# (0.8333333333333334, ['no, it was a valid hypothesis.', 0], 'but we had a secret helper', 141)
# (1.0, ['okay.', 0], 'nikolas', 13)
# (1.0, ['okay.', 0], 'eemeli', 13)
# (0.8888888888888888, ['well, what do you want to do?', 0], 'long time no see you should come more often', 11)
# (0.8888888888888888, ["i wouldn't.", 1], 'i have been busy iisakki is no longer young', 8)
# (0.8, ['do you want me to move?', 4], 'do you have the list', 54)
# (0.875, ["i wouldn't.", 1], 'well i will be so many new children', 8)
# (0.8461538461538461, ['in all of them, that is the point.', 1], 'as a matter of fact one name is missing from that list elsa', 50)
# (1.0, ["i wouldn't.", 1], 'is that', 8)
# (1.0, ["agreed, what's your point?", 0], 'a girl three months', 1)
# (0.8571428571428571, ['i want to leave.', 1], 'let us add her to the list', 12)
# (0.875, ["what's the protocol for leaving?", 1], 'what is the name of this little princess', 14)
# (1.0, ['okay.', 0], 'aada', 13)
# (1.0, ['okay.', 0], 'aada', 13)
# (1.0, ["i wouldn't.", 1], 'hello aada', 8)
# (1.0, ["agreed, what's your point?", 0], 'nikolas meet henrik and hermanni', 1)
# (1.0, ["i wouldn't.", 1], 'my sons', 8)
# (0.875, ["i wouldn't.", 1], 'i sought them out and asked them here', 8)
# (1.0, ["agreed, what's your point?", 0], 'we were wrong when we', 1)
# (0.7777777777777778, ['i want to leave.', 1], 'we want to make it up to our father', 12)
# (0.7777777777777778, ["you're going to have to call her.", 1], 'we came to take him to live with us', 128)
# (1.0, ["agreed, what's your point?", 0], 'to live with you where', 1)
# (0.9230769230769231, ['well, what do you want to do?', 0], 'away from here father is too old to be living in arctic conditions', 11)
# (0.8333333333333334, ["that's a biological impossibility and you didn't have to come.", 0], 'you will get the house and the workshop you have earned them', 115)
# (1.0, ["i wouldn't.", 1], 'wait nikolas', 8)
# (1.0, ['okay.', 0], 'nikolas', 13)
# (0.75, ['i want to leave.', 1], 'nikolas try to understand', 12)
# (0.8888888888888888, ["i wouldn't.", 1], 'even though i love you like my own son', 8)
# (0.875, ["what's the protocol for leaving?", 1], 'this key opens the chest under my bed', 14)
# (0.8888888888888888, ["i wouldn't.", 1], 'i have always been skimpy maybe too much so', 8)
# (0.8333333333333334, ["i wouldn't.", 1], 'i think you can do better', 8)
# (1.0, ["i wouldn't.", 1], 'try to understand', 8)
# (1.0, ['okay.', 0], 'eemeli', 13)
# (1.0, ['okay.', 0], 'nikolas', 13)
# (1.0, ["agreed, what's your point?", 0], 'where have you been', 1)
# (1.0, ["agreed, what's your point?", 0], 'here but everything is unfinished', 1)
# (0.8333333333333334, ["what's the protocol for leaving?", 1], 'these should last for ten years', 14)
# (0.7142857142857143, ['this is really impressive.', 4], 'this is barely enough for next christmas', 45)
# (1.0, ["i wouldn't.", 1], 'a map', 8)
# (0.7777777777777778, ["you're going to have to call her.", 1], 'there there to this remote village to these houses', 128)
# (1.0, ["agreed, what's your point?", 0], 'there there there there there christmas presents', 1)
# (1.0, ["i wouldn't.", 1], 'christmas presents', 8)
# (0.8461538461538461, ['well, what do you want to do?', 0], 'so many villages and children how do you know who will get what', 11)
# (0.8, ['this is really impressive.', 4], 'there is a simple way', 45)
# (1.0, ["i wouldn't.", 1], 'what is it', 8)
# (0.8571428571428571, ["i wouldn't.", 1], 'i shall write names on the wrapping', 8)
# (1.0, ['okay.', 0], 'wrapping', 13)
# (0.75, ['this is really impressive.', 4], 'ingenious is not it', 45)
# (0.8, ['this is really impressive.', 4], 'how is all this possible', 45)
# (0.75, ['this is really impressive.', 4], 'iisakki is life savings', 45)
# (0.7777777777777778, ['i want to leave.', 1], 'now i can bring christmas cheer to the children', 12)
# (0.8333333333333334, ["what's the protocol for leaving?", 1], 'nobody can live just for christmas', 14)
# (0.8666666666666667, ['i want to leave.', 1], 'i have been selfish i have only brought presents to those  who have helped me', 12)
# (1.0, ['okay.', 0], 'selfish', 13)
# (0.8333333333333334, ['i want to leave.', 1], 'from now on i am going to appear only on christmas eve', 12)
# (1.0, ['okay.', 0], 'nikolas', 13)
# (0.85, ['sheldon, this was your idea. a little extra money to get fractional t1 bandwidth in the apartment.', 0], 'i will visit your shop once a year  to replenish my supplies and to get a list of new children', 5)
# (0.875, ['i want to leave.', 1], 'there is more to life than just christmas', 12)
# (1.0, ["i wouldn't.", 1], 'like what', 8)
# (0.6, ['that is an antisocial implication.', 1], 'it is an impossible task', 65)
# (0.7777777777777778, ['so do you have some sort of a job?', 0], 'you do not have room for all those presents', 74)
# (0.9, ['well, what do you want to do?', 0], 'and hilma will not be able to pull the load', 11)
# (1.0, ["agreed, what's your point?", 0], 'it can not be done', 1)
# (1.0, ["i wouldn't.", 1], 'yes it can', 8)
# (0.8, ['this is really impressive.', 4], 'christmas is around the corner', 45)
# (0.8, ['i want to leave.', 1], 'animals are quick to learn', 12)
# (1.0, ["agreed, what's your point?", 0], 'reindeer are not horses', 1)
# (0.6666666666666666, ['this is really impressive.', 4], 'hilla this is child is play', 45)
# (0.8571428571428571, ["i wouldn't.", 1], 'i can handle reindeer dear reindeer dear', 8)
# (1.0, ["i wouldn't.", 1], 'you can try', 8)
# (0.9090909090909091, ["i wouldn't.", 1], 'reindeer obey me better when i am wearing this colourful cap', 8)
# (0.9, ["what's the protocol for leaving?", 1], 'even the squirrels are afraid of such a garish colour', 14)
# (0.8461538461538461, ['i have a board. if you like boards, this is my board.', 0], 'reindeer would obey me even if i had a potholder on my head', 46)
# (0.8571428571428571, ["i wouldn't.", 1], 'i do not need any red caps', 8)
# (0.875, ["agreed, what's your point?", 0], 'okay fall in line put your antlers down', 1)
# (1.0, ["agreed, what's your point?", 0], 'come to nikolas chopchop', 1)
# (0.875, ["agreed, what's your point?", 0], 'dasher dancer prancer and blitzen your training begins', 1)
# (0.8571428571428571, ["the hair products are sheldon's.", 0], 'the first lesson lassoing dancer behave yourself', 109)
# (1.0, ["i wouldn't.", 1], 'sit there', 8)
# (1.0, ["i wouldn't.", 1], 'sit sit stay', 8)
# (0.9090909090909091, ['well, what do you want to do?', 0], 'dasher if you do not behave nikolas will catch you prancer', 11)
# (1.0, ["agreed, what's your point?", 0], 'let us try again', 1)
# (1.0, ["i wouldn't.", 1], 'hold it', 8)
# (1.0, ["i wouldn't.", 1], 'dancer prancer', 8)
# (0.8181818181818182, ["that's a biological impossibility and you didn't have to come.", 0], 'a red cap a red coat and frieze trousers to boot', 115)
# (0.75, ['participate in the what?', 4], 'what was the colour', 69)
# (1.0, ['okay.', 0], 'red', 13)
# (1.0, ["agreed, what's your point?", 0], 'could you repeat that', 1)
# (1.0, ['okay.', 0], 'red', 13)
# (0.75, ["i wouldn't.", 1], 'i will show you', 8)
# (0.7777777777777778, ['well, what do you want to do?', 0], 'let us see aada what do you have there', 11)
# (1.0, ["i wouldn't.", 1], 'a spinning top', 8)
# (1.0, ["i wouldn't.", 1], 'that is nice', 8)
# (0.8571428571428571, ['in all of them, that is the point.', 1], 'in a few years the mysterious presentbearer  became the staple of children is stories', 50)
# (0.8, ["you're going to have to call her.", 1], 'some swore to have seen elves bringing presents at christmas', 128)
# (0.9, ["what's the protocol for leaving?", 1], 'others claimed that the presents were from a childfriendly gnome', 14)
# (1.0, ["agreed, what's your point?", 0], 'luckily they did not suspect me', 1)
# (1.0, ["i wouldn't.", 1], 'nikolas is coming', 8)
# (1.0, ["i wouldn't.", 1], 'run away', 8)
# (1.0, ["i wouldn't.", 1], 'good day', 8)
# (0.75, ['participate in the what?', 4], 'where are the others', 69)
# (1.0, ["agreed, what's your point?", 0], 'they are afraid of you', 1)
# (0.8461538461538461, ['that is an antisocial implication.', 1], 'mikko said that it is not you who brings us presents at christmas', 65)
# (0.8571428571428571, ['this is really impressive.', 4], 'that you hate children is it true', 45)
# (0.75, ['this is really impressive.', 4], 'mikko is half right', 45)
# (0.8333333333333334, ['uh, do you guys mind if i start?', 4], 'i do not bring presents but i do not hate children either', 51)
# (0.75, ['participate in the what?', 4], 'who brings the presents', 69)
# (0.8571428571428571, ["i wouldn't.", 1], 'nikolas told me when i asked him', 8)
# (0.8888888888888888, ['well, what do you want to do?', 0], 'aada claims that you do not bring us presents', 11)
# (1.0, ["i wouldn't.", 1], 'aada is right', 8)
# (1.0, ['okay.', 0], 'aada', 13)
# (0.8888888888888888, ["oh, that's so nice, i'd love to.", 4], 'why did you say so tell her the truth', 40)
# (0.8, ["come on, i'll show you the trick with the shower.", 0], 'no way children must not associate me with the presents', 103)
# (1.0, ["agreed, what's your point?", 0], 'it would ruin everything', 1)
# (1.0, ["i wouldn't.", 1], 'why is that', 8)
# (1.0, ['okay.', 0], 'nikolas', 13)
# (1.0, ['okay.', 0], 'eemeli', 13)
# (1.0, ["i wouldn't.", 1], 'is aada here', 8)
# (1.0, ["agreed, what's your point?", 0], 'aada has gone missing', 1)
# (1.0, ["agreed, what's your point?", 0], 'dear mother and father do not worry', 1)
# (0.8, ['i want to leave.', 1], 'i went to find out  who brings all the presents', 12)
# (0.9090909090909091, ['i want to leave.', 1], 'we have to wake everybody up and arrange a search party', 12)
# (0.9090909090909091, ["i wouldn't.", 1], 'you must lend me some clothes otherwise i will be exposed', 8)
# (1.0, ["agreed, what's your point?", 0], 'okay boys hurry on home', 1)
# (0.8571428571428571, ["he's kind of a nerd. juice box?", 2], 'let us form groups of two a torch and a lantern for each group', 123)
# (0.8888888888888888, ['so do you have some sort of a job?', 0], 'aada could not have gone far let us hurry', 74)
# (0.8, ["i wouldn't.", 1], 'i know where she is', 8)
# (1.0, ["agreed, what's your point?", 0], 'what did you say mikko', 1)
# (0.8571428571428571, ['i want to leave.', 1], 'aada wants to deliver you a present', 12)
# (1.0, ["i wouldn't.", 1], 'me why', 8)
# (0.9090909090909091, ['well, what do you want to do?', 0], 'aada does not believe that you do not bring us presents', 11)
# (0.8571428571428571, ['well, what do you want to do?', 0], 'why did not you tell us earlier', 11)
# (0.6, ['i want to leave.', 1], 'i promised not to tell', 12)
# (1.0, ["i wouldn't.", 1], 'will aada return', 8)
# (0.8571428571428571, ["um, penny, that's where i sit.", 1], 'aada does not know where you live', 52)
# (0.8, ["oh, i don't think i'll be able to stop thinking about it.", 4], 'and even if she knew  she will not be able to walk that far aada', 132)
# (1.0, ['okay.', 0], 'nikolas', 13)
# (1.0, ['okay.', 0], 'aada', 13)
# (0.8, ['well, what do you want to do?', 0], 'nobody thought that you would manage to get this far', 11)
# (0.8888888888888888, ['this is really impressive.', 4], 'twelve miles in a blizzard how is it possible', 45)
# (0.7142857142857143, ['no, it was a valid hypothesis.', 0], 'it was nothing on a reindeer sleigh', 141)
# (1.0, ["i wouldn't.", 1], 'a reindeer sleigh', 8)
# (1.0, ["i wouldn't.", 1], 'what reindeer sleigh', 8)
# (1.0, ["agreed, what's your point?", 0], 'suddenly a sleigh appeared', 1)
# (0.8461538461538461, ["i resent you saying we don't have company.", 1], 'i thought it was you but the sleigh was empty well not quite', 63)
# (0.8666666666666667, ["i don't know, i've never reneged on a proffer of sperm before.", 0], 'i was cold so i put on your clothes then the reindeer brought me here', 15)
# (0.75, ["i wouldn't.", 1], 'i told aada everything', 8)
# (0.8947368421052632, ['i want to leave.', 1], 'how i would become the way i am  and why it was so important to deliver presents at christmas', 12)
# (0.8571428571428571, ["i just, i can't believe i trusted him.", 4], 'i even revealed my dream of continuing this tradition  when i would be gone', 85)
# (0.875, ["he's kind of a nerd. juice box?", 2], 'what kind of girl would aada be now if she had not become a water nymph', 123)
# (1.0, ["agreed, what's your point?", 0], 'hopefully she would be like you', 1)
# (1.0, ["agreed, what's your point?", 0], 'aada kept her promise', 1)
# (0.8888888888888888, ['in all of them, that is the point.', 1], 'she did not reveal my secret quite the opposite', 50)
# (1.0, ["agreed, what's your point?", 0], 'he did not look like nikolas', 1)
# (0.9090909090909091, ['significant improvement over the old neighbour.', 0], 'he was a wrinkly old man  who called himself christmas codger', 21)
# (0.8823529411764706, ['it was. until i fell in love with a jerk.', 4], 'the years passed and before i knew it  my friendship with aada had lasted almost twenty years', 79)
# (1.0, ['okay.', 0], 'nikolas', 13)
# (1.0, ['okay.', 0], 'well', 13)
# (0.75, ["i wouldn't.", 1], 'i am getting married', 8)
# (1.0, ["i wouldn't.", 1], 'to mikko', 8)
# (0.7777777777777778, ['do you want me to move?', 4], 'nikolas will you pick me up on christmas morning', 54)
# (0.75, ["i wouldn't.", 1], 'of course i will', 8)
# (1.0, ["i wouldn't.", 1], 'for what', 8)
# (1.0, ["i wouldn't.", 1], 'for everything', 8)
# (0.8461538461538461, ['in all of them, that is the point.', 1], 'fear of losing love is part of love it is part of life', 50)
# (1.0, ["agreed, what's your point?", 0], 'your father eemeli taught me that', 1)
# (0.7, ['come on, you know how it is with breakups.', 0], 'you have taught me how wonderful it is to give', 117)
# (0.8, ['so do you have some sort of a job?', 0], 'nikolas maybe you should think of yourself for a change', 74)
# (1.0, ["i wouldn't.", 1], 'nothing lasts forever', 8)
# (0.8181818181818182, ["oh, you're inviting me over to eat?", 4], 'it was time for me to give in to my years', 38)
# (0.8888888888888888, ["what's the protocol for leaving?", 1], 'next christmas would be the last my last christmas', 14)
# (0.8571428571428571, ['this is really impressive.', 4], 'it is beautiful who is it for', 45)
# (0.8333333333333334, ["i wouldn't.", 1], 'can i gift wrap it no', 8)
# (0.5, ['i want to leave.', 1], 'i want to do it myself', 12)
# (1.0, ["agreed, what's your point?", 0], 'see you on christmas morning', 1)
# (0.8181818181818182, ['well, what do you want to do?', 0], 'are you sure you do not want any help at christmas', 11)
# (0.625, ['i want to leave.', 1], 'yes i want to do my rounds alone', 12)
# (0.7777777777777778, ['this is really impressive.', 4], 'nikolas remember your promise this is the last christmas', 45)
# (0.6, ['this is really impressive.', 4], 'this is the last christmas', 45)
# (1.0, ['okay.', 0], 'nikolas', 13)
# (0.875, ["agreed, what's your point?", 0], 'merry christmas to little aada your brother nikolas', 1)
# (0.8571428571428571, ['yes, but not of the same species.', 1], 'we will not be seeing nikolas again', 93)
# (0.875, ["i wouldn't.", 1], 'i can not explain i just know it', 8)
# (0.9090909090909091, ['well, what do you want to do?', 0], 'what are you doing there is no sense in doing that', 11)
# (0.8, ['i want to leave.', 1], 'nikolas wanted this to continue', 12)
# (0.8888888888888888, ['save it for your blog, howard.', 0], 'a present for our nikolas will disappoint other children', 106)
# (0.8333333333333334, ['this is really impressive.', 4], 'other fathers have done this too it is not the same thing', 45)
# (0.75, ['uh, that sounds interesting.', 4], 'mikko that is cheating', 130)
# (1.0, ['okay.', 0], 'mikko', 13)
# (1.0, ["agreed, what's your point?", 0], 'merry christmas little aada', 1)
# (1.0, ["i wouldn't.", 1], 'merry christmas nikolas', 8)
# (1.0, ["agreed, what's your point?", 0], 'dasher dancer prancer and blitzen ahoy', 1)
# (1.0, ["i wouldn't.", 1], 'merry christmas', 8)
# (0.8695652173913043, ['hey, is there a trick to getting it to switch from tub to shower. oh. hi, sorry. hello!', 4], 'if a photon is directed through a plane with two slits in it and either is observed it will not go through both', 99)
# (1.0, ["agreed, what's your point?", 0], 'if unobserved it will', 1)
# (0.9285714285714286, ["what's the protocol for leaving?", 1], 'if it is observed after it left the plane before it hits its target', 14)
# (0.875, ['yes, but not of the same species.', 1], 'it will not have gone through both slits', 93)
# (0.8, ["agreed, what's your point?", 0], 'agreed what is your point', 1)
# (0.4, ["there's no point, i just think it's a good idea for a t-shirt.", 1], 'there is no point i just think it is a good idea for a tshirt', 2)
# (0.875, ['this is really impressive.', 4], 'one across is aegean eight down is nabokov', 45)
# (1.0, ["agreed, what's your point?", 0], 'twentysix across is mcm', 1)
# (0.8333333333333334, ["agreed, what's your point?", 0], 'fourteen down is move your finger', 1)
# (1.0, ["agreed, what's your point?", 0], 'phylum which makes 14 across portauprince', 1)
# (0.8888888888888888, ['this is really impressive.', 4], 'see papa doc is capital idea that is portauprince', 45)
# (1.0, ['okay.', 0], 'haiti', 13)
# (0.8, ["i wouldn't.", 1], 'can i help you  yes', 8)
# (0.8571428571428571, ["what's the protocol for leaving?", 1], 'um is this the highiq sperm bank', 14)
# (0.8181818181818182, ["oh, good. then you won't be disappointed.", 1], 'if you have to ask maybe you should not be here', 91)
# (0.6666666666666666, ['this is really impressive.', 4], 'i think this is the place', 45)
# (1.0, ["agreed, what's your point?", 0], 'fill these out  thank you', 1)
# (1.0, ["agreed, what's your point?", 0], 'we will be right back', 1)
# (0.9090909090909091, ["agreed, what's your point?", 0], 'oh take your time i will just finish my crossword puzzle', 1)
# (1.0, ["i wouldn't.", 1], 'oh wait', 8)
# (0.8888888888888888, ["i wouldn't.", 1], 'leonard i do not think i can do this', 8)
# (1.0, ["agreed, what's your point?", 0], 'what are you kidding', 1)
# (1.0, ["agreed, what's your point?", 0], 'we are committing genetic fraud', 1)
# (0.8666666666666667, ["you're welcome, oh, you're going to step right, okay, i'll....", 0], 'there is no guarantee our sperm is going to generate highiq offspring think about that', 107)
# (0.7857142857142857, ['i have a board. if you like boards, this is my board.', 0], 'i have a sister with the same basic dna mix who hostesses at fuddruckers', 46)
# (0.8, ["agreed, what's your point?", 0], 'sheldon this was your idea', 1)
# (0.5, ['sheldon, this was your idea. a little extra money to get fractional t1 bandwidth in the apartment.', 0], 'a little extra money to get fractional t1 bandwidth in the apartment', 5)
# (0.7777777777777778, ["i just, i can't believe i trusted him.", 4], 'i know and i do yearn for faster downloads', 85)
# (0.9285714285714286, ['this is really impressive.', 4], 'there is some poor woman who is gonna pin her hopes on my sperm', 45)
# (0.8846153846153846, ["there's no point, i just think it's a good idea for a t-shirt.", 1], 'what if she winds up with a toddler who does not know if he should use a differential to solve for the area under a curve', 2)
# (0.625, ["i'm sure she'll still love him.", 0], 'i am sure she will still love him', 7)
# (0.6666666666666666, ["i wouldn't.", 1], 'i would not', 8)
# (0.6666666666666666, ['well, what do you want to do?', 0], 'well what do you wanna do', 11)
# !!!! (0.25, ['i want to leave.', 1], 'i want to leave', 12)
# (0.7, ["what's the protocol for leaving?", 1], 'what is the protocol for leaving  i do not know', 14)
# (0.4, ["i don't know, i've never reneged on a proffer of sperm before.", 0], 'i have never reneged on a proffer of sperm before', 15)
# (1.0, ["agreed, what's your point?", 0], 'let us try just walking out', 1)
# (1.0, ["i wouldn't.", 1], 'bye  byebye', 8)
# (1.0, ["i wouldn't.", 1], 'nice meeting you', 8)
# (0.875, ['significant improvement over the old neighbour.', 0], 'are you still mad about the sperm bank', 21)
# (0.875, ['that is an antisocial implication.', 1], 'you wanna hear an interesting thing about stairs', 65)
# (1.0, ["i wouldn't.", 1], 'not really', 8)
# !!!! (0.16666666666666666, ['if the height of a single step is off by as little as two millimetres, most people will trip.', 1], 'if the height of a step is off by as little as two millimeters  most people will trip', 16)
# (0.75, ["i wouldn't.", 1], 'i do not care', 8)
# (0.8571428571428571, ['that is an antisocial implication.', 1], 'two millime that does not seem right', 65)
# (1.0, ["i wouldn't.", 1], 'it is true', 8)
# (0.8, ["i just, i can't believe i trusted him.", 4], 'i did a series of experiments when i was 12', 85)
# (1.0, ["agreed, what's your point?", 0], 'my father broke his clavicle', 1)
# (0.9, ['well, what do you want to do?', 0], 'is that why they sent you to boarding school no', 11)
# (0.8888888888888888, ["what's the protocol for leaving?", 1], 'that was the result of my work with lasers', 14)
# (0.6666666666666666, ['new neighbour?', 0], 'new neighbor sheldon', 19)
# (1.0, ['okay.', 0], 'evidently', 13)
# !!!! (0.16666666666666666, ['significant improvement over the old neighbour.', 0], 'significant improvement over the old neighbor', 21)
# (0.4, ['two hundred pound transvestite with a skin condition, yes she is.', 1], 'twohundred pound transvestite with a skin condition yes she is', 22)
# (1.0, ["i wouldn't.", 1], 'oh hi', 8)
# (1.0, ['okay.', 0], 'hi', 13)
# !!!! (0.36363636363636365, ["we don't mean to interrupt, we live across the hall.", 0], 'we do not mean to interrupt we live across the hall', 27)
# (0.75, ['uh, that sounds interesting.', 4], 'oh that is nice', 130)
# (1.0, ["agreed, what's your point?", 0], 'no we do not live together', 1)
# (0.9, ["i wouldn't.", 1], 'i mean we live together but in separate heterosexual bedrooms', 8)
# (0.8888888888888888, ["agreed, what's your point?", 0], 'okay well guess i am your new neighbor  penny', 1)
# (1.0, ["i wouldn't.", 1], 'leonard sheldon', 8)
# (0.8333333333333334, ['i want to leave.', 1], 'well oh welcome to the building', 12)
# !!!! (0.3333333333333333, ['thank you, maybe we can have coffee sometime.', 4], 'oh thank you maybe we can have coffee sometime', 29)
# (1.0, ["i wouldn't.", 1], 'oh great', 8)
# (1.0, ["i wouldn't.", 1], 'well bye', 8)
# (0.875, ["what's the protocol for leaving?", 1], 'should we have invited her for lunch no', 14)
# (0.8888888888888888, ['so do you have some sort of a job?', 0], 'we are gonna start season two of battlestar galactica', 74)
# (0.8571428571428571, ["what's the protocol for leaving?", 1], 'we already watched the season two dvds', 14)
# (1.0, ["i wouldn't.", 1], 'not with commentary', 8)
# (0.9285714285714286, ["i wouldn't.", 1], 'i think we should be good neighbors invite her over make her feel welcome', 8)
# (1.0, ["agreed, what's your point?", 0], 'we never invited louielouise over', 1)
# (0.8571428571428571, ['that is an antisocial implication.', 1], 'well and that was wrong of us', 65)
# (0.8333333333333334, ['i want to leave.', 1], 'we need to widen our circle', 12)
# (0.8333333333333334, ["i wouldn't.", 1], 'i have a very wide circle', 8)
# (0.8333333333333334, ["i wouldn't.", 1], 'i have 212 friends on myspace', 8)
# (0.7777777777777778, ['so do you have some sort of a job?', 0], 'yes and you have never met one of them', 74)
# (0.6666666666666666, ['that is an antisocial implication.', 1], 'that is the beauty of it', 65)
# (0.8333333333333334, ["i wouldn't.", 1], 'i am gonna invite her over', 8)
# (0.875, ["he's kind of a nerd. juice box?", 2], 'we will have a nice meal and chat', 123)
# (0.875, ['uh, do you guys mind if i start?', 4], 'we do not chat at least not offline', 51)
# (0.8, ['this is really impressive.', 4], 'well it is not difficult', 45)
# (0.8666666666666667, ['well, what do you want to do?', 0], 'you just listen to what she says and then you say something appropriate in response', 11)
# (0.6666666666666666, ['in what universe?', 0], 'to what end', 49)
# (1.0, ["i wouldn't.", 1], 'hi again  hi', 8)
# (0.9090909090909091, ["there's no point, i just think it's a good idea for a t-shirt.", 1], 'anyway we brought home indian food and i know that moving can be stressful and i find that when i am undergoing stress that good food and company can have a comforting effect', 2)
# (0.8571428571428571, ['i have a board. if you like boards, this is my board.', 0], 'also curry is a natural laxative and i do not have to tell you that you know a clean colon is just one less thing to worry about', 46)
# (0.5238095238095238, ["leonard, i'm not expert here but i believe in the context of a luncheon invitation, you might want to skip the reference to bowel movements.", 1], 'i am no expert but in the context of a lunch invitation you might wanna skip the reference to bowel movements', 37)
# (0.5, ["oh, you're inviting me over to eat?", 4], 'oh you are inviting me over to eat', 38)
# (0.7777777777777778, ["oh, that's so nice, i'd love to.", 4], 'oh that is so nice i would love to', 40)
# !!!! (0.2, ['so, what do you guys do for fun around here?', 4], 'so what do you guys do for fun around here', 42)
# (0.8571428571428571, ["what's the protocol for leaving?", 1], 'well today we tried masturbating for money', 14)
# (1.0, ["agreed, what's your point?", 0], 'okay well make yourself at home', 1)
# (0.9090909090909091, ['this is really impressive.', 4], 'this looks like some serious stuff leonard did you do this', 45)
# (0.8, ['this is really impressive.', 4], 'actually that is my work', 45)
# (0.8823529411764706, ["there's no point, i just think it's a good idea for a t-shirt.", 1], 'yeah well it is just some quantum mechanics with a little string theory doodling around the edges', 2)
# (0.75, ['yes, but not of the same species.', 1], 'it is a spoof of the bornoppenheimer approximation', 93)
# (0.45454545454545453, ["so you're like, one of those, beautiful mind genius guys.", 4], 'so you are like one of those beautiful mind genius guys', 43)
# (1.0, ['okay.', 0], 'yeah', 13)
# !!!! (0.25, ['this is really impressive.', 4], 'this is really impressive', 45)
# !!!! (0.25, ['i have a board. if you like boards, this is my board.', 0], 'i have a board if you like boards this is my board', 46)
# (1.0, ["i wouldn't.", 1], 'holy smokes', 8)
# (0.8888888888888888, ['i have a board. if you like boards, this is my board.', 0], 'if by holy smokes you mean a derivative restatement of the stuff you can find scribbled on the wall of any men is room at mit sure', 46)
# (0.9090909090909091, ["i wouldn't.", 1], 'who has not seen this differential below here i sit brokenhearted', 8)
# !!!! (0.23529411764705882, ["at least i didn't have to invent twenty-six dimensions just to make the math come out.", 0], 'at least i did not have to invent 26 dimensions just to make the math come out', 47)
# (0.75, ["i didn't invent them, they're there.", 1], 'i did not invent them they are there', 48)
# !!!! (0.3333333333333333, ['in what universe?', 0], 'in what universe', 49)
# !!!! (0.25, ['in all of them, that is the point.', 1], 'in all of them that is the point', 50)
# !!!! (0.2857142857142857, ['uh, do you guys mind if i start?', 4], 'do you guys mind if i start', 51)
# (1.0, ["i wouldn't.", 1], 'penny  yeah', 8)
# (0.6, ['that is an antisocial implication.', 1], 'that is where i sit', 65)
# (0.8, ['i want to leave.', 1], 'so sit next to me', 12)
# (0.75, ["i wouldn't.", 1], 'no i sit there', 8)
# (1.0, ["i wouldn't.", 1], 'here we go', 8)
# (0.9047619047619048, ['in all of them, that is the point.', 1], 'in winter that seat is close enough to the radiator to remain warm yet not so close as to cause perspiration', 50)
# (0.875, ['hang on, there really is a lady here?', 2], 'in the summer it is in a cross breeze created by opening windows there and there', 96)
# (0.9130434782608695, ['if the height of a single step is off by as little as two millimetres, most people will trip.', 1], 'it faces the television at an angle that is neither direct discouraging conversation nor so far wide as to create a parallax distortion', 16)
# (0.8333333333333334, ['i have a board. if you like boards, this is my board.', 0], 'i could go on but i think i have made my point', 46)
# !!!! (0.16666666666666666, ['do you want me to move?', 4], 'do you want me to move', 54)
# !!!! (0.25, ['just sit somewhere else.', 0], 'just sit somewhere else', 56)
# (1.0, ["i wouldn't.", 1], 'sheldon sit', 8)
# (0.75, ['this is really impressive.', 4], 'well this is nice', 45)
# (0.6666666666666666, ['so do you have some sort of a job?', 0], 'we do not have a lot of company over', 74)
# (0.7777777777777778, ['that is an antisocial implication.', 1], 'that is not true koothrappali and wolowitz come over', 65)
# (0.6666666666666666, ["i wouldn't.", 1], 'yes i know', 8)
# (0.8181818181818182, ['participate in the what?', 4], 'tuesday night we played klingon boggle until 1 in the morning', 69)
# (0.6666666666666666, ["i wouldn't.", 1], 'yeah i remember', 8)
# !!!! (0.3333333333333333, ["i resent you saying we don't have company.", 1], 'i resent you saying we do not have company', 63)
# (0.8333333333333334, ['that is an antisocial implication.', 1], 'that has a negative social implication', 65)
# (0.6, ["i said i'm sorry.", 0], 'i said i am sorry', 66)
# (0.6666666666666666, ['so, klingon boggle?', 4], 'so klingon boggle', 67)
# (0.8888888888888888, ['this is really impressive.', 4], 'yeah it is like regular boggle but in klingon', 45)
# ...
# !!!! (0.3333333333333333, ['save it for your blog, howard.', 0], 'save it for your blog howard', 106)
# (0.75, ['in what universe?', 0], 'speaks in foreign language', 49)
# (0.9090909090909091, ["i wouldn't.", 1], 'leonard all right there it goes it sticks i am sorry', 8)
# (1.0, ["i wouldn't.", 1], 'okay thanks', 8)
# (0.9, ['well, what do you want to do?', 0], 'you are welcome oh you are just gonna step right', 11)
# (1.0, ['okay.', 0], 'okay', 13)
# (1.0, ["i wouldn't.", 1], 'penny hey leonard', 8)
# !!!! (0.3333333333333333, ["the hair products are sheldon's.", 0], 'the hair products are sheldon is', 109)
# (1.0, ["i wouldn't.", 1], 'penny okay', 8)
# (0.42857142857142855, ['um, okay. can i ask you a favour.', 4], 'um can i ask you a favor', 110)
# (1.0, ["i wouldn't.", 1], 'a favor', 8)
# (0.8, ['well, if that was a movie i would go see it.', 0], 'sure you could ask me a favor i would do you a favor for you', 76)
# (0.8571428571428571, ['this is really impressive.', 4], 'it is okay if you say no', 45)
# (0.8333333333333334, ["i wouldn't.", 1], 'oh i will probably say yes', 8)
# (0.8, ["he's kind of a nerd. juice box?", 2], 'it is just not the kind of thing you ask a guy you just met', 123)
# (0.9090909090909091, ["i wouldn't.", 1], 'i really think we should examine the chain of causality here', 8)
# (1.0, ["i wouldn't.", 1], 'must we', 8)
# (1.0, ["i wouldn't.", 1], 'event a', 8)
# (0.875, ['in what universe?', 0], 'a beautiful woman stands naked in our shower', 49)
# (1.0, ["i wouldn't.", 1], 'event b', 8)
# (0.8125, ["we don't mean to interrupt, we live across the hall.", 0], 'we drive halfway across town to retrieve a television set from the aforementioned woman is exboyfriend', 27)
# (0.8571428571428571, ['hang on, there really is a lady here?', 2], 'on what plane of existence is there even a semirational link between these events', 96)
# !!!! (0.2222222222222222, ['she asked me to do her a favour, sheldon.', 0], 'she asked me to do her a favor sheldon', 114)
# (0.9130434782608695, ['sheldon, this was your idea. a little extra money to get fractional t1 bandwidth in the apartment.', 0], 'well that may be the proximal cause of our journey but we both know it exists in contradistinction to the higherlevel distal cause', 5)
# (1.0, ["i wouldn't.", 1], 'which is', 8)
# (0.8, ["agreed, what's your point?", 0], 'you think with your penis', 1)
# (0.4166666666666667, ["that's a biological impossibility and you didn't have to come.", 0], 'that is a biological impossibility and you did not have to come', 115)
# (0.875, ['i want to leave.', 1], 'i could have stayed behind to watch wolowitz hit on penny in russian arabic and farsi', 12)
# (0.8888888888888888, ['yes, but not of the same species.', 1], 'and why can not she get her own tv', 93)
# !!!! (0.2222222222222222, ['come on, you know how it is with breakups.', 0], 'come on you know how it is with breakups', 117)
# (0.875, ["i wouldn't.", 1], 'no i do not and neither do you', 8)
# (0.875, ["i wouldn't.", 1], 'but i i broke up with joyce kim', 8)
# !!!! (0.15384615384615385, ['you did not break up with joyce kim, she defected to north korea.', 1], 'you did not break up with joyce kim she defected to north korea', 118)
# (1.0, ["agreed, what's your point?", 0], 'to mend her broken heart', 1)
# (0.6666666666666666, ['this is really impressive.', 4], 'this situation is much less complicated', 45)
# (0.8823529411764706, ["we don't mean to interrupt, we live across the hall.", 0], 'there is some dispute between penny and her exboyfriend as to who gets custody of the tv', 27)
# (0.7777777777777778, ['she asked me to do her a favour, sheldon.', 0], 'she just wanted to avoid a scene with him', 114)
# (0.7777777777777778, ["you're going to have to call her.", 1], 'so we get to have a scene with him', 128)
# (0.9, ['well, what do you want to do?', 0], 'no sheldon there is not going to be a scene', 11)
# (0.8888888888888888, ['this is really impressive.', 4], 'there is two of us and one of him', 45)
# (0.8181818181818182, ['um, okay. can i ask you a favour.', 4], 'leonard the two of us can not even carry a tv', 110)
# (0.8181818181818182, ['thanks. you guys are really sweet.', 4], 'so you guys work with leonard and sheldon at the university', 90)
# (0.5714285714285714, ["uh, i'm sorry, do you speak english?", 4], 'i am sorry do you speak english', 120)
# (0.45454545454545453, ["oh, he speaks english, he just can't speak to women.", 2], 'oh he speaks english he just can not speak to women', 121)
# (0.8333333333333334, ['this is really impressive.', 4], 'he is kind of a nerd', 45)
# (1.0, ["i wouldn't.", 1], 'juice box', 8)
# (0.8, ["i wouldn't.", 1], 'i will do the talking', 8)
# (1.0, ["i wouldn't.", 1], 'man yeah', 8)
# (0.8571428571428571, ["i wouldn't.", 1], 'hi i am leonard this is sheldon', 8)
# (0.75, ["i wouldn't.", 1], 'what did i just', 8)
# (0.8888888888888888, ['i want to leave.', 1], 'we are here to pick up penny is tv', 12)
# (1.0, ["i wouldn't.", 1], 'get lost', 8)
# (0.8, ["agreed, what's your point?", 0], 'okay thanks for your time', 1)
# (0.8888888888888888, ['yes, but not of the same species.', 1], 'we are not gonna give up just like that', 93)
# (0.7142857142857143, ['participate in the what?', 4], 'leonard the tv is in the building', 69)
# (0.8333333333333334, ["we don't mean to interrupt, we live across the hall.", 0], 'we have been denied access to the building ergo we are done', 27)
# (0.8518518518518519, ["at least i didn't have to invent twenty-six dimensions just to make the math come out.", 0], 'if i were to give up at the first hitch i never would have identified the fingerprints of string theory in the aftermath of the big bang', 47)
# (0.8333333333333334, ["agreed, what's your point?", 0], 'my apologies what is your plan', 1)
# !!!! (0.2727272727272727, ["it's just a privilege to watch your mind at work.", 1], 'it is just a privilege to watch your mind at work', 125)
# (0.8888888888888888, ['so do you have some sort of a job?', 0], 'come on we have a combined iq of 360', 74)
# (0.8571428571428571, ["we don't mean to interrupt, we live across the hall.", 0], 'we should be able to figure out how to get into a stupid building', 27)
# (0.75, ['well, what do you want to do?', 0], 'what do you think their combined iq is', 11)
# (0.75, ['just sit somewhere else.', 0], 'just grab the door', 56)
# (0.75, ['this is really impressive.', 4], 'leonard this is it', 45)
# (0.8, ["i wouldn't.", 1], 'i will do the talking', 8)
# (0.875, ["i wouldn't.", 1], 'good thinking i will just be the muscle', 8)
# (0.8333333333333334, ["i wouldn't.", 1], 'i am leonard this is sheldon', 8)
# (1.0, ["i wouldn't.", 1], 'from the intercom', 8)
# (0.7777777777777778, ['participate in the what?', 4], 'how the hell did you get in the building', 69)
# (1.0, ["agreed, what's your point?", 0], 'tell him about our iq', 1)
# (1.0, ["i wouldn't.", 1], 'leonard  what', 8)
# !!!! (0.16666666666666666, ['my mom bought me those pants.', 1], 'my mom bought me those pants', 126)
# (0.5714285714285714, ["you're going to have to call her.", 1], 'you are gonna have to call her', 128)
# (0.8, ['um, okay. can i ask you a favour.', 4], 'sheldon i am so sorry i dragged you through this', 110)
# (0.875, ['no, it was a valid hypothesis.', 0], 'it is okay it was not my first pantsing and it will not be my last', 141)
# (0.8571428571428571, ['do you want me to move?', 4], 'and you were right about my motives', 54)
# (0.8125, ["that's a biological impossibility and you didn't have to come.", 0], 'i was hoping to establish a relationship with penny that might have someday led to sex', 115)
# (0.7777777777777778, ['do you want me to move?', 4], 'sheldon well you got me out of my pants', 54)
# (0.8333333333333334, ["i wouldn't.", 1], 'anyway i have learned my lesson', 8)
# (0.9090909090909091, ["i wouldn't.", 1], 'she is out of my league i am done with her', 8)
# (0.8421052631578947, ["i just, i can't believe i trusted him.", 4], 'i have got my work one day i will win the nobel prize and then i will die alone', 85)
# (0.75, ['do you want me to move?', 4], 'do not think like that you are not going to die alone', 54)
# (0.75, ['thanks. you guys are really sweet.', 4], 'thank you sheldon you are a good friend', 90)
# (0.8181818181818182, ['so do you have some sort of a job?', 0], 'sheldon and you are certainly not gonna win a nobel prize', 74)
# (0.8461538461538461, ['this is really impressive.', 4], 'this is one of my favorite places to kick back after a quest', 45)
# (1.0, ["agreed, what's your point?", 0], 'they have a great house ale', 1)
# (1.0, ["agreed, what's your point?", 0], 'penny wow cool tiger', 1)
# (0.875, ["i wouldn't.", 1], 'yeah i have had him since level 10', 8)
# (1.0, ["agreed, what's your point?", 0], 'his name is buttons', 1)
# (0.8235294117647058, ["yeah, i've had him since level ten. his name is buttons. anyway, if you had your own game character we could hang out, maybe go on a quest.", 2], 'anyway if you had your own game character we could hang out maybe go on a quest', 129)
# (0.6666666666666666, ['uh, that sounds interesting.', 4], 'that sounds interesting', 130)
# (0.5, ["so you'll think about it?", 2], 'so you will think about it', 131)
# (0.42857142857142855, ["oh, i don't think i'll be able to stop thinking about it.", 4], 'oh i do not think i will be able to stop thinking about it', 132)
# (1.0, ['okay.', 0], 'smooth', 13)
# (1.0, ["i wouldn't.", 1], 'we are home', 8)
# (0.6, ['oh, my god, what happened?', 4], 'oh my god what happened', 138)
# !!!! (0.21428571428571427, ['well, your ex-boyfriend sends his regards and i think the rest is fairly self-explanatory.', 0], 'well your exboyfriend sends his regards and i think the rest is fairly selfexplanatory', 139)
# !!!! (0.35294117647058826, ["i'm so sorry, i really thought if you guys went instead of me he wouldn't be such an ass.", 4], 'i really thought if you guys went instead of me he would not be such an ass', 140)
# !!!! (0.3333333333333333, ['no, it was a valid hypothesis.', 0], 'no it was a valid hypothesis', 141)
# (0.6, ['no, it was a valid hypothesis.', 0], 'that was a valid hypo', 141)
# (0.8, ['i want to leave.', 1], 'what is happening to you', 12)
# (0.8888888888888888, ["what's the protocol for leaving?", 1], 'really thank you so much for going and trying', 14)
# (0.8333333333333334, ['just sit somewhere else.', 0], 'you just you are so terrific', 56)
# (0.8421052631578947, ['uh, do you guys mind if i start?', 4], 'why do not you put some clothes on i will get my purse and dinner is on me okay', 51)
# (1.0, ["i wouldn't.", 1], 'really great', 8)
# (1.0, ["i wouldn't.", 1], 'thank you', 8)
# (0.625, ["thank you. you're not done with her, are you?", 1], 'you are not done with her are you', 144)
# (1.0, ["agreed, what's your point?", 0], 'our babies will be smart and beautiful', 1)
# (1.0, ["agreed, what's your point?", 0], 'not to mention imaginary', 1)
# (0.875, ['um, okay. can i ask you a favour.', 4], 'is thai food okay with you penny  sure', 110)
# (0.8, ["we don't mean to interrupt, we live across the hall.", 0], 'we can not have thai we had indian for lunch', 27)
# (1.0, ["agreed, what's your point?", 0], 'they are both currybased cuisines', 1)
# (1.0, ["agreed, what's your point?", 0], 'it would be gastronomically redundant', 1)
# (0.7333333333333333, ["you're going to have to call her.", 1], 'i can see we are going to have to spell out everything for this girl', 128)
# (1.0, ["i wouldn't.", 1], 'any ideas raj', 8)
# (0.9, ['well, what do you want to do?', 0], 'turn left on lake street and head up to colorado', 11)
# (0.9, ["i wouldn't.", 1], 'i know a wonderful little sushi bar that has karaoke', 8)
# (0.6, ['uh, that sounds interesting.', 4], 'oh that sounds like fun', 130)
# (0.8888888888888888, ['well, what do you want to do?', 0], 'singing baby baby do not get hooked on me', 11)
# (0.8888888888888888, ['well, what do you want to do?', 0], 'oh baby baby do not get hooked on me', 11)
# (0.8928571428571429, ["i don't know, i've never reneged on a proffer of sperm before.", 0], 'i do not know your odds in the world as a whole but as far as the population of this car goes you are a veritable mac daddy', 15)
# (0.8571428571428571, ['do you want me to move?', 4], 'baby do not get hooked on me', 54)
# (0.875, ['just sit somewhere else.', 0], 'yo we should just play this straight up', 56)
# (1.0, ["agreed, what's your point?", 0], 'those cats will fold under pressure', 1)
# (0.9090909090909091, ["we don't mean to interrupt, we live across the hall.", 0], 'we can take these fools with our eyes closed come on', 27)
# (0.8, ['yes, but not of the same species.', 1], 'no doubt but i do not wanna diss them in front of their home crowd', 93)
# (0.75, ["i wouldn't.", 1], 'd i got you', 8)
# (0.6666666666666666, ["i wouldn't.", 1], 'i got yall', 8)
# (0.8888888888888888, ["it's right down the hall.", 0], 'all right man come on let us do it', 89)
# (0.875, ['in all of them, that is the point.', 1], 'all right all right yall that was hot', 50)
# (1.0, ["agreed, what's your point?", 0], 'and the winner is', 1)
# (0.8, ['participate in the what?', 4], 'sphere and the thug unit', 69)
# (1.0, ["i wouldn't.", 1], 'who wants next', 8)
# (0.875, ['well, it sounds wonderful.', 0], 'let us get it going on in here', 78)
# (0.8, ['i want to leave.', 1], 'yall want some of this', 12)
# (1.0, ["i wouldn't.", 1], 'we got next', 8)
# (0.9230769230769231, ['in what universe?', 0], 'all right all right yall let us get it popping in this mall', 49)
# (0.9, ['yes, but not of the same species.', 1], 'you have not seen him pop come on come on', 93)
# (0.875, ["i wouldn't.", 1], 'hey i got that get out of here', 8)
# (1.0, ["agreed, what's your point?", 0], 'get back break it up', 1)
# (1.0, ["agreed, what's your point?", 0], 'get back get back we good', 1)
# (0.8333333333333334, ['in all of them, that is the point.', 1], 'all right all right let us hear it for the thug unit', 50)
# (0.7142857142857143, ['save it for your blog, howard.', 0], 'give it up for the goon squad', 106)
# (0.9090909090909091, ["i wouldn't.", 1], 'what is up i think the goon squad got it yall', 8)
# (0.8571428571428571, ["uh, i'm sorry, do you speak english?", 4], 'double or nothing says you got lucky', 120)
# (1.0, ["i wouldn't.", 1], 'it is on', 8)
# (0.9166666666666666, ['well, what do you want to do?', 0], 'let us go let us go what the hell are you doing', 11)
# (0.75, ["i wouldn't.", 1], 'man i am out', 8)
# (0.8571428571428571, ['well, what do you want to do?', 0], 'what the hell you walking away for', 11)
# (0.875, ["i wouldn't.", 1], 'i say we double up on these niggas', 8)
# (0.875, ['this is really impressive.', 4], 'you know this ai not our spot d', 45)
# (0.8571428571428571, ['this is really impressive.', 4], 'sphere is crew do not know us', 45)
# (0.875, ['in what universe?', 0], 'do not know what we are bringing period', 49)
# (0.8333333333333334, ["the hair products are sheldon's.", 0], 'the more paper we take home', 109)
# (1.0, ["agreed, what's your point?", 0], 'did you see that cat', 1)
# (0.8571428571428571, ['in all of them, that is the point.', 1], 'if he thinks he is being hustled that is paper we will not spend', 50)
# (1.0, ["agreed, what's your point?", 0], 'why are you acting all scared', 1)
# (1.0, ["i wouldn't.", 1], 'l am not', 8)
# (0.8571428571428571, ["uh, i'm sorry, do you speak english?", 4], 'l am acting smart you try it', 120)
# (0.8571428571428571, ["agreed, what's your point?", 0], 'do not i always got your back', 1)
# (0.8571428571428571, ["agreed, what's your point?", 0], 'do not i always have your back', 1)
# (0.8888888888888888, ["i wouldn't.", 1], 'you know i got it man but i am', 8)
# (0.8888888888888888, ['do you want me to move?', 4], 'lf you ai not with it just go home', 54)
# (0.8571428571428571, ['do you want me to move?', 4], 'like you could do this without me', 54)
# (1.0, ["i wouldn't.", 1], 'for real dj', 8)
# (0.8571428571428571, ["agreed, what's your point?", 0], 'we ai not shit without your brother', 1)
# (0.9, ['this is really impressive.', 4], 'you know it is gonna get nasty up in here', 45)
# (0.8888888888888888, ['do you want me to move?', 4], 'do not wanna let stuff get out of hand', 54)

# %% [markdown]
# ### Pattern Matching From both Side

# %%
"""
utterances: original utt in episode side
segments: segmented in episode side
subtitles: original sentence in open subtitles
"""
subtitle_transformed = []
for x in subtitles:
    subtitle_transformed.append(transformation(x))

utterance_transformed = []
for x in utterances:
    utterance_transformed.append([transformation(x[0]), x[1]])

# %%
# String Matching from episode to subtitles
utt_segments = []
for x in utterance_transformed:
    utt = x[0]
    utt_tokens = utt.strip().split(' ')
    if len(utt_tokens)>=6:
        num_iter = len(utt_tokens) // 6
        for i in range(num_iter):
            utt_segments.append([" ".join(utt_tokens[i*6: i*6+6]), x[1]])

subtitle_indexs_dict_e2s = {}
count = 0
for i, x in enumerate(utt_segments):
    utt_seg = x[0]
    for j, sub in enumerate(subtitle_transformed):
        if utt_seg in sub:
            if j in subtitle_indexs_dict_e2s:
                subtitle_indexs_dict_e2s[j].append([utt_seg, i])
            else:
                subtitle_indexs_dict_e2s[j] = [[utt_seg, i]]
            count += 1
            print(utt_seg, i)
            print(sub, j)
            print("=="*50)
print(count)
# Out:
# if a photon is directed through 0
# if a photon is directed through a plane with two slits in it and either is observed it will not go through both 397
# ====================================================================================================
# a plane with two slits in 1
# if a photon is directed through a plane with two slits in it and either is observed it will not go through both 397
# ====================================================================================================
# it will not go through both 3
# if a photon is directed through a plane with two slits in it and either is observed it will not go through both 397
# ====================================================================================================
# it will not have gone through 8
# it will not have gone through both slits 400
# ====================================================================================================
# there is no point i just 9
# there is no point i just think it is a good idea for a tshirt 402
# ====================================================================================================
# think it is a good idea 10
# there is no point i just think it is a good idea for a tshirt 402
# ====================================================================================================
# think it is a good idea 10
# i do not eat it i think it is a good idea 543
# ====================================================================================================
# one across is aegean eight down 11
# one across is aegean eight down is nabokov 403
# ====================================================================================================
# fourteen down is move your finger 13
# fourteen down is move your finger 405
# ====================================================================================================
# see papa doc is capital idea 15
# see papa doc is capital idea that is portauprince 407
# ====================================================================================================
# sperm is going to generate high 18
# there is no guarantee our sperm is going to generate highiq offspring think about that 420
# ====================================================================================================
# have a sister with the same 20
# i have a sister with the same basic dna mix who hostesses at fuddruckers 421
# ====================================================================================================
# basic dna mix who hostesses at 21
# i have a sister with the same basic dna mix who hostesses at fuddruckers 421
# ====================================================================================================
# little extra money to get fractional 23
# a little extra money to get fractional t1 bandwidth in the apartment 423
# ====================================================================================================
# i know and i do yearn 24
# i know and i do yearn for faster downloads 424
# ====================================================================================================
# pin her hopes on my sperm 27
# there is some poor woman who is gonna pin her hopes on my sperm 425
# ====================================================================================================
# what if she winds up with 28
# what if she winds up with a toddler who does not know if he should use a differential to solve for the area under a curve 426
# ====================================================================================================
# a toddler who does not know 29
# what if she winds up with a toddler who does not know if he should use a differential to solve for the area under a curve 426
# ====================================================================================================
# i am sure she will still 32
# i am sure she will still love him 427
# ====================================================================================================
# i am sure she will still 33
# i am sure she will still love him 427
# ====================================================================================================
# what is the protocol for leaving 35
# what is the protocol for leaving i do not know 431
# ====================================================================================================
# never reneged on a proffer of 37
# i have never reneged on a proffer of sperm before 432
# ====================================================================================================
# step is off by as little 39
# if the height of a step is off by as little as two millimeters most people will trip 439
# ====================================================================================================
# a series of experiments when i 43
# i did a series of experiments when i was 12 443
# ====================================================================================================
# we do not mean to interrupt 47
# we do not mean to interrupt we live across the hall 453
# ====================================================================================================
# thank you maybe we can have 48
# oh thank you maybe we can have coffee sometime 460
# ====================================================================================================
# oh you are inviting me over 53
# oh you are inviting me over to eat 485
# ====================================================================================================
# oh that is so nice i 54
# oh that is so nice i would love to 486
# ====================================================================================================
# so what do you guys do 55
# so what do you guys do for fun around here 487
# ====================================================================================================
# so you are like one of 56
# so you are like one of those beautiful mind genius guys 494
# ====================================================================================================
# i have a board if you 57
# i have a board if you like boards this is my board 497
# ====================================================================================================
# like boards this is my board 58
# i have a board if you like boards this is my board 497
# ====================================================================================================
# at least i did not have 59
# at least i did not have to invent 26 dimensions just to make the math come out 501
# ====================================================================================================
# i did not invent them they 61
# i did not invent them they are there 502
# ====================================================================================================
# in all of them that is 62
# in all of them that is the point 504
# ====================================================================================================
# close enough to the radiator to 66
# in winter that seat is close enough to the radiator to remain warm yet not so close as to cause perspiration 511
# ====================================================================================================
# an angle that is neither direct 73
# it faces the television at an angle that is neither direct discouraging conversation nor so far wide as to create a parallax distortion 513
# ====================================================================================================
# i could go on but i 76
# i could go on but i think i have made my point 514
# ====================================================================================================
# think i have made my point 77
# i could go on but i think i have made my point 514
# ====================================================================================================
# do you want me to move 78
# do you want me to move 515
# ====================================================================================================
# i resent you saying we do 79
# i resent you saying we do not have company 524
# ====================================================================================================
# yes it tells us that you 80
# yes it tells us that you participate in the mass cultural delusion that the sun is position relative to arbitrary constellations at the time of your birth somehow affects your personality 531
# ====================================================================================================
# participate in the mass cultural delusion 81
# yes it tells us that you participate in the mass cultural delusion that the sun is position relative to arbitrary constellations at the time of your birth somehow affects your personality 531
# ====================================================================================================
# the time of your birth somehow 84
# yes it tells us that you participate in the mass cultural delusion that the sun is position relative to arbitrary constellations at the time of your birth somehow affects your personality 531
# ====================================================================================================
# i think what sheldon is trying 85
# i think what sheldon is trying to say is that sagittarius would not have been our first guess 533
# ====================================================================================================
# to say is that sagittarius would 86
# i think what sheldon is trying to say is that sagittarius would not have been our first guess 533
# ====================================================================================================
# not have been our first guess 87
# i think what sheldon is trying to say is that sagittarius would not have been our first guess 533
# ====================================================================================================
# oh yeah a lot of people 88
# oh yeah a lot of people think i am a water sign 534
# ====================================================================================================
# think i am a water sign 89
# oh yeah a lot of people think i am a water sign 534
# ====================================================================================================
# okay let us see what else 90
# okay let us see what else 535
# ====================================================================================================
# okay let us see what else 90
# okay let us see what else 550
# ====================================================================================================
# except for fish and the occasional 92
# no except for fish and the occasional steak 537
# ====================================================================================================
# well that is interesting leonard can 93
# well that is interesting leonard can not process corn 538
# ====================================================================================================
# well that is interesting leonard can 94
# well that is interesting leonard can not process corn 538
# ====================================================================================================
# so do you have some sort 95
# so do you have some sort of a job penny 539
# ====================================================================================================
# oh yeah i am a waitress 96
# oh yeah i am a waitress at the cheesecake factory 540
# ====================================================================================================
# oh god you know four years 102
# oh god you know four years i lived with him 557
# ====================================================================================================
# that is like as long as 104
# four years that is like as long as high school 558
# ====================================================================================================
# it took you four years to 105
# it took you four years to get through high school 559
# ====================================================================================================
# i just i can not believe 106
# i just i can not believe i trusted him 560
# ====================================================================================================
# his lying cheating guts i still 111
# even though i hate his lying cheating guts i still love him 565
# ====================================================================================================
# it is right down the hall 112
# it is right down the hall 579
# ====================================================================================================
# thanks you guys are really sweet 113
# okay thanks you guys are really sweet 580
# ====================================================================================================
# oh good then you will not 114
# oh good then you will not be disappointed 590
# ====================================================================================================
# what makes you think she would 115
# what makes you think she would not have sex with me 591
# ====================================================================================================
# am a male and she is 117
# i am a male and she is a female 592
# ====================================================================================================
# yes but not of the same 118
# yes but not of the same species 593
# ====================================================================================================
# lady she is just a new 123
# and she is not a lady she is just a new neighbor 613
# ====================================================================================================
# hang on there really is a 124
# hang on there really is a lady here 614
# ====================================================================================================
# and you want us out because 125
# and you want us out because you are anticipating coitus 616
# ====================================================================================================
# hey is there a trick to 126
# hey is there a trick to getting it to switch from tub to shower 621
# ====================================================================================================
# getting it to switch from tub 127
# hey is there a trick to getting it to switch from tub to shower 621
# ====================================================================================================
# familiar with some of my work 131
# you may be familiar with some of my work 625
# ====================================================================================================
# it is currently orbiting jupiter is 132
# it is currently orbiting jupiter is largest moon taking highresolution digital photographs 626
# ====================================================================================================
# largest moon taking highresolution digital photographs 133
# it is currently orbiting jupiter is largest moon taking highresolution digital photographs 626
# ====================================================================================================
# familiar with some of my work 136
# you may be familiar with some of my work 625
# ====================================================================================================
# it is currently orbiting jupiter is 137
# it is currently orbiting jupiter is largest moon taking highresolution digital photographs 626
# ====================================================================================================
# largest moon taking highresolution digital photographs 138
# it is currently orbiting jupiter is largest moon taking highresolution digital photographs 626
# ====================================================================================================
# penny i work at the cheesecake 139
# penny i work at the cheesecake factory 627
# ====================================================================================================
# it is french for good shower 141
# it is french for good shower 630
# ====================================================================================================
# it is a sentiment i can 142
# it is a sentiment i can express in six languages 631
# ====================================================================================================
# save it for your blog howard 143
# save it for your blog howard 632
# ====================================================================================================
# you are welcome oh you are 144
# you are welcome oh you are just gonna step right 636
# ====================================================================================================
# the hair products are sheldon is 146
# the hair products are sheldon is 639
# ====================================================================================================
# to retrieve a television set from 151
# we drive halfway across town to retrieve a television set from the aforementioned woman is exboyfriend 652
# ====================================================================================================
# on what plane of existence is 153
# on what plane of existence is there even a semirational link between these events 653
# ====================================================================================================
# there even a semirational link between 154
# on what plane of existence is there even a semirational link between these events 653
# ====================================================================================================
# she asked me to do her 155
# she asked me to do her a favor sheldon 654
# ====================================================================================================
# that is a biological impossibility and 156
# that is a biological impossibility and you did not have to come 658
# ====================================================================================================
# you did not have to come 157
# that is a biological impossibility and you did not have to come 658
# ====================================================================================================
# hit on penny in russian arabic 160
# i could have stayed behind to watch wolowitz hit on penny in russian arabic and farsi 659
# ====================================================================================================
# come on you know how it 162
# come on you know how it is with breakups 661
# ====================================================================================================
# you did not break up with 163
# you did not break up with joyce kim she defected to north korea 664
# ====================================================================================================
# joyce kim she defected to north 164
# you did not break up with joyce kim she defected to north korea 664
# ====================================================================================================
# penny and her exboyfriend as to 168
# there is some dispute between penny and her exboyfriend as to who gets custody of the tv 667
# ====================================================================================================
# who gets custody of the tv 169
# there is some dispute between penny and her exboyfriend as to who gets custody of the tv 667
# ====================================================================================================
# oh he speaks english he just 172
# oh he speaks english he just can not speak to women 675
# ====================================================================================================
# he is kind of a nerd 173
# he is kind of a nerd 676
# ====================================================================================================
# it is just a privilege to 174
# it is just a privilege to watch your mind at work 690
# ====================================================================================================
# my mom bought me those pants 175
# my mom bought me those pants 703
# ====================================================================================================
# yeah i have had him since 177
# yeah i have had him since level 10 719
# ====================================================================================================
# anyway if you had your own 179
# anyway if you had your own game character we could hang out maybe go on a quest 721
# ====================================================================================================
# game character we could hang out 180
# anyway if you had your own game character we could hang out maybe go on a quest 721
# ====================================================================================================
# so you will think about it 181
# so you will think about it 723
# ====================================================================================================
# oh i do not think i 182
# oh i do not think i will be able to stop thinking about it 724
# ====================================================================================================
# will be able to stop thinking 183
# oh i do not think i will be able to stop thinking about it 724
# ====================================================================================================
# so you will think about it 184
# so you will think about it 723
# ====================================================================================================
# oh i do not think i 185
# oh i do not think i will be able to stop thinking about it 724
# ====================================================================================================
# will be able to stop thinking 186
# oh i do not think i will be able to stop thinking about it 724
# ====================================================================================================
# well your exboyfriend sends his regards 187
# well your exboyfriend sends his regards and i think the rest is fairly selfexplanatory 728
# ====================================================================================================
# and i think the rest is 188
# well your exboyfriend sends his regards and i think the rest is fairly selfexplanatory 728
# ====================================================================================================
# thought if you guys went instead 190
# i really thought if you guys went instead of me he would not be such an ass 729
# ====================================================================================================
# of me he would not be 191
# i really thought if you guys went instead of me he would not be such an ass 729
# ====================================================================================================
# no it was a valid hypothesis 192
# no it was a valid hypothesis 730
# ====================================================================================================
# really thank you so much for 193
# really thank you so much for going and trying 733
# ====================================================================================================
# not you put some clothes on 196
# why do not you put some clothes on i will get my purse and dinner is on me okay 735
# ====================================================================================================
# i will get my purse and 197
# why do not you put some clothes on i will get my purse and dinner is on me okay 735
# ====================================================================================================
# 117

# %%
for i, sub in enumerate(subtitles):
    # Show matching results
    if i in subtitle_indexs_dict_e2s:
        print(sub)
        print(subtitle_indexs_dict_e2s[i])
        print("=="*50)
    # Show the whole subtitle, matched subtitle will be highlighted
    if i in subtitle_indexs_dict_e2s:
        print("!!!!", sub)
    else:
        print(sub)
# Out:
# i think that we can manage that
# i am not going to take part in that nonsense
# you do not live here iisakki it is not of your concern
# quit your yapping
# we will all take care of nikolas
# beginning with the hannuses
# the boy will move to the next family on christmas
# is this agreed
# yes
# merry christmas sister aada
# i could not forget my mother and my father  and my sister aada
# i knew they would not be coming back  but i missed them dearly
# but time heals the wounds  and by autumn the sadness began to fade away
# my boat is broken fix it
# ask your father
# my father has gone fishing
# ask your mother then
# mother can not do it
# give it to me
# turn boat
# it will not turn
# why does not it come here turn right
# there it goes
# i did not know it back then  but eemeli would become a good friend
# good throw it bounced off the water
# i found a great stone
# stretch your arm back and throw
# you can do it one two three
# let us get another one
# then came the moment i had been dreading
# i had to move to another family for the very first time
# are you sure you will find your way to the heinos
# bye bye
# bye bye
# years families and christmases came and went
# every christmas i carved presents  for the children of my former families
# as the years passed there were so many of them  that i had to deliver the presents to their front doors at night
# it suited me fine  because i did not want to make a great fuss about it
# instead i acted ignorant  if someone came to thank me after christmas
# on my sixth year not everything went as planned
# that year was hard for the whole village
# early frost wiped out almost the entire crop
# it was like the lake was empty of fish that year
# no fish today either
# that is right hilla
# that is a pity
# if things did not turn for the better  no family would be able to house me for the winter
# eemeli what is it
# it is mad iisakki run away
# get your homes in shipshape for christmas
# scoops ladles cups
# spatulas tubs and potato mashers i have everything you need here
# and if i do not have it it can be made to order
# boy come here
# you have not bought this from me
# are you buying things from other carpenters instead of iisakki
# a bad year we have no money we can barely feed ourselves
# where did you buy this answer me
# i made it myself
# do not lie whippersnapper
# and whose boy are you
# nobody is
# oh yeah you are the poor devil who is going around from house to house
# where are the others
# at the village meeting
# what is so important that they must have a meeting
# they are deciding what to do with me they can not afford me
# no wonder you must be such a glutton  that you have ruined the village
# and now i can not sell anything
# you should have been cast into the lake get lost
# but why you do not like children
# he can help me at work
# we know you iisakki
# i was planning to shape that brat into a man within a year  but if my offer is not good enough for you there is nothing i can do
# wait iisakki
# maybe maybe we should consider it
# there is nothing to consider
# he will be better off with me  than starving to death here in this poor village right
# this might be the last time i can visit you
# iisakki lives so far away
# merry christmas little aada
# nikolas come and see
# nikolas
# it is been six years since you were orphaned and came to us
# at first i was sorry that we could not find you a family  to take you in
# you had to go around from household to household one year at a time
# but now i believe that none of us have regretted it
# we all have gotten to know you
# and so in a way you are our child
# and our brother
# on behalf of all the villagers especially the children  we want to give you a little memento
# i can not
# of course you can
# the sledge belongs to you
# are you still loafing about get in the sleigh
# or you can walk the whole way
# you are not going to cry are you
# hilma trot along home before night falls
# what are you gawking at take hilma into the stall
# i will go inside and light the stove
# and leave this sledge in the stall
# no mucking about here you came here to work get up
# and you sleep there
# no buts did you forget whose house this is
# and you will call me master
# yes master
# good your name is brat
# it suits you better than nikolas take your bags in there move it
# wake up brat get to work
# let us get to the workshop you go on ahead
# where is the workshop
# you are standing on it
# take a look at this dresser
# the secret is in the wooden inlays
# it is made of maple this is how i make money
# scoops and ladles are child is play compared to this
# these will go to parsons gentleman farmers and other wealthy people
# this will go to a judge
# is this chair going there too
# it is made of pine this is made of maple
# do not you recognise timber species
# maybe i made a mistake you are no good as a carpenter
# you have not made a mistake master i am a quick learner
# a quick learner eh let us see how quickly you learn to tidy up
# get on with it
# where are you going
# upstairs
# you do not need to go upstairs to tidy up the workshop
# there is no need to clean up here
# the workbench is covered with dust
# if it gets mixed with varnish or stain the whole work is ruined
# lesson number one
# the workshop will be kept tidy at all times no matter what
# lesson number two hand me your sheathknife
# you do not use this on my timber
# do not
# it was my father is
# take a decent sheathknife from there
# remember to snuff out the candles
# it has no branches
# how can i find my things now
# master
# a year has passed and i have to go soon  so i thought that i would thank all the villagers
# maybe i could take a day off
# when time is pressing  you do not waste time thinking you work harder
# a day off eh
# what are you doing here why are not you in bed
# have you stolen timber from me
# you threw it away master
# so this is what you do behind my back
# i am sorry master
# it is not badly broken
# bring me the wood drill and a headless nail
# why are you working in the dark it only results in duds and rejects
# now you can not tell it is broken
# you have more toys somewhere right
# you must really like those little brats
# did you plan to slip out to deliver presents  because i did not give you a day off
# that is what i thought
# go on then  but remember to return before sunrise
# we do not idle away even though it is christmas
# master
# not a word i may change my mind
# you can build your toys in the evenings
# i might even help you at least now i can get some sleep
# building toys in the middle of the night humbug
# finally you showed up i thought you had gone into hibernation
# i already put your junk in the sleigh
# what are you gawking at
# you would not have made it back before sunrise
# the last workday would have gone to waste hop in
# that was the last house
# this is foolishness
# i can understand why you do this but an old man like me
# let us go home
# there is one more place
# hold on show me that
# i made a horse like this when the boys were young
# what boys
# i had two boys hermanni and henrik
# and a wife marget she died when the boys were about your age
# then they went to sea and left me all alone  because i had become like this
# i see henrik and hermanni in all children
# that is why i am mean to children
# i still miss my boys
# what i mean to say is you could stay with me
# merry christmas nikolas
# my father is sheathknife thank you master
# from now on you can call me iisakki
# merry christmas aada
# merry christmas aada
# merry christmas iisakki
# merry christmas nikolas
# that is enough let us go
# that christmas changed everything the village overcame the bad years
# my vagabond life was over
# iisakki provided me a home that i did not have to give up
# thank you very much good day to you
# good day to you
# come and buy a dresser
# the years with iisakki passed quickly
# before i knew it i was all grown up with a beard and all
# the village had grown
# there were so many new children  that me and iisakki could not keep count
# but we had a secret helper
# nikolas
# eemeli
# long time no see you should come more often
# i have been busy iisakki is no longer young
# do you have the list
# well i will be so many new children
# as a matter of fact one name is missing from that list elsa
# is that
# a girl three months
# let us add her to the list
# what is the name of this little princess
# aada
# aada
# hello aada
# nikolas meet henrik and hermanni
# my sons
# i sought them out and asked them here
# we were wrong when we
# we want to make it up to our father
# we came to take him to live with us
# to live with you where
# away from here father is too old to be living in arctic conditions
# you will get the house and the workshop you have earned them
# wait nikolas
# nikolas
# nikolas try to understand
# even though i love you like my own son
# this key opens the chest under my bed
# i have always been skimpy maybe too much so
# i think you can do better
# try to understand
# eemeli
# nikolas
# where have you been
# here but everything is unfinished
# these should last for ten years
# this is barely enough for next christmas
# a map
# there there to this remote village to these houses
# there there there there there christmas presents
# christmas presents
# so many villages and children how do you know who will get what
# there is a simple way
# what is it
# i shall write names on the wrapping
# wrapping
# ingenious is not it
# how is all this possible
# iisakki is life savings
# now i can bring christmas cheer to the children
# nobody can live just for christmas
# i have been selfish i have only brought presents to those  who have helped me
# selfish
# from now on i am going to appear only on christmas eve
# nikolas
# i will visit your shop once a year  to replenish my supplies and to get a list of new children
# there is more to life than just christmas
# like what
# it is an impossible task
# you do not have room for all those presents
# and hilma will not be able to pull the load
# it can not be done
# yes it can
# christmas is around the corner
# animals are quick to learn
# reindeer are not horses
# hilla this is child is play
# i can handle reindeer dear reindeer dear
# you can try
# reindeer obey me better when i am wearing this colourful cap
# even the squirrels are afraid of such a garish colour
# reindeer would obey me even if i had a potholder on my head
# i do not need any red caps
# okay fall in line put your antlers down
# come to nikolas chopchop
# dasher dancer prancer and blitzen your training begins
# the first lesson lassoing dancer behave yourself
# sit there
# sit sit stay
# dasher if you do not behave nikolas will catch you prancer
# let us try again
# hold it
# dancer prancer
# a red cap a red coat and frieze trousers to boot
# what was the colour
# red
# could you repeat that
# red
# i will show you
# let us see aada what do you have there
# a spinning top
# that is nice
# in a few years the mysterious presentbearer  became the staple of children is stories
# some swore to have seen elves bringing presents at christmas
# others claimed that the presents were from a childfriendly gnome
# luckily they did not suspect me
# nikolas is coming
# run away
# good day
# where are the others
# they are afraid of you
# mikko said that it is not you who brings us presents at christmas
# that you hate children is it true
# mikko is half right
# i do not bring presents but i do not hate children either
# who brings the presents
# nikolas told me when i asked him
# aada claims that you do not bring us presents
# aada is right
# aada
# why did you say so tell her the truth
# no way children must not associate me with the presents
# it would ruin everything
# why is that
# nikolas
# eemeli
# is aada here
# aada has gone missing
# dear mother and father do not worry
# i went to find out  who brings all the presents
# we have to wake everybody up and arrange a search party
# you must lend me some clothes otherwise i will be exposed
# okay boys hurry on home
# let us form groups of two a torch and a lantern for each group
# aada could not have gone far let us hurry
# i know where she is
# what did you say mikko
# aada wants to deliver you a present
# me why
# aada does not believe that you do not bring us presents
# why did not you tell us earlier
# i promised not to tell
# will aada return
# aada does not know where you live
# and even if she knew  she will not be able to walk that far aada
# nikolas
# aada
# nobody thought that you would manage to get this far
# twelve miles in a blizzard how is it possible
# it was nothing on a reindeer sleigh
# a reindeer sleigh
# what reindeer sleigh
# suddenly a sleigh appeared
# i thought it was you but the sleigh was empty well not quite
# i was cold so i put on your clothes then the reindeer brought me here
# i told aada everything
# how i would become the way i am  and why it was so important to deliver presents at christmas
# i even revealed my dream of continuing this tradition  when i would be gone
# what kind of girl would aada be now if she had not become a water nymph
# hopefully she would be like you
# aada kept her promise
# she did not reveal my secret quite the opposite
# he did not look like nikolas
# he was a wrinkly old man  who called himself christmas codger
# the years passed and before i knew it  my friendship with aada had lasted almost twenty years
# nikolas
# well
# i am getting married
# to mikko
# nikolas will you pick me up on christmas morning
# of course i will
# for what
# for everything
# fear of losing love is part of love it is part of life
# your father eemeli taught me that
# you have taught me how wonderful it is to give
# nikolas maybe you should think of yourself for a change
# nothing lasts forever
# it was time for me to give in to my years
# next christmas would be the last my last christmas
# it is beautiful who is it for
# can i gift wrap it no
# i want to do it myself
# see you on christmas morning
# are you sure you do not want any help at christmas
# yes i want to do my rounds alone
# nikolas remember your promise this is the last christmas
# this is the last christmas
# nikolas
# merry christmas to little aada your brother nikolas
# we will not be seeing nikolas again
# i can not explain i just know it
# what are you doing there is no sense in doing that
# nikolas wanted this to continue
# a present for our nikolas will disappoint other children
# other fathers have done this too it is not the same thing
# mikko that is cheating
# mikko
# merry christmas little aada
# merry christmas nikolas
# dasher dancer prancer and blitzen ahoy
# merry christmas
# if a photon is directed through a plane with two slits in it and either is observed it will not go through both
# [['if a photon is directed through', 0], ['a plane with two slits in', 1], ['it will not go through both', 3]]
# ====================================================================================================
# !!!! if a photon is directed through a plane with two slits in it and either is observed it will not go through both
# if unobserved it will
# if it is observed after it left the plane before it hits its target
# it will not have gone through both slits
# [['it will not have gone through', 8]]
# ====================================================================================================
# !!!! it will not have gone through both slits
# agreed what is your point
# there is no point i just think it is a good idea for a tshirt
# [['there is no point i just', 9], ['think it is a good idea', 10]]
# ====================================================================================================
# !!!! there is no point i just think it is a good idea for a tshirt
# one across is aegean eight down is nabokov
# [['one across is aegean eight down', 11]]
# ====================================================================================================
# !!!! one across is aegean eight down is nabokov
# twentysix across is mcm
# fourteen down is move your finger
# [['fourteen down is move your finger', 13]]
# ====================================================================================================
# !!!! fourteen down is move your finger
# phylum which makes 14 across portauprince
# see papa doc is capital idea that is portauprince
# [['see papa doc is capital idea', 15]]
# ====================================================================================================
# !!!! see papa doc is capital idea that is portauprince
# haiti
# can i help you  yes
# um is this the highiq sperm bank
# if you have to ask maybe you should not be here
# i think this is the place
# fill these out  thank you
# we will be right back
# oh take your time i will just finish my crossword puzzle
# oh wait
# leonard i do not think i can do this
# what are you kidding
# we are committing genetic fraud
# there is no guarantee our sperm is going to generate highiq offspring think about that
# [['sperm is going to generate high', 18]]
# ====================================================================================================
# !!!! there is no guarantee our sperm is going to generate highiq offspring think about that
# i have a sister with the same basic dna mix who hostesses at fuddruckers
# [['have a sister with the same', 20], ['basic dna mix who hostesses at', 21]]
# ====================================================================================================
# !!!! i have a sister with the same basic dna mix who hostesses at fuddruckers
# sheldon this was your idea
# a little extra money to get fractional t1 bandwidth in the apartment
# [['little extra money to get fractional', 23]]
# ====================================================================================================
# !!!! a little extra money to get fractional t1 bandwidth in the apartment
# i know and i do yearn for faster downloads
# [['i know and i do yearn', 24]]
# ====================================================================================================
# !!!! i know and i do yearn for faster downloads
# there is some poor woman who is gonna pin her hopes on my sperm
# [['pin her hopes on my sperm', 27]]
# ====================================================================================================
# !!!! there is some poor woman who is gonna pin her hopes on my sperm
# what if she winds up with a toddler who does not know if he should use a differential to solve for the area under a curve
# [['what if she winds up with', 28], ['a toddler who does not know', 29]]
# ====================================================================================================
# !!!! what if she winds up with a toddler who does not know if he should use a differential to solve for the area under a curve
# i am sure she will still love him
# [['i am sure she will still', 32], ['i am sure she will still', 33]]
# ====================================================================================================
# !!!! i am sure she will still love him
# i would not
# well what do you wanna do
# i want to leave
# what is the protocol for leaving  i do not know
# [['what is the protocol for leaving', 35]]
# ====================================================================================================
# !!!! what is the protocol for leaving  i do not know
# i have never reneged on a proffer of sperm before
# [['never reneged on a proffer of', 37]]
# ====================================================================================================
# !!!! i have never reneged on a proffer of sperm before
# let us try just walking out
# bye  byebye
# nice meeting you
# are you still mad about the sperm bank
# you wanna hear an interesting thing about stairs
# not really
# if the height of a step is off by as little as two millimeters  most people will trip
# [['step is off by as little', 39]]
# ====================================================================================================
# !!!! if the height of a step is off by as little as two millimeters  most people will trip
# i do not care
# two millime that does not seem right
# it is true
# i did a series of experiments when i was 12
# [['a series of experiments when i', 43]]
# ====================================================================================================
# !!!! i did a series of experiments when i was 12
# my father broke his clavicle
# is that why they sent you to boarding school no
# that was the result of my work with lasers
# new neighbor sheldon
# evidently
# significant improvement over the old neighbor
# twohundred pound transvestite with a skin condition yes she is
# oh hi
# hi
# we do not mean to interrupt we live across the hall
# [['we do not mean to interrupt', 47]]
# ====================================================================================================
# !!!! we do not mean to interrupt we live across the hall
# oh that is nice
# no we do not live together
# i mean we live together but in separate heterosexual bedrooms
# okay well guess i am your new neighbor  penny
# leonard sheldon
# well oh welcome to the building
# oh thank you maybe we can have coffee sometime
# [['thank you maybe we can have', 48]]
# ====================================================================================================
# !!!! oh thank you maybe we can have coffee sometime
# oh great
# well bye
# should we have invited her for lunch no
# we are gonna start season two of battlestar galactica
# we already watched the season two dvds
# not with commentary
# i think we should be good neighbors invite her over make her feel welcome
# we never invited louielouise over
# well and that was wrong of us
# we need to widen our circle
# i have a very wide circle
# i have 212 friends on myspace
# yes and you have never met one of them
# that is the beauty of it
# i am gonna invite her over
# we will have a nice meal and chat
# we do not chat at least not offline
# well it is not difficult
# you just listen to what she says and then you say something appropriate in response
# to what end
# hi again  hi
# anyway we brought home indian food and i know that moving can be stressful and i find that when i am undergoing stress that good food and company can have a comforting effect
# also curry is a natural laxative and i do not have to tell you that you know a clean colon is just one less thing to worry about
# i am no expert but in the context of a lunch invitation you might wanna skip the reference to bowel movements
# oh you are inviting me over to eat
# [['oh you are inviting me over', 53]]
# ====================================================================================================
# !!!! oh you are inviting me over to eat
# oh that is so nice i would love to
# [['oh that is so nice i', 54]]
# ====================================================================================================
# !!!! oh that is so nice i would love to
# so what do you guys do for fun around here
# [['so what do you guys do', 55]]
# ====================================================================================================
# !!!! so what do you guys do for fun around here
# well today we tried masturbating for money
# okay well make yourself at home
# this looks like some serious stuff leonard did you do this
# actually that is my work
# yeah well it is just some quantum mechanics with a little string theory doodling around the edges
# it is a spoof of the bornoppenheimer approximation
# so you are like one of those beautiful mind genius guys
# [['so you are like one of', 56]]
# ====================================================================================================
# !!!! so you are like one of those beautiful mind genius guys
# yeah
# this is really impressive
# i have a board if you like boards this is my board
# [['i have a board if you', 57], ['like boards this is my board', 58]]
# ====================================================================================================
# !!!! i have a board if you like boards this is my board
# holy smokes
# if by holy smokes you mean a derivative restatement of the stuff you can find scribbled on the wall of any men is room at mit sure
# who has not seen this differential below here i sit brokenhearted
# at least i did not have to invent 26 dimensions just to make the math come out
# [['at least i did not have', 59]]
# ====================================================================================================
# !!!! at least i did not have to invent 26 dimensions just to make the math come out
# i did not invent them they are there
# [['i did not invent them they', 61]]
# ====================================================================================================
# !!!! i did not invent them they are there
# in what universe
# in all of them that is the point
# [['in all of them that is', 62]]
# ====================================================================================================
# !!!! in all of them that is the point
# do you guys mind if i start
# penny  yeah
# that is where i sit
# so sit next to me
# no i sit there
# here we go
# in winter that seat is close enough to the radiator to remain warm yet not so close as to cause perspiration
# [['close enough to the radiator to', 66]]
# ====================================================================================================
# !!!! in winter that seat is close enough to the radiator to remain warm yet not so close as to cause perspiration
# in the summer it is in a cross breeze created by opening windows there and there
# it faces the television at an angle that is neither direct discouraging conversation nor so far wide as to create a parallax distortion
# [['an angle that is neither direct', 73]]
# ====================================================================================================
# !!!! it faces the television at an angle that is neither direct discouraging conversation nor so far wide as to create a parallax distortion
# i could go on but i think i have made my point
# [['i could go on but i', 76], ['think i have made my point', 77]]
# ====================================================================================================
# !!!! i could go on but i think i have made my point
# do you want me to move
# [['do you want me to move', 78]]
# ====================================================================================================
# !!!! do you want me to move
# just sit somewhere else
# sheldon sit
# well this is nice
# we do not have a lot of company over
# that is not true koothrappali and wolowitz come over
# yes i know
# tuesday night we played klingon boggle until 1 in the morning
# yeah i remember
# i resent you saying we do not have company
# [['i resent you saying we do', 79]]
# ====================================================================================================
# !!!! i resent you saying we do not have company
# that has a negative social implication
# i said i am sorry
# so klingon boggle
# yeah it is like regular boggle but in klingon
# that is probably enough about us so tell us about you
# i am a sagittarius which probably tells you way more than you need to know
# yes it tells us that you participate in the mass cultural delusion that the sun is position relative to arbitrary constellations at the time of your birth somehow affects your personality
# [['yes it tells us that you', 80], ['participate in the mass cultural delusion', 81], ['the time of your birth somehow', 84]]
# ====================================================================================================
# !!!! yes it tells us that you participate in the mass cultural delusion that the sun is position relative to arbitrary constellations at the time of your birth somehow affects your personality
# participate in the what
# i think what sheldon is trying to say is that sagittarius would not have been our first guess
# [['i think what sheldon is trying', 85], ['to say is that sagittarius would', 86], ['not have been our first guess', 87]]
# ====================================================================================================
# !!!! i think what sheldon is trying to say is that sagittarius would not have been our first guess
# oh yeah a lot of people think i am a water sign
# [['oh yeah a lot of people', 88], ['think i am a water sign', 89]]
# ====================================================================================================
# !!!! oh yeah a lot of people think i am a water sign
# okay let us see what else
# [['okay let us see what else', 90]]
# ====================================================================================================
# !!!! okay let us see what else
# oh i am a vegetarian
# no except for fish and the occasional steak
# [['except for fish and the occasional', 92]]
# ====================================================================================================
# !!!! no except for fish and the occasional steak
# well that is interesting leonard can not process corn
# [['well that is interesting leonard can', 93], ['well that is interesting leonard can', 94]]
# ====================================================================================================
# !!!! well that is interesting leonard can not process corn
# so do you have some sort of a job penny
# [['so do you have some sort', 95]]
# ====================================================================================================
# !!!! so do you have some sort of a job penny
# oh yeah i am a waitress at the cheesecake factory
# [['oh yeah i am a waitress', 96]]
# ====================================================================================================
# !!!! oh yeah i am a waitress at the cheesecake factory
# i love cheesecake
# you are lactose intolerant
# i do not eat it i think it is a good idea
# [['think it is a good idea', 10]]
# ====================================================================================================
# !!!! i do not eat it i think it is a good idea
# anyways i am also writing a screenplay
# it is about this sensitive girl who comes to la from lincoln nebraska to be an actress and winds up a waitress at the cheesecake factory
# so it is based on your life
# no i am from omaha
# if that was a movie i would go see it
# i know right
# okay let us see what else
# [['okay let us see what else', 90]]
# ====================================================================================================
# !!!! okay let us see what else
# i guess that is about it
# that is the story of penny
# well it sounds wonderful
# it was
# until i fell in love with a jerk
# mouths i do not know
# oh god you know four years i lived with him
# [['oh god you know four years', 102]]
# ====================================================================================================
# !!!! oh god you know four years i lived with him
# four years that is like as long as high school
# [['that is like as long as', 104]]
# ====================================================================================================
# !!!! four years that is like as long as high school
# it took you four years to get through high school
# [['it took you four years to', 105]]
# ====================================================================================================
# !!!! it took you four years to get through high school
# i just i can not believe i trusted him
# [['i just i can not believe', 106]]
# ====================================================================================================
# !!!! i just i can not believe i trusted him
# should i say something
# i feel i should say something you
# no you will only make it worse
# you wanna know the most pathetic part
# even though i hate his lying cheating guts i still love him
# [['his lying cheating guts i still', 111]]
# ====================================================================================================
# !!!! even though i hate his lying cheating guts i still love him
# is that crazy
# no it is not crazy
# it is a
# it is a paradox
# paradoxes are part of nature
# i mean think about light if you look at huygens light is a wave as confirmed by the doubleslit experiments
# but then along comes albert einstein and discovers that light behaves like particles too
# well i did not make it worse
# oh i am so sorry i am such a mess
# and on top of everything else i am all gross from moving and my stupid shower does not work
# our shower works
# would it be totally weird if i used it
# no
# it is right down the hall
# [['it is right down the hall', 112]]
# ====================================================================================================
# !!!! it is right down the hall
# okay thanks you guys are really sweet
# [['thanks you guys are really sweet', 113]]
# ====================================================================================================
# !!!! okay thanks you guys are really sweet
# well this is an interesting development
# leonard how so
# sheldon it has been some time since we have had a woman take her clothes off in our apartment
# that is not true remember at thanksgiving my grandmother with alzheimer is had that episode
# it has been some time since we have had a woman take her clothes off after which we did not wanna rip our eyes out
# the worst part was watching her carve that turkey
# so what exactly are you trying to accomplish here
# that woman in there is not going to have sex with you
# well i am not trying to have sex with her
# oh good then you will not be disappointed
# [['oh good then you will not', 114]]
# ====================================================================================================
# !!!! oh good then you will not be disappointed
# what makes you think she would not have sex with me
# [['what makes you think she would', 115]]
# ====================================================================================================
# !!!! what makes you think she would not have sex with me
# i am a male and she is a female
# [['am a male and she is', 117]]
# ====================================================================================================
# !!!! i am a male and she is a female
# yes but not of the same species
# [['yes but not of the same', 118]]
# ====================================================================================================
# !!!! yes but not of the same species
# i am not gonna engage in hypotheticals here
# i am just trying to be a good neighbor
# oh of course
# that is not to say that if a carnal relationship were to develop that i would not participate
# however briefly
# do you think this possibility will be hindered when she discovers your luke skywalker no more tears shampoo
# it is darth vader shampoo
# luke skywalker is the conditioner
# wait till you see this
# it is fantastic unbelievable
# see what
# it is a stephen hawking lecture from mit in 1974
# this is not a good time
# imitating computerized voice it is before he became a creepy computer voice
# that is great you guys have to go
# it is just not a good time
# leonard has a lady over
# in normal voice yeah right your grandmother back in town
# no
# and she is not a lady she is just a new neighbor
# [['lady she is just a new', 123]]
# ====================================================================================================
# !!!! and she is not a lady she is just a new neighbor
# hang on there really is a lady here
# [['hang on there really is a', 124]]
# ====================================================================================================
# !!!! hang on there really is a lady here
# uhhuh
# and you want us out because you are anticipating coitus
# [['and you want us out because', 125]]
# ====================================================================================================
# !!!! and you want us out because you are anticipating coitus
# i am not anticipating coitus
# so she is available for coitus
# can we please just stop saying coitus
# technically that would be coitus interruptus
# hey is there a trick to getting it to switch from tub to shower
# [['hey is there a trick to', 126], ['getting it to switch from tub', 127]]
# ====================================================================================================
# !!!! hey is there a trick to getting it to switch from tub to shower
# oh hi sorry hello
# enchanté mademoiselle
# howard wolowitz caltech department of applied physics
# you may be familiar with some of my work
# [['familiar with some of my work', 131], ['familiar with some of my work', 136]]
# ====================================================================================================
# !!!! you may be familiar with some of my work
# it is currently orbiting jupiter is largest moon taking highresolution digital photographs
# [['it is currently orbiting jupiter is', 132], ['largest moon taking highresolution digital photographs', 133], ['it is currently orbiting jupiter is', 137], ['largest moon taking highresolution digital photographs', 138]]
# ====================================================================================================
# !!!! it is currently orbiting jupiter is largest moon taking highresolution digital photographs
# penny i work at the cheesecake factory
# [['penny i work at the cheesecake', 139]]
# ====================================================================================================
# !!!! penny i work at the cheesecake factory
# i will show you the trick with the shower  okay
# speaks in french
# it is french for good shower
# [['it is french for good shower', 141]]
# ====================================================================================================
# !!!! it is french for good shower
# it is a sentiment i can express in six languages
# [['it is a sentiment i can', 142]]
# ====================================================================================================
# !!!! it is a sentiment i can express in six languages
# save it for your blog howard
# [['save it for your blog howard', 143]]
# ====================================================================================================
# !!!! save it for your blog howard
# speaks in foreign language
# leonard all right there it goes it sticks i am sorry
# okay thanks
# you are welcome oh you are just gonna step right
# [['you are welcome oh you are', 144]]
# ====================================================================================================
# !!!! you are welcome oh you are just gonna step right
# okay
# penny hey leonard
# the hair products are sheldon is
# [['the hair products are sheldon is', 146]]
# ====================================================================================================
# !!!! the hair products are sheldon is
# penny okay
# um can i ask you a favor
# a favor
# sure you could ask me a favor i would do you a favor for you
# it is okay if you say no
# oh i will probably say yes
# it is just not the kind of thing you ask a guy you just met
# i really think we should examine the chain of causality here
# must we
# event a
# a beautiful woman stands naked in our shower
# event b
# we drive halfway across town to retrieve a television set from the aforementioned woman is exboyfriend
# [['to retrieve a television set from', 151]]
# ====================================================================================================
# !!!! we drive halfway across town to retrieve a television set from the aforementioned woman is exboyfriend
# on what plane of existence is there even a semirational link between these events
# [['on what plane of existence is', 153], ['there even a semirational link between', 154]]
# ====================================================================================================
# !!!! on what plane of existence is there even a semirational link between these events
# she asked me to do her a favor sheldon
# [['she asked me to do her', 155]]
# ====================================================================================================
# !!!! she asked me to do her a favor sheldon
# well that may be the proximal cause of our journey but we both know it exists in contradistinction to the higherlevel distal cause
# which is
# you think with your penis
# that is a biological impossibility and you did not have to come
# [['that is a biological impossibility and', 156], ['you did not have to come', 157]]
# ====================================================================================================
# !!!! that is a biological impossibility and you did not have to come
# i could have stayed behind to watch wolowitz hit on penny in russian arabic and farsi
# [['hit on penny in russian arabic', 160]]
# ====================================================================================================
# !!!! i could have stayed behind to watch wolowitz hit on penny in russian arabic and farsi
# and why can not she get her own tv
# come on you know how it is with breakups
# [['come on you know how it', 162]]
# ====================================================================================================
# !!!! come on you know how it is with breakups
# no i do not and neither do you
# but i i broke up with joyce kim
# you did not break up with joyce kim she defected to north korea
# [['you did not break up with', 163], ['joyce kim she defected to north', 164]]
# ====================================================================================================
# !!!! you did not break up with joyce kim she defected to north korea
# to mend her broken heart
# this situation is much less complicated
# there is some dispute between penny and her exboyfriend as to who gets custody of the tv
# [['penny and her exboyfriend as to', 168], ['who gets custody of the tv', 169]]
# ====================================================================================================
# !!!! there is some dispute between penny and her exboyfriend as to who gets custody of the tv
# she just wanted to avoid a scene with him
# so we get to have a scene with him
# no sheldon there is not going to be a scene
# there is two of us and one of him
# leonard the two of us can not even carry a tv
# so you guys work with leonard and sheldon at the university
# i am sorry do you speak english
# oh he speaks english he just can not speak to women
# [['oh he speaks english he just', 172]]
# ====================================================================================================
# !!!! oh he speaks english he just can not speak to women
# he is kind of a nerd
# [['he is kind of a nerd', 173]]
# ====================================================================================================
# !!!! he is kind of a nerd
# juice box
# i will do the talking
# man yeah
# hi i am leonard this is sheldon
# what did i just
# we are here to pick up penny is tv
# get lost
# okay thanks for your time
# we are not gonna give up just like that
# leonard the tv is in the building
# we have been denied access to the building ergo we are done
# if i were to give up at the first hitch i never would have identified the fingerprints of string theory in the aftermath of the big bang
# my apologies what is your plan
# it is just a privilege to watch your mind at work
# [['it is just a privilege to', 174]]
# ====================================================================================================
# !!!! it is just a privilege to watch your mind at work
# come on we have a combined iq of 360
# we should be able to figure out how to get into a stupid building
# what do you think their combined iq is
# just grab the door
# leonard this is it
# i will do the talking
# good thinking i will just be the muscle
# i am leonard this is sheldon
# from the intercom
# how the hell did you get in the building
# tell him about our iq
# leonard  what
# my mom bought me those pants
# [['my mom bought me those pants', 175]]
# ====================================================================================================
# !!!! my mom bought me those pants
# you are gonna have to call her
# sheldon i am so sorry i dragged you through this
# it is okay it was not my first pantsing and it will not be my last
# and you were right about my motives
# i was hoping to establish a relationship with penny that might have someday led to sex
# sheldon well you got me out of my pants
# anyway i have learned my lesson
# she is out of my league i am done with her
# i have got my work one day i will win the nobel prize and then i will die alone
# do not think like that you are not going to die alone
# thank you sheldon you are a good friend
# sheldon and you are certainly not gonna win a nobel prize
# this is one of my favorite places to kick back after a quest
# they have a great house ale
# penny wow cool tiger
# yeah i have had him since level 10
# [['yeah i have had him since', 177]]
# ====================================================================================================
# !!!! yeah i have had him since level 10
# his name is buttons
# anyway if you had your own game character we could hang out maybe go on a quest
# [['anyway if you had your own', 179], ['game character we could hang out', 180]]
# ====================================================================================================
# !!!! anyway if you had your own game character we could hang out maybe go on a quest
# that sounds interesting
# so you will think about it
# [['so you will think about it', 181], ['so you will think about it', 184]]
# ====================================================================================================
# !!!! so you will think about it
# oh i do not think i will be able to stop thinking about it
# [['oh i do not think i', 182], ['will be able to stop thinking', 183], ['oh i do not think i', 185], ['will be able to stop thinking', 186]]
# ====================================================================================================
# !!!! oh i do not think i will be able to stop thinking about it
# smooth
# we are home
# oh my god what happened
# well your exboyfriend sends his regards and i think the rest is fairly selfexplanatory
# [['well your exboyfriend sends his regards', 187], ['and i think the rest is', 188]]
# ====================================================================================================
# !!!! well your exboyfriend sends his regards and i think the rest is fairly selfexplanatory
# i really thought if you guys went instead of me he would not be such an ass
# [['thought if you guys went instead', 190], ['of me he would not be', 191]]
# ====================================================================================================
# !!!! i really thought if you guys went instead of me he would not be such an ass
# no it was a valid hypothesis
# [['no it was a valid hypothesis', 192]]
# ====================================================================================================
# !!!! no it was a valid hypothesis
# that was a valid hypo
# what is happening to you
# really thank you so much for going and trying
# [['really thank you so much for', 193]]
# ====================================================================================================
# !!!! really thank you so much for going and trying
# you just you are so terrific
# why do not you put some clothes on i will get my purse and dinner is on me okay
# [['not you put some clothes on', 196], ['i will get my purse and', 197]]
# ====================================================================================================
# !!!! why do not you put some clothes on i will get my purse and dinner is on me okay
# really great
# thank you
# you are not done with her are you
# our babies will be smart and beautiful
# not to mention imaginary
# is thai food okay with you penny  sure
# we can not have thai we had indian for lunch
# they are both currybased cuisines
# it would be gastronomically redundant
# i can see we are going to have to spell out everything for this girl
# any ideas raj
# turn left on lake street and head up to colorado
# i know a wonderful little sushi bar that has karaoke
# oh that sounds like fun
# singing baby baby do not get hooked on me
# oh baby baby do not get hooked on me
# i do not know your odds in the world as a whole but as far as the population of this car goes you are a veritable mac daddy
# baby do not get hooked on me
# yo we should just play this straight up
# those cats will fold under pressure
# we can take these fools with our eyes closed come on
# no doubt but i do not wanna diss them in front of their home crowd
# d i got you
# i got yall
# all right man come on let us do it
# all right all right yall that was hot
# and the winner is
# sphere and the thug unit
# who wants next
# let us get it going on in here
# yall want some of this
# we got next
# all right all right yall let us get it popping in this mall
# you have not seen him pop come on come on
# hey i got that get out of here
# get back break it up
# get back get back we good
# all right all right let us hear it for the thug unit
# give it up for the goon squad
# what is up i think the goon squad got it yall
# double or nothing says you got lucky
# it is on
# let us go let us go what the hell are you doing
# man i am out
# what the hell you walking away for
# i say we double up on these niggas
# you know this ai not our spot d
# sphere is crew do not know us
# do not know what we are bringing period
# the more paper we take home
# did you see that cat
# if he thinks he is being hustled that is paper we will not spend
# why are you acting all scared
# l am not
# l am acting smart you try it
# do not i always got your back
# do not i always have your back
# you know i got it man but i am
# lf you ai not with it just go home
# like you could do this without me
# for real dj
# we ai not shit without your brother
# you know it is gonna get nasty up in here
# do not wanna let stuff get out of hand

# %%
# String Matching from subtitles to utterance
sub_segments = []
for k, sub in enumerate(subtitle_transformed):
    sub_tokens = sub.strip().split(' ')
    if len(sub_tokens)>=6:
        num_iter = len(sub_tokens) // 6
        for i in range(num_iter):
            sub_segments.append([" ".join(sub_tokens[i*6: i*6+6]), k])

subtitle_indexs_dict_s2e = {}
for j, x in enumerate(sub_segments):
    sub_seg = x[0]
    for i, x in enumerate(utterance_transformed):
        utt = x[0]
        speaker = x[1]
        if sub_seg in utt:
            if j in subtitle_indexs_dict_s2e:
                subtitle_indexs_dict_s2e[j].append([utt, i])
            else:
                subtitle_indexs_dict_s2e[j] = [[utt, i]]

# %%
for x in subtitle_indexs_dict_s2e:
    print(x, "--", subtitle_indexs_dict_s2e[x][0][1])
    print(subtitle_indexs_dict_s2e[x][0][0])
    print(sub_segments[x])
    print()
# Out:
# 294 -- 0
# if a photon is directed through a plane with two slits in it and either slit is observed it will not go through both slits if it is unobserved it will however if it is observed after it is left the plane but before it hits its target it will not have gone through both slits
# ['if a photon is directed through', 397]
#
# 295 -- 0
# if a photon is directed through a plane with two slits in it and either slit is observed it will not go through both slits if it is unobserved it will however if it is observed after it is left the plane but before it hits its target it will not have gone through both slits
# ['a plane with two slits in', 397]
#
# 297 -- 0
# if a photon is directed through a plane with two slits in it and either slit is observed it will not go through both slits if it is unobserved it will however if it is observed after it is left the plane but before it hits its target it will not have gone through both slits
# ['if it is observed after it', 399]
#
# 299 -- 0
# if a photon is directed through a plane with two slits in it and either slit is observed it will not go through both slits if it is unobserved it will however if it is observed after it is left the plane but before it hits its target it will not have gone through both slits
# ['it will not have gone through', 400]
#
# 300 -- 2
# there is no point i just think it is a good idea for a tshirt
# ['there is no point i just', 402]
#
# 301 -- 2
# there is no point i just think it is a good idea for a tshirt
# ['think it is a good idea', 402]
#
# 302 -- 3
# one across is aegean eight down is nabakov twentysix across is mcm fourteen down is move your finger phylum which makes fourteen across portauprince see papa doc is capital idea that is portauprince haiti
# ['one across is aegean eight down', 403]
#
# 303 -- 3
# one across is aegean eight down is nabakov twentysix across is mcm fourteen down is move your finger phylum which makes fourteen across portauprince see papa doc is capital idea that is portauprince haiti
# ['fourteen down is move your finger', 405]
#
# 305 -- 3
# one across is aegean eight down is nabakov twentysix across is mcm fourteen down is move your finger phylum which makes fourteen across portauprince see papa doc is capital idea that is portauprince haiti
# ['see papa doc is capital idea', 407]
#
# 313 -- 4
# no we are committing genetic fraud there is no guarantee that our sperm is going to generate high iq offspring think about that i have a sister with the same basic dna mix who hostesses at fuddruckers
# ['i have a sister with the', 421]
#
# 314 -- 4
# no we are committing genetic fraud there is no guarantee that our sperm is going to generate high iq offspring think about that i have a sister with the same basic dna mix who hostesses at fuddruckers
# ['same basic dna mix who hostesses', 421]
#
# 315 -- 5
# sheldon this was your idea a little extra money to get fractional t1 bandwidth in the apartment
# ['a little extra money to get', 423]
#
# 316 -- 5
# sheldon this was your idea a little extra money to get fractional t1 bandwidth in the apartment
# ['fractional t1 bandwidth in the apartment', 423]
#
# 317 -- 6
# i know and i do yearn for faster downloads but there is some poor woman is going to pin her hopes on my sperm what if she winds up with a toddler who does not know if he should use an integral or a differential to solve the area under a curve
# ['i know and i do yearn', 424]
#
# 320 -- 6
# i know and i do yearn for faster downloads but there is some poor woman is going to pin her hopes on my sperm what if she winds up with a toddler who does not know if he should use an integral or a differential to solve the area under a curve
# ['what if she winds up with', 426]
#
# 321 -- 6
# i know and i do yearn for faster downloads but there is some poor woman is going to pin her hopes on my sperm what if she winds up with a toddler who does not know if he should use an integral or a differential to solve the area under a curve
# ['a toddler who does not know', 426]
#
# 324 -- 7
# i am sure she will still love him
# ['i am sure she will still', 427]
#
# 326 -- 14
# what is the protocol for leaving
# ['what is the protocol for leaving', 431]
#
# 327 -- 15
# i do not know i have never reneged on a proffer of sperm before
# ['i have never reneged on a', 432]
#
# 332 -- 16
# if the height of a single step is off by as little as two millimetres most people will trip
# ['is off by as little as', 439]
#
# 335 -- 18
# no it is true i did a series of experiments when i was twelve my father broke his clavicle
# ['i did a series of experiments', 443]
#
# 340 -- 27
# we do not mean to interrupt we live across the hall
# ['we do not mean to interrupt', 453]
#
# 374 -- 38
# oh you are inviting me over to eat
# ['oh you are inviting me over', 485]
#
# 375 -- 40
# oh that is so nice i would love to
# ['oh that is so nice i', 486]
#
# 376 -- 42
# so what do you guys do for fun around here
# ['so what do you guys do', 487]
#
# 383 -- 43
# so you are like one of those beautiful mind genius guys
# ['so you are like one of', 494]
#
# 384 -- 46
# i have a board if you like boards this is my board
# ['i have a board if you', 497]
#
# 385 -- 46
# i have a board if you like boards this is my board
# ['like boards this is my board', 497]
#
# 391 -- 47
# at least i did not have to invent twentysix dimensions just to make the math come out
# ['at least i did not have', 501]
#
# 393 -- 48
# i did not invent them they are there
# ['i did not invent them they', 502]
#
# 394 -- 50
# in all of them that is the point
# ['in all of them that is', 504]
#
# 395 -- 51
# uh do you guys mind if i start
# ['do you guys mind if i', 505]
#
# 397 -- 53
# in the winter that seat is close enough to the radiator to remain warm and yet not so close as to cause perspiration in the summer it is directly in the path of a cross breeze created by open windows there and there it faces the television at an angle that is neither direct thus discouraging conversation nor so far wide to create a parallax distortion i could go on but i think i have made my point
# ['enough to the radiator to remain', 511]
#
# 401 -- 53
# in the winter that seat is close enough to the radiator to remain warm and yet not so close as to cause perspiration in the summer it is directly in the path of a cross breeze created by open windows there and there it faces the television at an angle that is neither direct thus discouraging conversation nor so far wide to create a parallax distortion i could go on but i think i have made my point
# ['it faces the television at an', 513]
#
# 404 -- 53
# in the winter that seat is close enough to the radiator to remain warm and yet not so close as to cause perspiration in the summer it is directly in the path of a cross breeze created by open windows there and there it faces the television at an angle that is neither direct thus discouraging conversation nor so far wide to create a parallax distortion i could go on but i think i have made my point
# ['i could go on but i', 514]
#
# 405 -- 53
# in the winter that seat is close enough to the radiator to remain warm and yet not so close as to cause perspiration in the summer it is directly in the path of a cross breeze created by open windows there and there it faces the television at an angle that is neither direct thus discouraging conversation nor so far wide to create a parallax distortion i could go on but i think i have made my point
# ['think i have made my point', 514]
#
# 406 -- 54
# do you want me to move
# ['do you want me to move', 515]
#
# 410 -- 63
# i resent you saying we do not have company
# ['i resent you saying we do', 524]
#
# 416 -- 68
# yes it tells us that you participate in the mass cultural delusion that the sun is apparent position relative to arbitrarily defined constellations and the time of your birth somehow effects your personality
# ['yes it tells us that you', 531]
#
# 417 -- 68
# yes it tells us that you participate in the mass cultural delusion that the sun is apparent position relative to arbitrarily defined constellations and the time of your birth somehow effects your personality
# ['participate in the mass cultural delusion', 531]
#
# 421 -- 70
# i think what sheldon is trying to say is that sagittarius would not have been our first guess
# ['i think what sheldon is trying', 533]
#
# 422 -- 70
# i think what sheldon is trying to say is that sagittarius would not have been our first guess
# ['to say is that sagittarius would', 533]
#
# 423 -- 70
# i think what sheldon is trying to say is that sagittarius would not have been our first guess
# ['not have been our first guess', 533]
#
# 424 -- 71
# oh yeah a lot of people think i am a water sign okay let us see what else oh i am a vegetarian oh except for fish and the occasional steak i love steak
# ['oh yeah a lot of people', 534]
#
# 425 -- 71
# oh yeah a lot of people think i am a water sign okay let us see what else oh i am a vegetarian oh except for fish and the occasional steak i love steak
# ['think i am a water sign', 534]
#
# 426 -- 71
# oh yeah a lot of people think i am a water sign okay let us see what else oh i am a vegetarian oh except for fish and the occasional steak i love steak
# ['okay let us see what else', 535]
#
# 428 -- 72
# well that is interesting leonard can not process corn
# ['well that is interesting leonard can', 538]
#
# 429 -- 74
# so do you have some sort of a job
# ['so do you have some sort', 539]
#
# 430 -- 75
# oh yeah i am a waitress at the cheesecake factory
# ['oh yeah i am a waitress', 540]
#
# 432 -- 2
# there is no point i just think it is a good idea for a tshirt
# ['think it is a good idea', 543]
#
# 439 -- 76
# well if that was a movie i would go see it
# ['if that was a movie i', 548]
#
# 440 -- 71
# oh yeah a lot of people think i am a water sign okay let us see what else oh i am a vegetarian oh except for fish and the occasional steak i love steak
# ['okay let us see what else', 550]
#
# 442 -- 77
# i know right okay let us see what else um that is about it that is the story of penny
# ['that is the story of penny', 552]
#
# 443 -- 79
# it was until i fell in love with a jerk
# ['until i fell in love with', 555]
#
# 444 -- 82
# oh god you know four years i lived with him four years that is like as long as high school
# ['oh god you know four years', 557]
#
# 445 -- 82
# oh god you know four years i lived with him four years that is like as long as high school
# ['four years that is like as', 558]
#
# 446 -- 83
# it took you four years to get through high school
# ['it took you four years to', 559]
#
# 447 -- 85
# i just i can not believe i trusted him
# ['i just i can not believe', 560]
#
# 449 -- 87
# you no you will only make it worse
# ['no you will only make it', 563]
#
# 451 -- 88
# you want to know the most pathetic part even though i hate his lying cheating guts i still love him is that crazy
# ['even though i hate his lying', 565]
#
# 452 -- 88
# you want to know the most pathetic part even though i hate his lying cheating guts i still love him is that crazy
# ['cheating guts i still love him', 565]
#
# 464 -- 89
# it is right down the hall
# ['it is right down the hall', 579]
#
# 481 -- 91
# oh good then you will not be disappointed
# ['oh good then you will not', 590]
#
# 482 -- 92
# what makes you think she would not have sex with me i am a male and she is a female
# ['what makes you think she would', 591]
#
# 483 -- 92
# what makes you think she would not have sex with me i am a male and she is a female
# ['i am a male and she', 592]
#
# 484 -- 93
# yes but not of the same species
# ['yes but not of the same', 593]
#
# 486 -- 94
# i am not going to engage in hypotheticals here i am just trying to be a good neighbour
# ['i am just trying to be', 595]
#
# 500 -- 95
# no and she is not a lady she is just a new neighbour
# ['and she is not a lady', 613]
#
# 502 -- 96
# hang on there really is a lady here
# ['hang on there really is a', 614]
#
# 503 -- 98
# and you want us out because you are anticipating coitus
# ['and you want us out because', 616]
#
# 507 -- 99
# hey is there a trick to getting it to switch from tub to shower oh hi sorry hello
# ['hey is there a trick to', 621]
#
# 508 -- 99
# hey is there a trick to getting it to switch from tub to shower oh hi sorry hello
# ['getting it to switch from tub', 621]
#
# 509 -- 100
# enchante madamoiselle howard wolowitz caltech department of applied physics you may be familiar with some of my work it is currently orbiting jupiter is largest moon taking highresolution digital photographs
# ['howard wolowitz caltech department of applied', 624]
#
# 510 -- 100
# enchante madamoiselle howard wolowitz caltech department of applied physics you may be familiar with some of my work it is currently orbiting jupiter is largest moon taking highresolution digital photographs
# ['you may be familiar with some', 625]
#
# 511 -- 100
# enchante madamoiselle howard wolowitz caltech department of applied physics you may be familiar with some of my work it is currently orbiting jupiter is largest moon taking highresolution digital photographs
# ['it is currently orbiting jupiter is', 626]
#
# 512 -- 100
# enchante madamoiselle howard wolowitz caltech department of applied physics you may be familiar with some of my work it is currently orbiting jupiter is largest moon taking highresolution digital photographs
# ['largest moon taking highresolution digital photographs', 626]
#
# 513 -- 102
# penny i work at the cheesecake factory
# ['penny i work at the cheesecake', 627]
#
# 514 -- 103
# come on i will show you the trick with the shower
# ['i will show you the trick', 628]
#
# 515 -- 105
# it is french for good shower it is a sentiment i can express in six languages
# ['it is french for good shower', 630]
#
# 516 -- 105
# it is french for good shower it is a sentiment i can express in six languages
# ['it is a sentiment i can', 631]
#
# 517 -- 106
# save it for your blog howard
# ['save it for your blog howard', 632]
#
# 519 -- 107
# you are welcome oh you are going to step right okay i will
# ['you are welcome oh you are', 636]
#
# 520 -- 109
# the hair products are sheldon is
# ['the hair products are sheldon is', 639]
#
# 529 -- 113
# event a a beautiful woman stands naked in our shower event b we drive half way across town to retrieve a television set from the aforementioned woman is exboyfriend query on what plane of existence is there even a semirational link between these events
# ['a beautiful woman stands naked in', 650]
#
# 531 -- 113
# event a a beautiful woman stands naked in our shower event b we drive half way across town to retrieve a television set from the aforementioned woman is exboyfriend query on what plane of existence is there even a semirational link between these events
# ['retrieve a television set from the', 652]
#
# 532 -- 113
# event a a beautiful woman stands naked in our shower event b we drive half way across town to retrieve a television set from the aforementioned woman is exboyfriend query on what plane of existence is there even a semirational link between these events
# ['on what plane of existence is', 653]
#
# 533 -- 113
# event a a beautiful woman stands naked in our shower event b we drive half way across town to retrieve a television set from the aforementioned woman is exboyfriend query on what plane of existence is there even a semirational link between these events
# ['there even a semirational link between', 653]
#
# 534 -- 114
# she asked me to do her a favour sheldon
# ['she asked me to do her', 654]
#
# 538 -- 115
# that is a biological impossibility and you did not have to come
# ['that is a biological impossibility and', 658]
#
# 539 -- 115
# that is a biological impossibility and you did not have to come
# ['you did not have to come', 658]
#
# 543 -- 117
# come on you know how it is with breakups
# ['come on you know how it', 661]
#
# 546 -- 118
# you did not break up with joyce kim she defected to north korea
# ['you did not break up with', 664]
#
# 547 -- 118
# you did not break up with joyce kim she defected to north korea
# ['joyce kim she defected to north', 664]
#
# 548 -- 119
# to mend her broken heart this situation is much less complicated there is some kind of dispute between penny and her exboyfriend as to who gets custody of the tv she just wanted to avoid having a scene with him
# ['this situation is much less complicated', 666]
#
# 550 -- 119
# to mend her broken heart this situation is much less complicated there is some kind of dispute between penny and her exboyfriend as to who gets custody of the tv she just wanted to avoid having a scene with him
# ['and her exboyfriend as to who', 667]
#
# 557 -- 120
# uh i am sorry do you speak english
# ['i am sorry do you speak', 674]
#
# 558 -- 121
# oh he speaks english he just can not speak to women
# ['oh he speaks english he just', 675]
#
# 559 -- 123
# he is kind of a nerd juice box
# ['he is kind of a nerd', 676]
#
# 571 -- 125
# it is just a privilege to watch your mind at work
# ['it is just a privilege to', 690]
#
# 579 -- 126
# my mom bought me those pants
# ['my mom bought me those pants', 703]
#
# 600 -- 129
# yeah i have had him since level ten his name is buttons anyway if you had your own game character we could hang out maybe go on a quest
# ['yeah i have had him since', 719]
#
# 601 -- 129
# yeah i have had him since level ten his name is buttons anyway if you had your own game character we could hang out maybe go on a quest
# ['anyway if you had your own', 721]
#
# 602 -- 129
# yeah i have had him since level ten his name is buttons anyway if you had your own game character we could hang out maybe go on a quest
# ['game character we could hang out', 721]
#
# 603 -- 131
# so you will think about it
# ['so you will think about it', 723]
#
# 604 -- 132
# oh i do not think i will be able to stop thinking about it
# ['oh i do not think i', 724]
#
# 605 -- 132
# oh i do not think i will be able to stop thinking about it
# ['will be able to stop thinking', 724]
#
# 606 -- 139
# well your exboyfriend sends his regards and i think the rest is fairly selfexplanatory
# ['well your exboyfriend sends his regards', 728]
#
# 607 -- 139
# well your exboyfriend sends his regards and i think the rest is fairly selfexplanatory
# ['and i think the rest is', 728]
#
# 608 -- 140
# i am so sorry i really thought if you guys went instead of me he would not be such an ass
# ['i really thought if you guys', 729]
#
# 609 -- 140
# i am so sorry i really thought if you guys went instead of me he would not be such an ass
# ['went instead of me he would', 729]
#
# 610 -- 141
# no it was a valid hypothesis
# ['no it was a valid hypothesis', 730]
#
# 611 -- 142
# really thank you so much for going and trying you are uh you are so terrific why do not you put some clothes on i will get my purse and dinner is on me okay
# ['really thank you so much for', 733]
#
# 613 -- 142
# really thank you so much for going and trying you are uh you are so terrific why do not you put some clothes on i will get my purse and dinner is on me okay
# ['why do not you put some', 735]
#
# 614 -- 142
# really thank you so much for going and trying you are uh you are so terrific why do not you put some clothes on i will get my purse and dinner is on me okay
# ['clothes on i will get my', 735]
#
# 615 -- 142
# really thank you so much for going and trying you are uh you are so terrific why do not you put some clothes on i will get my purse and dinner is on me okay
# ['purse and dinner is on me', 735]
#
# 616 -- 144
# thank you you are not done with her are you
# ['you are not done with her', 738]

# %%
# Combine two set and show in the open subtitle
temp_set = set()
for x in subtitle_indexs_dict_s2e:
    temp_set.add(sub_segments[x][1])
print(len(temp_set))
for x in subtitle_indexs_dict_e2s:
    temp_set.add(x)
print(len(temp_set))
for x in valid_utterances:
    # print(x[-1])
    temp_set.add(x[-1])
print(len(temp_set))
# for i, sub in enumerate(subtitles):
#     # Show the whole subtitle, matched subtitle will be highlighted
#     if i in temp_set:
#         print("!!!!", sub)
#     else:
#         print(sub)
# Out:
# 93
# 99
# 102
