# %%
import pickle as pkl
import json

# %%
# Merge all episode indexs data
results = {}
with open('episode_indexs_0_20.pkl', 'rb') as f:
    temp = pkl.load(f)
    for x in temp:
        results[x] = temp[x]
    print(len(results))
    print(results.keys())
    print('=='*50)

with open('episode_indexs_20_40.pkl', 'rb') as f:
    temp = pkl.load(f)
    for x in temp:
        results[x] = temp[x]
    print(len(results))
    print(results.keys())
    print('=='*50)

with open('episode_indexs_40_60.pkl', 'rb') as f:
    temp = pkl.load(f)
    for x in temp:
        results[x] = temp[x]
    print(len(results))
    print(results.keys())
    print('=='*50)

with open('episode_indexs_60_90.pkl', 'rb') as f:
    temp = pkl.load(f)
    for x in temp:
        results[x] = temp[x]
    print(len(results))
    print(results.keys())
    print('=='*50)

with open('episode_indexs_90_100.pkl', 'rb') as f:
    temp = pkl.load(f)
    for x in temp:
        results[x] = temp[x]
    print(len(results))
    print(results.keys())
    print('=='*50)

with open('episode_indexs_100_150.pkl', 'rb') as f:
    temp = pkl.load(f)
    for x in temp:
        results[x] = temp[x]
    print(len(results))
    print(results.keys())
    print('=='*50)

with open('episode_indexs_150_180.pkl', 'rb') as f:
    temp = pkl.load(f)
    for x in temp:
        results[x] = temp[x]
    print(len(results))
    print(results.keys())
    print('=='*50)

with open('episode_indexs_180_end.pkl', 'rb') as f:
    temp = pkl.load(f)
    for x in temp:
        results[x] = temp[x]
    print(len(results))
    print(results.keys())
    print('=='*50)
# Out:
# 40
# dict_keys(['S04E21', 'S06E21', 'S08E06', 'S07E20', 'S04E12', 'S09E09', 'S08E07', 'S02E03', 'S09E08', 'S02E17', 'S05E14', 'S09E20', 'S09E22', 'S04E23', 'S05E07', 'S05E23', 'S07E11', 'S09E15', 'S08E16', 'S01E12', 'S07E19', 'S03E09', 'S04E02', 'S05E12', 'S06E20', 'S06E12', 'S02E06', 'S02E05', 'S08E01', 'S04E19', 'S02E21', 'S02E20', 'S07E14', 'S08E10', 'S03E23', 'S08E17', 'S07E07', 'S06E08', 'S08E22', 'S08E21'])
# ...
# 55
# dict_keys(['S04E21', 'S06E21', 'S08E06', 'S07E20', 'S04E12', 'S09E09', 'S08E07', 'S02E03', 'S09E08', 'S02E17', 'S05E14', 'S09E20', 'S09E22', 'S04E23', 'S05E07', 'S05E23', 'S07E11', 'S09E15', 'S08E16', 'S01E12', 'S07E19', 'S03E09', 'S04E02', 'S05E12', 'S06E20', 'S06E12', 'S02E06', 'S02E05', 'S08E01', 'S04E19', 'S02E21', 'S02E20', 'S07E14', 'S08E10', 'S03E23', 'S08E17', 'S07E07', 'S06E08', 'S08E22', 'S08E21', 'S09E02', 'S01E06', 'S04E17', 'S09E01', 'S02E02', 'S05E05', 'S05E15', 'S08E14', 'S09E18', 'S03E05', 'S02E15', 'S03E04', 'S02E08', 'S04E22', 'S04E03'])
# ...
# 63
# ...

# %%
with open('episode_indexs_transformed.pkl', 'rb') as f:
    results = pkl.load(f)
print(len(results))
# Out:
# 204

# %%
for x in results:
    print(x, len(results[x]))
# Out:
# S04E17 133
# S03E20 182
# S02E23 97
# S06E09 390
# S09E09 1565
# S04E21 228
# S05E08 305
# S06E19 860
# S03E12 1021
# S05E10 1275
# S09E18 762
# S08E20 518
# S06E18 211
# S05E20 436
# S03E06 248
# S02E13 55
# S07E10 298
# S09E14 838
# S08E21 570
# S07E21 521
# S04E01 237
# S03E22 598
# S05E19 276
# S03E07 175
# S03E15 499
# S07E08 148
# S01E16 181
# S05E23 363
# S04E24 283
# S05E18 343
# S06E05 190
# S04E02 199
# S04E15 826
# S01E04 217
# S02E01 502
# S01E01 1241
# S02E08 1753
# S01E12 381
# S02E14 604
# S06E16 1361
# S04E19 872
# S05E16 1840
# S06E15 224
# S08E15 277
# S09E08 2808
# S07E16 445
# S02E11 307
# S04E12 244
# S03E09 715
# S06E08 110
# S02E22 988
# S02E02 65
# S01E14 3352
# S03E23 167
# S02E16 969
# S08E18 2920
# S04E20 1487
# S08E03 219
# S04E16 639
# S09E11 680
# S08E24 76
# S09E13 823
# S08E10 293
# S08E04 188
# S03E18 755
# S03E08 200
# S06E01 349
# S09E23 319
# S09E17 379
# S01E10 752
# S03E05 176
# S09E03 194
# S08E06 311
# S07E20 256
# S03E04 1979
# S09E22 590
# ...

# %%
epi_keys = list(results.keys())
for x in epi_keys[:2]:
    temp = results[x]
    print(x, len(temp))
    for item in temp:
        print(item)
    print('=='*50)
# Out:
# S04E17 133
# [6275973, 'well no sir and do you', 'well no sir and do you know why', '當然不 你知道為什麼嗎?']
# [6275975, 'every thursday night for the last', 'every thursday night for the last eight years you and i and our friends have gathered here in this very spot to break bread covered with cheese and sauce discuss the issues of the day and yes share a laugh or two', '過去八年裡每個週四晚上 你 我 還有我們的朋友們 坐在這裡 切開塗滿芝士和香腸的麵餅 談論一下生活 偶爾相視一笑']
# [6275975, 'eight years you and i and', 'every thursday night for the last eight years you and i and our friends have gathered here in this very spot to break bread covered with cheese and sauce discuss the issues of the day and yes share a laugh or two', '過去八年裡每個週四晚上 你 我 還有我們的朋友們 坐在這裡 切開塗滿芝士和香腸的麵餅 談論一下生活 偶爾相視一笑']
# ...

# %%
with open('episode_indexs.pkl', 'rb') as f:
    results = pkl.load(f)
print(len(results))
# Out:
# 204

# %%
# # Define input file
# input_file_path = "episode_indexs_test.pkl"

# %%
# # Load Data
# with open(input_file_path, 'rb') as f:
#     results = pkl.load(f)

# %%
# Load Open Subtitle
with open('en_subtitles.pkl', 'rb') as f:
    en_subtitle = pkl.load(f)
with open('zh_subtitles.pkl', 'rb') as f:
    zh_subtitle = pkl.load(f)

# %%
# Load All Data
results = {}
with open('episode_indexs_former_20.pkl', 'rb') as f:
    temp = pkl.load(f)
    for x in temp:
        results[x] = temp[x]
with open('episode_indexs_40_60.pkl', 'rb') as f:
    temp = pkl.load(f)
    for x in temp:
        results[x] = temp[x]

# %%
with open('episode_indexs_all_2.pkl', 'rb') as f:
    results = pkl.load(f)
print(len(results))
# Out:
# 142

# %%
for x in results:
    temp.add(x)

# %%
print(len(temp))
# Out:
# 142

# %%
# Load Alignment result
with open('episode_indexs_transformed.pkl', 'rb') as f:
    results = pkl.load(f)
print(len(results))

# %%
epi_keys = list(results.keys())
for item in epi_keys[:2]:
    print(item, )
# Out:
# S04E17
# S03E20

# %%
# Check the alignment using indexs
target_index_dict = {}

for item in results:
    print(item)
    dic = {}
    for x in results[item]:
        dic[x[0]] = x[1:]
    idxs = sorted(list(dic.keys()))
    print(idxs)
    gaps = []
    for i in range(len(idxs)-1):
        gaps.append(idxs[i+1]-idxs[i])
    print(gaps)
    for i in range(len(gaps)-3):
        if max(gaps[i: i+3]) < 1000:
            print("Target Indexs:", idxs[i: i+3])
            target_index_dict[item] = idxs[i: i+3]
            break
    print('=='*50)
# Out:
# S04E17
# [130240, 358864, 515967, 788537, 1164062, 1287339, 2547862, 2921155, 3115171, 3173358, 3232744, 3421640, 3464833, 3521733, 3785308, 4370538, 4402735, 4424465, 4477601, 4479659, 4715266, 4840842, 4942791, 5120034, 5520379, 5873000, 5891392, 6275973, 6275975, 6275976, 6276008, 6276009, 6276010, 6276029, 6276030, 6276063, 6276064, 6276065, 6276067, 6276069, 6276070, 6276071, 6276072, 6276089, 6276091, 6276139, 6276140, 6276141, 6276152, 6276153, 6276155, 6276159, 6276164, 6276165, 6276166, 6276167, 6276168, 6276169, 6276170, 6276189, 6276194, 6276196, 6276247, 6276258, 6276275, 6693460, 6780130, 6884678, 6907809, 7065557, 7389585, 7477326, 7529991, 7572042, 7771402, 8048739, 8254350, 8770553, 8928943, 9034111, 9459045, 9802629]
# ...

# %%
season_dict = {}
for item in target_index_dict:
    temp = item.strip().split('E')
    season_key = temp[0]
    episode_key = temp[1]
    if season_key not in season_dict:
        season_dict[season_key] = {}
    else:
        season_dict[season_key][episode_key] = target_index_dict[item]

# %%
for item in target_index_dict:
    temp = item.strip().split('E')
    season_key = temp[0]
    episode_key = temp[1]
    if season_key not in season_dict:
        season_dict[season_key] = {}
    else:
        season_dict[season_key][episode_key] = target_index_dict[item]

# %%
count = 0
for item in sorted(season_dict.keys()):
    episodes = []
    print(item)
    for x in sorted(season_dict[item].keys()):
        e_key = item + "E" + x
        count += 1
        print(e_key, season_dict[item][x])

print(count)
# Out:
# S01
# S01E01 [2884721, 2884762, 2884778]
# S01E02 [4236002, 4236003, 4236020]
# S01E03 [4236281, 4236282, 4236287]
# S01E04 [4236604, 4236606, 4236620]
# S01E05 [4236906, 4236907, 4236909]
# S01E06 [4237187, 4237188, 4237189]
# S01E07 [4245874, 4245876, 4245879]
# S01E08 [1188486, 1188996, 1189674]
# S01E09 [4701261, 4701262, 4701286]
# S01E10 [4700044, 4700047, 4700059]
# S01E11 [4700339, 4700340, 4700341]
# S01E12 [4700457, 4700628, 4700638]
# S01E13 [4700940, 4700941, 4700942]
# S01E14 [101478, 101578, 101642]
# S01E15 [1730785, 1731468, 1732044]
# S01E16 [4702248, 4702249, 4702266]
# S02
# S02E01 [4813144, 4813146, 4813152]
# S02E02 [4798781, 4798782, 4798783]
# S02E03 [4798374, 4799104, 4799105]
# S02E04 [4799403, 4799404, 4799427]
# S02E05 [4799723, 4799724, 4799729]
# S02E06 [3346071, 3346448, 3346899]
# S02E07 [4800306, 4800307, 4800308]
# S02E08 [150136, 150192, 150467]
# S02E09 [4800746, 4800879, 4800880]
# S02E10 [2058811, 2059111, 2059113]
# ...

# %%
# Locate utterances and subtitles for one episode
base = 4424331
bias = 400
subtitles_en = en_subtitle[base-bias: base+bias]
subtitles_zh = zh_subtitle[base-bias: base+bias]
episode = u

# %%
# Out:
# 800

# %%
print(target_index_dict['S08E18'])
print(season_dict['S08E18'])
# Out:
# [319626, 320615, 320618]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/w9/673mfrb56v7dvx7hhvw7s6240000gn/T/ipykernel_39364/1544666220.py in <module>
#       1 print(target_index_dict['S08E18'])
# ----> 2 print(season_dict['S08E18'])
#
# KeyError: 'S08E18'

# %%
base = 320615
print(en_subtitle[320615], zh_subtitle[320615])
# Out:
# He just left out with his family in the middle of the night last night. 他带着全家溜走了 在半夜三更

# %%
base = 7887587
for i in range(40):
    print(en_subtitle[base-40+i], zh_subtitle[base-40+i])
print("=======", en_subtitle[base-40+i], zh_subtitle[base-40+i])
for i in range(40):
    print(en_subtitle[base+i], zh_subtitle[base+i])
# Out:
# He's been my strong right arm. 他一直是我的左右手
# He can be yours, too. 对你也一样
# The buck stops with you. 你责无旁贷
# Good luck to you, Tom. 也祝你好运 汤姆
# Everybody ready? 准备好了吗
# Yep. 好 出发
# All right, got food, water for the next few days, maps, plenty of ammo. 食物和水都够几天用的 地图 大量弹药
# What else do you need? 还需要什么
# Wish to hell I was going with you. 我真希望能和你一起去
# Doesn't feel right. 但觉得不应该
# I know. You got to be here. 我明白 你必须留下来
# Somebody got to hold down this fort. 总得有人守住营地
# And you know I got Jeanne to think about now. 现在我也得考虑珍了
# So, get it done. 祝你成功
# If you're not back soon, I'm gonna come looking for you. 你要是不快回来 我就去找你
# Noted. 记住了
# Hey. We all know the bug made you do it. 我们都知道是你做的事情都是因为虫子
# Now go find Anne. 去把安带回来
# Let's mount up. 上马
# Hey, Lyle. 莱尔
# Remind me to pull the old eyebug defense next time somebody wants to lock me up. 下次有人想把我关起来的时候 记得提醒我带上防眼线虫的家伙
# Don't let it get to you. 别理他
# Raise your right hand. Repeat after me. 举起右手 跟着我念
# I, Marina Louise Peralta... 我 玛琳娜・路易・派拉塔
# ...

# %%
# Load Memor Dataset
with open('memor/data.json') as f:
    data = json.load(f)

# %%
print(len(data.keys()))
print(data.keys())
# Out:
# 5502
# ...

# %%
utterances = []
for item in data:
    if item.strip().split('_')[0]=='S01E01':
        utterances.extend(data[item]['sentences'])

# %%
base = 4424331
bias = 400
subtitle_pool = en_subtitle[base-bias: base+bias]

# %%
print(utterances)
# Out:
# ["if a photon is directed through a plane with two slits in it and either slit is observed it will not go through both slits. if it's unobserved it will, however, if it's observed after it's left the plane but before it hits its target, it will not have gone through both slits.", "agreed, what's your point?", "there's no point, i just think it's a good idea for a t-shirt.", "one across is aegean, eight down is nabakov, twenty-six across is mcm, fourteen down is... move your finger... phylum, which makes fourteen across port-au-prince. see, papa doc's capital idea, that's port-au-prince. haiti.", "no. we are committing genetic fraud. there's no guarantee that our sperm is going to generate high iq offspring, think about that. i have a sister with the same basic dna mix who hostesses at fuddruckers.", 'sheldon, this was your idea. a little extra money to get fractional t1 bandwidth in the apartment.', "i know, and i do yearn for faster downloads, but there's some poor woman is going to
# ...

# %%
for x in subtitle_pool:
    for item in utterances:
        if item!='' and x.strip() in item.strip():
            print("Subtitle:", x)
            print("Utterance:", item)
            print('=='*50)

# %%
for subtitle in subtitle_pool:
    for utt in utterances:

        pass

# %%
print(len(utterances))
# Out:
# 145

# %%
for x in utterances:
    print(x)
    print()
# Out:
# if a photon is directed through a plane with two slits in it and either slit is observed it will not go through both slits. if it's unobserved it will, however, if it's observed after it's left the plane but before it hits its target, it will not have gone through both slits.
#
# agreed, what's your point?
#
# there's no point, i just think it's a good idea for a t-shirt.
#
# one across is aegean, eight down is nabakov, twenty-six across is mcm, fourteen down is... move your finger... phylum, which makes fourteen across port-au-prince. see, papa doc's capital idea, that's port-au-prince. haiti.
#
# no. we are committing genetic fraud. there's no guarantee that our sperm is going to generate high iq offspring, think about that. i have a sister with the same basic dna mix who hostesses at fuddruckers.
#
# sheldon, this was your idea. a little extra money to get fractional t1 bandwidth in the apartment.
#
# ...

# %%
for x in subtitle_pool:
    print(x)
# Out:
# I think that we can manage that.
# I'm not going to take part in that nonsense.
# You don't live here, Iisakki. It's not of your concern.
# Quit your yapping.
# We'll all take care of Nikolas.
# Beginning with the Hannuses.
# The boy will move to the next family on Christmas.
# Is this agreed?
# -Yes.
# Merry Christmas, sister Aada.
# I could not forget my mother and my father - and my sister Aada.
# I knew they would not be coming back - but I missed them dearly.
# But time heals the wounds - and by autumn the sadness began to fade away.
# My boat's broken. Fix it.
# -Ask your father.
# My father has gone fishing.
# -Ask your mother, then.
# Mother can't do it.
# -Give it to me.
# Turn, boat!
# -It won't turn!
# Why doesn't it come here? Turn right!
# There it goes!
# I didn't know it back then - but Eemeli would become a good friend.
# Good throw. It bounced off the water.
# I found a great stone.
# -Stretch your arm back and throw.
# You can do it. One, two, three!
# ...

# %%
start = utterances[0]
end = utterances[-2]
print(start)
print()
print(end)
# Out:
# if a photon is directed through a plane with two slits in it and either slit is observed it will not go through both slits. if it's unobserved it will, however, if it's observed after it's left the plane but before it hits its target, it will not have gone through both slits.
#
# really? great.

# %%
base = 4244471
for i in range(40):
    print(en_subtitle[base-40+i], zh_subtitle[base-40+i])
print("=======", en_subtitle[base-40+i], zh_subtitle[base-40+i])
for i in range(400):
    print(en_subtitle[base+i], zh_subtitle[base+i])
# Out:
# Find new friends. 去找新朋友
# - So who wants to rent Fiddler? 那谁去租那部音乐剧?
# - No need. We have the special edition. 没必要 我们有特别收藏版
# Well, maybe we are like Haroon and Tanvir. 也许我们真的就像Haroon和Tanvir
# This is Dr. Sheldon Cooper. 我是Sheldon Cooper博士
# Yeah, I need to cancel my membership to the planetarium. 我想取消天文馆的会员资格
# Yeah, well, I'm sorry too but there's just no room for you in my wallet. 我也很抱歉 但我钱包里没地方放会员卡了
# No, I understand, but it was between you and the Museum of Natural History and frankly, you don't have dinosaurs. 我能理解 但我要在 你们和自然历史博物馆中选择 坦白说 你们那儿没恐龙
# Oh, I'll miss you too. Bye-bye. 我也会怀念你们的 再见
# Okay, I know you're texting about me and I'd really like you to stop. 好啦 我知道你们在发短信说我 你们最好停下来
# Oh, dear, I am rightly and truly screwed. 亲爱的 我彻底完蛋了
# I thought you were finding new friends. 嗨 我以为你去找新朋友了
# I've got some feelers out. 我那边有那个音乐剧的碟
# In the meantime, listen to this. 还有 听这个
# [ON RECORDING] Hi, Rajesh, this is Lalita Gupta. 嗨 Rajesh 我是Lalita Gupta
# ...

# %%
for item in sorted(season_dict.keys()):
    episodes = []
    print(item)
    for x in sorted(season_dict[item].keys()):
        print(x, season_dict[item][x])
    print("=="*50)
# Out:
# S01
# 01 [4424328, 4424331, 4424357]
# 02 [4236021, 4236022, 4236028]
# 03 [4236310, 4236332, 4236337]
# 05 [4236908, 4236909, 4236926]
# 06 [4237188, 4237202, 4237264]
# 07 [4245874, 4245881, 4245883]
# 08 [4244392, 4244471, 4244472]
# 09 [4701261, 4701262, 4701286]
# 10 [4700061, 4700111, 4700116]
# 14 [4701576, 4701608, 4701654]
# 15 [4701920, 4701971, 4701980]
# 16 [4702249, 4702266, 4702302]
# ...
# S02
# 02 [4798782, 4798802, 4798842]
# 04 [4799433, 4799447, 4799450]
# 05 [4799732, 4799733, 4799761]
# 06 [4799982, 4799984, 4800024]
# 07 [4800351, 4800363, 4800407]
# 08 [4800620, 4800627, 4800628]
# 11 [4798509, 4798575, 4798578]
# 15 [5254719, 5254748, 5254775]
# 17 [5255278, 5255298, 5255324]
# 19 [5255848, 5255854, 5255929]
# 20 [5256126, 5256133, 5256246]
# 21 [5256437, 5256438, 5256441]
# 22 [5256711, 5256721, 5256722]
# 23 [5377378, 5377381, 5377390]
# ...
# S03
# 02 [5425052, 5425061, 5425063]
# 03 [5424694, 5424704, 5424770]
# 04 [5444344, 5444345, 5444351]
# ...

# %%
idx_dict = {}
for item in sorted(season_dict.keys()):
    # print(item)
    temp = {}
    for x in sorted(season_dict[item].keys()):
        temp[x] = season_dict[item][x][1]
    idx_dict[item] = temp
        # print(x, season_dict[item][x])

for x in idx_dict:
    print(x)
    temp = idx_dict[x]
    for item in temp:
        print(item, temp[item])
# Out:
# {'S01': {'01': 4424416, '02': 4236085, '03': 4236344, '04': 4236691, '05': 4237012, '06': 4237286, '07': 4245883, '08': 4244471, '09': 4701262, '10': 4700162, '11': 4700385, '12': 4700651, '13': 4701030, '14': 4701608, '15': 4701971, '16': 4702266}, 'S02': {'01': 4813154, '02': 4798802, '03': 4799222, '04': 4799458, '05': 4799733, '06': 4800063, '07': 4800363, '08': 4800711, '09': 4800897, '11': 4798575, '12': 5253750, '13': 5254075, '14': 5254393, '15': 5254748, '16': 5254981, '17': 5255298, '18': 5255652, '19': 5256053, '20': 5256254, '21': 5256441, '22': 5256721, '23': 5377393}, 'S03': {'01': 5422094, '02': 5425063, '03': 5424704, '04': 5444345, '05': 5444768, '06': 5444154, '07': 5450286, '08': 5452069, '09': 5455738, '10': 5458185, '11': 5458517, '12': 5802547, '14': 5831934, '15': 5834199, '16': 5838524, '18': 5855807, '20': 5887766, '21': 5930850, '22': 5931162, '23': 5883357}, 'S04': {'01': 5895828, '02': 5896702, '03': 5897198, '04': 5897311, '05': 5897719, '06': 5898005, '0
# ...

# %%
# Out:
# love me now? 你现在爱我了吗？
# You love me, do you? 你爱我了 是吗？
# Maek... 阿云... ...
# Maek.... 阿云... ...
# Where are you, Maek? 阿云 你在哪里？
# Maek...you promised.... you will stay with me forever 阿云... ... 你对我...
# I love you 我爱你... ...
# ********* 坡 阿暖 作品
# Iht, i don't know... if you can see this handphone film 阿石 我不知道... 你是否能看到这段手机影像
# but if you see it you will know in my heart 但是如果你看到了 你就会知道 在我心底
# I love you very much love you...till the moment my breath stops 我也很爱你 爱你... 直到我停止呼吸的那一刻
# Watch this, it's really cool. 看好了 超级酷
# Call Leonard Hofstadter. 呼叫Leonard Hofstadter
# Did you say: "Call Hellen Boxlightner? 您需要呼叫Helen Boxleitner吗?
# Did you say: "Call Temple Badsaidor?" 您需要呼叫Temple Beth Seder吗?
# Let me try! - 让我试试
# Call... 呼叫Mcflono McfIlooloon
# Calling "Rajesh Koothrappali." 正在呼叫Rajesh Koothrappali
# That's very impressive. 真是叹为观止啊
# And a little racist. 再加点种族主义
# If we're all through playing "mock the flawed technology," 你们嘲讽科技瑕疵够了吧
# can we get on with Halo night? 能不能开始玩光晕了?
# ...

# %%
for x in idx_dict:
    print(x)
    temp = []
    for item in idx_dict[x]:
        temp.append(idx_dict[x][item])
    temp = sorted(temp)
    print(temp)
    print()
    gaps = []
    for i in range(len(temp)-1):
        gaps.append(temp[i+1]-temp[i])
    print(gaps)
    print()
    print('=='*50)
    # temp_indexs = idx_dict[x]
    # for item in temp_indexs:
    #     print(item, temp_indexs[item])
# Out:
# S01
# [4236085, 4236344, 4236691, 4237012, 4237286, 4244471, 4245883, 4424416, 4700162, 4700385, 4700651, 4701030, 4701262, 4701608, 4701971, 4702266]
#
# [259, 347, 321, 274, 7185, 1412, 178533, 275746, 223, 266, 379, 232, 346, 363, 295]
#
# ...
# S02
# [4798575, 4798802, 4799222, 4799458, 4799733, 4800063, 4800363, 4800711, 4800897, 4813154, 5253750, 5254075, 5254393, 5254748, 5254981, 5255298, 5255652, 5256053, 5256254, 5256441, 5256721, 5377393]
#
# [227, 420, 236, 275, 330, 300, 348, 186, 12257, 440596, 325, 318, 355, 233, 317, 354, 401, 201, 187, 280, 120672]
#
# ...
# S03
# [5422094, 5424704, 5425063, 5444154, 5444345, 5444768, 5450286, 5452069, 5455738, 5458185, 5458517, 5802547, 5831934, 5834199, 5838524, 5855807, 5883357, 5887766, 5930850, 5931162]
#
# [2610, 359, 19091, 191, 423, 5518, 1783, 3669, 2447, 332, 344030, 29387, 2265, 4325, 17283, 27550, 4409, 43084, 312]
#
# ...
# S04
# ...

# %%
base = 5253750
for i in range(20):
    print(en_subtitle[base-40+i], zh_subtitle[base-40+i])
print("=======", en_subtitle[base-40+i], zh_subtitle[base-40+i])
for i in range(20):
    print(en_subtitle[base+i], zh_subtitle[base+i])
# Out:
# I told you to go gently- everybody back out, back out. 跟你说了要温柔
# All right, that's the last servo. 好了 最后一个部件
# Behold the Mobile Omnidirectional Neutralization and Termination Eradicator. 人家看到的 是全方位运动 销毁终结切割器
# Or-- Monte. 或者 MONT
# Featuring one articulated razor-sharp killing saw one polycarbonate grinding wheel steel-armor plate exoskeleton top and bottom. 装有铰接式锋利锯齿 聚碳酸脂磨刀和转动轮
# Enough horsepower to drive 110 pounds of mechanized death from zero to holy crap in 4.8 seconds. 从上到下为钢制金属板外壳 其马力足以将110磅的机械 彻底毁灭 只需短短4.8秒
# Is it wrong to say I love our killer robot? 如果说我爱我们的机器人杀手 是不是大罪过?
# As with my father, I both love and fear it. 跟对我爸爸一样 我既爱它又怕它
# All right, enough chitchat. Let's destroy something. 好了 废话少说 我们来搞点破坏
# One, two, three. Unh. 1 2 3
# Okay, what shall be first to taste the wrath of Monte? 好了 让谁先来尝尝Monte的厉害
# Maybe we should start small. Oh, perhaps today is the day we finally find out what's inside the Magic 8 Ball. 也许我们该从小的东西开始
# Did it when I was 4. 我四岁时就做过了
# ...

# %%
# for x in idx_dict:
#     print(x)
#     temp = idx_dict[x]
#     for item in temp:
#         print(item, temp[item])
# Out:
# S01
# 01 4424416
# 02 4236085
# 03 4236344
# 04 4236691
# 05 4237012
# 06 4237286
# 07 4245883
# 08 4244471
# 09 4701262
# 10 4700162
# 11 4700385
# 12 4700651
# 13 4701030
# 14 4701608
# 15 4701971
# 16 4702266
# S02
# 01 4813154
# 02 4798802
# 03 4799222
# 04 4799458
# 05 4799733
# 06 4800063
# 07 4800363
# 08 4800711
# 09 4800897
# 11 4798575
# 12 5253750
# 13 5254075
# 14 5254393
# 15 5254748
# 16 5254981
# 17 5255298
# 18 5255652
# 19 5256053
# 20 5256254
# 21 5256441
# 22 5256721
# 23 5377393
# S03
# 01 5422094
# 02 5425063
# 03 5424704
# 04 5444345
# 05 5444768
# 06 5444154
# 07 5450286
# 08 5452069
# 09 5455738
# 10 5458185
# 11 5458517
# 12 5802547
# 14 5831934
# 15 5834199
# 16 5838524
# 18 5855807
# 20 5887766
# 21 5930850
# 22 5931162
# 23 5883357
# S04
# 01 5895828
# 02 5896702
# 03 5897198
# 04 5897311
# 05 5897719
# 06 5898005
# 07 5898370
# 08 5898659
# 09 5898892
# 11 5896415
# 12 6274580
# 13 6274850
# 14 6275069
# 15 6275364
# 16 6275662
# 17 6276010
# 18 6276401
# ...

# %%
for x in data:
    print(x.strip().split('_')[0])
# Out:
# S01E01
# S01E01
# S01E01
# S01E01
# S01E01
# S01E01
# S01E01
# S01E01
# S01E01
# S01E01
# S01E01
# S01E01
# S01E01
# S01E01
# S01E01
# S01E01
# S01E01
# S01E01
# S01E01
# S01E01
# S01E01
# S01E01
# S01E01
# S01E01
# S01E01
# S01E01
# S01E01
# S01E01
# S01E01
# S01E01
# S01E01
# S01E01
# S01E01
# S01E01
# S01E01
# S01E01
# S01E01
# S01E01
# S01E01
# S01E01
# S01E01
# S01E01
# S01E02
# S01E02
# S01E02
# S01E02
# S01E02
# S01E02
# S01E02
# S01E02
# S01E02
# S01E02
# S01E02
# S01E02
# S01E02
# S01E02
# S01E02
# S01E02
# S01E02
# S01E02
# S01E02
# S01E02
# S01E02
# S01E02
# S01E02
# S01E02
# S01E02
# S01E02
# S01E02
# S01E02
# S01E02
# S01E02
# S01E02
# S01E02
# S01E02
# S01E02
# S01E02
# S01E02
# S01E02
# S01E02
# S01E03
# S01E03
# S01E03
# S01E03
# S01E03
# S01E03
# S01E03
# S01E03
# S01E03
# S01E03
# S01E03
# S01E03
# S01E03
# S01E03
# S01E03
# S01E03
# S01E03
# S01E03
# S01E03
# S01E03
# S01E03
# S01E03
# S01E03
# S01E03
# S01E03
# S01E03
# S01E03
# S01E03
# S01E03
# S01E03
# S01E03
# ...

# %%
results = {}
with open('episode_indexs_5_test.pkl', 'rb') as f:
    temp = pkl.load(f)
    for x in temp:
        results[x] = temp[x]
    for x in results:
        print(x)
        for item in results[x]:
            print(item)
# Out:
# S01E16
# [6588245, ' i was going to do', 'And i was going to do this.', '因为我要使出这招']
# [4702249, 'rant was a concise summation of', 'For the record, that psychotic rant was a concise summation of the research of Bertram Forer who, in 1948, proved conclusively through meticulous experiments that astrology is pseudoscientific hokum.', '请注意 你所谓的"疯言疯语" 是巴纳姆效应的简明总结 他在1948年经过精密的设计性实验得出']
# [4702272, 'parents would change their mind ', "When I was little, I'd think my parents would change their mind and surprise me.", '我是指 在我还小的时候 我曾想也许我父母会改变主意 然后给我一个惊喜派对']
# [4702273, 'came home from my cello lesson', 'This one birthday, I came home from my cello lesson and I saw strange cars parked out front.', '比如有次生日 我刚学完大提琴回家 我看到很多陌生车停在门外']
# [4702302, 'have a birthday party before hell', 'The possibility exists Leonard could have a birthday party before hell freezes over.', '-- 在地狱结冰之前 Leonard过生日派对存在可能性']
# ...
