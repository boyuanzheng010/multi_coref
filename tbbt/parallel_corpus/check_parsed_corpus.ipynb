# %%
import pickle as pkl
import spacy
import csv
import json
from copy import deepcopy
from tqdm import tqdm
import benepar

# %%
sm_parser = spacy.load('en_core_web_sm')
berkeley_parser = spacy.load('en_core_web_md')
berkeley_parser.add_pipe("benepar", config={"model": "benepar_en3"})
# stanza_parser = spacy_stanza.load_pipeline('en')
trf_parser = spacy.load("en_core_web_trf")

# %%
# Load Parsed Corpus
sm_parser = spacy.load('en_core_web_sm')

with open('tbbt_en_zh.pkl', 'rb') as f_zh:
    with open('tbbt_en_fa.pkl', 'rb') as f_fa:
        zh = pkl.load(f_zh)
        fa = pkl.load(f_fa)
        inter_keys = set(zh.keys()) & set(fa.keys())

with open('parsed_corpus.pkl', 'rb') as f:
    nps = pkl.load(f)
with open('parsed_corpus_all.pkl', 'rb') as f:
    tags = pkl.load(f)

# %%
print(nps[(1,1)][0][0])
# Out:
# {'utterance': ' So if a photon is directed through a plane with two slits in it and either slit is observed it will not go through both slits. If it’s unobserved it will, however, if it’s observed after it’s left the plane but before it hits its target, it will not have gone through both slits.', 'speaker': 'Sheldon', 'en_subtitles': ['If a photon is directed through a plane with two slits in it and either is observed it will not go through both.', 'If unobserved, it will.', "If it's observed after it left the plane, before it hits its target...", 'it will not have gone through both slits.'], 'zh_subtitles': ['将光子正对平面上的双缝 观察任意一个隙缝 它不会穿过那两个隙缝', '如果没被观察 那就会', '总之 如果观察它在离开平面到击中目标之前', '它就不会穿过那两个隙缝'], 'sm_noun_chunk': [('a photon', 1, 3), ('a plane', 6, 8), ('two slits', 9, 11), ('it', 12, 13), ('it', 17, 18), ('both', 22, 23), ('it', 27, 28), ('it', 31, 32), ('it', 35, 36), ('the plane', 37, 39), ('it', 41, 42), ('its target', 43, 45), ('it', 46, 47), ('both slits', 52, 54)], 'sm_pron': [('it', 12, 13), ('it', 17, 18), ('both', 22, 23), ('it', 27, 28), ('it', 31, 32), ('it', 35, 36), ('it', 41, 42), ('its', 43, 44), ('it', 46, 47)], 'berkeley_noun_chunk': [('a photon', 1, 3), ('a plane', 6, 8), ('two slits', 9, 11), ('it', 12, 13), ('it', 17, 18), ('both', 22, 23), ('it', 27, 28), ('it', 31, 32), ('it', 35, 36), ('the plane', 37, 39), ('it', 41, 42), ('its target', 43, 45), ('it', 46, 47), ('both slits', 52, 54)], 'berkeley_pron': [('it', 12, 13), ('it', 17, 18), ('both', 22, 23), ('it', 27, 28), ('it', 31, 32), ('it', 35, 36), ('it', 41, 42), ('its', 43, 44), ('it', 46, 47)], 'trf_noun_chunk': [('a photon', 1, 3), ('a plane', 6, 8), ('two slits', 9, 11), ('it', 12, 13), ('either', 14, 15), ('it', 17, 18), ('both', 22, 23), ('it', 27, 28), ('it', 31, 32), ('it', 35, 36), ('the plane', 37, 39), ('it', 41, 42), ('its target', 43, 45), ('it', 46, 47), ('both slits', 52, 54)], 'trf_pron': [('it', 12, 13), ('either', 14, 15), ('it', 17, 18), ('both', 22, 23), ('it', 27, 28), ('it', 31, 32), ('it', 35, 36), ('it', 41, 42), ('its', 43, 44), ('it', 46, 47)]}

# %%
# Merge
def merge_maximum_span(spans):
    spans.sort(key=lambda x: x[1])
    to_pop = []
    for j, (word_0, start_idx_0, end_idx_0) in enumerate(spans):
        for k, (word_1, start_idx_1, end_idx_1) in enumerate(spans):
            if k==j:
                continue
            if (start_idx_1 >= start_idx_0) and (end_idx_1 <= end_idx_0):
                to_pop.append(spans[k])
    for item in to_pop:
        if item in spans:
            spans.remove(item)

    spans.sort(key=lambda x: x[1])

    return spans

# %%
# Collect Data
output = []
for epi_key in inter_keys:
    if epi_key != (1,8):
        continue
    for i in range(len(nps[epi_key])):
        all_sentences = []
        all_query_spans = []

        scene = nps[epi_key][i]
        scene_tag = tags[epi_key][i]
        j = 0
        for utt, tag in zip(scene, scene_tag):
            speaker = utt['speaker'].strip().strip("(").strip(")").strip().strip(".").strip().strip(":")
            speaker_tokens = [item.text for item in sm_parser(speaker)]
            if "en_subtitles" not in utt:
                sentence = utt['utterance']
                utt['sm_noun_chunk'] = [(item.text, item.start, item.end) for item in sm_parser(sentence).noun_chunks]
                utt['sm_pron'] = [(item.text,i, i+1) for i, item in enumerate(sm_parser(sentence)) if item.pos_=="PRON"]
                utt['berkeley_noun_chunk'] = [(item.text, item.start, item.end) for item in berkeley_parser(sentence).noun_chunks]
                utt['berkeley_pron'] = [(item.text,i, i+1) for i, item in enumerate(berkeley_parser(sentence)) if item.pos_=="PRON"]
                utt['trf_noun_chunk'] = [(item.text, item.start, item.end) for item in trf_parser(sentence).noun_chunks]
                utt['trf_pron'] = [(item.text,i, i+1) for i, item in enumerate(trf_parser(sentence)) if item.pos_=="PRON"]
            else:
                sentence = " ".join([x.strip().lstrip('-').lstrip().lstrip('.').lstrip() for x in utt['en_subtitles']])
            sentence_token = [item.text for item in sm_parser(sentence)]
            noun_phrase = merge_maximum_span(list(set(utt['sm_noun_chunk']) | set(utt['berkeley_noun_chunk']) | set(utt['trf_noun_chunk'])))
            pron = merge_maximum_span(list(set(utt['sm_pron']) | set(utt['berkeley_pron']) | set(utt['trf_pron'])))
            mention = list(set(noun_phrase)|set(pron))
            mention.sort(key=lambda x: x[1])

            all_sentences.append(speaker_tokens + [":"] + sentence_token)
            for span in mention:
                all_query_spans.append({
                        "sentenceIndex": j,
                        "startToken": span[1] + len(speaker_tokens) + 1,
                        "endToken": span[2] + len(speaker_tokens) + 1
                    })
            j+=1
        output.append({
            "sentences": all_sentences,
            "querySpans": all_query_spans,
            "candidateSpans": all_query_spans,
            "clickSpans": all_query_spans,
            })

with open('sample_annotate_epi_1_8_new.csv', "w", encoding="utf-8") as csv_fh:
        fieldnames = ['json_data']
        writer = csv.DictWriter(csv_fh, fieldnames, lineterminator='\n')
        writer.writeheader()
        for line in output:
            writer.writerow({'json_data': json.dumps(line)})

# %%
for utt in tags[(1,1)][0]:
    for item in utt:
        print(item, ":", utt[item], len(utt[item]))
    print("=="*50)
# Out:
# utterance :  So if a photon is directed through a plane with two slits in it and either slit is observed it will not go through both slits. If it’s unobserved it will, however, if it’s observed after it’s left the plane but before it hits its target, it will not have gone through both slits. 280
# speaker : Sheldon 7
# en_subtitles : ['If a photon is directed through a plane with two slits in it and either is observed it will not go through both.', 'If unobserved, it will.', "If it's observed after it left the plane, before it hits its target...", 'it will not have gone through both slits.'] 4
# zh_subtitles : ['将光子正对平面上的双缝 观察任意一个隙缝 它不会穿过那两个隙缝', '如果没被观察 那就会', '总之 如果观察它在离开平面到击中目标之前', '它就不会穿过那两个隙缝'] 4
# sm_pron : [('If', 0, 1, 'SCONJ', 'IN'), ('a', 1, 2, 'DET', 'DT'), ('photon', 2, 3, 'NOUN', 'NN'), ('is', 3, 4, 'AUX', 'VBZ'), ('directed', 4, 5, 'VERB', 'VBN'), ('through', 5, 6, 'ADP', 'IN'), ('a', 6, 7, 'DET', 'DT'), ('plane', 7, 8, 'NOUN', 'NN'), ('with', 8, 9, 'ADP', 'IN'), ('two', 9, 10, 'NUM', 'CD'), ('slits', 10, 11, 'NOUN', 'NNS'), ('in', 11, 12, 'ADP', 'IN'), ('it', 12, 13, 'PRON', 'PRP'), ('and', 13, 14, 'CCONJ', 'CC'), ('either', 14, 15, 'CCONJ', 'CC'), ('is', 15, 16, 'AUX', 'VBZ'), ('observed', 16, 17, 'VERB', 'VBN'), ('it', 17, 18, 'PRON', 'PRP'), ('will', 18, 19, 'AUX', 'MD'), ('not', 19, 20, 'PART', 'RB'), ('go', 20, 21, 'VERB', 'VB'), ('through', 21, 22, 'ADP', 'IN'), ('both', 22, 23, 'PRON', 'DT'), ('.', 23, 24, 'PUNCT', '.'), ('If', 24, 25, 'SCONJ', 'IN'), ('unobserved', 25, 26, 'VERB', 'VBN'), (',', 26, 27, 'PUNCT', ','), ('it', 27, 28, 'PRON', 'PRP'), ('will', 28, 29, 'AUX', 'MD'), ('.', 29, 30, 'PUNCT', '.'), ('If', 30, 31, 'SCONJ', 'IN'), ('it', 31, 32, 'PRON', 'PRP'), ("'s", 32, 33, 'AUX', 'VBZ'), ('observed', 33, 34, 'VERB', 'VBN'), ('after', 34, 35, 'SCONJ', 'IN'), ('it', 35, 36, 'PRON', 'PRP'), ('left', 36, 37, 'VERB', 'VBD'), ('the', 37, 38, 'DET', 'DT'), ('plane', 38, 39, 'NOUN', 'NN'), (',', 39, 40, 'PUNCT', ','), ('before', 40, 41, 'SCONJ', 'IN'), ('it', 41, 42, 'PRON', 'PRP'), ('hits', 42, 43, 'VERB', 'VBZ'), ('its', 43, 44, 'PRON', 'PRP$'), ('target', 44, 45, 'NOUN', 'NN'), ('...', 45, 46, 'PUNCT', ':'), ('it', 46, 47, 'PRON', 'PRP'), ('will', 47, 48, 'AUX', 'MD'), ('not', 48, 49, 'PART', 'RB'), ('have', 49, 50, 'AUX', 'VB'), ('gone', 50, 51, 'VERB', 'VBN'), ('through', 51, 52, 'ADP', 'IN'), ('both', 52, 53, 'DET', 'DT'), ('slits', 53, 54, 'NOUN', 'NNS'), ('.', 54, 55, 'PUNCT', '.')] 55
# berkeley_pron : [('If', 0, 1, 'SCONJ', 'IN'), ('a', 1, 2, 'DET', 'DT'), ('photon', 2, 3, 'NOUN', 'NN'), ('is', 3, 4, 'AUX', 'VBZ'), ('directed', 4, 5, 'VERB', 'VBN'), ('through', 5, 6, 'ADP', 'IN'), ('a', 6, 7, 'DET', 'DT'), ('plane', 7, 8, 'NOUN', 'NN'), ('with', 8, 9, 'ADP', 'IN'), ('two', 9, 10, 'NUM', 'CD'), ('slits', 10, 11, 'NOUN', 'NNS'), ('in', 11, 12, 'ADP', 'IN'), ('it', 12, 13, 'PRON', 'PRP'), ('and', 13, 14, 'CCONJ', 'CC'), ('either', 14, 15, 'CCONJ', 'DT'), ('is', 15, 16, 'AUX', 'VBZ'), ('observed', 16, 17, 'VERB', 'VBN'), ('it', 17, 18, 'PRON', 'PRP'), ('will', 18, 19, 'AUX', 'MD'), ('not', 19, 20, 'PART', 'RB'), ('go', 20, 21, 'VERB', 'VB'), ('through', 21, 22, 'ADP', 'IN'), ('both', 22, 23, 'PRON', 'DT'), ('.', 23, 24, 'PUNCT', '.'), ('If', 24, 25, 'SCONJ', 'IN'), ('unobserved', 25, 26, 'VERB', 'JJ'), (',', 26, 27, 'PUNCT', ','), ('it', 27, 28, 'PRON', 'PRP'), ('will', 28, 29, 'AUX', 'MD'), ('.', 29, 30, 'PUNCT', '.'), ('If', 30, 31, 'SCONJ', 'IN'), ('it', 31, 32, 'PRON', 'PRP'), ("'s", 32, 33, 'AUX', 'VBZ'), ('observed', 33, 34, 'VERB', 'VBN'), ('after', 34, 35, 'SCONJ', 'IN'), ('it', 35, 36, 'PRON', 'PRP'), ('left', 36, 37, 'VERB', 'VBD'), ('the', 37, 38, 'DET', 'DT'), ('plane', 38, 39, 'NOUN', 'NN'), (',', 39, 40, 'PUNCT', ','), ('before', 40, 41, 'SCONJ', 'IN'), ('it', 41, 42, 'PRON', 'PRP'), ('hits', 42, 43, 'VERB', 'VBZ'), ('its', 43, 44, 'PRON', 'PRP$'), ('target', 44, 45, 'NOUN', 'NN'), ('...', 45, 46, 'PUNCT', ':'), ('it', 46, 47, 'PRON', 'PRP'), ('will', 47, 48, 'AUX', 'MD'), ('not', 48, 49, 'PART', 'RB'), ('have', 49, 50, 'AUX', 'VB'), ('gone', 50, 51, 'VERB', 'VBN'), ('through', 51, 52, 'ADP', 'IN'), ('both', 52, 53, 'DET', 'DT'), ('slits', 53, 54, 'NOUN', 'NNS'), ('.', 54, 55, 'PUNCT', '.')] 55
# trf_pron : [('If', 0, 1, 'SCONJ', 'IN'), ('a', 1, 2, 'DET', 'DT'), ('photon', 2, 3, 'NOUN', 'NN'), ('is', 3, 4, 'AUX', 'VBZ'), ('directed', 4, 5, 'VERB', 'VBN'), ('through', 5, 6, 'ADP', 'IN'), ('a', 6, 7, 'DET', 'DT'), ('plane', 7, 8, 'NOUN', 'NN'), ('with', 8, 9, 'ADP', 'IN'), ('two', 9, 10, 'NUM', 'CD'), ('slits', 10, 11, 'NOUN', 'NNS'), ('in', 11, 12, 'ADP', 'IN'), ('it', 12, 13, 'PRON', 'PRP'), ('and', 13, 14, 'CCONJ', 'CC'), ('either', 14, 15, 'PRON', 'DT'), ('is', 15, 16, 'AUX', 'VBZ'), ('observed', 16, 17, 'VERB', 'VBN'), ('it', 17, 18, 'PRON', 'PRP'), ('will', 18, 19, 'AUX', 'MD'), ('not', 19, 20, 'PART', 'RB'), ('go', 20, 21, 'VERB', 'VB'), ('through', 21, 22, 'ADP', 'IN'), ('both', 22, 23, 'PRON', 'DT'), ('.', 23, 24, 'PUNCT', '.'), ('If', 24, 25, 'SCONJ', 'IN'), ('unobserved', 25, 26, 'ADJ', 'JJ'), (',', 26, 27, 'PUNCT', ','), ('it', 27, 28, 'PRON', 'PRP'), ('will', 28, 29, 'AUX', 'MD'), ('.', 29, 30, 'PUNCT', '.'), ('If', 30, 31, 'SCONJ', 'IN'), ('it', 31, 32, 'PRON', 'PRP'), ("'s", 32, 33, 'AUX', 'VBZ'), ('observed', 33, 34, 'VERB', 'VBN'), ('after', 34, 35, 'SCONJ', 'IN'), ('it', 35, 36, 'PRON', 'PRP'), ('left', 36, 37, 'VERB', 'VBD'), ('the', 37, 38, 'DET', 'DT'), ('plane', 38, 39, 'NOUN', 'NN'), (',', 39, 40, 'PUNCT', ','), ('before', 40, 41, 'SCONJ', 'IN'), ('it', 41, 42, 'PRON', 'PRP'), ('hits', 42, 43, 'VERB', 'VBZ'), ('its', 43, 44, 'PRON', 'PRP$'), ('target', 44, 45, 'NOUN', 'NN'), ('...', 45, 46, 'PUNCT', ':'), ('it', 46, 47, 'PRON', 'PRP'), ('will', 47, 48, 'AUX', 'MD'), ('not', 48, 49, 'PART', 'RB'), ('have', 49, 50, 'AUX', 'VB'), ('gone', 50, 51, 'VERB', 'VBN'), ('through', 51, 52, 'ADP', 'IN'), ('both', 52, 53, 'DET', 'DT'), ('slits', 53, 54, 'NOUN', 'NNS'), ('.', 54, 55, 'PUNCT', '.')] 55
# ====================================================================================================
# utterance :  Agreed, what’s your point? 27
# speaker : Leonard 7
# en_subtitles : ["Agreed. What's your point?"] 1
# zh_subtitles : ['没错 但你为什么要说这个?'] 1
# sm_pron : [('Agreed', 0, 1, 'VERB', 'VBN'), ('.', 1, 2, 'PUNCT', '.'), ('What', 2, 3, 'PRON', 'WP'), ("'s", 3, 4, 'AUX', 'VBZ'), ('your', 4, 5, 'PRON', 'PRP$'), ('point', 5, 6, 'NOUN', 'NN'), ('?', 6, 7, 'PUNCT', '.')] 7
# berkeley_pron : [('Agreed', 0, 1, 'VERB', 'VBN'), ('.', 1, 2, 'PUNCT', '.'), ('What', 2, 3, 'PRON', 'WP'), ("'s", 3, 4, 'AUX', 'VBZ'), ('your', 4, 5, 'PRON', 'PRP$'), ('point', 5, 6, 'NOUN', 'NN'), ('?', 6, 7, 'PUNCT', '.')] 7
# trf_pron : [('Agreed', 0, 1, 'INTJ', 'UH'), ('.', 1, 2, 'PUNCT', '.'), ('What', 2, 3, 'PRON', 'WP'), ("'s", 3, 4, 'AUX', 'VBZ'), ('your', 4, 5, 'PRON', 'PRP$'), ('point', 5, 6, 'NOUN', 'NN'), ('?', 6, 7, 'PUNCT', '.')] 7
# ====================================================================================================
# utterance :  There’s no point, I just think it’s a good idea for a tee-shirt.  66
# speaker : Sheldon 7
# en_subtitles : ["There's no point, I just think it's a good idea for a T-shirt."] 1
# zh_subtitles : ['没什么 我只是觉得这个主意 可以用于设计T恤衫'] 1
# sm_pron : [('There', 0, 1, 'PRON', 'EX'), ("'s", 1, 2, 'VERB', 'VBZ'), ('no', 2, 3, 'DET', 'DT'), ('point', 3, 4, 'NOUN', 'NN'), (',', 4, 5, 'PUNCT', ','), ('I', 5, 6, 'PRON', 'PRP'), ('just', 6, 7, 'ADV', 'RB'), ('think', 7, 8, 'VERB', 'VBP'), ('it', 8, 9, 'PRON', 'PRP'), ("'s", 9, 10, 'AUX', 'VBZ'), ('a', 10, 11, 'DET', 'DT'), ('good', 11, 12, 'ADJ', 'JJ'), ('idea', 12, 13, 'NOUN', 'NN'), ('for', 13, 14, 'ADP', 'IN'), ('a', 14, 15, 'DET', 'DT'), ('T', 15, 16, 'PROPN', 'NNP'), ('-', 16, 17, 'PUNCT', 'HYPH'), ('shirt', 17, 18, 'NOUN', 'NN'), ('.', 18, 19, 'PUNCT', '.')] 19
# berkeley_pron : [('There', 0, 1, 'PRON', 'EX'), ("'s", 1, 2, 'VERB', 'VBZ'), ('no', 2, 3, 'DET', 'DT'), ('point', 3, 4, 'NOUN', 'NN'), (',', 4, 5, 'PUNCT', ','), ('I', 5, 6, 'PRON', 'PRP'), ('just', 6, 7, 'ADV', 'RB'), ('think', 7, 8, 'VERB', 'VBP'), ('it', 8, 9, 'PRON', 'PRP'), ("'s", 9, 10, 'AUX', 'VBZ'), ('a', 10, 11, 'DET', 'DT'), ('good', 11, 12, 'ADJ', 'JJ'), ('idea', 12, 13, 'NOUN', 'NN'), ('for', 13, 14, 'ADP', 'IN'), ('a', 14, 15, 'DET', 'DT'), ('T', 15, 16, 'PROPN', 'NNP'), ('-', 16, 17, 'PUNCT', 'HYPH'), ('shirt', 17, 18, 'NOUN', 'NN'), ('.', 18, 19, 'PUNCT', '.')] 19
# trf_pron : [('There', 0, 1, 'PRON', 'EX'), ("'s", 1, 2, 'VERB', 'VBZ'), ('no', 2, 3, 'DET', 'DT'), ('point', 3, 4, 'NOUN', 'NN'), (',', 4, 5, 'PUNCT', ','), ('I', 5, 6, 'PRON', 'PRP'), ('just', 6, 7, 'ADV', 'RB'), ('think', 7, 8, 'VERB', 'VBP'), ('it', 8, 9, 'PRON', 'PRP'), ("'s", 9, 10, 'AUX', 'VBZ'), ('a', 10, 11, 'DET', 'DT'), ('good', 11, 12, 'ADJ', 'JJ'), ('idea', 12, 13, 'NOUN', 'NN'), ('for', 13, 14, 'ADP', 'IN'), ('a', 14, 15, 'DET', 'DT'), ('T', 15, 16, 'NOUN', 'NN'), ('-', 16, 17, 'PUNCT', 'HYPH'), ('shirt', 17, 18, 'NOUN', 'NN'), ('.', 18, 19, 'PUNCT', '.')] 19
# ====================================================================================================
# utterance :  Excuse me? 11
# speaker : Leonard 7
# ====================================================================================================
# utterance :  Hang on.  10
# speaker : Receptionist 12
# ====================================================================================================
# utterance :  One across is Aegean, eight down is Nabakov, twenty-six across is MCM, fourteen down is… move your finger… phylum, which makes fourteen across Port-au-Prince. See, Papa Doc’s capital idea, that’s Port-au-Prince. Haiti.  220
# speaker : Leonard 7
# en_subtitles : ['One across is Aegean, eight down is Nabokov.', 'Twenty-six across is MCM.', 'Fourteen down is... Move your finger.', 'phylum, which makes 14 across Port-Au-Prince.', "See, Papa Doc's capital idea, that's Port-Au-Prince.", 'Haiti.'] 6
# zh_subtitles : ['横1是Aegean (爱情海)', '竖8是Nabokov (小说洛丽塔的作者) 横26是MCM', '竖14是...', '手指挪开点 Phylum (生物门类) 这样一来横14就是Port -au', '瞧 提示是"Papa doc的首都" (海地前总统) 所以是太子港', '海地的'] 6
# sm_pron : [('One', 0, 1, 'NUM', 'CD'), ('across', 1, 2, 'ADV', 'RB'), ('is', 2, 3, 'AUX', 'VBZ'), ('Aegean', 3, 4, 'PROPN', 'NNP'), (',', 4, 5, 'PUNCT', ','), ('eight', 5, 6, 'NUM', 'CD'), ('down', 6, 7, 'ADV', 'RB'), ('is', 7, 8, 'AUX', 'VBZ'), ('Nabokov', 8, 9, 'PROPN', 'NNP'), ('.', 9, 10, 'PUNCT', '.'), ('Twenty', 10, 11, 'NUM', 'CD'), ('-', 11, 12, 'PUNCT', 'HYPH'), ('six', 12, 13, 'NUM', 'CD'), ('across', 13, 14, 'ADV', 'RB'), ('is', 14, 15, 'AUX', 'VBZ'), ('MCM', 15, 16, 'PROPN', 'NNP'), ('.', 16, 17, 'PUNCT', '.'), ('Fourteen', 17, 18, 'NUM', 'CD'), ('down', 18, 19, 'ADV', 'RB'), ('is', 19, 20, 'AUX', 'VBZ'), ('...', 20, 21, 'PUNCT', ':'), ('Move', 21, 22, 'VERB', 'VB'), ('your', 22, 23, 'PRON', 'PRP$'), ('finger', 23, 24, 'NOUN', 'NN'), ('.', 24, 25, 'PUNCT', '.'), ('phylum', 25, 26, 'NOUN', 'NNS'), (',', 26, 27, 'PUNCT', ','), ('which', 27, 28, 'PRON', 'WDT'), ('makes', 28, 29, 'VERB', 'VBZ'), ('14', 29, 30, 'NUM', 'CD'), ('across', 30, 31, 'ADP', 'IN'), ('Port', 31, 32, 'PROPN', 'NNP'), ('-', 32, 33, 'PUNCT', 'HYPH'), ('Au', 33, 34, 'PROPN', 'NNP'), ('-', 34, 35, 'PUNCT', 'HYPH'), ('Prince', 35, 36, 'PROPN', 'NNP'), ('.', 36, 37, 'PUNCT', '.'), ('See', 37, 38, 'VERB', 'VB'), (',', 38, 39, 'PUNCT', ','), ('Papa', 39, 40, 'PROPN', 'NNP'), ('Doc', 40, 41, 'PROPN', 'NNP'), ("'s", 41, 42, 'PART', 'POS'), ('capital', 42, 43, 'NOUN', 'NN'), ('idea', 43, 44, 'NOUN', 'NN'), (',', 44, 45, 'PUNCT', ','), ('that', 45, 46, 'PRON', 'DT'), ("'s", 46, 47, 'AUX', 'VBZ'), ('Port', 47, 48, 'PROPN', 'NNP'), ('-', 48, 49, 'PUNCT', 'HYPH'), ('Au', 49, 50, 'PROPN', 'NNP'), ('-', 50, 51, 'PUNCT', 'HYPH'), ('Prince', 51, 52, 'PROPN', 'NNP'), ('.', 52, 53, 'PUNCT', '.'), ('Haiti', 53, 54, 'PROPN', 'NNP'), ('.', 54, 55, 'PUNCT', '.')] 55
# berkeley_pron : [('One', 0, 1, 'NUM', 'CD'), ('across', 1, 2, 'ADP', 'RB'), ('is', 2, 3, 'AUX', 'VBZ'), ('Aegean', 3, 4, 'PROPN', 'NNP'), (',', 4, 5, 'PUNCT', ','), ('eight', 5, 6, 'NUM', 'CD'), ('down', 6, 7, 'ADV', 'RB'), ('is', 7, 8, 'AUX', 'VBZ'), ('Nabokov', 8, 9, 'PROPN', 'NNP'), ('.', 9, 10, 'PUNCT', '.'), ('Twenty', 10, 11, 'NUM', 'CD'), ('-', 11, 12, 'PUNCT', 'HYPH'), ('six', 12, 13, 'NUM', 'CD'), ('across', 13, 14, 'ADP', 'IN'), ('is', 14, 15, 'AUX', 'VBZ'), ('MCM', 15, 16, 'PROPN', 'NNP'), ('.', 16, 17, 'PUNCT', '.'), ('Fourteen', 17, 18, 'NUM', 'CD'), ('down', 18, 19, 'ADV', 'RB'), ('is', 19, 20, 'AUX', 'VBZ'), ('...', 20, 21, 'PUNCT', ':'), ('Move', 21, 22, 'VERB', 'VB'), ('your', 22, 23, 'PRON', 'PRP$'), ('finger', 23, 24, 'NOUN', 'NN'), ('.', 24, 25, 'PUNCT', '.'), ('phylum', 25, 26, 'NOUN', 'NN'), (',', 26, 27, 'PUNCT', ','), ('which', 27, 28, 'PRON', 'WDT'), ('makes', 28, 29, 'VERB', 'VBZ'), ('14', 29, 30, 'NUM', 'CD'), ('across', 30, 31, 'ADP', 'IN'), ('Port', 31, 32, 'PROPN', 'NNP'), ('-', 32, 33, 'PUNCT', 'HYPH'), ('Au', 33, 34, 'PROPN', 'NNP'), ('-', 34, 35, 'NOUN', 'HYPH'), ('Prince', 35, 36, 'NOUN', 'NNP'), ('.', 36, 37, 'PUNCT', '.'), ('See', 37, 38, 'VERB', 'VB'), (',', 38, 39, 'PUNCT', ','), ('Papa', 39, 40, 'PROPN', 'NNP'), ('Doc', 40, 41, 'PROPN', 'NNP'), ("'s", 41, 42, 'PART', 'POS'), ('capital', 42, 43, 'NOUN', 'NN'), ('idea', 43, 44, 'NOUN', 'NN'), (',', 44, 45, 'PUNCT', ','), ('that', 45, 46, 'PRON', 'DT'), ("'s", 46, 47, 'AUX', 'VBZ'), ('Port', 47, 48, 'PROPN', 'NNP'), ('-', 48, 49, 'PUNCT', 'HYPH'), ('Au', 49, 50, 'PROPN', 'NNP'), ('-', 50, 51, 'NOUN', 'HYPH'), ('Prince', 51, 52, 'NOUN', 'NNP'), ('.', 52, 53, 'PUNCT', '.'), ('Haiti', 53, 54, 'PROPN', 'NNP'), ('.', 54, 55, 'PUNCT', '.')] 55
# trf_pron : [('One', 0, 1, 'NUM', 'CD'), ('across', 1, 2, 'ADV', 'RB'), ('is', 2, 3, 'AUX', 'VBZ'), ('Aegean', 3, 4, 'PROPN', 'NNP'), (',', 4, 5, 'PUNCT', ','), ('eight', 5, 6, 'NUM', 'CD'), ('down', 6, 7, 'ADV', 'RB'), ('is', 7, 8, 'AUX', 'VBZ'), ('Nabokov', 8, 9, 'PROPN', 'NNP'), ('.', 9, 10, 'PUNCT', '.'), ('Twenty', 10, 11, 'NUM', 'CD'), ('-', 11, 12, 'PUNCT', 'HYPH'), ('six', 12, 13, 'NUM', 'CD'), ('across', 13, 14, 'ADV', 'RB'), ('is', 14, 15, 'AUX', 'VBZ'), ('MCM', 15, 16, 'PROPN', 'NNP'), ('.', 16, 17, 'PUNCT', '.'), ('Fourteen', 17, 18, 'NUM', 'CD'), ('down', 18, 19, 'ADV', 'RB'), ('is', 19, 20, 'AUX', 'VBZ'), ('...', 20, 21, 'PUNCT', ':'), ('Move', 21, 22, 'VERB', 'VB'), ('your', 22, 23, 'PRON', 'PRP$'), ('finger', 23, 24, 'NOUN', 'NN'), ('.', 24, 25, 'PUNCT', '.'), ('phylum', 25, 26, 'PROPN', 'NNP'), (',', 26, 27, 'PUNCT', ','), ('which', 27, 28, 'PRON', 'WDT'), ('makes', 28, 29, 'VERB', 'VBZ'), ('14', 29, 30, 'NUM', 'CD'), ('across', 30, 31, 'ADP', 'IN'), ('Port', 31, 32, 'PROPN', 'NNP'), ('-', 32, 33, 'PUNCT', 'HYPH'), ('Au', 33, 34, 'PROPN', 'NNP'), ('-', 34, 35, 'PUNCT', 'HYPH'), ('Prince', 35, 36, 'PROPN', 'NNP'), ('.', 36, 37, 'PUNCT', '.'), ('See', 37, 38, 'VERB', 'VB'), (',', 38, 39, 'PUNCT', ','), ('Papa', 39, 40, 'PROPN', 'NNP'), ('Doc', 40, 41, 'PROPN', 'NNP'), ("'s", 41, 42, 'PART', 'POS'), ('capital', 42, 43, 'NOUN', 'NN'), ('idea', 43, 44, 'NOUN', 'NN'), (',', 44, 45, 'PUNCT', ','), ('that', 45, 46, 'PRON', 'WDT'), ("'s", 46, 47, 'AUX', 'VBZ'), ('Port', 47, 48, 'PROPN', 'NNP'), ('-', 48, 49, 'PUNCT', 'HYPH'), ('Au', 49, 50, 'PROPN', 'NNP'), ('-', 50, 51, 'PUNCT', 'HYPH'), ('Prince', 51, 52, 'PROPN', 'NNP'), ('.', 52, 53, 'PUNCT', '.'), ('Haiti', 53, 54, 'PROPN', 'NNP'), ('.', 54, 55, 'PUNCT', '.')] 55
# ====================================================================================================
# utterance :  Can I help you? 16
# speaker : Receptionist 12
# en_subtitles : ['Can I help you? - Yes.'] 1
# zh_subtitles : ['- 能为你效劳吗?'] 1
# sm_pron : [('Can', 0, 1, 'AUX', 'MD'), ('I', 1, 2, 'PRON', 'PRP'), ('help', 2, 3, 'VERB', 'VB'), ('you', 3, 4, 'PRON', 'PRP'), ('?', 4, 5, 'PUNCT', '.'), ('-', 5, 6, 'PUNCT', ':'), ('Yes', 6, 7, 'INTJ', 'UH'), ('.', 7, 8, 'PUNCT', '.')] 8
# berkeley_pron : [('Can', 0, 1, 'AUX', 'MD'), ('I', 1, 2, 'PRON', 'PRP'), ('help', 2, 3, 'VERB', 'VB'), ('you', 3, 4, 'PRON', 'PRP'), ('?', 4, 5, 'PUNCT', '.'), ('-', 5, 6, 'PUNCT', ':'), ('Yes', 6, 7, 'INTJ', 'UH'), ('.', 7, 8, 'PUNCT', '.')] 8
# trf_pron : [('Can', 0, 1, 'AUX', 'MD'), ('I', 1, 2, 'PRON', 'PRP'), ('help', 2, 3, 'VERB', 'VB'), ('you', 3, 4, 'PRON', 'PRP'), ('?', 4, 5, 'PUNCT', '.'), ('-', 5, 6, 'PUNCT', ':'), ('Yes', 6, 7, 'INTJ', 'UH'), ('.', 7, 8, 'PUNCT', '.')] 8
# ====================================================================================================
# utterance :  Yes. Um, is this the High IQ sperm bank? 41
# speaker : Leonard 7
# en_subtitles : ['Um, is this the high-IQ sperm bank?'] 1
# zh_subtitles : ['这里是高智商精子银行吗?'] 1
# sm_pron : [('Um', 0, 1, 'INTJ', 'UH'), (',', 1, 2, 'PUNCT', ','), ('is', 2, 3, 'AUX', 'VBZ'), ('this', 3, 4, 'PRON', 'DT'), ('the', 4, 5, 'DET', 'DT'), ('high', 5, 6, 'ADJ', 'JJ'), ('-', 6, 7, 'PUNCT', 'HYPH'), ('IQ', 7, 8, 'NOUN', 'NN'), ('sperm', 8, 9, 'NOUN', 'NN'), ('bank', 9, 10, 'NOUN', 'NN'), ('?', 10, 11, 'PUNCT', '.')] 11
# berkeley_pron : [('Um', 0, 1, 'INTJ', 'UH'), (',', 1, 2, 'PUNCT', ','), ('is', 2, 3, 'AUX', 'VBZ'), ('this', 3, 4, 'PRON', 'DT'), ('the', 4, 5, 'DET', 'DT'), ('high', 5, 6, 'ADJ', 'JJ'), ('-', 6, 7, 'PUNCT', 'HYPH'), ('IQ', 7, 8, 'NOUN', 'NN'), ('sperm', 8, 9, 'NOUN', 'NN'), ('bank', 9, 10, 'NOUN', 'NN'), ('?', 10, 11, 'PUNCT', '.')] 11
# trf_pron : [('Um', 0, 1, 'INTJ', 'UH'), (',', 1, 2, 'PUNCT', ','), ('is', 2, 3, 'AUX', 'VBZ'), ('this', 3, 4, 'PRON', 'DT'), ('the', 4, 5, 'DET', 'DT'), ('high', 5, 6, 'ADJ', 'JJ'), ('-', 6, 7, 'PUNCT', 'HYPH'), ('IQ', 7, 8, 'NOUN', 'NN'), ('sperm', 8, 9, 'NOUN', 'NN'), ('bank', 9, 10, 'NOUN', 'NN'), ('?', 10, 11, 'PUNCT', '.')] 11
# ====================================================================================================
# utterance :  If you have to ask, maybe you shouldn’t be here. 49
# speaker : Receptionist 12
# en_subtitles : ["If you have to ask, maybe you shouldn't be here."] 1
# zh_subtitles : ['如果你这么问 也许你不该来这'] 1
# sm_pron : [('If', 0, 1, 'SCONJ', 'IN'), ('you', 1, 2, 'PRON', 'PRP'), ('have', 2, 3, 'VERB', 'VBP'), ('to', 3, 4, 'PART', 'TO'), ('ask', 4, 5, 'VERB', 'VB'), (',', 5, 6, 'PUNCT', ','), ('maybe', 6, 7, 'ADV', 'RB'), ('you', 7, 8, 'PRON', 'PRP'), ('should', 8, 9, 'AUX', 'MD'), ("n't", 9, 10, 'PART', 'RB'), ('be', 10, 11, 'AUX', 'VB'), ('here', 11, 12, 'ADV', 'RB'), ('.', 12, 13, 'PUNCT', '.')] 13
# berkeley_pron : [('If', 0, 1, 'SCONJ', 'IN'), ('you', 1, 2, 'PRON', 'PRP'), ('have', 2, 3, 'VERB', 'VBP'), ('to', 3, 4, 'PART', 'TO'), ('ask', 4, 5, 'VERB', 'VB'), (',', 5, 6, 'PUNCT', ','), ('maybe', 6, 7, 'ADV', 'RB'), ('you', 7, 8, 'PRON', 'PRP'), ('should', 8, 9, 'AUX', 'MD'), ("n't", 9, 10, 'PART', 'RB'), ('be', 10, 11, 'AUX', 'VB'), ('here', 11, 12, 'ADV', 'RB'), ('.', 12, 13, 'PUNCT', '.')] 13
# trf_pron : [('If', 0, 1, 'SCONJ', 'IN'), ('you', 1, 2, 'PRON', 'PRP'), ('have', 2, 3, 'VERB', 'VBP'), ('to', 3, 4, 'PART', 'TO'), ('ask', 4, 5, 'VERB', 'VB'), (',', 5, 6, 'PUNCT', ','), ('maybe', 6, 7, 'ADV', 'RB'), ('you', 7, 8, 'PRON', 'PRP'), ('should', 8, 9, 'AUX', 'MD'), ("n't", 9, 10, 'PART', 'RB'), ('be', 10, 11, 'AUX', 'VB'), ('here', 11, 12, 'ADV', 'RB'), ('.', 12, 13, 'PUNCT', '.')] 13
# ====================================================================================================
# utterance :  I think this is the place. 27
# speaker : Sheldon 7
# en_subtitles : ['I think this is the place.'] 1
# zh_subtitles : ['我想就是这没错了'] 1
# sm_pron : [('I', 0, 1, 'PRON', 'PRP'), ('think', 1, 2, 'VERB', 'VBP'), ('this', 2, 3, 'PRON', 'DT'), ('is', 3, 4, 'AUX', 'VBZ'), ('the', 4, 5, 'DET', 'DT'), ('place', 5, 6, 'NOUN', 'NN'), ('.', 6, 7, 'PUNCT', '.')] 7
# berkeley_pron : [('I', 0, 1, 'PRON', 'PRP'), ('think', 1, 2, 'VERB', 'VBP'), ('this', 2, 3, 'PRON', 'DT'), ('is', 3, 4, 'AUX', 'VBZ'), ('the', 4, 5, 'DET', 'DT'), ('place', 5, 6, 'NOUN', 'NN'), ('.', 6, 7, 'PUNCT', '.')] 7
# trf_pron : [('I', 0, 1, 'PRON', 'PRP'), ('think', 1, 2, 'VERB', 'VBP'), ('this', 2, 3, 'PRON', 'DT'), ('is', 3, 4, 'AUX', 'VBZ'), ('the', 4, 5, 'DET', 'DT'), ('place', 5, 6, 'NOUN', 'NN'), ('.', 6, 7, 'PUNCT', '.')] 7
# ====================================================================================================
# utterance :  Fill these out. 16
# speaker : Receptionist 12
# en_subtitles : ['Fill these out. - Thank you.'] 1
# zh_subtitles : ['- 把这个填一填'] 1
# sm_pron : [('Fill', 0, 1, 'VERB', 'VB'), ('these', 1, 2, 'PRON', 'DT'), ('out', 2, 3, 'ADP', 'RP'), ('.', 3, 4, 'PUNCT', '.'), ('-', 4, 5, 'PUNCT', ':'), ('Thank', 5, 6, 'VERB', 'VBP'), ('you', 6, 7, 'PRON', 'PRP'), ('.', 7, 8, 'PUNCT', '.')] 8
# berkeley_pron : [('Fill', 0, 1, 'VERB', 'VB'), ('these', 1, 2, 'PRON', 'DT'), ('out', 2, 3, 'ADP', 'RP'), ('.', 3, 4, 'PUNCT', '.'), ('-', 4, 5, 'PUNCT', ':'), ('Thank', 5, 6, 'VERB', 'VB'), ('you', 6, 7, 'PRON', 'PRP'), ('.', 7, 8, 'PUNCT', '.')] 8
# trf_pron : [('Fill', 0, 1, 'VERB', 'VB'), ('these', 1, 2, 'PRON', 'DT'), ('out', 2, 3, 'ADP', 'RP'), ('.', 3, 4, 'PUNCT', '.'), ('-', 4, 5, 'PUNCT', ':'), ('Thank', 5, 6, 'VERB', 'VBP'), ('you', 6, 7, 'PRON', 'PRP'), ('.', 7, 8, 'PUNCT', '.')] 8
# ====================================================================================================
# utterance :  Thank-you. We’ll be right back. 32
# speaker : Leonard 7
# en_subtitles : ["We'll be right back."] 1
# zh_subtitles : ['- 谢谢 我们马上好'] 1
# sm_pron : [('We', 0, 1, 'PRON', 'PRP'), ("'ll", 1, 2, 'AUX', 'MD'), ('be', 2, 3, 'AUX', 'VB'), ('right', 3, 4, 'ADV', 'RB'), ('back', 4, 5, 'ADV', 'RB'), ('.', 5, 6, 'PUNCT', '.')] 6
# berkeley_pron : [('We', 0, 1, 'PRON', 'PRP'), ("'ll", 1, 2, 'AUX', 'MD'), ('be', 2, 3, 'AUX', 'VB'), ('right', 3, 4, 'ADV', 'RB'), ('back', 4, 5, 'ADV', 'RB'), ('.', 5, 6, 'PUNCT', '.')] 6
# trf_pron : [('We', 0, 1, 'PRON', 'PRP'), ("'ll", 1, 2, 'AUX', 'MD'), ('be', 2, 3, 'AUX', 'VB'), ('right', 3, 4, 'ADV', 'RB'), ('back', 4, 5, 'ADV', 'RB'), ('.', 5, 6, 'PUNCT', '.')] 6
# ====================================================================================================
# utterance :  Oh, take your time. I’ll just finish my crossword puzzle. Oh wait. 67
# speaker : Receptionist 12
# en_subtitles : ["Oh, take your time. I'll just finish my crossword puzzle.", 'Oh, wait.'] 2
# zh_subtitles : ['慢慢来 我还要玩填字游戏', '噢 慢着'] 2
# sm_pron : [('Oh', 0, 1, 'INTJ', 'UH'), (',', 1, 2, 'PUNCT', ','), ('take', 2, 3, 'VERB', 'VB'), ('your', 3, 4, 'PRON', 'PRP$'), ('time', 4, 5, 'NOUN', 'NN'), ('.', 5, 6, 'PUNCT', '.'), ('I', 6, 7, 'PRON', 'PRP'), ("'ll", 7, 8, 'AUX', 'MD'), ('just', 8, 9, 'ADV', 'RB'), ('finish', 9, 10, 'VERB', 'VB'), ('my', 10, 11, 'PRON', 'PRP$'), ('crossword', 11, 12, 'NOUN', 'NN'), ('puzzle', 12, 13, 'NOUN', 'NN'), ('.', 13, 14, 'PUNCT', '.'), ('Oh', 14, 15, 'INTJ', 'UH'), (',', 15, 16, 'PUNCT', ','), ('wait', 16, 17, 'VERB', 'VB'), ('.', 17, 18, 'PUNCT', '.')] 18
# berkeley_pron : [('Oh', 0, 1, 'INTJ', 'UH'), (',', 1, 2, 'PUNCT', ','), ('take', 2, 3, 'VERB', 'VB'), ('your', 3, 4, 'PRON', 'PRP$'), ('time', 4, 5, 'NOUN', 'NN'), ('.', 5, 6, 'PUNCT', '.'), ('I', 6, 7, 'PRON', 'PRP'), ("'ll", 7, 8, 'AUX', 'MD'), ('just', 8, 9, 'ADV', 'RB'), ('finish', 9, 10, 'VERB', 'VB'), ('my', 10, 11, 'PRON', 'PRP$'), ('crossword', 11, 12, 'ADJ', 'NN'), ('puzzle', 12, 13, 'NOUN', 'NN'), ('.', 13, 14, 'PUNCT', '.'), ('Oh', 14, 15, 'INTJ', 'UH'), (',', 15, 16, 'PUNCT', ','), ('wait', 16, 17, 'VERB', 'VB'), ('.', 17, 18, 'PUNCT', '.')] 18
# trf_pron : [('Oh', 0, 1, 'INTJ', 'UH'), (',', 1, 2, 'PUNCT', ','), ('take', 2, 3, 'VERB', 'VB'), ('your', 3, 4, 'PRON', 'PRP$'), ('time', 4, 5, 'NOUN', 'NN'), ('.', 5, 6, 'PUNCT', '.'), ('I', 6, 7, 'PRON', 'PRP'), ("'ll", 7, 8, 'AUX', 'MD'), ('just', 8, 9, 'ADV', 'RB'), ('finish', 9, 10, 'VERB', 'VB'), ('my', 10, 11, 'PRON', 'PRP$'), ('crossword', 11, 12, 'NOUN', 'NN'), ('puzzle', 12, 13, 'NOUN', 'NN'), ('.', 13, 14, 'PUNCT', '.'), ('Oh', 14, 15, 'INTJ', 'UH'), (',', 15, 16, 'PUNCT', ','), ('wait', 16, 17, 'VERB', 'VB'), ('.', 17, 18, 'PUNCT', '.')] 18
# ====================================================================================================
# utterance :  Leonard, I don’t think I can do this. 38
# speaker : Sheldon 7
# en_subtitles : ["Leonard, I don't think I can do this."] 1
# zh_subtitles : ['Leonard 我办不到'] 1
# sm_pron : [('Leonard', 0, 1, 'PROPN', 'NNP'), (',', 1, 2, 'PUNCT', ','), ('I', 2, 3, 'PRON', 'PRP'), ('do', 3, 4, 'AUX', 'VBP'), ("n't", 4, 5, 'PART', 'RB'), ('think', 5, 6, 'VERB', 'VB'), ('I', 6, 7, 'PRON', 'PRP'), ('can', 7, 8, 'AUX', 'MD'), ('do', 8, 9, 'VERB', 'VB'), ('this', 9, 10, 'PRON', 'DT'), ('.', 10, 11, 'PUNCT', '.')] 11
# berkeley_pron : [('Leonard', 0, 1, 'PROPN', 'NNP'), (',', 1, 2, 'PUNCT', ','), ('I', 2, 3, 'PRON', 'PRP'), ('do', 3, 4, 'AUX', 'VBP'), ("n't", 4, 5, 'PART', 'RB'), ('think', 5, 6, 'VERB', 'VB'), ('I', 6, 7, 'PRON', 'PRP'), ('can', 7, 8, 'AUX', 'MD'), ('do', 8, 9, 'VERB', 'VB'), ('this', 9, 10, 'PRON', 'DT'), ('.', 10, 11, 'PUNCT', '.')] 11
# trf_pron : [('Leonard', 0, 1, 'PROPN', 'NNP'), (',', 1, 2, 'PUNCT', ','), ('I', 2, 3, 'PRON', 'PRP'), ('do', 3, 4, 'AUX', 'VBP'), ("n't", 4, 5, 'PART', 'RB'), ('think', 5, 6, 'VERB', 'VB'), ('I', 6, 7, 'PRON', 'PRP'), ('can', 7, 8, 'AUX', 'MD'), ('do', 8, 9, 'VERB', 'VB'), ('this', 9, 10, 'PRON', 'DT'), ('.', 10, 11, 'PUNCT', '.')] 11
# ====================================================================================================
# utterance :  What, are you kidding? You’re a semi-pro.  43
# speaker : Leonard 7
# en_subtitles : ['What, are you kidding?'] 1
# zh_subtitles : ['开玩笑? 你可是半职业人士'] 1
# sm_pron : [('What', 0, 1, 'PRON', 'WP'), (',', 1, 2, 'PUNCT', ','), ('are', 2, 3, 'AUX', 'VBP'), ('you', 3, 4, 'PRON', 'PRP'), ('kidding', 4, 5, 'VERB', 'VBG'), ('?', 5, 6, 'PUNCT', '.')] 6
# berkeley_pron : [('What', 0, 1, 'PRON', 'WP'), (',', 1, 2, 'PUNCT', ','), ('are', 2, 3, 'AUX', 'VBP'), ('you', 3, 4, 'PRON', 'PRP'), ('kidding', 4, 5, 'VERB', 'VBG'), ('?', 5, 6, 'PUNCT', '.')] 6
# trf_pron : [('What', 0, 1, 'PRON', 'WP'), (',', 1, 2, 'PUNCT', ','), ('are', 2, 3, 'AUX', 'VBP'), ('you', 3, 4, 'PRON', 'PRP'), ('kidding', 4, 5, 'VERB', 'VBG'), ('?', 5, 6, 'PUNCT', '.')] 6
# ====================================================================================================
# utterance :  No. We are committing genetic fraud. There’s no guarantee that our sperm is going to generate high IQ offspring, think about that. I have a sister with the same basic DNA mix who hostesses at Fuddruckers. 205
# speaker : Sheldon 7
# en_subtitles : ['We are committing genetic fraud.', "There's no guarantee our sperm's going to generate high-IQ offspring. Think about that.", 'I have a sister with the same basic DNA mix who hostesses at Fuddruckers.'] 3
# zh_subtitles : ['不 我们这样是诈骗', '我们没法保证 生出来的一定是高智商小孩', '我姐姐跟我有一套相同的基本基因 她却在Fuddrucker餐厅当服务生'] 3
# sm_pron : [('We', 0, 1, 'PRON', 'PRP'), ('are', 1, 2, 'AUX', 'VBP'), ('committing', 2, 3, 'VERB', 'VBG'), ('genetic', 3, 4, 'ADJ', 'JJ'), ('fraud', 4, 5, 'NOUN', 'NN'), ('.', 5, 6, 'PUNCT', '.'), ('There', 6, 7, 'PRON', 'EX'), ("'s", 7, 8, 'VERB', 'VBZ'), ('no', 8, 9, 'DET', 'DT'), ('guarantee', 9, 10, 'NOUN', 'NN'), ('our', 10, 11, 'PRON', 'PRP$'), ('sperm', 11, 12, 'NOUN', 'NN'), ("'s", 12, 13, 'AUX', 'POS'), ('going', 13, 14, 'VERB', 'VBG'), ('to', 14, 15, 'PART', 'TO'), ('generate', 15, 16, 'VERB', 'VB'), ('high', 16, 17, 'ADJ', 'JJ'), ('-', 17, 18, 'PUNCT', 'HYPH'), ('IQ', 18, 19, 'NOUN', 'NN'), ('offspring', 19, 20, 'NOUN', 'NN'), ('.', 20, 21, 'PUNCT', '.'), ('Think', 21, 22, 'VERB', 'VB'), ('about', 22, 23, 'ADP', 'IN'), ('that', 23, 24, 'PRON', 'DT'), ('.', 24, 25, 'PUNCT', '.'), ('I', 25, 26, 'PRON', 'PRP'), ('have', 26, 27, 'VERB', 'VBP'), ('a', 27, 28, 'DET', 'DT'), ('sister', 28, 29, 'NOUN', 'NN'), ('with', 29, 30, 'ADP', 'IN'), ('the', 30, 31, 'DET', 'DT'), ('same', 31, 32, 'ADJ', 'JJ'), ('basic', 32, 33, 'ADJ', 'JJ'), ('DNA', 33, 34, 'NOUN', 'NN'), ('mix', 34, 35, 'NOUN', 'NN'), ('who', 35, 36, 'PRON', 'WP'), ('hostesses', 36, 37, 'VERB', 'VBZ'), ('at', 37, 38, 'ADP', 'IN'), ('Fuddruckers', 38, 39, 'PROPN', 'NNP'), ('.', 39, 40, 'PUNCT', '.')] 40
# berkeley_pron : [('We', 0, 1, 'PRON', 'PRP'), ('are', 1, 2, 'AUX', 'VBP'), ('committing', 2, 3, 'VERB', 'VBG'), ('genetic', 3, 4, 'ADJ', 'JJ'), ('fraud', 4, 5, 'NOUN', 'NN'), ('.', 5, 6, 'PUNCT', '.'), ('There', 6, 7, 'PRON', 'EX'), ("'s", 7, 8, 'VERB', 'VBZ'), ('no', 8, 9, 'DET', 'DT'), ('guarantee', 9, 10, 'NOUN', 'NN'), ('our', 10, 11, 'PRON', 'PRP$'), ('sperm', 11, 12, 'NOUN', 'NN'), ("'s", 12, 13, 'AUX', 'VBZ'), ('going', 13, 14, 'VERB', 'VBG'), ('to', 14, 15, 'PART', 'TO'), ('generate', 15, 16, 'VERB', 'VB'), ('high', 16, 17, 'ADJ', 'JJ'), ('-', 17, 18, 'PUNCT', 'HYPH'), ('IQ', 18, 19, 'NOUN', 'NN'), ('offspring', 19, 20, 'NOUN', 'NNS'), ('.', 20, 21, 'PUNCT', '.'), ('Think', 21, 22, 'VERB', 'VB'), ('about', 22, 23, 'ADP', 'IN'), ('that', 23, 24, 'PRON', 'DT'), ('.', 24, 25, 'PUNCT', '.'), ('I', 25, 26, 'PRON', 'PRP'), ('have', 26, 27, 'VERB', 'VBP'), ('a', 27, 28, 'DET', 'DT'), ('sister', 28, 29, 'NOUN', 'NN'), ('with', 29, 30, 'ADP', 'IN'), ('the', 30, 31, 'DET', 'DT'), ('same', 31, 32, 'ADJ', 'JJ'), ('basic', 32, 33, 'ADJ', 'JJ'), ('DNA', 33, 34, 'NOUN', 'NNP'), ('mix', 34, 35, 'NOUN', 'NN'), ('who', 35, 36, 'PRON', 'WP'), ('hostesses', 36, 37, 'VERB', 'VBZ'), ('at', 37, 38, 'ADP', 'IN'), ('Fuddruckers', 38, 39, 'PROPN', 'NNP'), ('.', 39, 40, 'PUNCT', '.')] 40
# trf_pron : [('We', 0, 1, 'PRON', 'PRP'), ('are', 1, 2, 'AUX', 'VBP'), ('committing', 2, 3, 'VERB', 'VBG'), ('genetic', 3, 4, 'ADJ', 'JJ'), ('fraud', 4, 5, 'NOUN', 'NN'), ('.', 5, 6, 'PUNCT', '.'), ('There', 6, 7, 'PRON', 'EX'), ("'s", 7, 8, 'VERB', 'VBZ'), ('no', 8, 9, 'DET', 'DT'), ('guarantee', 9, 10, 'NOUN', 'NN'), ('our', 10, 11, 'PRON', 'PRP$'), ('sperm', 11, 12, 'NOUN', 'NN'), ("'s", 12, 13, 'AUX', 'VBZ'), ('going', 13, 14, 'VERB', 'VBG'), ('to', 14, 15, 'PART', 'TO'), ('generate', 15, 16, 'VERB', 'VB'), ('high', 16, 17, 'ADJ', 'JJ'), ('-', 17, 18, 'PUNCT', 'HYPH'), ('IQ', 18, 19, 'NOUN', 'NN'), ('offspring', 19, 20, 'NOUN', 'NN'), ('.', 20, 21, 'PUNCT', '.'), ('Think', 21, 22, 'VERB', 'VB'), ('about', 22, 23, 'ADP', 'IN'), ('that', 23, 24, 'SCONJ', 'IN'), ('.', 24, 25, 'PUNCT', '.'), ('I', 25, 26, 'PRON', 'PRP'), ('have', 26, 27, 'VERB', 'VBP'), ('a', 27, 28, 'DET', 'DT'), ('sister', 28, 29, 'NOUN', 'NN'), ('with', 29, 30, 'ADP', 'IN'), ('the', 30, 31, 'DET', 'DT'), ('same', 31, 32, 'ADJ', 'JJ'), ('basic', 32, 33, 'ADJ', 'JJ'), ('DNA', 33, 34, 'NOUN', 'NN'), ('mix', 34, 35, 'NOUN', 'NN'), ('who', 35, 36, 'PRON', 'WP'), ('hostesses', 36, 37, 'VERB', 'VBZ'), ('at', 37, 38, 'ADP', 'IN'), ('Fuddruckers', 38, 39, 'PROPN', 'NNPS'), ('.', 39, 40, 'PUNCT', '.')] 40
# ====================================================================================================
# utterance :  Sheldon, this was your idea. A little extra money to get fractional T1 bandwidth in the apartment. 99
# speaker : Leonard 7
# en_subtitles : ['Sheldon, this was your idea.', 'A little extra money to get fractional T1 bandwidth in the apartment?'] 2
# zh_subtitles : ['Sheldon 这可是你的主意啊', '轻松赚点钱 就有钱能升级我们的网络带宽'] 2
# sm_pron : [('Sheldon', 0, 1, 'PROPN', 'NNP'), (',', 1, 2, 'PUNCT', ','), ('this', 2, 3, 'PRON', 'DT'), ('was', 3, 4, 'AUX', 'VBD'), ('your', 4, 5, 'PRON', 'PRP$'), ('idea', 5, 6, 'NOUN', 'NN'), ('.', 6, 7, 'PUNCT', '.'), ('A', 7, 8, 'DET', 'DT'), ('little', 8, 9, 'ADJ', 'JJ'), ('extra', 9, 10, 'ADJ', 'JJ'), ('money', 10, 11, 'NOUN', 'NN'), ('to', 11, 12, 'PART', 'TO'), ('get', 12, 13, 'VERB', 'VB'), ('fractional', 13, 14, 'ADJ', 'JJ'), ('T1', 14, 15, 'PROPN', 'NNP'), ('bandwidth', 15, 16, 'ADV', 'RB'), ('in', 16, 17, 'ADP', 'IN'), ('the', 17, 18, 'DET', 'DT'), ('apartment', 18, 19, 'NOUN', 'NN'), ('?', 19, 20, 'PUNCT', '.')] 20
# berkeley_pron : [('Sheldon', 0, 1, 'PROPN', 'NNP'), (',', 1, 2, 'PUNCT', ','), ('this', 2, 3, 'PRON', 'DT'), ('was', 3, 4, 'AUX', 'VBD'), ('your', 4, 5, 'PRON', 'PRP$'), ('idea', 5, 6, 'NOUN', 'NN'), ('.', 6, 7, 'PUNCT', '.'), ('A', 7, 8, 'DET', 'DT'), ('little', 8, 9, 'ADJ', 'JJ'), ('extra', 9, 10, 'ADJ', 'JJ'), ('money', 10, 11, 'NOUN', 'NN'), ('to', 11, 12, 'PART', 'TO'), ('get', 12, 13, 'VERB', 'VB'), ('fractional', 13, 14, 'ADJ', 'JJ'), ('T1', 14, 15, 'NOUN', 'NN'), ('bandwidth', 15, 16, 'NOUN', 'NN'), ('in', 16, 17, 'ADP', 'IN'), ('the', 17, 18, 'DET', 'DT'), ('apartment', 18, 19, 'NOUN', 'NN'), ('?', 19, 20, 'PUNCT', '.')] 20
# trf_pron : [('Sheldon', 0, 1, 'PROPN', 'NNP'), (',', 1, 2, 'PUNCT', ','), ('this', 2, 3, 'PRON', 'DT'), ('was', 3, 4, 'AUX', 'VBD'), ('your', 4, 5, 'PRON', 'PRP$'), ('idea', 5, 6, 'NOUN', 'NN'), ('.', 6, 7, 'PUNCT', '.'), ('A', 7, 8, 'DET', 'DT'), ('little', 8, 9, 'ADJ', 'JJ'), ('extra', 9, 10, 'ADJ', 'JJ'), ('money', 10, 11, 'NOUN', 'NN'), ('to', 11, 12, 'PART', 'TO'), ('get', 12, 13, 'VERB', 'VB'), ('fractional', 13, 14, 'ADJ', 'JJ'), ('T1', 14, 15, 'NOUN', 'NN'), ('bandwidth', 15, 16, 'NOUN', 'NN'), ('in', 16, 17, 'ADP', 'IN'), ('the', 17, 18, 'DET', 'DT'), ('apartment', 18, 19, 'NOUN', 'NN'), ('?', 19, 20, 'PUNCT', '.')] 20
# ====================================================================================================
# utterance :  I know, and I do yearn for faster downloads, but there’s some poor woman is going to pin her hopes on my sperm, what if she winds up with a toddler who doesn’t know if he should use an integral or a differential to solve the area under a curve. 245
# speaker : Sheldon 7
# en_subtitles : ['I know. And I do yearn for faster downloads.', "There's some poor woman who's gonna pin her hopes on my sperm.", "What if she winds up with a toddler who doesn't know if he should use a differential to solve for the area under a curve?"] 3
# zh_subtitles : ['我知道 我确实很渴望高速下载', '但一些可怜的女人 会把希望寄托在我的精子上', '万一生出来一个 连曲线下部的面积用积分还是微分算 都搞不清楚的小屁孩怎么办?'] 3
# sm_pron : [('I', 0, 1, 'PRON', 'PRP'), ('know', 1, 2, 'VERB', 'VBP'), ('.', 2, 3, 'PUNCT', '.'), ('And', 3, 4, 'CCONJ', 'CC'), ('I', 4, 5, 'PRON', 'PRP'), ('do', 5, 6, 'AUX', 'VBP'), ('yearn', 6, 7, 'VERB', 'VB'), ('for', 7, 8, 'ADP', 'IN'), ('faster', 8, 9, 'ADJ', 'JJR'), ('downloads', 9, 10, 'NOUN', 'NNS'), ('.', 10, 11, 'PUNCT', '.'), ('There', 11, 12, 'PRON', 'EX'), ("'s", 12, 13, 'VERB', 'VBZ'), ('some', 13, 14, 'DET', 'DT'), ('poor', 14, 15, 'ADJ', 'JJ'), ('woman', 15, 16, 'NOUN', 'NN'), ('who', 16, 17, 'PRON', 'WP'), ("'s", 17, 18, 'AUX', 'VBZ'), ('gon', 18, 19, 'VERB', 'VBG'), ('na', 19, 20, 'PART', 'TO'), ('pin', 20, 21, 'VERB', 'VB'), ('her', 21, 22, 'PRON', 'PRP'), ('hopes', 22, 23, 'NOUN', 'NNS'), ('on', 23, 24, 'ADP', 'IN'), ('my', 24, 25, 'PRON', 'PRP$'), ('sperm', 25, 26, 'NOUN', 'NN'), ('.', 26, 27, 'PUNCT', '.'), ('What', 27, 28, 'PRON', 'WP'), ('if', 28, 29, 'SCONJ', 'IN'), ('she', 29, 30, 'PRON', 'PRP'), ('winds', 30, 31, 'VERB', 'VBZ'), ('up', 31, 32, 'ADP', 'RP'), ('with', 32, 33, 'ADP', 'IN'), ('a', 33, 34, 'DET', 'DT'), ('toddler', 34, 35, 'NOUN', 'NN'), ('who', 35, 36, 'PRON', 'WP'), ('does', 36, 37, 'AUX', 'VBZ'), ("n't", 37, 38, 'PART', 'RB'), ('know', 38, 39, 'VERB', 'VB'), ('if', 39, 40, 'SCONJ', 'IN'), ('he', 40, 41, 'PRON', 'PRP'), ('should', 41, 42, 'AUX', 'MD'), ('use', 42, 43, 'VERB', 'VB'), ('a', 43, 44, 'DET', 'DT'), ('differential', 44, 45, 'NOUN', 'NN'), ('to', 45, 46, 'PART', 'TO'), ('solve', 46, 47, 'VERB', 'VB'), ('for', 47, 48, 'ADP', 'IN'), ('the', 48, 49, 'DET', 'DT'), ('area', 49, 50, 'NOUN', 'NN'), ('under', 50, 51, 'ADP', 'IN'), ('a', 51, 52, 'DET', 'DT'), ('curve', 52, 53, 'NOUN', 'NN'), ('?', 53, 54, 'PUNCT', '.')] 54
# berkeley_pron : [('I', 0, 1, 'PRON', 'PRP'), ('know', 1, 2, 'VERB', 'VBP'), ('.', 2, 3, 'PUNCT', '.'), ('And', 3, 4, 'CCONJ', 'CC'), ('I', 4, 5, 'PRON', 'PRP'), ('do', 5, 6, 'AUX', 'VBP'), ('yearn', 6, 7, 'VERB', 'VB'), ('for', 7, 8, 'ADP', 'IN'), ('faster', 8, 9, 'ADJ', 'JJR'), ('downloads', 9, 10, 'NOUN', 'NNS'), ('.', 10, 11, 'PUNCT', '.'), ('There', 11, 12, 'PRON', 'EX'), ("'s", 12, 13, 'VERB', 'VBZ'), ('some', 13, 14, 'DET', 'DT'), ('poor', 14, 15, 'ADJ', 'JJ'), ('woman', 15, 16, 'NOUN', 'NN'), ('who', 16, 17, 'PRON', 'WP'), ("'s", 17, 18, 'AUX', 'VBZ'), ('gon', 18, 19, 'VERB', 'TO'), ('na', 19, 20, 'PART', 'TO'), ('pin', 20, 21, 'VERB', 'VB'), ('her', 21, 22, 'PRON', 'PRP$'), ('hopes', 22, 23, 'NOUN', 'NNS'), ('on', 23, 24, 'ADP', 'IN'), ('my', 24, 25, 'PRON', 'PRP$'), ('sperm', 25, 26, 'NOUN', 'NN'), ('.', 26, 27, 'PUNCT', '.'), ('What', 27, 28, 'PRON', 'WP'), ('if', 28, 29, 'SCONJ', 'IN'), ('she', 29, 30, 'PRON', 'PRP'), ('winds', 30, 31, 'VERB', 'VBZ'), ('up', 31, 32, 'ADP', 'RP'), ('with', 32, 33, 'ADP', 'IN'), ('a', 33, 34, 'DET', 'DT'), ('toddler', 34, 35, 'NOUN', 'NN'), ('who', 35, 36, 'PRON', 'WP'), ('does', 36, 37, 'AUX', 'VBZ'), ("n't", 37, 38, 'PART', 'RB'), ('know', 38, 39, 'VERB', 'VB'), ('if', 39, 40, 'SCONJ', 'IN'), ('he', 40, 41, 'PRON', 'PRP'), ('should', 41, 42, 'AUX', 'MD'), ('use', 42, 43, 'VERB', 'VB'), ('a', 43, 44, 'DET', 'DT'), ('differential', 44, 45, 'NOUN', 'NN'), ('to', 45, 46, 'PART', 'TO'), ('solve', 46, 47, 'VERB', 'VB'), ('for', 47, 48, 'ADP', 'IN'), ('the', 48, 49, 'DET', 'DT'), ('area', 49, 50, 'NOUN', 'NN'), ('under', 50, 51, 'ADP', 'IN'), ('a', 51, 52, 'DET', 'DT'), ('curve', 52, 53, 'NOUN', 'NN'), ('?', 53, 54, 'PUNCT', '.')] 54
# trf_pron : [('I', 0, 1, 'PRON', 'PRP'), ('know', 1, 2, 'VERB', 'VBP'), ('.', 2, 3, 'PUNCT', '.'), ('And', 3, 4, 'CCONJ', 'CC'), ('I', 4, 5, 'PRON', 'PRP'), ('do', 5, 6, 'AUX', 'VBP'), ('yearn', 6, 7, 'VERB', 'VB'), ('for', 7, 8, 'ADP', 'IN'), ('faster', 8, 9, 'ADJ', 'JJR'), ('downloads', 9, 10, 'NOUN', 'NNS'), ('.', 10, 11, 'PUNCT', '.'), ('There', 11, 12, 'PRON', 'EX'), ("'s", 12, 13, 'VERB', 'VBZ'), ('some', 13, 14, 'DET', 'DT'), ('poor', 14, 15, 'ADJ', 'JJ'), ('woman', 15, 16, 'NOUN', 'NN'), ('who', 16, 17, 'PRON', 'WP'), ("'s", 17, 18, 'AUX', 'VBZ'), ('gon', 18, 19, 'PART', 'TO'), ('na', 19, 20, 'PART', 'TO'), ('pin', 20, 21, 'VERB', 'VB'), ('her', 21, 22, 'PRON', 'PRP$'), ('hopes', 22, 23, 'NOUN', 'NNS'), ('on', 23, 24, 'ADP', 'IN'), ('my', 24, 25, 'PRON', 'PRP$'), ('sperm', 25, 26, 'NOUN', 'NN'), ('.', 26, 27, 'PUNCT', '.'), ('What', 27, 28, 'PRON', 'WP'), ('if', 28, 29, 'SCONJ', 'IN'), ('she', 29, 30, 'PRON', 'PRP'), ('winds', 30, 31, 'VERB', 'VBZ'), ('up', 31, 32, 'ADP', 'RP'), ('with', 32, 33, 'ADP', 'IN'), ('a', 33, 34, 'DET', 'DT'), ('toddler', 34, 35, 'NOUN', 'NN'), ('who', 35, 36, 'PRON', 'WP'), ('does', 36, 37, 'AUX', 'VBZ'), ("n't", 37, 38, 'PART', 'RB'), ('know', 38, 39, 'VERB', 'VB'), ('if', 39, 40, 'SCONJ', 'IN'), ('he', 40, 41, 'PRON', 'PRP'), ('should', 41, 42, 'AUX', 'MD'), ('use', 42, 43, 'VERB', 'VB'), ('a', 43, 44, 'DET', 'DT'), ('differential', 44, 45, 'NOUN', 'NN'), ('to', 45, 46, 'PART', 'TO'), ('solve', 46, 47, 'VERB', 'VB'), ('for', 47, 48, 'ADP', 'IN'), ('the', 48, 49, 'DET', 'DT'), ('area', 49, 50, 'NOUN', 'NN'), ('under', 50, 51, 'ADP', 'IN'), ('a', 51, 52, 'DET', 'DT'), ('curve', 52, 53, 'NOUN', 'NN'), ('?', 53, 54, 'PUNCT', '.')] 54
# ====================================================================================================
# utterance :  I’m sure she’ll still love him. 32
# speaker : Leonard 7
# en_subtitles : ["I'm sure she'll still love him."] 1
# zh_subtitles : ['我想她还是会爱那个宝宝的'] 1
# sm_pron : [('I', 0, 1, 'PRON', 'PRP'), ("'m", 1, 2, 'AUX', 'VBP'), ('sure', 2, 3, 'ADJ', 'JJ'), ('she', 3, 4, 'PRON', 'PRP'), ("'ll", 4, 5, 'AUX', 'MD'), ('still', 5, 6, 'ADV', 'RB'), ('love', 6, 7, 'VERB', 'VB'), ('him', 7, 8, 'PRON', 'PRP'), ('.', 8, 9, 'PUNCT', '.')] 9
# berkeley_pron : [('I', 0, 1, 'PRON', 'PRP'), ("'m", 1, 2, 'AUX', 'VBP'), ('sure', 2, 3, 'ADJ', 'JJ'), ('she', 3, 4, 'PRON', 'PRP'), ("'ll", 4, 5, 'AUX', 'MD'), ('still', 5, 6, 'ADV', 'RB'), ('love', 6, 7, 'VERB', 'VB'), ('him', 7, 8, 'PRON', 'PRP'), ('.', 8, 9, 'PUNCT', '.')] 9
# trf_pron : [('I', 0, 1, 'PRON', 'PRP'), ("'m", 1, 2, 'AUX', 'VBP'), ('sure', 2, 3, 'ADJ', 'JJ'), ('she', 3, 4, 'PRON', 'PRP'), ("'ll", 4, 5, 'AUX', 'MD'), ('still', 5, 6, 'ADV', 'RB'), ('love', 6, 7, 'VERB', 'VB'), ('him', 7, 8, 'PRON', 'PRP'), ('.', 8, 9, 'PUNCT', '.')] 9
# ====================================================================================================
# utterance :  I wouldn’t. 12
# speaker : Sheldon 7
# en_subtitles : ["I wouldn't."] 1
# zh_subtitles : ['我不会'] 1
# sm_pron : [('I', 0, 1, 'PRON', 'PRP'), ('would', 1, 2, 'AUX', 'MD'), ("n't", 2, 3, 'PART', 'RB'), ('.', 3, 4, 'PUNCT', '.')] 4
# berkeley_pron : [('I', 0, 1, 'PRON', 'PRP'), ('would', 1, 2, 'AUX', 'MD'), ("n't", 2, 3, 'PART', 'RB'), ('.', 3, 4, 'PUNCT', '.')] 4
# trf_pron : [('I', 0, 1, 'PRON', 'PRP'), ('would', 1, 2, 'AUX', 'MD'), ("n't", 2, 3, 'PART', 'RB'), ('.', 3, 4, 'PUNCT', '.')] 4
# ====================================================================================================
# utterance :  Well, what do you want to do? 30
# speaker : Leonard 7
# en_subtitles : ['Well, what do you wanna do?'] 1
# zh_subtitles : ['你想要怎样?'] 1
# sm_pron : [('Well', 0, 1, 'INTJ', 'UH'), (',', 1, 2, 'PUNCT', ','), ('what', 2, 3, 'PRON', 'WP'), ('do', 3, 4, 'AUX', 'VBP'), ('you', 4, 5, 'PRON', 'PRP'), ('wanna', 5, 6, 'VERB', 'VB'), ('do', 6, 7, 'VERB', 'VB'), ('?', 7, 8, 'PUNCT', '.')] 8
# berkeley_pron : [('Well', 0, 1, 'INTJ', 'UH'), (',', 1, 2, 'PUNCT', ','), ('what', 2, 3, 'PRON', 'WP'), ('do', 3, 4, 'AUX', 'VBP'), ('you', 4, 5, 'PRON', 'PRP'), ('wanna', 5, 6, 'VERB', 'TO'), ('do', 6, 7, 'VERB', 'VB'), ('?', 7, 8, 'PUNCT', '.')] 8
# trf_pron : [('Well', 0, 1, 'INTJ', 'UH'), (',', 1, 2, 'PUNCT', ','), ('what', 2, 3, 'PRON', 'WP'), ('do', 3, 4, 'AUX', 'VBP'), ('you', 4, 5, 'PRON', 'PRP'), ('wanna', 5, 6, 'AUX', 'VB'), ('do', 6, 7, 'VERB', 'VB'), ('?', 7, 8, 'PUNCT', '.')] 8
# ====================================================================================================
# utterance :  I want to leave. 17
# speaker : Sheldon 7
# en_subtitles : ['I want to leave.'] 1
# zh_subtitles : ['- 我想要走'] 1
# sm_pron : [('I', 0, 1, 'PRON', 'PRP'), ('want', 1, 2, 'VERB', 'VBP'), ('to', 2, 3, 'PART', 'TO'), ('leave', 3, 4, 'VERB', 'VB'), ('.', 4, 5, 'PUNCT', '.')] 5
# berkeley_pron : [('I', 0, 1, 'PRON', 'PRP'), ('want', 1, 2, 'VERB', 'VBP'), ('to', 2, 3, 'PART', 'TO'), ('leave', 3, 4, 'VERB', 'VB'), ('.', 4, 5, 'PUNCT', '.')] 5
# trf_pron : [('I', 0, 1, 'PRON', 'PRP'), ('want', 1, 2, 'VERB', 'VBP'), ('to', 2, 3, 'PART', 'TO'), ('leave', 3, 4, 'VERB', 'VB'), ('.', 4, 5, 'PUNCT', '.')] 5
# ====================================================================================================
# utterance :  What’s the protocol for leaving? 33
# speaker : Sheldon 7
# en_subtitles : ["What's the protocol for leaving? - I don't know."] 1
# zh_subtitles : ['离开时要怎么说呢?'] 1
# sm_pron : [('What', 0, 1, 'PRON', 'WP'), ("'s", 1, 2, 'AUX', 'VBZ'), ('the', 2, 3, 'DET', 'DT'), ('protocol', 3, 4, 'NOUN', 'NN'), ('for', 4, 5, 'ADP', 'IN'), ('leaving', 5, 6, 'VERB', 'VBG'), ('?', 6, 7, 'PUNCT', '.'), ('-', 7, 8, 'PUNCT', ':'), ('I', 8, 9, 'PRON', 'PRP'), ('do', 9, 10, 'AUX', 'VBP'), ("n't", 10, 11, 'PART', 'RB'), ('know', 11, 12, 'VERB', 'VB'), ('.', 12, 13, 'PUNCT', '.')] 13
# berkeley_pron : [('What', 0, 1, 'PRON', 'WP'), ("'s", 1, 2, 'AUX', 'VBZ'), ('the', 2, 3, 'DET', 'DT'), ('protocol', 3, 4, 'NOUN', 'NN'), ('for', 4, 5, 'ADP', 'IN'), ('leaving', 5, 6, 'VERB', 'VBG'), ('?', 6, 7, 'PUNCT', '.'), ('-', 7, 8, 'PUNCT', ':'), ('I', 8, 9, 'PRON', 'PRP'), ('do', 9, 10, 'AUX', 'VBP'), ("n't", 10, 11, 'PART', 'RB'), ('know', 11, 12, 'VERB', 'VB'), ('.', 12, 13, 'PUNCT', '.')] 13
# trf_pron : [('What', 0, 1, 'PRON', 'WP'), ("'s", 1, 2, 'AUX', 'VBZ'), ('the', 2, 3, 'DET', 'DT'), ('protocol', 3, 4, 'NOUN', 'NN'), ('for', 4, 5, 'ADP', 'IN'), ('leaving', 5, 6, 'VERB', 'VBG'), ('?', 6, 7, 'PUNCT', '.'), ('-', 7, 8, 'PUNCT', ':'), ('I', 8, 9, 'PRON', 'PRP'), ('do', 9, 10, 'AUX', 'VBP'), ("n't", 10, 11, 'PART', 'RB'), ('know', 11, 12, 'VERB', 'VB'), ('.', 12, 13, 'PUNCT', '.')] 13
# ====================================================================================================
# utterance :  I don’t know, I’ve never reneged on a proffer of sperm before. 63
# speaker : Leonard 7
# en_subtitles : ["I've never reneged on a proffer of sperm before."] 1
# zh_subtitles : ['我不知道 我可从没有拒绝过提供精子的要求'] 1
# sm_pron : [('I', 0, 1, 'PRON', 'PRP'), ("'ve", 1, 2, 'AUX', 'VBP'), ('never', 2, 3, 'ADV', 'RB'), ('reneged', 3, 4, 'VERB', 'VBN'), ('on', 4, 5, 'ADP', 'IN'), ('a', 5, 6, 'DET', 'DT'), ('proffer', 6, 7, 'NOUN', 'NN'), ('of', 7, 8, 'ADP', 'IN'), ('sperm', 8, 9, 'NOUN', 'NN'), ('before', 9, 10, 'ADV', 'RB'), ('.', 10, 11, 'PUNCT', '.')] 11
# berkeley_pron : [('I', 0, 1, 'PRON', 'PRP'), ("'ve", 1, 2, 'AUX', 'VBP'), ('never', 2, 3, 'ADV', 'RB'), ('reneged', 3, 4, 'VERB', 'VBN'), ('on', 4, 5, 'ADP', 'IN'), ('a', 5, 6, 'DET', 'DT'), ('proffer', 6, 7, 'NOUN', 'NN'), ('of', 7, 8, 'ADP', 'IN'), ('sperm', 8, 9, 'NOUN', 'NN'), ('before', 9, 10, 'ADV', 'RB'), ('.', 10, 11, 'PUNCT', '.')] 11
# trf_pron : [('I', 0, 1, 'PRON', 'PRP'), ("'ve", 1, 2, 'AUX', 'VBP'), ('never', 2, 3, 'ADV', 'RB'), ('reneged', 3, 4, 'VERB', 'VBN'), ('on', 4, 5, 'ADP', 'IN'), ('a', 5, 6, 'DET', 'DT'), ('proffer', 6, 7, 'NOUN', 'NN'), ('of', 7, 8, 'ADP', 'IN'), ('sperm', 8, 9, 'NOUN', 'NN'), ('before', 9, 10, 'ADV', 'RB'), ('.', 10, 11, 'PUNCT', '.')] 11
# ====================================================================================================
# utterance :  Let’s try just walking out. 28
# speaker : Sheldon 7
# en_subtitles : ["Let's try just walking out."] 1
# zh_subtitles : ['我们就直接走出去吧'] 1
# sm_pron : [('Let', 0, 1, 'VERB', 'VB'), ("'s", 1, 2, 'PRON', 'PRP'), ('try', 2, 3, 'VERB', 'VB'), ('just', 3, 4, 'ADV', 'RB'), ('walking', 4, 5, 'VERB', 'VBG'), ('out', 5, 6, 'ADP', 'RP'), ('.', 6, 7, 'PUNCT', '.')] 7
# berkeley_pron : [('Let', 0, 1, 'VERB', 'VB'), ("'s", 1, 2, 'PRON', 'PRP'), ('try', 2, 3, 'VERB', 'VB'), ('just', 3, 4, 'ADV', 'RB'), ('walking', 4, 5, 'VERB', 'VBG'), ('out', 5, 6, 'ADP', 'RP'), ('.', 6, 7, 'PUNCT', '.')] 7
# trf_pron : [('Let', 0, 1, 'VERB', 'VB'), ("'s", 1, 2, 'PRON', 'PRP'), ('try', 2, 3, 'VERB', 'VB'), ('just', 3, 4, 'ADV', 'RB'), ('walking', 4, 5, 'VERB', 'VBG'), ('out', 5, 6, 'ADV', 'RB'), ('.', 6, 7, 'PUNCT', '.')] 7
# ====================================================================================================
# utterance :  Okay. 6
# speaker : Leonard 7
# ====================================================================================================
# utterance :  Bye-bye 8
# speaker : Sheldon 7
# ====================================================================================================
# utterance :  See you. 9
# speaker : Leonard 7
# ====================================================================================================

# %%
data = {}
with open('parsed_corpus.pkl', 'rb') as f:
    parsed = pkl.load(f)
    for item in inter_keys:
        data[item] = parsed[item]

# %%
temp = data[(1,1)][0]

# %%
for utt in temp:
    for item in utt:
        print(item, ":", utt[item], len(utt[item]))
    print("=="*50)
# Out:
# utterance :  So if a photon is directed through a plane with two slits in it and either slit is observed it will not go through both slits. If it’s unobserved it will, however, if it’s observed after it’s left the plane but before it hits its target, it will not have gone through both slits. 280
# speaker : Sheldon 7
# en_subtitles : ['If a photon is directed through a plane with two slits in it and either is observed it will not go through both.', 'If unobserved, it will.', "If it's observed after it left the plane, before it hits its target...", 'it will not have gone through both slits.'] 4
# zh_subtitles : ['将光子正对平面上的双缝 观察任意一个隙缝 它不会穿过那两个隙缝', '如果没被观察 那就会', '总之 如果观察它在离开平面到击中目标之前', '它就不会穿过那两个隙缝'] 4
# sm_noun_chunk : [('a photon', 1, 3), ('a plane', 6, 8), ('two slits', 9, 11), ('it', 12, 13), ('it', 17, 18), ('both', 22, 23), ('it', 27, 28), ('it', 31, 32), ('it', 35, 36), ('the plane', 37, 39), ('it', 41, 42), ('its target', 43, 45), ('it', 46, 47), ('both slits', 52, 54)] 14
# sm_pron : [('it', 12, 13), ('it', 17, 18), ('both', 22, 23), ('it', 27, 28), ('it', 31, 32), ('it', 35, 36), ('it', 41, 42), ('its', 43, 44), ('it', 46, 47)] 9
# berkeley_noun_chunk : [('a photon', 1, 3), ('a plane', 6, 8), ('two slits', 9, 11), ('it', 12, 13), ('it', 17, 18), ('both', 22, 23), ('it', 27, 28), ('it', 31, 32), ('it', 35, 36), ('the plane', 37, 39), ('it', 41, 42), ('its target', 43, 45), ('it', 46, 47), ('both slits', 52, 54)] 14
# berkeley_pron : [('it', 12, 13), ('it', 17, 18), ('both', 22, 23), ('it', 27, 28), ('it', 31, 32), ('it', 35, 36), ('it', 41, 42), ('its', 43, 44), ('it', 46, 47)] 9
# trf_noun_chunk : [('a photon', 1, 3), ('a plane', 6, 8), ('two slits', 9, 11), ('it', 12, 13), ('either', 14, 15), ('it', 17, 18), ('both', 22, 23), ('it', 27, 28), ('it', 31, 32), ('it', 35, 36), ('the plane', 37, 39), ('it', 41, 42), ('its target', 43, 45), ('it', 46, 47), ('both slits', 52, 54)] 15
# trf_pron : [('it', 12, 13), ('either', 14, 15), ('it', 17, 18), ('both', 22, 23), ('it', 27, 28), ('it', 31, 32), ('it', 35, 36), ('it', 41, 42), ('its', 43, 44), ('it', 46, 47)] 10
# ====================================================================================================
# utterance :  Agreed, what’s your point? 27
# speaker : Leonard 7
# en_subtitles : ["Agreed. What's your point?"] 1
# zh_subtitles : ['没错 但你为什么要说这个?'] 1
# sm_noun_chunk : [('What', 2, 3), ('your point', 4, 6)] 2
# sm_pron : [('What', 2, 3), ('your', 4, 5)] 2
# berkeley_noun_chunk : [('What', 2, 3), ('your point', 4, 6)] 2
# berkeley_pron : [('What', 2, 3), ('your', 4, 5)] 2
# trf_noun_chunk : [('What', 2, 3), ('your point', 4, 6)] 2
# trf_pron : [('What', 2, 3), ('your', 4, 5)] 2
# ====================================================================================================
# utterance :  There’s no point, I just think it’s a good idea for a tee-shirt.  66
# speaker : Sheldon 7
# en_subtitles : ["There's no point, I just think it's a good idea for a T-shirt."] 1
# zh_subtitles : ['没什么 我只是觉得这个主意 可以用于设计T恤衫'] 1
# sm_noun_chunk : [('no point', 2, 4), ('I', 5, 6), ('it', 8, 9), ('a good idea', 10, 13), ('a T-shirt', 14, 18)] 5
# sm_pron : [('There', 0, 1), ('I', 5, 6), ('it', 8, 9)] 3
# berkeley_noun_chunk : [('no point', 2, 4), ('I', 5, 6), ('it', 8, 9), ('a good idea', 10, 13), ('a T-shirt', 14, 18)] 5
# berkeley_pron : [('There', 0, 1), ('I', 5, 6), ('it', 8, 9)] 3
# trf_noun_chunk : [('no point', 2, 4), ('I', 5, 6), ('it', 8, 9), ('a good idea', 10, 13), ('a T-shirt', 14, 18)] 5
# trf_pron : [('There', 0, 1), ('I', 5, 6), ('it', 8, 9)] 3
# ====================================================================================================
# utterance :  Excuse me? 11
# speaker : Leonard 7
# ====================================================================================================
# utterance :  Hang on.  10
# speaker : Receptionist 12
# ====================================================================================================
# utterance :  One across is Aegean, eight down is Nabakov, twenty-six across is MCM, fourteen down is… move your finger… phylum, which makes fourteen across Port-au-Prince. See, Papa Doc’s capital idea, that’s Port-au-Prince. Haiti.  220
# speaker : Leonard 7
# en_subtitles : ['One across is Aegean, eight down is Nabokov.', 'Twenty-six across is MCM.', 'Fourteen down is... Move your finger.', 'phylum, which makes 14 across Port-Au-Prince.', "See, Papa Doc's capital idea, that's Port-Au-Prince.", 'Haiti.'] 6
# zh_subtitles : ['横1是Aegean (爱情海)', '竖8是Nabokov (小说洛丽塔的作者) 横26是MCM', '竖14是...', '手指挪开点 Phylum (生物门类) 这样一来横14就是Port -au', '瞧 提示是"Papa doc的首都" (海地前总统) 所以是太子港', '海地的'] 6
# sm_noun_chunk : [('Aegean', 3, 4), ('Nabokov', 8, 9), ('MCM', 15, 16), ('your finger', 22, 24), ('phylum', 25, 26), ('which', 27, 28), ('Port-Au-Prince', 31, 36), ("Papa Doc's capital idea", 39, 44), ('that', 45, 46), ('Port-Au-Prince', 47, 52), ('Haiti', 53, 54)] 11
# sm_pron : [('your', 22, 23), ('which', 27, 28), ('that', 45, 46)] 3
# berkeley_noun_chunk : [('Aegean', 3, 4), ('Nabokov', 8, 9), ('MCM', 15, 16), ('your finger', 22, 24), ('phylum', 25, 26), ('which', 27, 28), ('Port-Au', 31, 34), ('-', 34, 35), ('Prince', 35, 36), ("Papa Doc's capital idea", 39, 44), ('that', 45, 46), ('Port-Au-Prince', 47, 52), ('Haiti', 53, 54)] 13
# berkeley_pron : [('your', 22, 23), ('which', 27, 28), ('that', 45, 46)] 3
# trf_noun_chunk : [('Aegean', 3, 4), ('Nabokov', 8, 9), ('MCM', 15, 16), ('your finger', 22, 24), ('phylum', 25, 26), ('which', 27, 28), ('Port-Au-Prince', 31, 36), ('that', 45, 46), ('Port-Au-Prince', 47, 52), ('Haiti', 53, 54)] 10
# trf_pron : [('your', 22, 23), ('which', 27, 28), ('that', 45, 46)] 3
# ====================================================================================================
# utterance :  Can I help you? 16
# speaker : Receptionist 12
# en_subtitles : ['Can I help you? - Yes.'] 1
# zh_subtitles : ['- 能为你效劳吗?'] 1
# sm_noun_chunk : [('I', 1, 2), ('you', 3, 4)] 2
# sm_pron : [('I', 1, 2), ('you', 3, 4)] 2
# berkeley_noun_chunk : [('I', 1, 2), ('you', 3, 4)] 2
# berkeley_pron : [('I', 1, 2), ('you', 3, 4)] 2
# trf_noun_chunk : [('I', 1, 2), ('you', 3, 4)] 2
# trf_pron : [('I', 1, 2), ('you', 3, 4)] 2
# ====================================================================================================
# utterance :  Yes. Um, is this the High IQ sperm bank? 41
# speaker : Leonard 7
# en_subtitles : ['Um, is this the high-IQ sperm bank?'] 1
# zh_subtitles : ['这里是高智商精子银行吗?'] 1
# sm_noun_chunk : [('this', 3, 4), ('the high-IQ sperm bank', 4, 10)] 2
# sm_pron : [('this', 3, 4)] 1
# berkeley_noun_chunk : [('this', 3, 4), ('the high-IQ sperm bank', 4, 10)] 2
# berkeley_pron : [('this', 3, 4)] 1
# trf_noun_chunk : [('this', 3, 4), ('the high-IQ sperm bank', 4, 10)] 2
# trf_pron : [('this', 3, 4)] 1
# ====================================================================================================
# utterance :  If you have to ask, maybe you shouldn’t be here. 49
# speaker : Receptionist 12
# en_subtitles : ["If you have to ask, maybe you shouldn't be here."] 1
# zh_subtitles : ['如果你这么问 也许你不该来这'] 1
# sm_noun_chunk : [('you', 1, 2), ('you', 7, 8)] 2
# sm_pron : [('you', 1, 2), ('you', 7, 8)] 2
# berkeley_noun_chunk : [('you', 1, 2), ('you', 7, 8)] 2
# berkeley_pron : [('you', 1, 2), ('you', 7, 8)] 2
# trf_noun_chunk : [('you', 1, 2), ('you', 7, 8)] 2
# trf_pron : [('you', 1, 2), ('you', 7, 8)] 2
# ====================================================================================================
# utterance :  I think this is the place. 27
# speaker : Sheldon 7
# en_subtitles : ['I think this is the place.'] 1
# zh_subtitles : ['我想就是这没错了'] 1
# sm_noun_chunk : [('I', 0, 1), ('this', 2, 3), ('the place', 4, 6)] 3
# sm_pron : [('I', 0, 1), ('this', 2, 3)] 2
# berkeley_noun_chunk : [('I', 0, 1), ('this', 2, 3), ('the place', 4, 6)] 3
# berkeley_pron : [('I', 0, 1), ('this', 2, 3)] 2
# trf_noun_chunk : [('I', 0, 1), ('this', 2, 3), ('the place', 4, 6)] 3
# trf_pron : [('I', 0, 1), ('this', 2, 3)] 2
# ====================================================================================================
# utterance :  Fill these out. 16
# speaker : Receptionist 12
# en_subtitles : ['Fill these out. - Thank you.'] 1
# zh_subtitles : ['- 把这个填一填'] 1
# sm_noun_chunk : [('these', 1, 2), ('you', 6, 7)] 2
# sm_pron : [('these', 1, 2), ('you', 6, 7)] 2
# berkeley_noun_chunk : [('these', 1, 2), ('you', 6, 7)] 2
# berkeley_pron : [('these', 1, 2), ('you', 6, 7)] 2
# trf_noun_chunk : [('these', 1, 2), ('you', 6, 7)] 2
# trf_pron : [('these', 1, 2), ('you', 6, 7)] 2
# ====================================================================================================
# utterance :  Thank-you. We’ll be right back. 32
# speaker : Leonard 7
# en_subtitles : ["We'll be right back."] 1
# zh_subtitles : ['- 谢谢 我们马上好'] 1
# sm_noun_chunk : [('We', 0, 1)] 1
# sm_pron : [('We', 0, 1)] 1
# berkeley_noun_chunk : [('We', 0, 1)] 1
# berkeley_pron : [('We', 0, 1)] 1
# trf_noun_chunk : [('We', 0, 1)] 1
# trf_pron : [('We', 0, 1)] 1
# ====================================================================================================
# utterance :  Oh, take your time. I’ll just finish my crossword puzzle. Oh wait. 67
# speaker : Receptionist 12
# en_subtitles : ["Oh, take your time. I'll just finish my crossword puzzle.", 'Oh, wait.'] 2
# zh_subtitles : ['慢慢来 我还要玩填字游戏', '噢 慢着'] 2
# sm_noun_chunk : [('your time', 3, 5), ('I', 6, 7), ('my crossword puzzle', 10, 13)] 3
# sm_pron : [('your', 3, 4), ('I', 6, 7), ('my', 10, 11)] 3
# berkeley_noun_chunk : [('your time', 3, 5), ('I', 6, 7), ('my crossword puzzle', 10, 13)] 3
# berkeley_pron : [('your', 3, 4), ('I', 6, 7), ('my', 10, 11)] 3
# trf_noun_chunk : [('your time', 3, 5), ('I', 6, 7), ('my crossword puzzle', 10, 13)] 3
# trf_pron : [('your', 3, 4), ('I', 6, 7), ('my', 10, 11)] 3
# ====================================================================================================
# utterance :  Leonard, I don’t think I can do this. 38
# speaker : Sheldon 7
# en_subtitles : ["Leonard, I don't think I can do this."] 1
# zh_subtitles : ['Leonard 我办不到'] 1
# sm_noun_chunk : [('I', 2, 3), ('I', 6, 7), ('this', 9, 10)] 3
# sm_pron : [('I', 2, 3), ('I', 6, 7), ('this', 9, 10)] 3
# berkeley_noun_chunk : [('I', 2, 3), ('I', 6, 7), ('this', 9, 10)] 3
# berkeley_pron : [('I', 2, 3), ('I', 6, 7), ('this', 9, 10)] 3
# trf_noun_chunk : [('I', 2, 3), ('I', 6, 7), ('this', 9, 10)] 3
# trf_pron : [('I', 2, 3), ('I', 6, 7), ('this', 9, 10)] 3
# ====================================================================================================
# utterance :  What, are you kidding? You’re a semi-pro.  43
# speaker : Leonard 7
# en_subtitles : ['What, are you kidding?'] 1
# zh_subtitles : ['开玩笑? 你可是半职业人士'] 1
# sm_noun_chunk : [('What', 0, 1), ('you', 3, 4)] 2
# sm_pron : [('What', 0, 1), ('you', 3, 4)] 2
# berkeley_noun_chunk : [('What', 0, 1), ('you', 3, 4)] 2
# berkeley_pron : [('What', 0, 1), ('you', 3, 4)] 2
# trf_noun_chunk : [('What', 0, 1), ('you', 3, 4)] 2
# trf_pron : [('What', 0, 1), ('you', 3, 4)] 2
# ====================================================================================================
# utterance :  No. We are committing genetic fraud. There’s no guarantee that our sperm is going to generate high IQ offspring, think about that. I have a sister with the same basic DNA mix who hostesses at Fuddruckers. 205
# speaker : Sheldon 7
# en_subtitles : ['We are committing genetic fraud.', "There's no guarantee our sperm's going to generate high-IQ offspring. Think about that.", 'I have a sister with the same basic DNA mix who hostesses at Fuddruckers.'] 3
# zh_subtitles : ['不 我们这样是诈骗', '我们没法保证 生出来的一定是高智商小孩', '我姐姐跟我有一套相同的基本基因 她却在Fuddrucker餐厅当服务生'] 3
# sm_noun_chunk : [('We', 0, 1), ('genetic fraud', 3, 5), ('no guarantee', 8, 10), ('our sperm', 10, 12), ('high-IQ offspring', 16, 20), ('that', 23, 24), ('I', 25, 26), ('a sister', 27, 29), ('the same basic DNA mix', 30, 35), ('who', 35, 36), ('Fuddruckers', 38, 39)] 11
# sm_pron : [('We', 0, 1), ('There', 6, 7), ('our', 10, 11), ('that', 23, 24), ('I', 25, 26), ('who', 35, 36)] 6
# berkeley_noun_chunk : [('We', 0, 1), ('genetic fraud', 3, 5), ('no guarantee', 8, 10), ('our sperm', 10, 12), ('high-IQ offspring', 16, 20), ('that', 23, 24), ('I', 25, 26), ('a sister', 27, 29), ('the same basic DNA mix', 30, 35), ('who', 35, 36), ('Fuddruckers', 38, 39)] 11
# berkeley_pron : [('We', 0, 1), ('There', 6, 7), ('our', 10, 11), ('that', 23, 24), ('I', 25, 26), ('who', 35, 36)] 6
# trf_noun_chunk : [('We', 0, 1), ('genetic fraud', 3, 5), ('no guarantee', 8, 10), ('our sperm', 10, 12), ('high-IQ offspring', 16, 20), ('I', 25, 26), ('a sister', 27, 29), ('the same basic DNA mix', 30, 35), ('who', 35, 36), ('Fuddruckers', 38, 39)] 10
# trf_pron : [('We', 0, 1), ('There', 6, 7), ('our', 10, 11), ('I', 25, 26), ('who', 35, 36)] 5
# ====================================================================================================
# utterance :  Sheldon, this was your idea. A little extra money to get fractional T1 bandwidth in the apartment. 99
# speaker : Leonard 7
# en_subtitles : ['Sheldon, this was your idea.', 'A little extra money to get fractional T1 bandwidth in the apartment?'] 2
# zh_subtitles : ['Sheldon 这可是你的主意啊', '轻松赚点钱 就有钱能升级我们的网络带宽'] 2
# sm_noun_chunk : [('this', 2, 3), ('your idea', 4, 6), ('A little extra money', 7, 11), ('fractional T1', 13, 15), ('the apartment', 17, 19)] 5
# sm_pron : [('this', 2, 3), ('your', 4, 5)] 2
# berkeley_noun_chunk : [('this', 2, 3), ('your idea', 4, 6), ('A little extra money', 7, 11), ('fractional T1 bandwidth', 13, 16), ('the apartment', 17, 19)] 5
# berkeley_pron : [('this', 2, 3), ('your', 4, 5)] 2
# trf_noun_chunk : [('this', 2, 3), ('your idea', 4, 6), ('A little extra money', 7, 11), ('fractional T1 bandwidth', 13, 16), ('the apartment', 17, 19)] 5
# trf_pron : [('this', 2, 3), ('your', 4, 5)] 2
# ====================================================================================================
# utterance :  I know, and I do yearn for faster downloads, but there’s some poor woman is going to pin her hopes on my sperm, what if she winds up with a toddler who doesn’t know if he should use an integral or a differential to solve the area under a curve. 245
# speaker : Sheldon 7
# en_subtitles : ['I know. And I do yearn for faster downloads.', "There's some poor woman who's gonna pin her hopes on my sperm.", "What if she winds up with a toddler who doesn't know if he should use a differential to solve for the area under a curve?"] 3
# zh_subtitles : ['我知道 我确实很渴望高速下载', '但一些可怜的女人 会把希望寄托在我的精子上', '万一生出来一个 连曲线下部的面积用积分还是微分算 都搞不清楚的小屁孩怎么办?'] 3
# sm_noun_chunk : [('I', 0, 1), ('I', 4, 5), ('faster downloads', 8, 10), ('some poor woman', 13, 16), ('who', 16, 17), ('her hopes', 21, 23), ('my sperm', 24, 26), ('What', 27, 28), ('she', 29, 30), ('a toddler', 33, 35), ('who', 35, 36), ('he', 40, 41), ('a differential', 43, 45), ('the area', 48, 50), ('a curve', 51, 53)] 15
# sm_pron : [('I', 0, 1), ('I', 4, 5), ('There', 11, 12), ('who', 16, 17), ('her', 21, 22), ('my', 24, 25), ('What', 27, 28), ('she', 29, 30), ('who', 35, 36), ('he', 40, 41)] 10
# berkeley_noun_chunk : [('I', 0, 1), ('I', 4, 5), ('faster downloads', 8, 10), ('some poor woman', 13, 16), ('who', 16, 17), ('her hopes', 21, 23), ('my sperm', 24, 26), ('What', 27, 28), ('she', 29, 30), ('a toddler', 33, 35), ('who', 35, 36), ('he', 40, 41), ('a differential', 43, 45), ('the area', 48, 50), ('a curve', 51, 53)] 15
# berkeley_pron : [('I', 0, 1), ('I', 4, 5), ('There', 11, 12), ('who', 16, 17), ('her', 21, 22), ('my', 24, 25), ('What', 27, 28), ('she', 29, 30), ('who', 35, 36), ('he', 40, 41)] 10
# trf_noun_chunk : [('I', 0, 1), ('I', 4, 5), ('faster downloads', 8, 10), ('some poor woman', 13, 16), ('who', 16, 17), ('her hopes', 21, 23), ('my sperm', 24, 26), ('she', 29, 30), ('a toddler', 33, 35), ('who', 35, 36), ('he', 40, 41), ('a differential', 43, 45), ('the area', 48, 50), ('a curve', 51, 53)] 14
# trf_pron : [('I', 0, 1), ('I', 4, 5), ('There', 11, 12), ('who', 16, 17), ('her', 21, 22), ('my', 24, 25), ('What', 27, 28), ('she', 29, 30), ('who', 35, 36), ('he', 40, 41)] 10
# ====================================================================================================
# utterance :  I’m sure she’ll still love him. 32
# speaker : Leonard 7
# en_subtitles : ["I'm sure she'll still love him."] 1
# zh_subtitles : ['我想她还是会爱那个宝宝的'] 1
# sm_noun_chunk : [('I', 0, 1), ('she', 3, 4), ('him', 7, 8)] 3
# sm_pron : [('I', 0, 1), ('she', 3, 4), ('him', 7, 8)] 3
# berkeley_noun_chunk : [('I', 0, 1), ('she', 3, 4), ('him', 7, 8)] 3
# berkeley_pron : [('I', 0, 1), ('she', 3, 4), ('him', 7, 8)] 3
# trf_noun_chunk : [('I', 0, 1), ('she', 3, 4), ('him', 7, 8)] 3
# trf_pron : [('I', 0, 1), ('she', 3, 4), ('him', 7, 8)] 3
# ====================================================================================================
# utterance :  I wouldn’t. 12
# speaker : Sheldon 7
# en_subtitles : ["I wouldn't."] 1
# zh_subtitles : ['我不会'] 1
# sm_noun_chunk : [('I', 0, 1)] 1
# sm_pron : [('I', 0, 1)] 1
# berkeley_noun_chunk : [('I', 0, 1)] 1
# berkeley_pron : [('I', 0, 1)] 1
# trf_noun_chunk : [('I', 0, 1)] 1
# trf_pron : [('I', 0, 1)] 1
# ====================================================================================================
# utterance :  Well, what do you want to do? 30
# speaker : Leonard 7
# en_subtitles : ['Well, what do you wanna do?'] 1
# zh_subtitles : ['你想要怎样?'] 1
# sm_noun_chunk : [('what', 2, 3), ('you', 4, 5)] 2
# sm_pron : [('what', 2, 3), ('you', 4, 5)] 2
# berkeley_noun_chunk : [('what', 2, 3), ('you', 4, 5)] 2
# berkeley_pron : [('what', 2, 3), ('you', 4, 5)] 2
# trf_noun_chunk : [('what', 2, 3), ('you', 4, 5)] 2
# trf_pron : [('what', 2, 3), ('you', 4, 5)] 2
# ====================================================================================================
# utterance :  I want to leave. 17
# speaker : Sheldon 7
# en_subtitles : ['I want to leave.'] 1
# zh_subtitles : ['- 我想要走'] 1
# sm_noun_chunk : [('I', 0, 1)] 1
# sm_pron : [('I', 0, 1)] 1
# berkeley_noun_chunk : [('I', 0, 1)] 1
# berkeley_pron : [('I', 0, 1)] 1
# trf_noun_chunk : [('I', 0, 1)] 1
# trf_pron : [('I', 0, 1)] 1
# ====================================================================================================
# utterance :  What’s the protocol for leaving? 33
# speaker : Sheldon 7
# en_subtitles : ["What's the protocol for leaving? - I don't know."] 1
# zh_subtitles : ['离开时要怎么说呢?'] 1
# sm_noun_chunk : [('What', 0, 1), ('the protocol', 2, 4), ('I', 8, 9)] 3
# sm_pron : [('What', 0, 1), ('I', 8, 9)] 2
# berkeley_noun_chunk : [('What', 0, 1), ('the protocol', 2, 4), ('I', 8, 9)] 3
# berkeley_pron : [('What', 0, 1), ('I', 8, 9)] 2
# trf_noun_chunk : [('What', 0, 1), ('the protocol', 2, 4), ('I', 8, 9)] 3
# trf_pron : [('What', 0, 1), ('I', 8, 9)] 2
# ====================================================================================================
# utterance :  I don’t know, I’ve never reneged on a proffer of sperm before. 63
# speaker : Leonard 7
# en_subtitles : ["I've never reneged on a proffer of sperm before."] 1
# zh_subtitles : ['我不知道 我可从没有拒绝过提供精子的要求'] 1
# sm_noun_chunk : [('I', 0, 1), ('a proffer', 5, 7), ('sperm', 8, 9)] 3
# sm_pron : [('I', 0, 1)] 1
# berkeley_noun_chunk : [('I', 0, 1), ('a proffer', 5, 7), ('sperm', 8, 9)] 3
# berkeley_pron : [('I', 0, 1)] 1
# trf_noun_chunk : [('I', 0, 1), ('a proffer', 5, 7), ('sperm', 8, 9)] 3
# trf_pron : [('I', 0, 1)] 1
# ====================================================================================================
# utterance :  Let’s try just walking out. 28
# speaker : Sheldon 7
# en_subtitles : ["Let's try just walking out."] 1
# zh_subtitles : ['我们就直接走出去吧'] 1
# sm_noun_chunk : [("'s", 1, 2)] 1
# sm_pron : [("'s", 1, 2)] 1
# berkeley_noun_chunk : [("'s", 1, 2)] 1
# berkeley_pron : [("'s", 1, 2)] 1
# trf_noun_chunk : [("'s", 1, 2)] 1
# trf_pron : [("'s", 1, 2)] 1
# ====================================================================================================
# utterance :  Okay. 6
# speaker : Leonard 7
# ====================================================================================================
# utterance :  Bye-bye 8
# speaker : Sheldon 7
# ====================================================================================================
# utterance :  See you. 9
# speaker : Leonard 7
# ====================================================================================================

# %%
with open('parsed_corpus_small.pkl', 'rb') as f:
    parsed = pkl.load(f)

# %%
temp = parsed[(1,1)][0]
for utt in temp:
    for item in utt:
        print(item, ":", utt[item])
    print('=='*50)
# Out:
# utterance :  So if a photon is directed through a plane with two slits in it and either slit is observed it will not go through both slits. If it’s unobserved it will, however, if it’s observed after it’s left the plane but before it hits its target, it will not have gone through both slits.
# speaker : Sheldon
# en_subtitles : ['If a photon is directed through a plane with two slits in it and either is observed it will not go through both.', 'If unobserved, it will.', "If it's observed after it left the plane, before it hits its target...", 'it will not have gone through both slits.']
# zh_subtitles : ['将光子正对平面上的双缝 观察任意一个隙缝 它不会穿过那两个隙缝', '如果没被观察 那就会', '总之 如果观察它在离开平面到击中目标之前', '它就不会穿过那两个隙缝']
# sm_pron : [('If', 0, 1, 'SCONJ', 'IN'), ('a', 1, 2, 'DET', 'DT'), ('photon', 2, 3, 'NOUN', 'NN'), ('is', 3, 4, 'AUX', 'VBZ'), ('directed', 4, 5, 'VERB', 'VBN'), ('through', 5, 6, 'ADP', 'IN'), ('a', 6, 7, 'DET', 'DT'), ('plane', 7, 8, 'NOUN', 'NN'), ('with', 8, 9, 'ADP', 'IN'), ('two', 9, 10, 'NUM', 'CD'), ('slits', 10, 11, 'NOUN', 'NNS'), ('in', 11, 12, 'ADP', 'IN'), ('it', 12, 13, 'PRON', 'PRP'), ('and', 13, 14, 'CCONJ', 'CC'), ('either', 14, 15, 'CCONJ', 'CC'), ('is', 15, 16, 'AUX', 'VBZ'), ('observed', 16, 17, 'VERB', 'VBN'), ('it', 17, 18, 'PRON', 'PRP'), ('will', 18, 19, 'AUX', 'MD'), ('not', 19, 20, 'PART', 'RB'), ('go', 20, 21, 'VERB', 'VB'), ('through', 21, 22, 'ADP', 'IN'), ('both', 22, 23, 'PRON', 'DT'), ('.', 23, 24, 'PUNCT', '.'), ('If', 24, 25, 'SCONJ', 'IN'), ('unobserved', 25, 26, 'VERB', 'VBN'), (',', 26, 27, 'PUNCT', ','), ('it', 27, 28, 'PRON', 'PRP'), ('will', 28, 29, 'AUX', 'MD'), ('.', 29, 30, 'PUNCT', '.'), ('If', 30, 31, 'SCONJ', 'IN'), ('it', 31, 32, 'PRON', 'PRP'), ("'s", 32, 33, 'AUX', 'VBZ'), ('observed', 33, 34, 'VERB', 'VBN'), ('after', 34, 35, 'SCONJ', 'IN'), ('it', 35, 36, 'PRON', 'PRP'), ('left', 36, 37, 'VERB', 'VBD'), ('the', 37, 38, 'DET', 'DT'), ('plane', 38, 39, 'NOUN', 'NN'), (',', 39, 40, 'PUNCT', ','), ('before', 40, 41, 'SCONJ', 'IN'), ('it', 41, 42, 'PRON', 'PRP'), ('hits', 42, 43, 'VERB', 'VBZ'), ('its', 43, 44, 'PRON', 'PRP$'), ('target', 44, 45, 'NOUN', 'NN'), ('...', 45, 46, 'PUNCT', ':'), ('it', 46, 47, 'PRON', 'PRP'), ('will', 47, 48, 'AUX', 'MD'), ('not', 48, 49, 'PART', 'RB'), ('have', 49, 50, 'AUX', 'VB'), ('gone', 50, 51, 'VERB', 'VBN'), ('through', 51, 52, 'ADP', 'IN'), ('both', 52, 53, 'DET', 'DT'), ('slits', 53, 54, 'NOUN', 'NNS'), ('.', 54, 55, 'PUNCT', '.')]
# berkeley_pron : [('If', 0, 1, 'SCONJ', 'IN'), ('a', 1, 2, 'DET', 'DT'), ('photon', 2, 3, 'NOUN', 'NN'), ('is', 3, 4, 'AUX', 'VBZ'), ('directed', 4, 5, 'VERB', 'VBN'), ('through', 5, 6, 'ADP', 'IN'), ('a', 6, 7, 'DET', 'DT'), ('plane', 7, 8, 'NOUN', 'NN'), ('with', 8, 9, 'ADP', 'IN'), ('two', 9, 10, 'NUM', 'CD'), ('slits', 10, 11, 'NOUN', 'NNS'), ('in', 11, 12, 'ADP', 'IN'), ('it', 12, 13, 'PRON', 'PRP'), ('and', 13, 14, 'CCONJ', 'CC'), ('either', 14, 15, 'CCONJ', 'DT'), ('is', 15, 16, 'AUX', 'VBZ'), ('observed', 16, 17, 'VERB', 'VBN'), ('it', 17, 18, 'PRON', 'PRP'), ('will', 18, 19, 'AUX', 'MD'), ('not', 19, 20, 'PART', 'RB'), ('go', 20, 21, 'VERB', 'VB'), ('through', 21, 22, 'ADP', 'IN'), ('both', 22, 23, 'PRON', 'DT'), ('.', 23, 24, 'PUNCT', '.'), ('If', 24, 25, 'SCONJ', 'IN'), ('unobserved', 25, 26, 'VERB', 'JJ'), (',', 26, 27, 'PUNCT', ','), ('it', 27, 28, 'PRON', 'PRP'), ('will', 28, 29, 'AUX', 'MD'), ('.', 29, 30, 'PUNCT', '.'), ('If', 30, 31, 'SCONJ', 'IN'), ('it', 31, 32, 'PRON', 'PRP'), ("'s", 32, 33, 'AUX', 'VBZ'), ('observed', 33, 34, 'VERB', 'VBN'), ('after', 34, 35, 'SCONJ', 'IN'), ('it', 35, 36, 'PRON', 'PRP'), ('left', 36, 37, 'VERB', 'VBD'), ('the', 37, 38, 'DET', 'DT'), ('plane', 38, 39, 'NOUN', 'NN'), (',', 39, 40, 'PUNCT', ','), ('before', 40, 41, 'SCONJ', 'IN'), ('it', 41, 42, 'PRON', 'PRP'), ('hits', 42, 43, 'VERB', 'VBZ'), ('its', 43, 44, 'PRON', 'PRP$'), ('target', 44, 45, 'NOUN', 'NN'), ('...', 45, 46, 'PUNCT', ':'), ('it', 46, 47, 'PRON', 'PRP'), ('will', 47, 48, 'AUX', 'MD'), ('not', 48, 49, 'PART', 'RB'), ('have', 49, 50, 'AUX', 'VB'), ('gone', 50, 51, 'VERB', 'VBN'), ('through', 51, 52, 'ADP', 'IN'), ('both', 52, 53, 'DET', 'DT'), ('slits', 53, 54, 'NOUN', 'NNS'), ('.', 54, 55, 'PUNCT', '.')]
# trf_pron : [('If', 0, 1, 'SCONJ', 'IN'), ('a', 1, 2, 'DET', 'DT'), ('photon', 2, 3, 'NOUN', 'NN'), ('is', 3, 4, 'AUX', 'VBZ'), ('directed', 4, 5, 'VERB', 'VBN'), ('through', 5, 6, 'ADP', 'IN'), ('a', 6, 7, 'DET', 'DT'), ('plane', 7, 8, 'NOUN', 'NN'), ('with', 8, 9, 'ADP', 'IN'), ('two', 9, 10, 'NUM', 'CD'), ('slits', 10, 11, 'NOUN', 'NNS'), ('in', 11, 12, 'ADP', 'IN'), ('it', 12, 13, 'PRON', 'PRP'), ('and', 13, 14, 'CCONJ', 'CC'), ('either', 14, 15, 'PRON', 'DT'), ('is', 15, 16, 'AUX', 'VBZ'), ('observed', 16, 17, 'VERB', 'VBN'), ('it', 17, 18, 'PRON', 'PRP'), ('will', 18, 19, 'AUX', 'MD'), ('not', 19, 20, 'PART', 'RB'), ('go', 20, 21, 'VERB', 'VB'), ('through', 21, 22, 'ADP', 'IN'), ('both', 22, 23, 'PRON', 'DT'), ('.', 23, 24, 'PUNCT', '.'), ('If', 24, 25, 'SCONJ', 'IN'), ('unobserved', 25, 26, 'ADJ', 'JJ'), (',', 26, 27, 'PUNCT', ','), ('it', 27, 28, 'PRON', 'PRP'), ('will', 28, 29, 'AUX', 'MD'), ('.', 29, 30, 'PUNCT', '.'), ('If', 30, 31, 'SCONJ', 'IN'), ('it', 31, 32, 'PRON', 'PRP'), ("'s", 32, 33, 'AUX', 'VBZ'), ('observed', 33, 34, 'VERB', 'VBN'), ('after', 34, 35, 'SCONJ', 'IN'), ('it', 35, 36, 'PRON', 'PRP'), ('left', 36, 37, 'VERB', 'VBD'), ('the', 37, 38, 'DET', 'DT'), ('plane', 38, 39, 'NOUN', 'NN'), (',', 39, 40, 'PUNCT', ','), ('before', 40, 41, 'SCONJ', 'IN'), ('it', 41, 42, 'PRON', 'PRP'), ('hits', 42, 43, 'VERB', 'VBZ'), ('its', 43, 44, 'PRON', 'PRP$'), ('target', 44, 45, 'NOUN', 'NN'), ('...', 45, 46, 'PUNCT', ':'), ('it', 46, 47, 'PRON', 'PRP'), ('will', 47, 48, 'AUX', 'MD'), ('not', 48, 49, 'PART', 'RB'), ('have', 49, 50, 'AUX', 'VB'), ('gone', 50, 51, 'VERB', 'VBN'), ('through', 51, 52, 'ADP', 'IN'), ('both', 52, 53, 'DET', 'DT'), ('slits', 53, 54, 'NOUN', 'NNS'), ('.', 54, 55, 'PUNCT', '.')]
# ====================================================================================================
# utterance :  Agreed, what’s your point?
# speaker : Leonard
# en_subtitles : ["Agreed. What's your point?"]
# zh_subtitles : ['没错 但你为什么要说这个?']
# sm_pron : [('Agreed', 0, 1, 'VERB', 'VBN'), ('.', 1, 2, 'PUNCT', '.'), ('What', 2, 3, 'PRON', 'WP'), ("'s", 3, 4, 'AUX', 'VBZ'), ('your', 4, 5, 'PRON', 'PRP$'), ('point', 5, 6, 'NOUN', 'NN'), ('?', 6, 7, 'PUNCT', '.')]
# berkeley_pron : [('Agreed', 0, 1, 'VERB', 'VBN'), ('.', 1, 2, 'PUNCT', '.'), ('What', 2, 3, 'PRON', 'WP'), ("'s", 3, 4, 'AUX', 'VBZ'), ('your', 4, 5, 'PRON', 'PRP$'), ('point', 5, 6, 'NOUN', 'NN'), ('?', 6, 7, 'PUNCT', '.')]
# trf_pron : [('Agreed', 0, 1, 'INTJ', 'UH'), ('.', 1, 2, 'PUNCT', '.'), ('What', 2, 3, 'PRON', 'WP'), ("'s", 3, 4, 'AUX', 'VBZ'), ('your', 4, 5, 'PRON', 'PRP$'), ('point', 5, 6, 'NOUN', 'NN'), ('?', 6, 7, 'PUNCT', '.')]
# ====================================================================================================
# utterance :  There’s no point, I just think it’s a good idea for a tee-shirt.
# speaker : Sheldon
# en_subtitles : ["There's no point, I just think it's a good idea for a T-shirt."]
# zh_subtitles : ['没什么 我只是觉得这个主意 可以用于设计T恤衫']
# sm_pron : [('There', 0, 1, 'PRON', 'EX'), ("'s", 1, 2, 'VERB', 'VBZ'), ('no', 2, 3, 'DET', 'DT'), ('point', 3, 4, 'NOUN', 'NN'), (',', 4, 5, 'PUNCT', ','), ('I', 5, 6, 'PRON', 'PRP'), ('just', 6, 7, 'ADV', 'RB'), ('think', 7, 8, 'VERB', 'VBP'), ('it', 8, 9, 'PRON', 'PRP'), ("'s", 9, 10, 'AUX', 'VBZ'), ('a', 10, 11, 'DET', 'DT'), ('good', 11, 12, 'ADJ', 'JJ'), ('idea', 12, 13, 'NOUN', 'NN'), ('for', 13, 14, 'ADP', 'IN'), ('a', 14, 15, 'DET', 'DT'), ('T', 15, 16, 'PROPN', 'NNP'), ('-', 16, 17, 'PUNCT', 'HYPH'), ('shirt', 17, 18, 'NOUN', 'NN'), ('.', 18, 19, 'PUNCT', '.')]
# berkeley_pron : [('There', 0, 1, 'PRON', 'EX'), ("'s", 1, 2, 'VERB', 'VBZ'), ('no', 2, 3, 'DET', 'DT'), ('point', 3, 4, 'NOUN', 'NN'), (',', 4, 5, 'PUNCT', ','), ('I', 5, 6, 'PRON', 'PRP'), ('just', 6, 7, 'ADV', 'RB'), ('think', 7, 8, 'VERB', 'VBP'), ('it', 8, 9, 'PRON', 'PRP'), ("'s", 9, 10, 'AUX', 'VBZ'), ('a', 10, 11, 'DET', 'DT'), ('good', 11, 12, 'ADJ', 'JJ'), ('idea', 12, 13, 'NOUN', 'NN'), ('for', 13, 14, 'ADP', 'IN'), ('a', 14, 15, 'DET', 'DT'), ('T', 15, 16, 'PROPN', 'NNP'), ('-', 16, 17, 'PUNCT', 'HYPH'), ('shirt', 17, 18, 'NOUN', 'NN'), ('.', 18, 19, 'PUNCT', '.')]
# trf_pron : [('There', 0, 1, 'PRON', 'EX'), ("'s", 1, 2, 'VERB', 'VBZ'), ('no', 2, 3, 'DET', 'DT'), ('point', 3, 4, 'NOUN', 'NN'), (',', 4, 5, 'PUNCT', ','), ('I', 5, 6, 'PRON', 'PRP'), ('just', 6, 7, 'ADV', 'RB'), ('think', 7, 8, 'VERB', 'VBP'), ('it', 8, 9, 'PRON', 'PRP'), ("'s", 9, 10, 'AUX', 'VBZ'), ('a', 10, 11, 'DET', 'DT'), ('good', 11, 12, 'ADJ', 'JJ'), ('idea', 12, 13, 'NOUN', 'NN'), ('for', 13, 14, 'ADP', 'IN'), ('a', 14, 15, 'DET', 'DT'), ('T', 15, 16, 'NOUN', 'NN'), ('-', 16, 17, 'PUNCT', 'HYPH'), ('shirt', 17, 18, 'NOUN', 'NN'), ('.', 18, 19, 'PUNCT', '.')]
# ====================================================================================================
# utterance :  Excuse me?
# speaker : Leonard
# ====================================================================================================
# utterance :  Hang on.
# speaker : Receptionist
# ====================================================================================================
# utterance :  One across is Aegean, eight down is Nabakov, twenty-six across is MCM, fourteen down is… move your finger… phylum, which makes fourteen across Port-au-Prince. See, Papa Doc’s capital idea, that’s Port-au-Prince. Haiti.
# speaker : Leonard
# en_subtitles : ['One across is Aegean, eight down is Nabokov.', 'Twenty-six across is MCM.', 'Fourteen down is... Move your finger.', 'phylum, which makes 14 across Port-Au-Prince.', "See, Papa Doc's capital idea, that's Port-Au-Prince.", 'Haiti.']
# zh_subtitles : ['横1是Aegean (爱情海)', '竖8是Nabokov (小说洛丽塔的作者) 横26是MCM', '竖14是...', '手指挪开点 Phylum (生物门类) 这样一来横14就是Port -au', '瞧 提示是"Papa doc的首都" (海地前总统) 所以是太子港', '海地的']
# sm_pron : [('One', 0, 1, 'NUM', 'CD'), ('across', 1, 2, 'ADV', 'RB'), ('is', 2, 3, 'AUX', 'VBZ'), ('Aegean', 3, 4, 'PROPN', 'NNP'), (',', 4, 5, 'PUNCT', ','), ('eight', 5, 6, 'NUM', 'CD'), ('down', 6, 7, 'ADV', 'RB'), ('is', 7, 8, 'AUX', 'VBZ'), ('Nabokov', 8, 9, 'PROPN', 'NNP'), ('.', 9, 10, 'PUNCT', '.'), ('Twenty', 10, 11, 'NUM', 'CD'), ('-', 11, 12, 'PUNCT', 'HYPH'), ('six', 12, 13, 'NUM', 'CD'), ('across', 13, 14, 'ADV', 'RB'), ('is', 14, 15, 'AUX', 'VBZ'), ('MCM', 15, 16, 'PROPN', 'NNP'), ('.', 16, 17, 'PUNCT', '.'), ('Fourteen', 17, 18, 'NUM', 'CD'), ('down', 18, 19, 'ADV', 'RB'), ('is', 19, 20, 'AUX', 'VBZ'), ('...', 20, 21, 'PUNCT', ':'), ('Move', 21, 22, 'VERB', 'VB'), ('your', 22, 23, 'PRON', 'PRP$'), ('finger', 23, 24, 'NOUN', 'NN'), ('.', 24, 25, 'PUNCT', '.'), ('phylum', 25, 26, 'NOUN', 'NNS'), (',', 26, 27, 'PUNCT', ','), ('which', 27, 28, 'PRON', 'WDT'), ('makes', 28, 29, 'VERB', 'VBZ'), ('14', 29, 30, 'NUM', 'CD'), ('across', 30, 31, 'ADP', 'IN'), ('Port', 31, 32, 'PROPN', 'NNP'), ('-', 32, 33, 'PUNCT', 'HYPH'), ('Au', 33, 34, 'PROPN', 'NNP'), ('-', 34, 35, 'PUNCT', 'HYPH'), ('Prince', 35, 36, 'PROPN', 'NNP'), ('.', 36, 37, 'PUNCT', '.'), ('See', 37, 38, 'VERB', 'VB'), (',', 38, 39, 'PUNCT', ','), ('Papa', 39, 40, 'PROPN', 'NNP'), ('Doc', 40, 41, 'PROPN', 'NNP'), ("'s", 41, 42, 'PART', 'POS'), ('capital', 42, 43, 'NOUN', 'NN'), ('idea', 43, 44, 'NOUN', 'NN'), (',', 44, 45, 'PUNCT', ','), ('that', 45, 46, 'PRON', 'DT'), ("'s", 46, 47, 'AUX', 'VBZ'), ('Port', 47, 48, 'PROPN', 'NNP'), ('-', 48, 49, 'PUNCT', 'HYPH'), ('Au', 49, 50, 'PROPN', 'NNP'), ('-', 50, 51, 'PUNCT', 'HYPH'), ('Prince', 51, 52, 'PROPN', 'NNP'), ('.', 52, 53, 'PUNCT', '.'), ('Haiti', 53, 54, 'PROPN', 'NNP'), ('.', 54, 55, 'PUNCT', '.')]
# berkeley_pron : [('One', 0, 1, 'NUM', 'CD'), ('across', 1, 2, 'ADP', 'RB'), ('is', 2, 3, 'AUX', 'VBZ'), ('Aegean', 3, 4, 'PROPN', 'NNP'), (',', 4, 5, 'PUNCT', ','), ('eight', 5, 6, 'NUM', 'CD'), ('down', 6, 7, 'ADV', 'RB'), ('is', 7, 8, 'AUX', 'VBZ'), ('Nabokov', 8, 9, 'PROPN', 'NNP'), ('.', 9, 10, 'PUNCT', '.'), ('Twenty', 10, 11, 'NUM', 'CD'), ('-', 11, 12, 'PUNCT', 'HYPH'), ('six', 12, 13, 'NUM', 'CD'), ('across', 13, 14, 'ADP', 'IN'), ('is', 14, 15, 'AUX', 'VBZ'), ('MCM', 15, 16, 'PROPN', 'NNP'), ('.', 16, 17, 'PUNCT', '.'), ('Fourteen', 17, 18, 'NUM', 'CD'), ('down', 18, 19, 'ADV', 'RB'), ('is', 19, 20, 'AUX', 'VBZ'), ('...', 20, 21, 'PUNCT', ':'), ('Move', 21, 22, 'VERB', 'VB'), ('your', 22, 23, 'PRON', 'PRP$'), ('finger', 23, 24, 'NOUN', 'NN'), ('.', 24, 25, 'PUNCT', '.'), ('phylum', 25, 26, 'NOUN', 'NN'), (',', 26, 27, 'PUNCT', ','), ('which', 27, 28, 'PRON', 'WDT'), ('makes', 28, 29, 'VERB', 'VBZ'), ('14', 29, 30, 'NUM', 'CD'), ('across', 30, 31, 'ADP', 'IN'), ('Port', 31, 32, 'PROPN', 'NNP'), ('-', 32, 33, 'PUNCT', 'HYPH'), ('Au', 33, 34, 'PROPN', 'NNP'), ('-', 34, 35, 'NOUN', 'HYPH'), ('Prince', 35, 36, 'NOUN', 'NNP'), ('.', 36, 37, 'PUNCT', '.'), ('See', 37, 38, 'VERB', 'VB'), (',', 38, 39, 'PUNCT', ','), ('Papa', 39, 40, 'PROPN', 'NNP'), ('Doc', 40, 41, 'PROPN', 'NNP'), ("'s", 41, 42, 'PART', 'POS'), ('capital', 42, 43, 'NOUN', 'NN'), ('idea', 43, 44, 'NOUN', 'NN'), (',', 44, 45, 'PUNCT', ','), ('that', 45, 46, 'PRON', 'DT'), ("'s", 46, 47, 'AUX', 'VBZ'), ('Port', 47, 48, 'PROPN', 'NNP'), ('-', 48, 49, 'PUNCT', 'HYPH'), ('Au', 49, 50, 'PROPN', 'NNP'), ('-', 50, 51, 'NOUN', 'HYPH'), ('Prince', 51, 52, 'NOUN', 'NNP'), ('.', 52, 53, 'PUNCT', '.'), ('Haiti', 53, 54, 'PROPN', 'NNP'), ('.', 54, 55, 'PUNCT', '.')]
# trf_pron : [('One', 0, 1, 'NUM', 'CD'), ('across', 1, 2, 'ADV', 'RB'), ('is', 2, 3, 'AUX', 'VBZ'), ('Aegean', 3, 4, 'PROPN', 'NNP'), (',', 4, 5, 'PUNCT', ','), ('eight', 5, 6, 'NUM', 'CD'), ('down', 6, 7, 'ADV', 'RB'), ('is', 7, 8, 'AUX', 'VBZ'), ('Nabokov', 8, 9, 'PROPN', 'NNP'), ('.', 9, 10, 'PUNCT', '.'), ('Twenty', 10, 11, 'NUM', 'CD'), ('-', 11, 12, 'PUNCT', 'HYPH'), ('six', 12, 13, 'NUM', 'CD'), ('across', 13, 14, 'ADV', 'RB'), ('is', 14, 15, 'AUX', 'VBZ'), ('MCM', 15, 16, 'PROPN', 'NNP'), ('.', 16, 17, 'PUNCT', '.'), ('Fourteen', 17, 18, 'NUM', 'CD'), ('down', 18, 19, 'ADV', 'RB'), ('is', 19, 20, 'AUX', 'VBZ'), ('...', 20, 21, 'PUNCT', ':'), ('Move', 21, 22, 'VERB', 'VB'), ('your', 22, 23, 'PRON', 'PRP$'), ('finger', 23, 24, 'NOUN', 'NN'), ('.', 24, 25, 'PUNCT', '.'), ('phylum', 25, 26, 'PROPN', 'NNP'), (',', 26, 27, 'PUNCT', ','), ('which', 27, 28, 'PRON', 'WDT'), ('makes', 28, 29, 'VERB', 'VBZ'), ('14', 29, 30, 'NUM', 'CD'), ('across', 30, 31, 'ADP', 'IN'), ('Port', 31, 32, 'PROPN', 'NNP'), ('-', 32, 33, 'PUNCT', 'HYPH'), ('Au', 33, 34, 'PROPN', 'NNP'), ('-', 34, 35, 'PUNCT', 'HYPH'), ('Prince', 35, 36, 'PROPN', 'NNP'), ('.', 36, 37, 'PUNCT', '.'), ('See', 37, 38, 'VERB', 'VB'), (',', 38, 39, 'PUNCT', ','), ('Papa', 39, 40, 'PROPN', 'NNP'), ('Doc', 40, 41, 'PROPN', 'NNP'), ("'s", 41, 42, 'PART', 'POS'), ('capital', 42, 43, 'NOUN', 'NN'), ('idea', 43, 44, 'NOUN', 'NN'), (',', 44, 45, 'PUNCT', ','), ('that', 45, 46, 'PRON', 'WDT'), ("'s", 46, 47, 'AUX', 'VBZ'), ('Port', 47, 48, 'PROPN', 'NNP'), ('-', 48, 49, 'PUNCT', 'HYPH'), ('Au', 49, 50, 'PROPN', 'NNP'), ('-', 50, 51, 'PUNCT', 'HYPH'), ('Prince', 51, 52, 'PROPN', 'NNP'), ('.', 52, 53, 'PUNCT', '.'), ('Haiti', 53, 54, 'PROPN', 'NNP'), ('.', 54, 55, 'PUNCT', '.')]
# ====================================================================================================
# utterance :  Can I help you?
# speaker : Receptionist
# en_subtitles : ['Can I help you? - Yes.']
# zh_subtitles : ['- 能为你效劳吗?']
# sm_pron : [('Can', 0, 1, 'AUX', 'MD'), ('I', 1, 2, 'PRON', 'PRP'), ('help', 2, 3, 'VERB', 'VB'), ('you', 3, 4, 'PRON', 'PRP'), ('?', 4, 5, 'PUNCT', '.'), ('-', 5, 6, 'PUNCT', ':'), ('Yes', 6, 7, 'INTJ', 'UH'), ('.', 7, 8, 'PUNCT', '.')]
# berkeley_pron : [('Can', 0, 1, 'AUX', 'MD'), ('I', 1, 2, 'PRON', 'PRP'), ('help', 2, 3, 'VERB', 'VB'), ('you', 3, 4, 'PRON', 'PRP'), ('?', 4, 5, 'PUNCT', '.'), ('-', 5, 6, 'PUNCT', ':'), ('Yes', 6, 7, 'INTJ', 'UH'), ('.', 7, 8, 'PUNCT', '.')]
# trf_pron : [('Can', 0, 1, 'AUX', 'MD'), ('I', 1, 2, 'PRON', 'PRP'), ('help', 2, 3, 'VERB', 'VB'), ('you', 3, 4, 'PRON', 'PRP'), ('?', 4, 5, 'PUNCT', '.'), ('-', 5, 6, 'PUNCT', ':'), ('Yes', 6, 7, 'INTJ', 'UH'), ('.', 7, 8, 'PUNCT', '.')]
# ====================================================================================================
# utterance :  Yes. Um, is this the High IQ sperm bank?
# speaker : Leonard
# en_subtitles : ['Um, is this the high-IQ sperm bank?']
# zh_subtitles : ['这里是高智商精子银行吗?']
# sm_pron : [('Um', 0, 1, 'INTJ', 'UH'), (',', 1, 2, 'PUNCT', ','), ('is', 2, 3, 'AUX', 'VBZ'), ('this', 3, 4, 'PRON', 'DT'), ('the', 4, 5, 'DET', 'DT'), ('high', 5, 6, 'ADJ', 'JJ'), ('-', 6, 7, 'PUNCT', 'HYPH'), ('IQ', 7, 8, 'NOUN', 'NN'), ('sperm', 8, 9, 'NOUN', 'NN'), ('bank', 9, 10, 'NOUN', 'NN'), ('?', 10, 11, 'PUNCT', '.')]
# berkeley_pron : [('Um', 0, 1, 'INTJ', 'UH'), (',', 1, 2, 'PUNCT', ','), ('is', 2, 3, 'AUX', 'VBZ'), ('this', 3, 4, 'PRON', 'DT'), ('the', 4, 5, 'DET', 'DT'), ('high', 5, 6, 'ADJ', 'JJ'), ('-', 6, 7, 'PUNCT', 'HYPH'), ('IQ', 7, 8, 'NOUN', 'NN'), ('sperm', 8, 9, 'NOUN', 'NN'), ('bank', 9, 10, 'NOUN', 'NN'), ('?', 10, 11, 'PUNCT', '.')]
# trf_pron : [('Um', 0, 1, 'INTJ', 'UH'), (',', 1, 2, 'PUNCT', ','), ('is', 2, 3, 'AUX', 'VBZ'), ('this', 3, 4, 'PRON', 'DT'), ('the', 4, 5, 'DET', 'DT'), ('high', 5, 6, 'ADJ', 'JJ'), ('-', 6, 7, 'PUNCT', 'HYPH'), ('IQ', 7, 8, 'NOUN', 'NN'), ('sperm', 8, 9, 'NOUN', 'NN'), ('bank', 9, 10, 'NOUN', 'NN'), ('?', 10, 11, 'PUNCT', '.')]
# ====================================================================================================
# utterance :  If you have to ask, maybe you shouldn’t be here.
# speaker : Receptionist
# en_subtitles : ["If you have to ask, maybe you shouldn't be here."]
# zh_subtitles : ['如果你这么问 也许你不该来这']
# sm_pron : [('If', 0, 1, 'SCONJ', 'IN'), ('you', 1, 2, 'PRON', 'PRP'), ('have', 2, 3, 'VERB', 'VBP'), ('to', 3, 4, 'PART', 'TO'), ('ask', 4, 5, 'VERB', 'VB'), (',', 5, 6, 'PUNCT', ','), ('maybe', 6, 7, 'ADV', 'RB'), ('you', 7, 8, 'PRON', 'PRP'), ('should', 8, 9, 'AUX', 'MD'), ("n't", 9, 10, 'PART', 'RB'), ('be', 10, 11, 'AUX', 'VB'), ('here', 11, 12, 'ADV', 'RB'), ('.', 12, 13, 'PUNCT', '.')]
# berkeley_pron : [('If', 0, 1, 'SCONJ', 'IN'), ('you', 1, 2, 'PRON', 'PRP'), ('have', 2, 3, 'VERB', 'VBP'), ('to', 3, 4, 'PART', 'TO'), ('ask', 4, 5, 'VERB', 'VB'), (',', 5, 6, 'PUNCT', ','), ('maybe', 6, 7, 'ADV', 'RB'), ('you', 7, 8, 'PRON', 'PRP'), ('should', 8, 9, 'AUX', 'MD'), ("n't", 9, 10, 'PART', 'RB'), ('be', 10, 11, 'AUX', 'VB'), ('here', 11, 12, 'ADV', 'RB'), ('.', 12, 13, 'PUNCT', '.')]
# trf_pron : [('If', 0, 1, 'SCONJ', 'IN'), ('you', 1, 2, 'PRON', 'PRP'), ('have', 2, 3, 'VERB', 'VBP'), ('to', 3, 4, 'PART', 'TO'), ('ask', 4, 5, 'VERB', 'VB'), (',', 5, 6, 'PUNCT', ','), ('maybe', 6, 7, 'ADV', 'RB'), ('you', 7, 8, 'PRON', 'PRP'), ('should', 8, 9, 'AUX', 'MD'), ("n't", 9, 10, 'PART', 'RB'), ('be', 10, 11, 'AUX', 'VB'), ('here', 11, 12, 'ADV', 'RB'), ('.', 12, 13, 'PUNCT', '.')]
# ====================================================================================================
# utterance :  I think this is the place.
# speaker : Sheldon
# en_subtitles : ['I think this is the place.']
# zh_subtitles : ['我想就是这没错了']
# sm_pron : [('I', 0, 1, 'PRON', 'PRP'), ('think', 1, 2, 'VERB', 'VBP'), ('this', 2, 3, 'PRON', 'DT'), ('is', 3, 4, 'AUX', 'VBZ'), ('the', 4, 5, 'DET', 'DT'), ('place', 5, 6, 'NOUN', 'NN'), ('.', 6, 7, 'PUNCT', '.')]
# berkeley_pron : [('I', 0, 1, 'PRON', 'PRP'), ('think', 1, 2, 'VERB', 'VBP'), ('this', 2, 3, 'PRON', 'DT'), ('is', 3, 4, 'AUX', 'VBZ'), ('the', 4, 5, 'DET', 'DT'), ('place', 5, 6, 'NOUN', 'NN'), ('.', 6, 7, 'PUNCT', '.')]
# trf_pron : [('I', 0, 1, 'PRON', 'PRP'), ('think', 1, 2, 'VERB', 'VBP'), ('this', 2, 3, 'PRON', 'DT'), ('is', 3, 4, 'AUX', 'VBZ'), ('the', 4, 5, 'DET', 'DT'), ('place', 5, 6, 'NOUN', 'NN'), ('.', 6, 7, 'PUNCT', '.')]
# ====================================================================================================
# utterance :  Fill these out.
# speaker : Receptionist
# en_subtitles : ['Fill these out. - Thank you.']
# zh_subtitles : ['- 把这个填一填']
# sm_pron : [('Fill', 0, 1, 'VERB', 'VB'), ('these', 1, 2, 'PRON', 'DT'), ('out', 2, 3, 'ADP', 'RP'), ('.', 3, 4, 'PUNCT', '.'), ('-', 4, 5, 'PUNCT', ':'), ('Thank', 5, 6, 'VERB', 'VBP'), ('you', 6, 7, 'PRON', 'PRP'), ('.', 7, 8, 'PUNCT', '.')]
# berkeley_pron : [('Fill', 0, 1, 'VERB', 'VB'), ('these', 1, 2, 'PRON', 'DT'), ('out', 2, 3, 'ADP', 'RP'), ('.', 3, 4, 'PUNCT', '.'), ('-', 4, 5, 'PUNCT', ':'), ('Thank', 5, 6, 'VERB', 'VB'), ('you', 6, 7, 'PRON', 'PRP'), ('.', 7, 8, 'PUNCT', '.')]
# trf_pron : [('Fill', 0, 1, 'VERB', 'VB'), ('these', 1, 2, 'PRON', 'DT'), ('out', 2, 3, 'ADP', 'RP'), ('.', 3, 4, 'PUNCT', '.'), ('-', 4, 5, 'PUNCT', ':'), ('Thank', 5, 6, 'VERB', 'VBP'), ('you', 6, 7, 'PRON', 'PRP'), ('.', 7, 8, 'PUNCT', '.')]
# ====================================================================================================
# utterance :  Thank-you. We’ll be right back.
# speaker : Leonard
# en_subtitles : ["We'll be right back."]
# zh_subtitles : ['- 谢谢 我们马上好']
# sm_pron : [('We', 0, 1, 'PRON', 'PRP'), ("'ll", 1, 2, 'AUX', 'MD'), ('be', 2, 3, 'AUX', 'VB'), ('right', 3, 4, 'ADV', 'RB'), ('back', 4, 5, 'ADV', 'RB'), ('.', 5, 6, 'PUNCT', '.')]
# berkeley_pron : [('We', 0, 1, 'PRON', 'PRP'), ("'ll", 1, 2, 'AUX', 'MD'), ('be', 2, 3, 'AUX', 'VB'), ('right', 3, 4, 'ADV', 'RB'), ('back', 4, 5, 'ADV', 'RB'), ('.', 5, 6, 'PUNCT', '.')]
# trf_pron : [('We', 0, 1, 'PRON', 'PRP'), ("'ll", 1, 2, 'AUX', 'MD'), ('be', 2, 3, 'AUX', 'VB'), ('right', 3, 4, 'ADV', 'RB'), ('back', 4, 5, 'ADV', 'RB'), ('.', 5, 6, 'PUNCT', '.')]
# ====================================================================================================
# utterance :  Oh, take your time. I’ll just finish my crossword puzzle. Oh wait.
# speaker : Receptionist
# en_subtitles : ["Oh, take your time. I'll just finish my crossword puzzle.", 'Oh, wait.']
# zh_subtitles : ['慢慢来 我还要玩填字游戏', '噢 慢着']
# sm_pron : [('Oh', 0, 1, 'INTJ', 'UH'), (',', 1, 2, 'PUNCT', ','), ('take', 2, 3, 'VERB', 'VB'), ('your', 3, 4, 'PRON', 'PRP$'), ('time', 4, 5, 'NOUN', 'NN'), ('.', 5, 6, 'PUNCT', '.'), ('I', 6, 7, 'PRON', 'PRP'), ("'ll", 7, 8, 'AUX', 'MD'), ('just', 8, 9, 'ADV', 'RB'), ('finish', 9, 10, 'VERB', 'VB'), ('my', 10, 11, 'PRON', 'PRP$'), ('crossword', 11, 12, 'NOUN', 'NN'), ('puzzle', 12, 13, 'NOUN', 'NN'), ('.', 13, 14, 'PUNCT', '.'), ('Oh', 14, 15, 'INTJ', 'UH'), (',', 15, 16, 'PUNCT', ','), ('wait', 16, 17, 'VERB', 'VB'), ('.', 17, 18, 'PUNCT', '.')]
# berkeley_pron : [('Oh', 0, 1, 'INTJ', 'UH'), (',', 1, 2, 'PUNCT', ','), ('take', 2, 3, 'VERB', 'VB'), ('your', 3, 4, 'PRON', 'PRP$'), ('time', 4, 5, 'NOUN', 'NN'), ('.', 5, 6, 'PUNCT', '.'), ('I', 6, 7, 'PRON', 'PRP'), ("'ll", 7, 8, 'AUX', 'MD'), ('just', 8, 9, 'ADV', 'RB'), ('finish', 9, 10, 'VERB', 'VB'), ('my', 10, 11, 'PRON', 'PRP$'), ('crossword', 11, 12, 'ADJ', 'NN'), ('puzzle', 12, 13, 'NOUN', 'NN'), ('.', 13, 14, 'PUNCT', '.'), ('Oh', 14, 15, 'INTJ', 'UH'), (',', 15, 16, 'PUNCT', ','), ('wait', 16, 17, 'VERB', 'VB'), ('.', 17, 18, 'PUNCT', '.')]
# trf_pron : [('Oh', 0, 1, 'INTJ', 'UH'), (',', 1, 2, 'PUNCT', ','), ('take', 2, 3, 'VERB', 'VB'), ('your', 3, 4, 'PRON', 'PRP$'), ('time', 4, 5, 'NOUN', 'NN'), ('.', 5, 6, 'PUNCT', '.'), ('I', 6, 7, 'PRON', 'PRP'), ("'ll", 7, 8, 'AUX', 'MD'), ('just', 8, 9, 'ADV', 'RB'), ('finish', 9, 10, 'VERB', 'VB'), ('my', 10, 11, 'PRON', 'PRP$'), ('crossword', 11, 12, 'NOUN', 'NN'), ('puzzle', 12, 13, 'NOUN', 'NN'), ('.', 13, 14, 'PUNCT', '.'), ('Oh', 14, 15, 'INTJ', 'UH'), (',', 15, 16, 'PUNCT', ','), ('wait', 16, 17, 'VERB', 'VB'), ('.', 17, 18, 'PUNCT', '.')]
# ====================================================================================================
# utterance :  Leonard, I don’t think I can do this.
# speaker : Sheldon
# en_subtitles : ["Leonard, I don't think I can do this."]
# zh_subtitles : ['Leonard 我办不到']
# sm_pron : [('Leonard', 0, 1, 'PROPN', 'NNP'), (',', 1, 2, 'PUNCT', ','), ('I', 2, 3, 'PRON', 'PRP'), ('do', 3, 4, 'AUX', 'VBP'), ("n't", 4, 5, 'PART', 'RB'), ('think', 5, 6, 'VERB', 'VB'), ('I', 6, 7, 'PRON', 'PRP'), ('can', 7, 8, 'AUX', 'MD'), ('do', 8, 9, 'VERB', 'VB'), ('this', 9, 10, 'PRON', 'DT'), ('.', 10, 11, 'PUNCT', '.')]
# berkeley_pron : [('Leonard', 0, 1, 'PROPN', 'NNP'), (',', 1, 2, 'PUNCT', ','), ('I', 2, 3, 'PRON', 'PRP'), ('do', 3, 4, 'AUX', 'VBP'), ("n't", 4, 5, 'PART', 'RB'), ('think', 5, 6, 'VERB', 'VB'), ('I', 6, 7, 'PRON', 'PRP'), ('can', 7, 8, 'AUX', 'MD'), ('do', 8, 9, 'VERB', 'VB'), ('this', 9, 10, 'PRON', 'DT'), ('.', 10, 11, 'PUNCT', '.')]
# trf_pron : [('Leonard', 0, 1, 'PROPN', 'NNP'), (',', 1, 2, 'PUNCT', ','), ('I', 2, 3, 'PRON', 'PRP'), ('do', 3, 4, 'AUX', 'VBP'), ("n't", 4, 5, 'PART', 'RB'), ('think', 5, 6, 'VERB', 'VB'), ('I', 6, 7, 'PRON', 'PRP'), ('can', 7, 8, 'AUX', 'MD'), ('do', 8, 9, 'VERB', 'VB'), ('this', 9, 10, 'PRON', 'DT'), ('.', 10, 11, 'PUNCT', '.')]
# ====================================================================================================
# utterance :  What, are you kidding? You’re a semi-pro.
# speaker : Leonard
# en_subtitles : ['What, are you kidding?']
# zh_subtitles : ['开玩笑? 你可是半职业人士']
# sm_pron : [('What', 0, 1, 'PRON', 'WP'), (',', 1, 2, 'PUNCT', ','), ('are', 2, 3, 'AUX', 'VBP'), ('you', 3, 4, 'PRON', 'PRP'), ('kidding', 4, 5, 'VERB', 'VBG'), ('?', 5, 6, 'PUNCT', '.')]
# berkeley_pron : [('What', 0, 1, 'PRON', 'WP'), (',', 1, 2, 'PUNCT', ','), ('are', 2, 3, 'AUX', 'VBP'), ('you', 3, 4, 'PRON', 'PRP'), ('kidding', 4, 5, 'VERB', 'VBG'), ('?', 5, 6, 'PUNCT', '.')]
# trf_pron : [('What', 0, 1, 'PRON', 'WP'), (',', 1, 2, 'PUNCT', ','), ('are', 2, 3, 'AUX', 'VBP'), ('you', 3, 4, 'PRON', 'PRP'), ('kidding', 4, 5, 'VERB', 'VBG'), ('?', 5, 6, 'PUNCT', '.')]
# ====================================================================================================
# utterance :  No. We are committing genetic fraud. There’s no guarantee that our sperm is going to generate high IQ offspring, think about that. I have a sister with the same basic DNA mix who hostesses at Fuddruckers.
# speaker : Sheldon
# en_subtitles : ['We are committing genetic fraud.', "There's no guarantee our sperm's going to generate high-IQ offspring. Think about that.", 'I have a sister with the same basic DNA mix who hostesses at Fuddruckers.']
# zh_subtitles : ['不 我们这样是诈骗', '我们没法保证 生出来的一定是高智商小孩', '我姐姐跟我有一套相同的基本基因 她却在Fuddrucker餐厅当服务生']
# sm_pron : [('We', 0, 1, 'PRON', 'PRP'), ('are', 1, 2, 'AUX', 'VBP'), ('committing', 2, 3, 'VERB', 'VBG'), ('genetic', 3, 4, 'ADJ', 'JJ'), ('fraud', 4, 5, 'NOUN', 'NN'), ('.', 5, 6, 'PUNCT', '.'), ('There', 6, 7, 'PRON', 'EX'), ("'s", 7, 8, 'VERB', 'VBZ'), ('no', 8, 9, 'DET', 'DT'), ('guarantee', 9, 10, 'NOUN', 'NN'), ('our', 10, 11, 'PRON', 'PRP$'), ('sperm', 11, 12, 'NOUN', 'NN'), ("'s", 12, 13, 'AUX', 'POS'), ('going', 13, 14, 'VERB', 'VBG'), ('to', 14, 15, 'PART', 'TO'), ('generate', 15, 16, 'VERB', 'VB'), ('high', 16, 17, 'ADJ', 'JJ'), ('-', 17, 18, 'PUNCT', 'HYPH'), ('IQ', 18, 19, 'NOUN', 'NN'), ('offspring', 19, 20, 'NOUN', 'NN'), ('.', 20, 21, 'PUNCT', '.'), ('Think', 21, 22, 'VERB', 'VB'), ('about', 22, 23, 'ADP', 'IN'), ('that', 23, 24, 'PRON', 'DT'), ('.', 24, 25, 'PUNCT', '.'), ('I', 25, 26, 'PRON', 'PRP'), ('have', 26, 27, 'VERB', 'VBP'), ('a', 27, 28, 'DET', 'DT'), ('sister', 28, 29, 'NOUN', 'NN'), ('with', 29, 30, 'ADP', 'IN'), ('the', 30, 31, 'DET', 'DT'), ('same', 31, 32, 'ADJ', 'JJ'), ('basic', 32, 33, 'ADJ', 'JJ'), ('DNA', 33, 34, 'NOUN', 'NN'), ('mix', 34, 35, 'NOUN', 'NN'), ('who', 35, 36, 'PRON', 'WP'), ('hostesses', 36, 37, 'VERB', 'VBZ'), ('at', 37, 38, 'ADP', 'IN'), ('Fuddruckers', 38, 39, 'PROPN', 'NNP'), ('.', 39, 40, 'PUNCT', '.')]
# berkeley_pron : [('We', 0, 1, 'PRON', 'PRP'), ('are', 1, 2, 'AUX', 'VBP'), ('committing', 2, 3, 'VERB', 'VBG'), ('genetic', 3, 4, 'ADJ', 'JJ'), ('fraud', 4, 5, 'NOUN', 'NN'), ('.', 5, 6, 'PUNCT', '.'), ('There', 6, 7, 'PRON', 'EX'), ("'s", 7, 8, 'VERB', 'VBZ'), ('no', 8, 9, 'DET', 'DT'), ('guarantee', 9, 10, 'NOUN', 'NN'), ('our', 10, 11, 'PRON', 'PRP$'), ('sperm', 11, 12, 'NOUN', 'NN'), ("'s", 12, 13, 'AUX', 'VBZ'), ('going', 13, 14, 'VERB', 'VBG'), ('to', 14, 15, 'PART', 'TO'), ('generate', 15, 16, 'VERB', 'VB'), ('high', 16, 17, 'ADJ', 'JJ'), ('-', 17, 18, 'PUNCT', 'HYPH'), ('IQ', 18, 19, 'NOUN', 'NN'), ('offspring', 19, 20, 'NOUN', 'NNS'), ('.', 20, 21, 'PUNCT', '.'), ('Think', 21, 22, 'VERB', 'VB'), ('about', 22, 23, 'ADP', 'IN'), ('that', 23, 24, 'PRON', 'DT'), ('.', 24, 25, 'PUNCT', '.'), ('I', 25, 26, 'PRON', 'PRP'), ('have', 26, 27, 'VERB', 'VBP'), ('a', 27, 28, 'DET', 'DT'), ('sister', 28, 29, 'NOUN', 'NN'), ('with', 29, 30, 'ADP', 'IN'), ('the', 30, 31, 'DET', 'DT'), ('same', 31, 32, 'ADJ', 'JJ'), ('basic', 32, 33, 'ADJ', 'JJ'), ('DNA', 33, 34, 'NOUN', 'NNP'), ('mix', 34, 35, 'NOUN', 'NN'), ('who', 35, 36, 'PRON', 'WP'), ('hostesses', 36, 37, 'VERB', 'VBZ'), ('at', 37, 38, 'ADP', 'IN'), ('Fuddruckers', 38, 39, 'PROPN', 'NNP'), ('.', 39, 40, 'PUNCT', '.')]
# trf_pron : [('We', 0, 1, 'PRON', 'PRP'), ('are', 1, 2, 'AUX', 'VBP'), ('committing', 2, 3, 'VERB', 'VBG'), ('genetic', 3, 4, 'ADJ', 'JJ'), ('fraud', 4, 5, 'NOUN', 'NN'), ('.', 5, 6, 'PUNCT', '.'), ('There', 6, 7, 'PRON', 'EX'), ("'s", 7, 8, 'VERB', 'VBZ'), ('no', 8, 9, 'DET', 'DT'), ('guarantee', 9, 10, 'NOUN', 'NN'), ('our', 10, 11, 'PRON', 'PRP$'), ('sperm', 11, 12, 'NOUN', 'NN'), ("'s", 12, 13, 'AUX', 'VBZ'), ('going', 13, 14, 'VERB', 'VBG'), ('to', 14, 15, 'PART', 'TO'), ('generate', 15, 16, 'VERB', 'VB'), ('high', 16, 17, 'ADJ', 'JJ'), ('-', 17, 18, 'PUNCT', 'HYPH'), ('IQ', 18, 19, 'NOUN', 'NN'), ('offspring', 19, 20, 'NOUN', 'NN'), ('.', 20, 21, 'PUNCT', '.'), ('Think', 21, 22, 'VERB', 'VB'), ('about', 22, 23, 'ADP', 'IN'), ('that', 23, 24, 'SCONJ', 'IN'), ('.', 24, 25, 'PUNCT', '.'), ('I', 25, 26, 'PRON', 'PRP'), ('have', 26, 27, 'VERB', 'VBP'), ('a', 27, 28, 'DET', 'DT'), ('sister', 28, 29, 'NOUN', 'NN'), ('with', 29, 30, 'ADP', 'IN'), ('the', 30, 31, 'DET', 'DT'), ('same', 31, 32, 'ADJ', 'JJ'), ('basic', 32, 33, 'ADJ', 'JJ'), ('DNA', 33, 34, 'NOUN', 'NN'), ('mix', 34, 35, 'NOUN', 'NN'), ('who', 35, 36, 'PRON', 'WP'), ('hostesses', 36, 37, 'VERB', 'VBZ'), ('at', 37, 38, 'ADP', 'IN'), ('Fuddruckers', 38, 39, 'PROPN', 'NNPS'), ('.', 39, 40, 'PUNCT', '.')]
# ====================================================================================================
# utterance :  Sheldon, this was your idea. A little extra money to get fractional T1 bandwidth in the apartment.
# speaker : Leonard
# en_subtitles : ['Sheldon, this was your idea.', 'A little extra money to get fractional T1 bandwidth in the apartment?']
# zh_subtitles : ['Sheldon 这可是你的主意啊', '轻松赚点钱 就有钱能升级我们的网络带宽']
# sm_pron : [('Sheldon', 0, 1, 'PROPN', 'NNP'), (',', 1, 2, 'PUNCT', ','), ('this', 2, 3, 'PRON', 'DT'), ('was', 3, 4, 'AUX', 'VBD'), ('your', 4, 5, 'PRON', 'PRP$'), ('idea', 5, 6, 'NOUN', 'NN'), ('.', 6, 7, 'PUNCT', '.'), ('A', 7, 8, 'DET', 'DT'), ('little', 8, 9, 'ADJ', 'JJ'), ('extra', 9, 10, 'ADJ', 'JJ'), ('money', 10, 11, 'NOUN', 'NN'), ('to', 11, 12, 'PART', 'TO'), ('get', 12, 13, 'VERB', 'VB'), ('fractional', 13, 14, 'ADJ', 'JJ'), ('T1', 14, 15, 'PROPN', 'NNP'), ('bandwidth', 15, 16, 'ADV', 'RB'), ('in', 16, 17, 'ADP', 'IN'), ('the', 17, 18, 'DET', 'DT'), ('apartment', 18, 19, 'NOUN', 'NN'), ('?', 19, 20, 'PUNCT', '.')]
# berkeley_pron : [('Sheldon', 0, 1, 'PROPN', 'NNP'), (',', 1, 2, 'PUNCT', ','), ('this', 2, 3, 'PRON', 'DT'), ('was', 3, 4, 'AUX', 'VBD'), ('your', 4, 5, 'PRON', 'PRP$'), ('idea', 5, 6, 'NOUN', 'NN'), ('.', 6, 7, 'PUNCT', '.'), ('A', 7, 8, 'DET', 'DT'), ('little', 8, 9, 'ADJ', 'JJ'), ('extra', 9, 10, 'ADJ', 'JJ'), ('money', 10, 11, 'NOUN', 'NN'), ('to', 11, 12, 'PART', 'TO'), ('get', 12, 13, 'VERB', 'VB'), ('fractional', 13, 14, 'ADJ', 'JJ'), ('T1', 14, 15, 'NOUN', 'NN'), ('bandwidth', 15, 16, 'NOUN', 'NN'), ('in', 16, 17, 'ADP', 'IN'), ('the', 17, 18, 'DET', 'DT'), ('apartment', 18, 19, 'NOUN', 'NN'), ('?', 19, 20, 'PUNCT', '.')]
# trf_pron : [('Sheldon', 0, 1, 'PROPN', 'NNP'), (',', 1, 2, 'PUNCT', ','), ('this', 2, 3, 'PRON', 'DT'), ('was', 3, 4, 'AUX', 'VBD'), ('your', 4, 5, 'PRON', 'PRP$'), ('idea', 5, 6, 'NOUN', 'NN'), ('.', 6, 7, 'PUNCT', '.'), ('A', 7, 8, 'DET', 'DT'), ('little', 8, 9, 'ADJ', 'JJ'), ('extra', 9, 10, 'ADJ', 'JJ'), ('money', 10, 11, 'NOUN', 'NN'), ('to', 11, 12, 'PART', 'TO'), ('get', 12, 13, 'VERB', 'VB'), ('fractional', 13, 14, 'ADJ', 'JJ'), ('T1', 14, 15, 'NOUN', 'NN'), ('bandwidth', 15, 16, 'NOUN', 'NN'), ('in', 16, 17, 'ADP', 'IN'), ('the', 17, 18, 'DET', 'DT'), ('apartment', 18, 19, 'NOUN', 'NN'), ('?', 19, 20, 'PUNCT', '.')]
# ====================================================================================================
# utterance :  I know, and I do yearn for faster downloads, but there’s some poor woman is going to pin her hopes on my sperm, what if she winds up with a toddler who doesn’t know if he should use an integral or a differential to solve the area under a curve.
# speaker : Sheldon
# en_subtitles : ['I know. And I do yearn for faster downloads.', "There's some poor woman who's gonna pin her hopes on my sperm.", "What if she winds up with a toddler who doesn't know if he should use a differential to solve for the area under a curve?"]
# zh_subtitles : ['我知道 我确实很渴望高速下载', '但一些可怜的女人 会把希望寄托在我的精子上', '万一生出来一个 连曲线下部的面积用积分还是微分算 都搞不清楚的小屁孩怎么办?']
# sm_pron : [('I', 0, 1, 'PRON', 'PRP'), ('know', 1, 2, 'VERB', 'VBP'), ('.', 2, 3, 'PUNCT', '.'), ('And', 3, 4, 'CCONJ', 'CC'), ('I', 4, 5, 'PRON', 'PRP'), ('do', 5, 6, 'AUX', 'VBP'), ('yearn', 6, 7, 'VERB', 'VB'), ('for', 7, 8, 'ADP', 'IN'), ('faster', 8, 9, 'ADJ', 'JJR'), ('downloads', 9, 10, 'NOUN', 'NNS'), ('.', 10, 11, 'PUNCT', '.'), ('There', 11, 12, 'PRON', 'EX'), ("'s", 12, 13, 'VERB', 'VBZ'), ('some', 13, 14, 'DET', 'DT'), ('poor', 14, 15, 'ADJ', 'JJ'), ('woman', 15, 16, 'NOUN', 'NN'), ('who', 16, 17, 'PRON', 'WP'), ("'s", 17, 18, 'AUX', 'VBZ'), ('gon', 18, 19, 'VERB', 'VBG'), ('na', 19, 20, 'PART', 'TO'), ('pin', 20, 21, 'VERB', 'VB'), ('her', 21, 22, 'PRON', 'PRP'), ('hopes', 22, 23, 'NOUN', 'NNS'), ('on', 23, 24, 'ADP', 'IN'), ('my', 24, 25, 'PRON', 'PRP$'), ('sperm', 25, 26, 'NOUN', 'NN'), ('.', 26, 27, 'PUNCT', '.'), ('What', 27, 28, 'PRON', 'WP'), ('if', 28, 29, 'SCONJ', 'IN'), ('she', 29, 30, 'PRON', 'PRP'), ('winds', 30, 31, 'VERB', 'VBZ'), ('up', 31, 32, 'ADP', 'RP'), ('with', 32, 33, 'ADP', 'IN'), ('a', 33, 34, 'DET', 'DT'), ('toddler', 34, 35, 'NOUN', 'NN'), ('who', 35, 36, 'PRON', 'WP'), ('does', 36, 37, 'AUX', 'VBZ'), ("n't", 37, 38, 'PART', 'RB'), ('know', 38, 39, 'VERB', 'VB'), ('if', 39, 40, 'SCONJ', 'IN'), ('he', 40, 41, 'PRON', 'PRP'), ('should', 41, 42, 'AUX', 'MD'), ('use', 42, 43, 'VERB', 'VB'), ('a', 43, 44, 'DET', 'DT'), ('differential', 44, 45, 'NOUN', 'NN'), ('to', 45, 46, 'PART', 'TO'), ('solve', 46, 47, 'VERB', 'VB'), ('for', 47, 48, 'ADP', 'IN'), ('the', 48, 49, 'DET', 'DT'), ('area', 49, 50, 'NOUN', 'NN'), ('under', 50, 51, 'ADP', 'IN'), ('a', 51, 52, 'DET', 'DT'), ('curve', 52, 53, 'NOUN', 'NN'), ('?', 53, 54, 'PUNCT', '.')]
# berkeley_pron : [('I', 0, 1, 'PRON', 'PRP'), ('know', 1, 2, 'VERB', 'VBP'), ('.', 2, 3, 'PUNCT', '.'), ('And', 3, 4, 'CCONJ', 'CC'), ('I', 4, 5, 'PRON', 'PRP'), ('do', 5, 6, 'AUX', 'VBP'), ('yearn', 6, 7, 'VERB', 'VB'), ('for', 7, 8, 'ADP', 'IN'), ('faster', 8, 9, 'ADJ', 'JJR'), ('downloads', 9, 10, 'NOUN', 'NNS'), ('.', 10, 11, 'PUNCT', '.'), ('There', 11, 12, 'PRON', 'EX'), ("'s", 12, 13, 'VERB', 'VBZ'), ('some', 13, 14, 'DET', 'DT'), ('poor', 14, 15, 'ADJ', 'JJ'), ('woman', 15, 16, 'NOUN', 'NN'), ('who', 16, 17, 'PRON', 'WP'), ("'s", 17, 18, 'AUX', 'VBZ'), ('gon', 18, 19, 'VERB', 'TO'), ('na', 19, 20, 'PART', 'TO'), ('pin', 20, 21, 'VERB', 'VB'), ('her', 21, 22, 'PRON', 'PRP$'), ('hopes', 22, 23, 'NOUN', 'NNS'), ('on', 23, 24, 'ADP', 'IN'), ('my', 24, 25, 'PRON', 'PRP$'), ('sperm', 25, 26, 'NOUN', 'NN'), ('.', 26, 27, 'PUNCT', '.'), ('What', 27, 28, 'PRON', 'WP'), ('if', 28, 29, 'SCONJ', 'IN'), ('she', 29, 30, 'PRON', 'PRP'), ('winds', 30, 31, 'VERB', 'VBZ'), ('up', 31, 32, 'ADP', 'RP'), ('with', 32, 33, 'ADP', 'IN'), ('a', 33, 34, 'DET', 'DT'), ('toddler', 34, 35, 'NOUN', 'NN'), ('who', 35, 36, 'PRON', 'WP'), ('does', 36, 37, 'AUX', 'VBZ'), ("n't", 37, 38, 'PART', 'RB'), ('know', 38, 39, 'VERB', 'VB'), ('if', 39, 40, 'SCONJ', 'IN'), ('he', 40, 41, 'PRON', 'PRP'), ('should', 41, 42, 'AUX', 'MD'), ('use', 42, 43, 'VERB', 'VB'), ('a', 43, 44, 'DET', 'DT'), ('differential', 44, 45, 'NOUN', 'NN'), ('to', 45, 46, 'PART', 'TO'), ('solve', 46, 47, 'VERB', 'VB'), ('for', 47, 48, 'ADP', 'IN'), ('the', 48, 49, 'DET', 'DT'), ('area', 49, 50, 'NOUN', 'NN'), ('under', 50, 51, 'ADP', 'IN'), ('a', 51, 52, 'DET', 'DT'), ('curve', 52, 53, 'NOUN', 'NN'), ('?', 53, 54, 'PUNCT', '.')]
# trf_pron : [('I', 0, 1, 'PRON', 'PRP'), ('know', 1, 2, 'VERB', 'VBP'), ('.', 2, 3, 'PUNCT', '.'), ('And', 3, 4, 'CCONJ', 'CC'), ('I', 4, 5, 'PRON', 'PRP'), ('do', 5, 6, 'AUX', 'VBP'), ('yearn', 6, 7, 'VERB', 'VB'), ('for', 7, 8, 'ADP', 'IN'), ('faster', 8, 9, 'ADJ', 'JJR'), ('downloads', 9, 10, 'NOUN', 'NNS'), ('.', 10, 11, 'PUNCT', '.'), ('There', 11, 12, 'PRON', 'EX'), ("'s", 12, 13, 'VERB', 'VBZ'), ('some', 13, 14, 'DET', 'DT'), ('poor', 14, 15, 'ADJ', 'JJ'), ('woman', 15, 16, 'NOUN', 'NN'), ('who', 16, 17, 'PRON', 'WP'), ("'s", 17, 18, 'AUX', 'VBZ'), ('gon', 18, 19, 'PART', 'TO'), ('na', 19, 20, 'PART', 'TO'), ('pin', 20, 21, 'VERB', 'VB'), ('her', 21, 22, 'PRON', 'PRP$'), ('hopes', 22, 23, 'NOUN', 'NNS'), ('on', 23, 24, 'ADP', 'IN'), ('my', 24, 25, 'PRON', 'PRP$'), ('sperm', 25, 26, 'NOUN', 'NN'), ('.', 26, 27, 'PUNCT', '.'), ('What', 27, 28, 'PRON', 'WP'), ('if', 28, 29, 'SCONJ', 'IN'), ('she', 29, 30, 'PRON', 'PRP'), ('winds', 30, 31, 'VERB', 'VBZ'), ('up', 31, 32, 'ADP', 'RP'), ('with', 32, 33, 'ADP', 'IN'), ('a', 33, 34, 'DET', 'DT'), ('toddler', 34, 35, 'NOUN', 'NN'), ('who', 35, 36, 'PRON', 'WP'), ('does', 36, 37, 'AUX', 'VBZ'), ("n't", 37, 38, 'PART', 'RB'), ('know', 38, 39, 'VERB', 'VB'), ('if', 39, 40, 'SCONJ', 'IN'), ('he', 40, 41, 'PRON', 'PRP'), ('should', 41, 42, 'AUX', 'MD'), ('use', 42, 43, 'VERB', 'VB'), ('a', 43, 44, 'DET', 'DT'), ('differential', 44, 45, 'NOUN', 'NN'), ('to', 45, 46, 'PART', 'TO'), ('solve', 46, 47, 'VERB', 'VB'), ('for', 47, 48, 'ADP', 'IN'), ('the', 48, 49, 'DET', 'DT'), ('area', 49, 50, 'NOUN', 'NN'), ('under', 50, 51, 'ADP', 'IN'), ('a', 51, 52, 'DET', 'DT'), ('curve', 52, 53, 'NOUN', 'NN'), ('?', 53, 54, 'PUNCT', '.')]
# ====================================================================================================
# utterance :  I’m sure she’ll still love him.
# speaker : Leonard
# en_subtitles : ["I'm sure she'll still love him."]
# zh_subtitles : ['我想她还是会爱那个宝宝的']
# sm_pron : [('I', 0, 1, 'PRON', 'PRP'), ("'m", 1, 2, 'AUX', 'VBP'), ('sure', 2, 3, 'ADJ', 'JJ'), ('she', 3, 4, 'PRON', 'PRP'), ("'ll", 4, 5, 'AUX', 'MD'), ('still', 5, 6, 'ADV', 'RB'), ('love', 6, 7, 'VERB', 'VB'), ('him', 7, 8, 'PRON', 'PRP'), ('.', 8, 9, 'PUNCT', '.')]
# berkeley_pron : [('I', 0, 1, 'PRON', 'PRP'), ("'m", 1, 2, 'AUX', 'VBP'), ('sure', 2, 3, 'ADJ', 'JJ'), ('she', 3, 4, 'PRON', 'PRP'), ("'ll", 4, 5, 'AUX', 'MD'), ('still', 5, 6, 'ADV', 'RB'), ('love', 6, 7, 'VERB', 'VB'), ('him', 7, 8, 'PRON', 'PRP'), ('.', 8, 9, 'PUNCT', '.')]
# trf_pron : [('I', 0, 1, 'PRON', 'PRP'), ("'m", 1, 2, 'AUX', 'VBP'), ('sure', 2, 3, 'ADJ', 'JJ'), ('she', 3, 4, 'PRON', 'PRP'), ("'ll", 4, 5, 'AUX', 'MD'), ('still', 5, 6, 'ADV', 'RB'), ('love', 6, 7, 'VERB', 'VB'), ('him', 7, 8, 'PRON', 'PRP'), ('.', 8, 9, 'PUNCT', '.')]
# ====================================================================================================
# utterance :  I wouldn’t.
# speaker : Sheldon
# en_subtitles : ["I wouldn't."]
# zh_subtitles : ['我不会']
# sm_pron : [('I', 0, 1, 'PRON', 'PRP'), ('would', 1, 2, 'AUX', 'MD'), ("n't", 2, 3, 'PART', 'RB'), ('.', 3, 4, 'PUNCT', '.')]
# berkeley_pron : [('I', 0, 1, 'PRON', 'PRP'), ('would', 1, 2, 'AUX', 'MD'), ("n't", 2, 3, 'PART', 'RB'), ('.', 3, 4, 'PUNCT', '.')]
# trf_pron : [('I', 0, 1, 'PRON', 'PRP'), ('would', 1, 2, 'AUX', 'MD'), ("n't", 2, 3, 'PART', 'RB'), ('.', 3, 4, 'PUNCT', '.')]
# ====================================================================================================
# utterance :  Well, what do you want to do?
# speaker : Leonard
# en_subtitles : ['Well, what do you wanna do?']
# zh_subtitles : ['你想要怎样?']
# sm_pron : [('Well', 0, 1, 'INTJ', 'UH'), (',', 1, 2, 'PUNCT', ','), ('what', 2, 3, 'PRON', 'WP'), ('do', 3, 4, 'AUX', 'VBP'), ('you', 4, 5, 'PRON', 'PRP'), ('wanna', 5, 6, 'VERB', 'VB'), ('do', 6, 7, 'VERB', 'VB'), ('?', 7, 8, 'PUNCT', '.')]
# berkeley_pron : [('Well', 0, 1, 'INTJ', 'UH'), (',', 1, 2, 'PUNCT', ','), ('what', 2, 3, 'PRON', 'WP'), ('do', 3, 4, 'AUX', 'VBP'), ('you', 4, 5, 'PRON', 'PRP'), ('wanna', 5, 6, 'VERB', 'TO'), ('do', 6, 7, 'VERB', 'VB'), ('?', 7, 8, 'PUNCT', '.')]
# trf_pron : [('Well', 0, 1, 'INTJ', 'UH'), (',', 1, 2, 'PUNCT', ','), ('what', 2, 3, 'PRON', 'WP'), ('do', 3, 4, 'AUX', 'VBP'), ('you', 4, 5, 'PRON', 'PRP'), ('wanna', 5, 6, 'AUX', 'VB'), ('do', 6, 7, 'VERB', 'VB'), ('?', 7, 8, 'PUNCT', '.')]
# ====================================================================================================
# utterance :  I want to leave.
# speaker : Sheldon
# en_subtitles : ['I want to leave.']
# zh_subtitles : ['- 我想要走']
# sm_pron : [('I', 0, 1, 'PRON', 'PRP'), ('want', 1, 2, 'VERB', 'VBP'), ('to', 2, 3, 'PART', 'TO'), ('leave', 3, 4, 'VERB', 'VB'), ('.', 4, 5, 'PUNCT', '.')]
# berkeley_pron : [('I', 0, 1, 'PRON', 'PRP'), ('want', 1, 2, 'VERB', 'VBP'), ('to', 2, 3, 'PART', 'TO'), ('leave', 3, 4, 'VERB', 'VB'), ('.', 4, 5, 'PUNCT', '.')]
# trf_pron : [('I', 0, 1, 'PRON', 'PRP'), ('want', 1, 2, 'VERB', 'VBP'), ('to', 2, 3, 'PART', 'TO'), ('leave', 3, 4, 'VERB', 'VB'), ('.', 4, 5, 'PUNCT', '.')]
# ====================================================================================================
# utterance :  What’s the protocol for leaving?
# speaker : Sheldon
# en_subtitles : ["What's the protocol for leaving? - I don't know."]
# zh_subtitles : ['离开时要怎么说呢?']
# sm_pron : [('What', 0, 1, 'PRON', 'WP'), ("'s", 1, 2, 'AUX', 'VBZ'), ('the', 2, 3, 'DET', 'DT'), ('protocol', 3, 4, 'NOUN', 'NN'), ('for', 4, 5, 'ADP', 'IN'), ('leaving', 5, 6, 'VERB', 'VBG'), ('?', 6, 7, 'PUNCT', '.'), ('-', 7, 8, 'PUNCT', ':'), ('I', 8, 9, 'PRON', 'PRP'), ('do', 9, 10, 'AUX', 'VBP'), ("n't", 10, 11, 'PART', 'RB'), ('know', 11, 12, 'VERB', 'VB'), ('.', 12, 13, 'PUNCT', '.')]
# berkeley_pron : [('What', 0, 1, 'PRON', 'WP'), ("'s", 1, 2, 'AUX', 'VBZ'), ('the', 2, 3, 'DET', 'DT'), ('protocol', 3, 4, 'NOUN', 'NN'), ('for', 4, 5, 'ADP', 'IN'), ('leaving', 5, 6, 'VERB', 'VBG'), ('?', 6, 7, 'PUNCT', '.'), ('-', 7, 8, 'PUNCT', ':'), ('I', 8, 9, 'PRON', 'PRP'), ('do', 9, 10, 'AUX', 'VBP'), ("n't", 10, 11, 'PART', 'RB'), ('know', 11, 12, 'VERB', 'VB'), ('.', 12, 13, 'PUNCT', '.')]
# trf_pron : [('What', 0, 1, 'PRON', 'WP'), ("'s", 1, 2, 'AUX', 'VBZ'), ('the', 2, 3, 'DET', 'DT'), ('protocol', 3, 4, 'NOUN', 'NN'), ('for', 4, 5, 'ADP', 'IN'), ('leaving', 5, 6, 'VERB', 'VBG'), ('?', 6, 7, 'PUNCT', '.'), ('-', 7, 8, 'PUNCT', ':'), ('I', 8, 9, 'PRON', 'PRP'), ('do', 9, 10, 'AUX', 'VBP'), ("n't", 10, 11, 'PART', 'RB'), ('know', 11, 12, 'VERB', 'VB'), ('.', 12, 13, 'PUNCT', '.')]
# ====================================================================================================
# utterance :  I don’t know, I’ve never reneged on a proffer of sperm before.
# speaker : Leonard
# en_subtitles : ["I've never reneged on a proffer of sperm before."]
# zh_subtitles : ['我不知道 我可从没有拒绝过提供精子的要求']
# sm_pron : [('I', 0, 1, 'PRON', 'PRP'), ("'ve", 1, 2, 'AUX', 'VBP'), ('never', 2, 3, 'ADV', 'RB'), ('reneged', 3, 4, 'VERB', 'VBN'), ('on', 4, 5, 'ADP', 'IN'), ('a', 5, 6, 'DET', 'DT'), ('proffer', 6, 7, 'NOUN', 'NN'), ('of', 7, 8, 'ADP', 'IN'), ('sperm', 8, 9, 'NOUN', 'NN'), ('before', 9, 10, 'ADV', 'RB'), ('.', 10, 11, 'PUNCT', '.')]
# berkeley_pron : [('I', 0, 1, 'PRON', 'PRP'), ("'ve", 1, 2, 'AUX', 'VBP'), ('never', 2, 3, 'ADV', 'RB'), ('reneged', 3, 4, 'VERB', 'VBN'), ('on', 4, 5, 'ADP', 'IN'), ('a', 5, 6, 'DET', 'DT'), ('proffer', 6, 7, 'NOUN', 'NN'), ('of', 7, 8, 'ADP', 'IN'), ('sperm', 8, 9, 'NOUN', 'NN'), ('before', 9, 10, 'ADV', 'RB'), ('.', 10, 11, 'PUNCT', '.')]
# trf_pron : [('I', 0, 1, 'PRON', 'PRP'), ("'ve", 1, 2, 'AUX', 'VBP'), ('never', 2, 3, 'ADV', 'RB'), ('reneged', 3, 4, 'VERB', 'VBN'), ('on', 4, 5, 'ADP', 'IN'), ('a', 5, 6, 'DET', 'DT'), ('proffer', 6, 7, 'NOUN', 'NN'), ('of', 7, 8, 'ADP', 'IN'), ('sperm', 8, 9, 'NOUN', 'NN'), ('before', 9, 10, 'ADV', 'RB'), ('.', 10, 11, 'PUNCT', '.')]
# ====================================================================================================
# utterance :  Let’s try just walking out.
# speaker : Sheldon
# en_subtitles : ["Let's try just walking out."]
# zh_subtitles : ['我们就直接走出去吧']
# sm_pron : [('Let', 0, 1, 'VERB', 'VB'), ("'s", 1, 2, 'PRON', 'PRP'), ('try', 2, 3, 'VERB', 'VB'), ('just', 3, 4, 'ADV', 'RB'), ('walking', 4, 5, 'VERB', 'VBG'), ('out', 5, 6, 'ADP', 'RP'), ('.', 6, 7, 'PUNCT', '.')]
# berkeley_pron : [('Let', 0, 1, 'VERB', 'VB'), ("'s", 1, 2, 'PRON', 'PRP'), ('try', 2, 3, 'VERB', 'VB'), ('just', 3, 4, 'ADV', 'RB'), ('walking', 4, 5, 'VERB', 'VBG'), ('out', 5, 6, 'ADP', 'RP'), ('.', 6, 7, 'PUNCT', '.')]
# trf_pron : [('Let', 0, 1, 'VERB', 'VB'), ("'s", 1, 2, 'PRON', 'PRP'), ('try', 2, 3, 'VERB', 'VB'), ('just', 3, 4, 'ADV', 'RB'), ('walking', 4, 5, 'VERB', 'VBG'), ('out', 5, 6, 'ADV', 'RB'), ('.', 6, 7, 'PUNCT', '.')]
# ====================================================================================================
# utterance :  Okay.
# speaker : Leonard
# ====================================================================================================
# utterance :  Bye-bye
# speaker : Sheldon
# ====================================================================================================
# utterance :  See you.
# speaker : Leonard
# ====================================================================================================
